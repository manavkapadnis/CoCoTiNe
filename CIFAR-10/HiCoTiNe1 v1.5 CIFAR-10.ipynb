# %% [markdown]
# # Variants-Experiment 1.5
#
# ## Summed hidden representations and summed output logits.
# ## Mode. Compute classifications of all tiny networks, in all HiCo layers, and take the mode as the final classification.

# %%
from keras.models import Sequential
from keras.layers import Dense, Conv2D, Flatten
from keras.datasets import mnist
from keras.utils import to_categorical
import matplotlib.pyplot as plt
import numpy as np
import tensorflow as tf
import random
from scipy import stats
from sklearn.metrics import accuracy_score
from keras import backend as K

import os
import pickle
from google.colab import drive
drive.mount('/content/drive/')
# Out:
# Mounted at /content/drive/

# %%
SUB_REGION_SCALE = 14
NUM_HICO_LAYER = 5
NUM_TN = [10, 8, 6, 4, 2]
NUM_CONNECTION = [0, 5, 4, 3, 2]

#dataset specific parameters
NUM_CLASS = 10

# %% [markdown]
# ## Data Pre-Processing

# %%
with open('/content/drive/My Drive/fyp/CIFAR-10.pickle', 'rb') as f:
    X_train_cropped_list, y_train_one_hot, X_test_cropped_list, y_test_one_hot, coordinate_list, scale_list = pickle.load(f)

# %% [markdown]
# ## HiCo Layer 1

# %%
#build ANN model
ensemble = []
for i in range(NUM_TN[0]):
  model = Sequential()
  model.add(Dense(64, activation='relu', input_dim=SUB_REGION_SCALE*SUB_REGION_SCALE*3))
  model.add(Dense(64, activation='relu'))
  model.add(Dense(NUM_CLASS, activation = 'softmax'))
  model.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])
  ensemble.append((model, i, coordinate_list[i], scale_list[i]))

# %%
for i in range(NUM_TN[0]):
  ensemble[i][0].load_weights('/content/drive/My Drive/fyp/CIFAR-10_' + str(i) + '.h5')

# %%
hico_layers = []
hico_layers.append(ensemble)

# %%
del hico_layers[1:]

# %% [markdown]
# ## HiCo Layer 2+

# %%
# Function to get input of layer i-1
def get_previous_layer_input(hico_layers, layer, tn, train_image):
  input_hr = []
  input_ol = []
    
  if layer == 0:
    previous_layer_input = train_image[tn[1]]
    return previous_layer_input

  elif layer > 0:
    for i in range(NUM_CONNECTION[layer]):
      get_input = (K.function(hico_layers[layer-1][tn[1][i]][0].layers[0].input, hico_layers[layer-1][tn[1][i]][0].layers[1].output))
      input_hr.append(get_input(get_previous_layer_input(hico_layers, layer-1, hico_layers[layer-1][tn[1][i]], train_image)))
      
    input_hr = np.array(input_hr)
    input_hr = np.sum(input_hr, axis=0)

    for i in range(NUM_CONNECTION[layer]):
      get_input = (K.function(hico_layers[layer-1][tn[1][i]][0].layers[0].input, hico_layers[layer-1][tn[1][i]][0].layers[2].output))
      input_ol.append(get_input(get_previous_layer_input(hico_layers, layer-1, hico_layers[layer-1][tn[1][i]], train_image)))

    input_ol = np.array(input_ol)
    input_ol = np.sum(input_ol, axis=0)

    input = np.concatenate((input_hr, input_ol), axis=1)
    
    previous_layer_input = input
    return previous_layer_input

# %%
for i in range(1, NUM_HICO_LAYER):
  print('Layer %d' %i)
  ensemble = []
  X_train_input_list = []
  X_test_input_list = []

  for j in range(NUM_TN[i]):
    # Build model of HiCo layer i
    connection = tuple(random.sample(range(len(hico_layers[i-1])), k=NUM_CONNECTION[i]))
    model = Sequential()
    model.add(Dense(64, activation='relu', input_dim=64+NUM_CLASS))
    model.add(Dense(64, activation='relu'))
    model.add(Dense(NUM_CLASS, activation = 'softmax'))
    model.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])
    ensemble.append((model, connection))
  hico_layers.append(ensemble)
  print('HICO LENGTH')
  print(len(hico_layers))

  for j in range(NUM_TN[i]):
    # Get train hidden representation from HiCo layer i-1
    X_train_input_hr = []
    X_train_input_ol = []
    for k in range(NUM_CONNECTION[i]):
      get_input = (K.function(hico_layers[i-1][hico_layers[i][j][1][k]][0].layers[0].input, hico_layers[i-1][hico_layers[i][j][1][k]][0].layers[1].output))
      X_train_input_hr.append(get_input(get_previous_layer_input(hico_layers, i-1, hico_layers[i-1][hico_layers[i][j][1][k]], X_train_cropped_list)))
    X_train_input_hr = np.array(X_train_input_hr)
    X_train_input_hr = np.sum(X_train_input_hr, axis=0)

    for k in range(NUM_CONNECTION[i]):
      get_input = (K.function(hico_layers[i-1][hico_layers[i][j][1][k]][0].layers[0].input, hico_layers[i-1][hico_layers[i][j][1][k]][0].layers[2].output))
      X_train_input_ol.append(get_input(get_previous_layer_input(hico_layers, i-1, hico_layers[i-1][hico_layers[i][j][1][k]], X_train_cropped_list)))
    X_train_input_ol = np.array(X_train_input_ol)
    X_train_input_ol = np.sum(X_train_input_ol, axis=0)

    X_train_input = np.concatenate((X_train_input_hr, X_train_input_ol), axis=1)
    X_train_input_list.append(X_train_input)

    # Get test hidden representation from HiCo layer i-1
    X_test_input_hr = []
    X_test_input_ol = []
    for k in range(NUM_CONNECTION[i]):
      get_input = (K.function(hico_layers[i-1][hico_layers[i][j][1][k]][0].layers[0].input, hico_layers[i-1][hico_layers[i][j][1][k]][0].layers[1].output))
      X_test_input_hr.append(get_input(get_previous_layer_input(hico_layers, i-1, hico_layers[i-1][hico_layers[i][j][1][k]], X_test_cropped_list)))
    X_test_input_hr = np.array(X_test_input_hr)
    X_test_input_hr = np.sum(X_test_input_hr, axis=0)

    for k in range(NUM_CONNECTION[i]):
      get_input = (K.function(hico_layers[i-1][hico_layers[i][j][1][k]][0].layers[0].input, hico_layers[i-1][hico_layers[i][j][1][k]][0].layers[2].output))
      X_test_input_ol.append(get_input(get_previous_layer_input(hico_layers, i-1, hico_layers[i-1][hico_layers[i][j][1][k]], X_test_cropped_list)))
    X_test_input_ol = np.array(X_test_input_ol)
    X_test_input_ol = np.sum(X_test_input_ol, axis=0)

    X_test_input = np.concatenate((X_test_input_hr, X_test_input_ol), axis=1)
    X_test_input_list.append(X_test_input)

  #train model of HiCo layer i
  for j in range(NUM_TN[i]):
    print('Model %d' %j)
    hico_layers[i][j][0].fit(X_train_input_list[j], y_train_one_hot, validation_data=(X_test_input_list[j], y_test_one_hot), epochs=5, batch_size=128)
# Out:
# Layer 1
# HICO LENGTH
# 2
# Model 0
# Epoch 1/5
# 391/391 [==============================] - 2s 3ms/step - loss: 2.0177 - accuracy: 0.3039 - val_loss: 1.5613 - val_accuracy: 0.4418
# Epoch 2/5
# 391/391 [==============================] - 1s 2ms/step - loss: 1.5479 - accuracy: 0.4432 - val_loss: 1.5263 - val_accuracy: 0.4557
# Epoch 3/5
# 391/391 [==============================] - 1s 2ms/step - loss: 1.5050 - accuracy: 0.4560 - val_loss: 1.4937 - val_accuracy: 0.4625
# Epoch 4/5
# 391/391 [==============================] - 1s 2ms/step - loss: 1.4857 - accuracy: 0.4649 - val_loss: 1.4856 - val_accuracy: 0.4646
# Epoch 5/5
# 391/391 [==============================] - 1s 2ms/step - loss: 1.4591 - accuracy: 0.4780 - val_loss: 1.4863 - val_accuracy: 0.4648
# Model 1
# Epoch 1/5
# 391/391 [==============================] - 1s 3ms/step - loss: 1.8919 - accuracy: 0.3224 - val_loss: 1.5829 - val_accuracy: 0.4328
# Epoch 2/5
# 391/391 [==============================] - 1s 2ms/step - loss: 1.5692 - accuracy: 0.4312 - val_loss: 1.5480 - val_accuracy: 0.4457
# Epoch 3/5
# 391/391 [==============================] - 1s 2ms/step - loss: 1.5333 - accuracy: 0.4476 - val_loss: 1.5328 - val_accuracy: 0.4490
# Epoch 4/5
# 391/391 [==============================] - 1s 2ms/step - loss: 1.5136 - accuracy: 0.4523 - val_loss: 1.5152 - val_accuracy: 0.4548
# Epoch 5/5
# 391/391 [==============================] - 1s 2ms/step - loss: 1.4895 - accuracy: 0.4625 - val_loss: 1.5134 - val_accuracy: 0.4548
# Model 2
# Epoch 1/5
# 391/391 [==============================] - 1s 3ms/step - loss: 2.0361 - accuracy: 0.2861 - val_loss: 1.6428 - val_accuracy: 0.4156
# Epoch 2/5
# 391/391 [==============================] - 1s 2ms/step - loss: 1.6013 - accuracy: 0.4273 - val_loss: 1.5889 - val_accuracy: 0.4340
# Epoch 3/5
# 391/391 [==============================] - 1s 2ms/step - loss: 1.5660 - accuracy: 0.4414 - val_loss: 1.5806 - val_accuracy: 0.4432
# Epoch 4/5
# 391/391 [==============================] - 1s 2ms/step - loss: 1.5383 - accuracy: 0.4505 - val_loss: 1.5552 - val_accuracy: 0.4491
# Epoch 5/5
# 391/391 [==============================] - 1s 2ms/step - loss: 1.5283 - accuracy: 0.4544 - val_loss: 1.5370 - val_accuracy: 0.4556
# Model 3
# Epoch 1/5
# 391/391 [==============================] - 1s 2ms/step - loss: 1.9229 - accuracy: 0.3143 - val_loss: 1.5900 - val_accuracy: 0.4303
# Epoch 2/5
# 391/391 [==============================] - 1s 2ms/step - loss: 1.5628 - accuracy: 0.4387 - val_loss: 1.5771 - val_accuracy: 0.4342
# Epoch 3/5
# 391/391 [==============================] - 1s 2ms/step - loss: 1.5196 - accuracy: 0.4552 - val_loss: 1.5374 - val_accuracy: 0.4485
# Epoch 4/5
# 391/391 [==============================] - 1s 2ms/step - loss: 1.5124 - accuracy: 0.4573 - val_loss: 1.5529 - val_accuracy: 0.4408
# Epoch 5/5
# 391/391 [==============================] - 1s 2ms/step - loss: 1.4919 - accuracy: 0.4651 - val_loss: 1.5270 - val_accuracy: 0.4552
# Model 4
# Epoch 1/5
# 391/391 [==============================] - 2s 3ms/step - loss: 1.8997 - accuracy: 0.3204 - val_loss: 1.5457 - val_accuracy: 0.4453
# Epoch 2/5
# 391/391 [==============================] - 1s 2ms/step - loss: 1.5266 - accuracy: 0.4520 - val_loss: 1.5062 - val_accuracy: 0.4531
# Epoch 3/5
# 391/391 [==============================] - 1s 2ms/step - loss: 1.4777 - accuracy: 0.4682 - val_loss: 1.4943 - val_accuracy: 0.4624
# Epoch 4/5
# 391/391 [==============================] - 1s 2ms/step - loss: 1.4577 - accuracy: 0.4799 - val_loss: 1.4700 - val_accuracy: 0.4737
# Epoch 5/5
# 391/391 [==============================] - 1s 2ms/step - loss: 1.4346 - accuracy: 0.4843 - val_loss: 1.4708 - val_accuracy: 0.4748
# Model 5
# Epoch 1/5
# 391/391 [==============================] - 1s 3ms/step - loss: 1.8740 - accuracy: 0.3226 - val_loss: 1.6131 - val_accuracy: 0.4160
# Epoch 2/5
# 391/391 [==============================] - 1s 2ms/step - loss: 1.5837 - accuracy: 0.4309 - val_loss: 1.5852 - val_accuracy: 0.4336
# Epoch 3/5
# 391/391 [==============================] - 1s 2ms/step - loss: 1.5631 - accuracy: 0.4384 - val_loss: 1.5715 - val_accuracy: 0.4352
# Epoch 4/5
# 391/391 [==============================] - 1s 2ms/step - loss: 1.5223 - accuracy: 0.4553 - val_loss: 1.5523 - val_accuracy: 0.4448
# Epoch 5/5
# 391/391 [==============================] - 1s 2ms/step - loss: 1.5170 - accuracy: 0.4597 - val_loss: 1.5525 - val_accuracy: 0.4467
# Model 6
# Epoch 1/5
# 391/391 [==============================] - 1s 3ms/step - loss: 1.8390 - accuracy: 0.3342 - val_loss: 1.5953 - val_accuracy: 0.4316
# Epoch 2/5
# 391/391 [==============================] - 1s 2ms/step - loss: 1.5665 - accuracy: 0.4376 - val_loss: 1.5626 - val_accuracy: 0.4315
# Epoch 3/5
# 391/391 [==============================] - 1s 2ms/step - loss: 1.5331 - accuracy: 0.4467 - val_loss: 1.5489 - val_accuracy: 0.4423
# Epoch 4/5
# 391/391 [==============================] - 1s 2ms/step - loss: 1.5099 - accuracy: 0.4581 - val_loss: 1.5377 - val_accuracy: 0.4488
# Epoch 5/5
# 391/391 [==============================] - 1s 2ms/step - loss: 1.4937 - accuracy: 0.4629 - val_loss: 1.5239 - val_accuracy: 0.4486
# Model 7
# Epoch 1/5
# 391/391 [==============================] - 1s 3ms/step - loss: 1.9072 - accuracy: 0.3204 - val_loss: 1.6055 - val_accuracy: 0.4219
# Epoch 2/5
# 391/391 [==============================] - 1s 2ms/step - loss: 1.5841 - accuracy: 0.4287 - val_loss: 1.5531 - val_accuracy: 0.4453
# Epoch 3/5
# 391/391 [==============================] - 1s 2ms/step - loss: 1.5413 - accuracy: 0.4446 - val_loss: 1.5439 - val_accuracy: 0.4456
# Epoch 4/5
# 391/391 [==============================] - 1s 2ms/step - loss: 1.5178 - accuracy: 0.4569 - val_loss: 1.5357 - val_accuracy: 0.4551
# Epoch 5/5
# 391/391 [==============================] - 1s 2ms/step - loss: 1.5009 - accuracy: 0.4627 - val_loss: 1.5110 - val_accuracy: 0.4596
# Layer 2
# HICO LENGTH
# 3
# Model 0
# Epoch 1/5
# 391/391 [==============================] - 1s 3ms/step - loss: 1.7704 - accuracy: 0.3783 - val_loss: 1.4927 - val_accuracy: 0.4663
# Epoch 2/5
# 391/391 [==============================] - 1s 2ms/step - loss: 1.4627 - accuracy: 0.4757 - val_loss: 1.4595 - val_accuracy: 0.4777
# Epoch 3/5
# 391/391 [==============================] - 1s 2ms/step - loss: 1.4292 - accuracy: 0.4915 - val_loss: 1.4637 - val_accuracy: 0.4761
# Epoch 4/5
# 391/391 [==============================] - 1s 2ms/step - loss: 1.4175 - accuracy: 0.4928 - val_loss: 1.4485 - val_accuracy: 0.4863
# Epoch 5/5
# 391/391 [==============================] - 1s 2ms/step - loss: 1.3969 - accuracy: 0.4999 - val_loss: 1.4387 - val_accuracy: 0.4853
# Model 1
# Epoch 1/5
# 391/391 [==============================] - 2s 3ms/step - loss: 1.9994 - accuracy: 0.3682 - val_loss: 1.4812 - val_accuracy: 0.4735
# Epoch 2/5
# 391/391 [==============================] - 1s 2ms/step - loss: 1.4585 - accuracy: 0.4805 - val_loss: 1.4593 - val_accuracy: 0.4800
# Epoch 3/5
# 391/391 [==============================] - 1s 2ms/step - loss: 1.4281 - accuracy: 0.4906 - val_loss: 1.4811 - val_accuracy: 0.4770
# Epoch 4/5
# 391/391 [==============================] - 1s 2ms/step - loss: 1.4172 - accuracy: 0.4924 - val_loss: 1.4437 - val_accuracy: 0.4857
# Epoch 5/5
# 391/391 [==============================] - 1s 2ms/step - loss: 1.4054 - accuracy: 0.4970 - val_loss: 1.4372 - val_accuracy: 0.4872
# Model 2
# Epoch 1/5
# 391/391 [==============================] - 2s 3ms/step - loss: 1.8424 - accuracy: 0.3741 - val_loss: 1.4725 - val_accuracy: 0.4757
# Epoch 2/5
# 391/391 [==============================] - 1s 2ms/step - loss: 1.4405 - accuracy: 0.4838 - val_loss: 1.4603 - val_accuracy: 0.4798
# Epoch 3/5
# 391/391 [==============================] - 1s 2ms/step - loss: 1.4137 - accuracy: 0.4923 - val_loss: 1.4609 - val_accuracy: 0.4805
# Epoch 4/5
# 391/391 [==============================] - 1s 2ms/step - loss: 1.4068 - accuracy: 0.4956 - val_loss: 1.4547 - val_accuracy: 0.4798
# Epoch 5/5
# 391/391 [==============================] - 1s 2ms/step - loss: 1.3973 - accuracy: 0.4990 - val_loss: 1.4284 - val_accuracy: 0.4903
# Model 3
# Epoch 1/5
# 391/391 [==============================] - 1s 3ms/step - loss: 1.9070 - accuracy: 0.3608 - val_loss: 1.4904 - val_accuracy: 0.4728
# Epoch 2/5
# 391/391 [==============================] - 1s 2ms/step - loss: 1.4535 - accuracy: 0.4817 - val_loss: 1.4639 - val_accuracy: 0.4778
# Epoch 3/5
# 391/391 [==============================] - 1s 2ms/step - loss: 1.4128 - accuracy: 0.4976 - val_loss: 1.4480 - val_accuracy: 0.4839
# Epoch 4/5
# 391/391 [==============================] - 1s 2ms/step - loss: 1.4079 - accuracy: 0.4965 - val_loss: 1.4789 - val_accuracy: 0.4762
# Epoch 5/5
# 391/391 [==============================] - 1s 2ms/step - loss: 1.4076 - accuracy: 0.4970 - val_loss: 1.4421 - val_accuracy: 0.4845
# Model 4
# Epoch 1/5
# 391/391 [==============================] - 2s 3ms/step - loss: 1.8377 - accuracy: 0.3777 - val_loss: 1.5084 - val_accuracy: 0.4652
# Epoch 2/5
# 391/391 [==============================] - 1s 2ms/step - loss: 1.4575 - accuracy: 0.4776 - val_loss: 1.4739 - val_accuracy: 0.4755
# Epoch 3/5
# 391/391 [==============================] - 1s 2ms/step - loss: 1.4244 - accuracy: 0.4907 - val_loss: 1.4514 - val_accuracy: 0.4790
# Epoch 4/5
# 391/391 [==============================] - 1s 2ms/step - loss: 1.4215 - accuracy: 0.4942 - val_loss: 1.4493 - val_accuracy: 0.4854
# Epoch 5/5
# 391/391 [==============================] - 1s 2ms/step - loss: 1.4126 - accuracy: 0.4939 - val_loss: 1.4455 - val_accuracy: 0.4856
# Model 5
# Epoch 1/5
# 391/391 [==============================] - 1s 3ms/step - loss: 1.7889 - accuracy: 0.3790 - val_loss: 1.4889 - val_accuracy: 0.4652
# Epoch 2/5
# 391/391 [==============================] - 1s 2ms/step - loss: 1.4452 - accuracy: 0.4855 - val_loss: 1.4680 - val_accuracy: 0.4725
# Epoch 3/5
# 391/391 [==============================] - 1s 2ms/step - loss: 1.4195 - accuracy: 0.4900 - val_loss: 1.4461 - val_accuracy: 0.4844
# Epoch 4/5
# 391/391 [==============================] - 1s 2ms/step - loss: 1.3992 - accuracy: 0.5036 - val_loss: 1.4460 - val_accuracy: 0.4767
# Epoch 5/5
# 391/391 [==============================] - 1s 2ms/step - loss: 1.3940 - accuracy: 0.5006 - val_loss: 1.4366 - val_accuracy: 0.4829
# Layer 3
# HICO LENGTH
# 4
# Model 0
# Epoch 1/5
# 391/391 [==============================] - 2s 3ms/step - loss: 1.6458 - accuracy: 0.4199 - val_loss: 1.4800 - val_accuracy: 0.4757
# Epoch 2/5
# 391/391 [==============================] - 1s 2ms/step - loss: 1.3918 - accuracy: 0.5067 - val_loss: 1.4326 - val_accuracy: 0.4880
# Epoch 3/5
# 391/391 [==============================] - 1s 2ms/step - loss: 1.3857 - accuracy: 0.5040 - val_loss: 1.4238 - val_accuracy: 0.4889
# Epoch 4/5
# 391/391 [==============================] - 1s 2ms/step - loss: 1.3726 - accuracy: 0.5097 - val_loss: 1.4254 - val_accuracy: 0.4897
# Epoch 5/5
# 391/391 [==============================] - 1s 2ms/step - loss: 1.3694 - accuracy: 0.5101 - val_loss: 1.4148 - val_accuracy: 0.4926
# Model 1
# Epoch 1/5
# 391/391 [==============================] - 2s 3ms/step - loss: 1.6376 - accuracy: 0.4284 - val_loss: 1.4505 - val_accuracy: 0.4859
# Epoch 2/5
# 391/391 [==============================] - 1s 2ms/step - loss: 1.4038 - accuracy: 0.4983 - val_loss: 1.4378 - val_accuracy: 0.4884
# Epoch 3/5
# 391/391 [==============================] - 1s 2ms/step - loss: 1.3842 - accuracy: 0.5066 - val_loss: 1.4279 - val_accuracy: 0.4898
# Epoch 4/5
# 391/391 [==============================] - 1s 2ms/step - loss: 1.3732 - accuracy: 0.5083 - val_loss: 1.4320 - val_accuracy: 0.4883
# Epoch 5/5
# 391/391 [==============================] - 1s 2ms/step - loss: 1.3690 - accuracy: 0.5133 - val_loss: 1.4280 - val_accuracy: 0.4905
# Model 2
# Epoch 1/5
# 391/391 [==============================] - 2s 3ms/step - loss: 1.8131 - accuracy: 0.4000 - val_loss: 1.4509 - val_accuracy: 0.4850
# Epoch 2/5
# 391/391 [==============================] - 1s 2ms/step - loss: 1.3992 - accuracy: 0.4996 - val_loss: 1.4374 - val_accuracy: 0.4918
# Epoch 3/5
# 391/391 [==============================] - 1s 2ms/step - loss: 1.3896 - accuracy: 0.5057 - val_loss: 1.4352 - val_accuracy: 0.4934
# Epoch 4/5
# 391/391 [==============================] - 1s 2ms/step - loss: 1.3717 - accuracy: 0.5108 - val_loss: 1.4258 - val_accuracy: 0.4926
# Epoch 5/5
# 391/391 [==============================] - 1s 2ms/step - loss: 1.3622 - accuracy: 0.5139 - val_loss: 1.4186 - val_accuracy: 0.4950
# Model 3
# Epoch 1/5
# 391/391 [==============================] - 1s 3ms/step - loss: 1.6068 - accuracy: 0.4346 - val_loss: 1.4612 - val_accuracy: 0.4798
# Epoch 2/5
# 391/391 [==============================] - 1s 2ms/step - loss: 1.4027 - accuracy: 0.4987 - val_loss: 1.4220 - val_accuracy: 0.4937
# Epoch 3/5
# 391/391 [==============================] - 1s 2ms/step - loss: 1.3851 - accuracy: 0.5053 - val_loss: 1.4208 - val_accuracy: 0.4926
# Epoch 4/5
# 391/391 [==============================] - 1s 2ms/step - loss: 1.3785 - accuracy: 0.5109 - val_loss: 1.4235 - val_accuracy: 0.4932
# Epoch 5/5
# 391/391 [==============================] - 1s 2ms/step - loss: 1.3610 - accuracy: 0.5165 - val_loss: 1.4074 - val_accuracy: 0.4986
# Layer 4
# HICO LENGTH
# 5
# Model 0
# Epoch 1/5
# 391/391 [==============================] - 2s 3ms/step - loss: 1.5992 - accuracy: 0.4418 - val_loss: 1.4254 - val_accuracy: 0.4921
# Epoch 2/5
# 391/391 [==============================] - 1s 2ms/step - loss: 1.3739 - accuracy: 0.5090 - val_loss: 1.4099 - val_accuracy: 0.4965
# Epoch 3/5
# 391/391 [==============================] - 1s 2ms/step - loss: 1.3700 - accuracy: 0.5104 - val_loss: 1.4104 - val_accuracy: 0.4969
# Epoch 4/5
# 391/391 [==============================] - 1s 2ms/step - loss: 1.3533 - accuracy: 0.5166 - val_loss: 1.4137 - val_accuracy: 0.4914
# Epoch 5/5
# 391/391 [==============================] - 1s 2ms/step - loss: 1.3497 - accuracy: 0.5197 - val_loss: 1.4074 - val_accuracy: 0.4939
# Model 1
# Epoch 1/5
# 391/391 [==============================] - 2s 3ms/step - loss: 1.6626 - accuracy: 0.4339 - val_loss: 1.4436 - val_accuracy: 0.4894
# Epoch 2/5
# 391/391 [==============================] - 1s 2ms/step - loss: 1.3867 - accuracy: 0.5098 - val_loss: 1.4255 - val_accuracy: 0.4922
# Epoch 3/5
# 391/391 [==============================] - 1s 3ms/step - loss: 1.3735 - accuracy: 0.5111 - val_loss: 1.4207 - val_accuracy: 0.4951
# Epoch 4/5
# 391/391 [==============================] - 1s 3ms/step - loss: 1.3692 - accuracy: 0.5117 - val_loss: 1.4139 - val_accuracy: 0.4927
# Epoch 5/5
# 391/391 [==============================] - 1s 3ms/step - loss: 1.3662 - accuracy: 0.5146 - val_loss: 1.4157 - val_accuracy: 0.4912

# %% [markdown]
# ## Model Evaluation

# %%
# Predict on test image
y_pred_list = []
for j in range(NUM_TN[0]):
  y_pred = np.argmax(hico_layers[0][j][0].predict(X_test_cropped_list[j]), axis=1)
  y_pred_list.append(y_pred)

for i in range(1, NUM_HICO_LAYER):
  for j in range(NUM_TN[i]):

    # Get test hidden representation from HiCo layer i-1
    X_test_input_hr = []
    X_test_input_ol = []
    for k in range(NUM_CONNECTION[i]):
      get_input = (K.function(hico_layers[i-1][hico_layers[i][j][1][k]][0].layers[0].input, hico_layers[i-1][hico_layers[i][j][1][k]][0].layers[1].output))
      X_test_input_hr.append(get_input(get_previous_layer_input(hico_layers, i-1, hico_layers[i-1][hico_layers[i][j][1][k]], X_test_cropped_list)))
    X_test_input_hr = np.array(X_test_input_hr)
    X_test_input_hr = np.sum(X_test_input_hr, axis=0)

    for k in range(NUM_CONNECTION[i]):
      get_input = (K.function(hico_layers[i-1][hico_layers[i][j][1][k]][0].layers[0].input, hico_layers[i-1][hico_layers[i][j][1][k]][0].layers[2].output))
      X_test_input_ol.append(get_input(get_previous_layer_input(hico_layers, i-1, hico_layers[i-1][hico_layers[i][j][1][k]], X_test_cropped_list)))
    X_test_input_ol = np.array(X_test_input_ol)
    X_test_input_ol = np.sum(X_test_input_ol, axis=0)

    X_test_input = np.concatenate((X_test_input_hr, X_test_input_ol), axis=1)

    y_pred = np.argmax(hico_layers[i][j][0].predict(X_test_input), axis=1)
    y_pred_list.append(y_pred)

# HiCo voting (mode)
y_pred_list = np.array(y_pred_list)
y_pred_list = np.transpose(y_pred_list, (1, 0))
y_pred_list = stats.mode(y_pred_list, axis=1)[0]
y_pred_list = np.squeeze(y_pred_list)

# %%
y_test = np.argmax(y_test_one_hot, axis=1)

# %%
accuracy = accuracy_score(y_test, y_pred_list)
accuracy
# Out:
# 0.4946
