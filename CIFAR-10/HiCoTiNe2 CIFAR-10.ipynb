# %% [markdown]
# # HiCoTiNe 2. Adapted from HiCoTiNe v3.3.1
# ## Concatenated hidden representations.
# ## No raw input
# ## The weight of each TN is inversely proportional to the number of TNs in its HiCo layer, relative to the HiCo layer with the most TNs

# %%
from keras.models import Sequential
from keras.layers import Dense, Conv2D, Flatten
from keras.datasets import cifar10
from keras.utils import to_categorical
import matplotlib.pyplot as plt
import numpy as np
import tensorflow as tf
import random
from scipy import stats
from sklearn.metrics import accuracy_score
from keras import backend as K
import cv2

# %%
NUM_BATCH = 391
BATCH_SIZE = 128
SUB_REGION_SCALE = 14
MIN_SUB_REGION_SCALE = 12
MAX_SUB_REGION_SCALE = 16
NUM_TEST_STEP = 10
NUM_HICO_LAYER = 5
NUM_TN = [10, 8, 6, 4, 2]
NUM_CONNECTION = [0, 5, 4, 3, 2]
ALPHA = 0.1

#dataset specific parameters
NUM_CLASS = 10

# %% [markdown]
# ## Data Pre-Processing

# %%
#load dataset
(X_train, y_train), (X_test, y_test) = cifar10.load_data()

# %%
y_train = y_train.reshape(y_train.shape[0])
y_test = y_test.reshape(y_test.shape[0])

# %%
X_train.shape
# Out:
# (50000, 32, 32, 3)

# %%
#Generate cropped train image
X_train_cropped_list = []
y_train_cropped_list = []
#coordinate_list = []
for i in range(NUM_TN[0]):
  X_train_cropped_batch = []
  y_train_cropped_batch = []
  for j in range(NUM_BATCH):
    X_train_cropped = []
    y_train_cropped = []
    sub_region_scale = random.randint(MIN_SUB_REGION_SCALE, MAX_SUB_REGION_SCALE)
    x = random.randint(0, X_train.shape[1] - sub_region_scale)
    y = random.randint(0, X_train.shape[1] - sub_region_scale)
    
    if (j == NUM_BATCH - 1) and ((len(X_train) - j*BATCH_SIZE) % BATCH_SIZE):
      for k in range(len(X_train) - j*BATCH_SIZE):
        image_cropped = []
        for row in range(y, y + sub_region_scale):
          image_cropped_row = []
          for column in range(x, x + sub_region_scale):
            image_cropped_column = []
            for rgb in range(3):
              image_cropped_column.append(X_train[(j*BATCH_SIZE)+k][row][column][rgb])
            image_cropped_row.append(image_cropped_column)
          image_cropped.append(image_cropped_row)
        X_train_cropped.append(image_cropped)
        y_train_cropped.append(y_train[(j*BATCH_SIZE)+k])
      
      X_train_cropped = np.array(X_train_cropped)
      y_train_cropped = np.array(y_train_cropped)
      X_train_cropped_batch.append(X_train_cropped)
      y_train_cropped_batch.append(y_train_cropped)
      break

    for k in range(BATCH_SIZE):
      image_cropped = []
      for row in range(y, y + sub_region_scale):
        image_cropped_row = []
        for column in range(x, x + sub_region_scale):
          image_cropped_column = []
          for rgb in range(3):
            image_cropped_column.append(X_train[(j*BATCH_SIZE)+k][row][column][rgb])
          image_cropped_row.append(image_cropped_column)
        image_cropped.append(image_cropped_row)
      X_train_cropped.append(image_cropped)
      y_train_cropped.append(y_train[(j*BATCH_SIZE)+k])

    X_train_cropped = np.array(X_train_cropped)
    y_train_cropped = np.array(y_train_cropped)
    X_train_cropped_batch.append(X_train_cropped)
    y_train_cropped_batch.append(y_train_cropped)
  X_train_cropped_list.append(X_train_cropped_batch)
  y_train_cropped_list.append(y_train_cropped_batch)

# %%
#Generate cropped test image
X_test_cropped_list = []
for i in range(NUM_TN[0] * NUM_TEST_STEP):
  X_test_cropped = []
  sub_region_scale = random.randint(MIN_SUB_REGION_SCALE, MAX_SUB_REGION_SCALE)
  x = random.randint(0, X_test.shape[1] - sub_region_scale)
  y = random.randint(0, X_test.shape[1] - sub_region_scale)
  for j in range(X_test.shape[0]):
    image_cropped = []
    for row in range(y, y + sub_region_scale):
      image_cropped_row = []
      for column in range(x, x + sub_region_scale):
        image_cropped_column = []
        for rgb in range(3):
          image_cropped_column.append(X_test[j][row][column][rgb])
        image_cropped_row.append(image_cropped_column)
      image_cropped.append(image_cropped_row)
    X_test_cropped.append(image_cropped)

  X_test_cropped = np.array(X_test_cropped)
  X_test_cropped_list.append(X_test_cropped)

# %%
#rescaling dataset
for i in range(NUM_TN[0]):
  for j in range(NUM_BATCH):
    temp = []
    for k in range (len(X_train_cropped_list[i][j])):
      temp.append(cv2.resize(X_train_cropped_list[i][j][k], (SUB_REGION_SCALE, SUB_REGION_SCALE)))
    temp = np.array(temp)
    X_train_cropped_list[i][j] = temp

for i in range(NUM_TN[0] * NUM_TEST_STEP):
  temp = []
  for j in range(X_test.shape[0]):
    temp.append(cv2.resize(X_test_cropped_list[i][j], (SUB_REGION_SCALE, SUB_REGION_SCALE)))
  temp = np.array(temp)
  X_test_cropped_list[i] = temp

# %%
#normalizing dataset
for i in range(NUM_TN[0]):
  for j in range(NUM_BATCH):
    X_train_cropped_list[i][j] = X_train_cropped_list[i][j]/255

for i in range(NUM_TN[0] * NUM_TEST_STEP):
  X_test_cropped_list[i] = X_test_cropped_list[i]/255

# %%
#transform to vector
for i in range(NUM_TN[0]):
  for j in range(NUM_BATCH):
    X_train_cropped_list[i][j] = X_train_cropped_list[i][j].reshape((-1, SUB_REGION_SCALE*SUB_REGION_SCALE*3))

for i in range(NUM_TN[0] * NUM_TEST_STEP):
  X_test_cropped_list[i] = X_test_cropped_list[i].reshape((-1, SUB_REGION_SCALE*SUB_REGION_SCALE*3))

# %%
#one-hot encoding
y_train_one_hot = []
for i in range(NUM_TN[0]):
  temp = []
  for j in range(NUM_BATCH):
    temp.append(to_categorical(y_train_cropped_list[i][j], num_classes=NUM_CLASS))
  y_train_one_hot.append(temp)

y_test_one_hot = to_categorical(y_test)

# %% [markdown]
# ## HiCo Layer 1

# %%
#build ANN model
ensemble = []
for i in range(NUM_TN[0]):
  model = Sequential()
  model.add(Dense(64, activation='relu', input_dim=SUB_REGION_SCALE*SUB_REGION_SCALE*3))
  model.add(Dense(64, activation='relu'))
  model.add(Dense(NUM_CLASS, activation = 'softmax'))
  model.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])
  ensemble.append((model, i))

# %%
for i in range(NUM_TN[0]):
  print('Model %d' %i)
  for j in range(5):
    print('Epoch %d' %j)
    for k in range(NUM_BATCH):
      ensemble[i][0].train_on_batch(X_train_cropped_list[i][k], y_train_one_hot[i][k])
# Out:
# Model 0
# Epoch 0
# Epoch 1
# Epoch 2
# Epoch 3
# Epoch 4
# Model 1
# Epoch 0
# Epoch 1
# Epoch 2
# Epoch 3
# Epoch 4
# Model 2
# Epoch 0
# Epoch 1
# Epoch 2
# Epoch 3
# Epoch 4
# Model 3
# Epoch 0
# Epoch 1
# Epoch 2
# Epoch 3
# Epoch 4
# Model 4
# Epoch 0
# Epoch 1
# Epoch 2
# Epoch 3
# Epoch 4
# Model 5
# Epoch 0
# Epoch 1
# Epoch 2
# Epoch 3
# Epoch 4
# Model 6
# Epoch 0
# Epoch 1
# Epoch 2
# Epoch 3
# Epoch 4
# Model 7
# Epoch 0
# Epoch 1
# Epoch 2
# Epoch 3
# Epoch 4
# Model 8
# Epoch 0
# Epoch 1
# Epoch 2
# Epoch 3
# Epoch 4
# Model 9
# Epoch 0
# Epoch 1
# Epoch 2
# Epoch 3
# Epoch 4

# %%
hico_layers = []
hico_layers.append(ensemble)

# %%
del hico_layers[1:]

# %% [markdown]
# ## HiCo Layer 2+

# %%
X_train_cropped_list_combined = []
for i in range(NUM_TN[0]):
  X_train_cropped_list_combined.append(np.concatenate(X_train_cropped_list[i], axis=0))

y_train_one_hot_combined = to_categorical(y_train)

# %%
# Function to get input of layer i-1
def get_previous_layer_input(hico_layers, layer, tn, train_image):
  input = []
    
  if layer == 0:
    previous_layer_input = train_image[tn[1]]
    return previous_layer_input

  elif layer > 0:
    for i in range(NUM_CONNECTION[layer]):
      get_input = (K.function(hico_layers[layer-1][tn[1][i]][0].layers[0].input, hico_layers[layer-1][tn[1][i]][0].layers[1].output))
      input.append(get_input(get_previous_layer_input(hico_layers, layer-1, hico_layers[layer-1][tn[1][i]], train_image)))
      
    input = np.array(input)
    input = np.concatenate(input, axis=1)
    previous_layer_input = input
    return previous_layer_input

# %%
for i in range(1, NUM_HICO_LAYER):
  print('Layer %d' %i)
  ensemble = []
  X_train_input_list = []
  X_test_input_list = []

  for j in range(NUM_TN[i]):
    # Build model of HiCo layer i
    connection = tuple(random.sample(range(len(hico_layers[i-1])), k=NUM_CONNECTION[i]))
    model = Sequential()
    model.add(Dense(64, activation='relu', input_dim=64*NUM_CONNECTION[i]))
    model.add(Dense(64, activation='relu'))
    model.add(Dense(NUM_CLASS, activation = 'softmax'))
    model.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])
    ensemble.append((model, connection))
  hico_layers.append(ensemble)
  print('HICO LENGTH')
  print(len(hico_layers))

  for j in range(NUM_TN[i]):
    # Get train hidden representation from HiCo layer i-1
    X_train_input = []
    for k in range(NUM_CONNECTION[i]):
      get_input = (K.function(hico_layers[i-1][hico_layers[i][j][1][k]][0].layers[0].input, hico_layers[i-1][hico_layers[i][j][1][k]][0].layers[1].output))
      X_train_input.append(get_input(get_previous_layer_input(hico_layers, i-1, hico_layers[i-1][hico_layers[i][j][1][k]], X_train_cropped_list_combined)))
    X_train_input = np.array(X_train_input)
    X_train_input = np.concatenate(X_train_input, axis=1)
    X_train_input_list.append(X_train_input)

    # Get test hidden representation from HiCo layer i-1
    X_test_input = []
    for k in range(NUM_CONNECTION[i]):
      get_input = (K.function(hico_layers[i-1][hico_layers[i][j][1][k]][0].layers[0].input, hico_layers[i-1][hico_layers[i][j][1][k]][0].layers[1].output))
      X_test_input.append(get_input(get_previous_layer_input(hico_layers, i-1, hico_layers[i-1][hico_layers[i][j][1][k]], X_test_cropped_list)))
    X_test_input = np.array(X_test_input)
    X_test_input = np.concatenate(X_test_input, axis=1)
    X_test_input_list.append(X_test_input)

  #train model of HiCo layer i
  for j in range(NUM_TN[i]):
    print('Model %d' %j)
    hico_layers[i][j][0].fit(X_train_input_list[j], y_train_one_hot_combined, validation_data=(X_test_input_list[j], y_test_one_hot), epochs=5)
# Out:
# Layer 1
# HICO LENGTH
# 2
# Model 0
# Epoch 1/5
# 1563/1563 [==============================] - 4s 2ms/step - loss: 1.9114 - accuracy: 0.2751 - val_loss: 1.8449 - val_accuracy: 0.3078
# Epoch 2/5
# 1563/1563 [==============================] - 3s 2ms/step - loss: 1.7817 - accuracy: 0.3362 - val_loss: 1.8216 - val_accuracy: 0.3129
# Epoch 3/5
# 1563/1563 [==============================] - 3s 2ms/step - loss: 1.7494 - accuracy: 0.3433 - val_loss: 1.8081 - val_accuracy: 0.3275
# Epoch 4/5
# 1563/1563 [==============================] - 3s 2ms/step - loss: 1.7351 - accuracy: 0.3564 - val_loss: 1.8136 - val_accuracy: 0.3244
# Epoch 5/5
# 1563/1563 [==============================] - 3s 2ms/step - loss: 1.7278 - accuracy: 0.3571 - val_loss: 1.7916 - val_accuracy: 0.3337
# Model 1
# Epoch 1/5
# 1563/1563 [==============================] - 3s 2ms/step - loss: 1.9254 - accuracy: 0.2705 - val_loss: 1.8413 - val_accuracy: 0.3180
# Epoch 2/5
# 1563/1563 [==============================] - 3s 2ms/step - loss: 1.7923 - accuracy: 0.3299 - val_loss: 1.8066 - val_accuracy: 0.3206
# Epoch 3/5
# 1563/1563 [==============================] - 3s 2ms/step - loss: 1.7718 - accuracy: 0.3411 - val_loss: 1.7905 - val_accuracy: 0.3368
# Epoch 4/5
# 1563/1563 [==============================] - 3s 2ms/step - loss: 1.7427 - accuracy: 0.3539 - val_loss: 1.7799 - val_accuracy: 0.3401
# Epoch 5/5
# 1563/1563 [==============================] - 3s 2ms/step - loss: 1.7332 - accuracy: 0.3587 - val_loss: 1.7855 - val_accuracy: 0.3425
# Model 2
# Epoch 1/5
# 1563/1563 [==============================] - 4s 2ms/step - loss: 1.9171 - accuracy: 0.2704 - val_loss: 1.8161 - val_accuracy: 0.3194
# Epoch 2/5
# 1563/1563 [==============================] - 3s 2ms/step - loss: 1.7934 - accuracy: 0.3291 - val_loss: 1.7999 - val_accuracy: 0.3266
# Epoch 3/5
# 1563/1563 [==============================] - 3s 2ms/step - loss: 1.7622 - accuracy: 0.3402 - val_loss: 1.8016 - val_accuracy: 0.3278
# Epoch 4/5
# 1563/1563 [==============================] - 3s 2ms/step - loss: 1.7363 - accuracy: 0.3563 - val_loss: 1.7740 - val_accuracy: 0.3350
# Epoch 5/5
# 1563/1563 [==============================] - 3s 2ms/step - loss: 1.7262 - accuracy: 0.3593 - val_loss: 1.7700 - val_accuracy: 0.3445
# Model 3
# Epoch 1/5
# 1563/1563 [==============================] - 3s 2ms/step - loss: 1.9321 - accuracy: 0.2698 - val_loss: 1.8009 - val_accuracy: 0.3233
# Epoch 2/5
# 1563/1563 [==============================] - 3s 2ms/step - loss: 1.7906 - accuracy: 0.3276 - val_loss: 1.8041 - val_accuracy: 0.3203
# Epoch 3/5
# 1563/1563 [==============================] - 3s 2ms/step - loss: 1.7714 - accuracy: 0.3351 - val_loss: 1.7758 - val_accuracy: 0.3405
# Epoch 4/5
# 1563/1563 [==============================] - 3s 2ms/step - loss: 1.7492 - accuracy: 0.3492 - val_loss: 1.7673 - val_accuracy: 0.3391
# Epoch 5/5
# 1563/1563 [==============================] - 3s 2ms/step - loss: 1.7356 - accuracy: 0.3542 - val_loss: 1.7544 - val_accuracy: 0.3438
# Model 4
# Epoch 1/5
# 1563/1563 [==============================] - 3s 2ms/step - loss: 1.9164 - accuracy: 0.2755 - val_loss: 1.7911 - val_accuracy: 0.3280
# Epoch 2/5
# 1563/1563 [==============================] - 3s 2ms/step - loss: 1.7757 - accuracy: 0.3383 - val_loss: 1.7718 - val_accuracy: 0.3477
# Epoch 3/5
# 1563/1563 [==============================] - 3s 2ms/step - loss: 1.7404 - accuracy: 0.3511 - val_loss: 1.7288 - val_accuracy: 0.3540
# Epoch 4/5
# 1563/1563 [==============================] - 3s 2ms/step - loss: 1.7269 - accuracy: 0.3551 - val_loss: 1.7404 - val_accuracy: 0.3586
# Epoch 5/5
# 1563/1563 [==============================] - 3s 2ms/step - loss: 1.7078 - accuracy: 0.3623 - val_loss: 1.7526 - val_accuracy: 0.3546
# Model 5
# Epoch 1/5
# 1563/1563 [==============================] - 4s 2ms/step - loss: 1.9103 - accuracy: 0.2820 - val_loss: 1.8966 - val_accuracy: 0.2893
# Epoch 2/5
# 1563/1563 [==============================] - 3s 2ms/step - loss: 1.7877 - accuracy: 0.3307 - val_loss: 1.8680 - val_accuracy: 0.3033
# Epoch 3/5
# 1563/1563 [==============================] - 3s 2ms/step - loss: 1.7652 - accuracy: 0.3468 - val_loss: 1.8722 - val_accuracy: 0.3061
# Epoch 4/5
# 1563/1563 [==============================] - 3s 2ms/step - loss: 1.7421 - accuracy: 0.3528 - val_loss: 1.8561 - val_accuracy: 0.3144
# Epoch 5/5
# 1563/1563 [==============================] - 3s 2ms/step - loss: 1.7316 - accuracy: 0.3570 - val_loss: 1.8596 - val_accuracy: 0.3149
# Model 6
# Epoch 1/5
# 1563/1563 [==============================] - 4s 2ms/step - loss: 1.9157 - accuracy: 0.2723 - val_loss: 1.8149 - val_accuracy: 0.3213
# Epoch 2/5
# 1563/1563 [==============================] - 3s 2ms/step - loss: 1.7676 - accuracy: 0.3404 - val_loss: 1.8004 - val_accuracy: 0.3259
# Epoch 3/5
# 1563/1563 [==============================] - 3s 2ms/step - loss: 1.7472 - accuracy: 0.3489 - val_loss: 1.7727 - val_accuracy: 0.3408
# Epoch 4/5
# 1563/1563 [==============================] - 3s 2ms/step - loss: 1.7303 - accuracy: 0.3523 - val_loss: 1.7606 - val_accuracy: 0.3496
# Epoch 5/5
# 1563/1563 [==============================] - 3s 2ms/step - loss: 1.7165 - accuracy: 0.3622 - val_loss: 1.7670 - val_accuracy: 0.3417
# Model 7
# Epoch 1/5
# 1563/1563 [==============================] - 4s 2ms/step - loss: 1.9140 - accuracy: 0.2750 - val_loss: 1.8056 - val_accuracy: 0.3268
# Epoch 2/5
# 1563/1563 [==============================] - 3s 2ms/step - loss: 1.7780 - accuracy: 0.3369 - val_loss: 1.7763 - val_accuracy: 0.3400
# Epoch 3/5
# 1563/1563 [==============================] - 3s 2ms/step - loss: 1.7581 - accuracy: 0.3456 - val_loss: 1.7608 - val_accuracy: 0.3456
# Epoch 4/5
# 1563/1563 [==============================] - 3s 2ms/step - loss: 1.7234 - accuracy: 0.3652 - val_loss: 1.7620 - val_accuracy: 0.3452
# Epoch 5/5
# 1563/1563 [==============================] - 3s 2ms/step - loss: 1.7175 - accuracy: 0.3623 - val_loss: 1.7469 - val_accuracy: 0.3496
# Layer 2
# HICO LENGTH
# 3
# Model 0
# Epoch 1/5
# 1563/1563 [==============================] - 4s 2ms/step - loss: 1.7363 - accuracy: 0.3541 - val_loss: 1.7368 - val_accuracy: 0.3560
# Epoch 2/5
# 1563/1563 [==============================] - 3s 2ms/step - loss: 1.6284 - accuracy: 0.4000 - val_loss: 1.7206 - val_accuracy: 0.3623
# Epoch 3/5
# 1563/1563 [==============================] - 3s 2ms/step - loss: 1.6161 - accuracy: 0.4032 - val_loss: 1.7091 - val_accuracy: 0.3761
# Epoch 4/5
# 1563/1563 [==============================] - 3s 2ms/step - loss: 1.6033 - accuracy: 0.4079 - val_loss: 1.7128 - val_accuracy: 0.3708
# Epoch 5/5
# 1563/1563 [==============================] - 3s 2ms/step - loss: 1.5946 - accuracy: 0.4128 - val_loss: 1.7194 - val_accuracy: 0.3698
# Model 1
# Epoch 1/5
# 1563/1563 [==============================] - 3s 2ms/step - loss: 1.7363 - accuracy: 0.3595 - val_loss: 1.7365 - val_accuracy: 0.3635
# Epoch 2/5
# 1563/1563 [==============================] - 3s 2ms/step - loss: 1.6138 - accuracy: 0.4041 - val_loss: 1.7186 - val_accuracy: 0.3728
# Epoch 3/5
# 1563/1563 [==============================] - 3s 2ms/step - loss: 1.6002 - accuracy: 0.4070 - val_loss: 1.7289 - val_accuracy: 0.3678
# Epoch 4/5
# 1563/1563 [==============================] - 3s 2ms/step - loss: 1.5883 - accuracy: 0.4149 - val_loss: 1.7223 - val_accuracy: 0.3729
# Epoch 5/5
# 1563/1563 [==============================] - 3s 2ms/step - loss: 1.5732 - accuracy: 0.4201 - val_loss: 1.7239 - val_accuracy: 0.3772
# Model 2
# Epoch 1/5
# 1563/1563 [==============================] - 3s 2ms/step - loss: 1.7256 - accuracy: 0.3618 - val_loss: 1.7104 - val_accuracy: 0.3717
# Epoch 2/5
# 1563/1563 [==============================] - 3s 2ms/step - loss: 1.6217 - accuracy: 0.4012 - val_loss: 1.7141 - val_accuracy: 0.3713
# Epoch 3/5
# 1563/1563 [==============================] - 3s 2ms/step - loss: 1.5975 - accuracy: 0.4098 - val_loss: 1.7039 - val_accuracy: 0.3744
# Epoch 4/5
# 1563/1563 [==============================] - 3s 2ms/step - loss: 1.5902 - accuracy: 0.4157 - val_loss: 1.7166 - val_accuracy: 0.3739
# Epoch 5/5
# 1563/1563 [==============================] - 3s 2ms/step - loss: 1.5824 - accuracy: 0.4174 - val_loss: 1.7050 - val_accuracy: 0.3753
# Model 3
# Epoch 1/5
# 1563/1563 [==============================] - 3s 2ms/step - loss: 1.7263 - accuracy: 0.3599 - val_loss: 1.7203 - val_accuracy: 0.3633
# Epoch 2/5
# 1563/1563 [==============================] - 3s 2ms/step - loss: 1.6335 - accuracy: 0.3977 - val_loss: 1.7138 - val_accuracy: 0.3634
# Epoch 3/5
# 1563/1563 [==============================] - 3s 2ms/step - loss: 1.6093 - accuracy: 0.4058 - val_loss: 1.7121 - val_accuracy: 0.3742
# Epoch 4/5
# 1563/1563 [==============================] - 3s 2ms/step - loss: 1.5971 - accuracy: 0.4172 - val_loss: 1.7208 - val_accuracy: 0.3710
# Epoch 5/5
# 1563/1563 [==============================] - 3s 2ms/step - loss: 1.5904 - accuracy: 0.4130 - val_loss: 1.7183 - val_accuracy: 0.3716
# Model 4
# Epoch 1/5
# 1563/1563 [==============================] - 3s 2ms/step - loss: 1.7307 - accuracy: 0.3576 - val_loss: 1.7160 - val_accuracy: 0.3677
# Epoch 2/5
# 1563/1563 [==============================] - 3s 2ms/step - loss: 1.6121 - accuracy: 0.4060 - val_loss: 1.7089 - val_accuracy: 0.3704
# Epoch 3/5
# 1563/1563 [==============================] - 3s 2ms/step - loss: 1.5991 - accuracy: 0.4097 - val_loss: 1.7317 - val_accuracy: 0.3737
# Epoch 4/5
# 1563/1563 [==============================] - 3s 2ms/step - loss: 1.5816 - accuracy: 0.4183 - val_loss: 1.7277 - val_accuracy: 0.3733
# Epoch 5/5
# 1563/1563 [==============================] - 3s 2ms/step - loss: 1.5800 - accuracy: 0.4181 - val_loss: 1.7311 - val_accuracy: 0.3717
# Model 5
# Epoch 1/5
# 1563/1563 [==============================] - 3s 2ms/step - loss: 1.7385 - accuracy: 0.3559 - val_loss: 1.7056 - val_accuracy: 0.3671
# Epoch 2/5
# 1563/1563 [==============================] - 3s 2ms/step - loss: 1.6310 - accuracy: 0.3968 - val_loss: 1.7051 - val_accuracy: 0.3705
# Epoch 3/5
# 1563/1563 [==============================] - 3s 2ms/step - loss: 1.6091 - accuracy: 0.4071 - val_loss: 1.7049 - val_accuracy: 0.3798
# Epoch 4/5
# 1563/1563 [==============================] - 3s 2ms/step - loss: 1.5991 - accuracy: 0.4107 - val_loss: 1.7143 - val_accuracy: 0.3756
# Epoch 5/5
# 1563/1563 [==============================] - 3s 2ms/step - loss: 1.5971 - accuracy: 0.4101 - val_loss: 1.7066 - val_accuracy: 0.3787
# Layer 3
# HICO LENGTH
# 4
# Model 0
# Epoch 1/5
# 1563/1563 [==============================] - 3s 2ms/step - loss: 1.6555 - accuracy: 0.3926 - val_loss: 1.7075 - val_accuracy: 0.3691
# Epoch 2/5
# 1563/1563 [==============================] - 3s 2ms/step - loss: 1.5619 - accuracy: 0.4223 - val_loss: 1.7187 - val_accuracy: 0.3691
# Epoch 3/5
# 1563/1563 [==============================] - 3s 2ms/step - loss: 1.5575 - accuracy: 0.4288 - val_loss: 1.7231 - val_accuracy: 0.3701
# Epoch 4/5
# 1563/1563 [==============================] - 3s 2ms/step - loss: 1.5458 - accuracy: 0.4315 - val_loss: 1.7498 - val_accuracy: 0.3610
# Epoch 5/5
# 1563/1563 [==============================] - 3s 2ms/step - loss: 1.5434 - accuracy: 0.4274 - val_loss: 1.7224 - val_accuracy: 0.3693
# Model 1
# Epoch 1/5
# 1563/1563 [==============================] - 3s 2ms/step - loss: 1.6547 - accuracy: 0.3897 - val_loss: 1.7092 - val_accuracy: 0.3707
# Epoch 2/5
# 1563/1563 [==============================] - 3s 2ms/step - loss: 1.5641 - accuracy: 0.4279 - val_loss: 1.6994 - val_accuracy: 0.3779
# Epoch 3/5
# 1563/1563 [==============================] - 3s 2ms/step - loss: 1.5634 - accuracy: 0.4265 - val_loss: 1.7308 - val_accuracy: 0.3773
# Epoch 4/5
# 1563/1563 [==============================] - 3s 2ms/step - loss: 1.5348 - accuracy: 0.4358 - val_loss: 1.7291 - val_accuracy: 0.3798
# Epoch 5/5
# 1563/1563 [==============================] - 3s 2ms/step - loss: 1.5392 - accuracy: 0.4356 - val_loss: 1.7239 - val_accuracy: 0.3828
# Model 2
# Epoch 1/5
# 1563/1563 [==============================] - 3s 2ms/step - loss: 1.6654 - accuracy: 0.3866 - val_loss: 1.7200 - val_accuracy: 0.3785
# Epoch 2/5
# 1563/1563 [==============================] - 3s 2ms/step - loss: 1.5661 - accuracy: 0.4228 - val_loss: 1.7119 - val_accuracy: 0.3757
# Epoch 3/5
# 1563/1563 [==============================] - 3s 2ms/step - loss: 1.5572 - accuracy: 0.4263 - val_loss: 1.7262 - val_accuracy: 0.3730
# Epoch 4/5
# 1563/1563 [==============================] - 3s 2ms/step - loss: 1.5487 - accuracy: 0.4343 - val_loss: 1.7058 - val_accuracy: 0.3858
# Epoch 5/5
# 1563/1563 [==============================] - 3s 2ms/step - loss: 1.5367 - accuracy: 0.4330 - val_loss: 1.7316 - val_accuracy: 0.3746
# Model 3
# Epoch 1/5
# 1563/1563 [==============================] - 4s 2ms/step - loss: 1.6784 - accuracy: 0.3878 - val_loss: 1.7055 - val_accuracy: 0.3826
# Epoch 2/5
# 1563/1563 [==============================] - 3s 2ms/step - loss: 1.5597 - accuracy: 0.4299 - val_loss: 1.7090 - val_accuracy: 0.3707
# Epoch 3/5
# 1563/1563 [==============================] - 3s 2ms/step - loss: 1.5545 - accuracy: 0.4301 - val_loss: 1.7091 - val_accuracy: 0.3806
# Epoch 4/5
# 1563/1563 [==============================] - 3s 2ms/step - loss: 1.5473 - accuracy: 0.4302 - val_loss: 1.7271 - val_accuracy: 0.3796
# Epoch 5/5
# 1563/1563 [==============================] - 3s 2ms/step - loss: 1.5389 - accuracy: 0.4336 - val_loss: 1.7015 - val_accuracy: 0.3799
# Layer 4
# HICO LENGTH
# 5
# Model 0
# Epoch 1/5
# 1563/1563 [==============================] - 4s 2ms/step - loss: 1.6279 - accuracy: 0.4066 - val_loss: 1.7234 - val_accuracy: 0.3723
# Epoch 2/5
# 1563/1563 [==============================] - 3s 2ms/step - loss: 1.5341 - accuracy: 0.4344 - val_loss: 1.7366 - val_accuracy: 0.3751
# Epoch 3/5
# 1563/1563 [==============================] - 3s 2ms/step - loss: 1.5286 - accuracy: 0.4403 - val_loss: 1.7086 - val_accuracy: 0.3821
# Epoch 4/5
# 1563/1563 [==============================] - 3s 2ms/step - loss: 1.5279 - accuracy: 0.4372 - val_loss: 1.7210 - val_accuracy: 0.3786
# Epoch 5/5
# 1563/1563 [==============================] - 3s 2ms/step - loss: 1.5176 - accuracy: 0.4401 - val_loss: 1.7258 - val_accuracy: 0.3801
# Model 1
# Epoch 1/5
# 1563/1563 [==============================] - 3s 2ms/step - loss: 1.6250 - accuracy: 0.4041 - val_loss: 1.7233 - val_accuracy: 0.3735
# Epoch 2/5
# 1563/1563 [==============================] - 3s 2ms/step - loss: 1.5379 - accuracy: 0.4350 - val_loss: 1.7036 - val_accuracy: 0.3796
# Epoch 3/5
# 1563/1563 [==============================] - 3s 2ms/step - loss: 1.5337 - accuracy: 0.4356 - val_loss: 1.7339 - val_accuracy: 0.3730
# Epoch 4/5
# 1563/1563 [==============================] - 3s 2ms/step - loss: 1.5272 - accuracy: 0.4365 - val_loss: 1.7149 - val_accuracy: 0.3761
# Epoch 5/5
# 1563/1563 [==============================] - 3s 2ms/step - loss: 1.5196 - accuracy: 0.4383 - val_loss: 1.7167 - val_accuracy: 0.3743

# %% [markdown]
# ## Model Evaluation

# %%
# Predict on test image
y_pred_list_2 = []
for h in range(NUM_TEST_STEP):
  y_pred_list = []
  for j in range(NUM_TN[0]):
    y_pred = hico_layers[0][j][0].predict(X_test_cropped_list[(h*NUM_TN[0])+j])
    y_pred = y_pred * ((1 + ALPHA) - (NUM_TN[0] / max(NUM_TN)))
    y_pred_list.append(y_pred)

  for i in range(1, NUM_HICO_LAYER):
    for j in range(NUM_TN[i]):

      # Get test hidden representation from HiCo layer i-1
      X_test_input = []
      for k in range(NUM_CONNECTION[i]):
        get_input = (K.function(hico_layers[i-1][hico_layers[i][j][1][k]][0].layers[0].input, hico_layers[i-1][hico_layers[i][j][1][k]][0].layers[1].output))
        X_test_input.append(get_input(get_previous_layer_input(hico_layers, i-1, hico_layers[i-1][hico_layers[i][j][1][k]], X_test_cropped_list[h*NUM_TN[0]:(h+1)*NUM_TN[0]])))
      X_test_input = np.array(X_test_input)
      X_test_input = np.concatenate(X_test_input, axis=1)
      y_pred = hico_layers[i][j][0].predict(X_test_input)
      y_pred = y_pred * ((1 + ALPHA) - (NUM_TN[i] / max(NUM_TN)))
      y_pred_list.append(y_pred)

  # HiCo voting
  y_pred_list = np.array(y_pred_list)
  y_pred_list = np.transpose(y_pred_list, (1, 0, 2))
  y_pred_list = np.sum(y_pred_list, axis=1)
  y_pred_list_2.append(y_pred_list)

y_pred_list_2 = np.array(y_pred_list_2)
y_pred_list_2 = np.transpose(y_pred_list_2, (1, 0, 2))
y_pred_list_2 = np.argmax(np.sum(y_pred_list_2, axis=1), axis=1)

# %%
accuracy = accuracy_score(y_test, y_pred_list_2)
accuracy
# Out:
# 0.4323
