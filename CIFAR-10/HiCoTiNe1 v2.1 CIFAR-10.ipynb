# %% [markdown]
# # Variants-Experiment 2.1. Adapted from HiCoTiNe v1.1
#
# ## Concatenated hidden representations.
# ## No raw input
# ## Mode. Compute classifications of all tiny networks, in all HiCo layers, and take the mode as the final classification.

# %%
from keras.models import Sequential
from keras.layers import Dense, Conv2D, Flatten
from keras.datasets import mnist
from keras.utils import to_categorical
import matplotlib.pyplot as plt
import numpy as np
import tensorflow as tf
import random
from scipy import stats
from sklearn.metrics import accuracy_score
from keras import backend as K

import os
import pickle
from google.colab import drive
drive.mount('/content/drive/')
# Out:
# Mounted at /content/drive/

# %%
SUB_REGION_SCALE = 14
NUM_HICO_LAYER = 3
NUM_TN = [10, 4, 2]
NUM_CONNECTION = [0, 2, 2]

#dataset specific parameters
NUM_CLASS = 10

# %% [markdown]
# ## Data Pre-Processing

# %%
with open('/content/drive/My Drive/fyp/CIFAR-10.pickle', 'rb') as f:
    X_train_cropped_list, y_train_one_hot, X_test_cropped_list, y_test_one_hot, coordinate_list, scale_list = pickle.load(f)

# %% [markdown]
# ## HiCo Layer 1

# %%
#build ANN model
ensemble = []
for i in range(NUM_TN[0]):
  model = Sequential()
  model.add(Dense(64, activation='relu', input_dim=SUB_REGION_SCALE*SUB_REGION_SCALE*3))
  model.add(Dense(64, activation='relu'))
  model.add(Dense(NUM_CLASS, activation = 'softmax'))
  model.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])
  ensemble.append((model, i, coordinate_list[i], scale_list[i]))

# %%
for i in range(NUM_TN[0]):
  ensemble[i][0].load_weights('/content/drive/My Drive/fyp/CIFAR-10_' + str(i) + '.h5')

# %%
hico_layers = []
hico_layers.append(ensemble)

# %%
del hico_layers[1:]

# %% [markdown]
# ## HiCo Layer 2+

# %%
# Function to get input of layer i-1
def get_previous_layer_input(hico_layers, layer, tn, train_image):
  input = []
    
  if layer == 0:
    previous_layer_input = train_image[tn[1]]
    return previous_layer_input

  elif layer > 0:
    for i in range(NUM_CONNECTION[layer]):
      get_input = (K.function(hico_layers[layer-1][tn[1][i]][0].layers[0].input, hico_layers[layer-1][tn[1][i]][0].layers[1].output))
      input.append(get_input(get_previous_layer_input(hico_layers, layer-1, hico_layers[layer-1][tn[1][i]], train_image)))
      
    input = np.array(input)
    input = np.concatenate(input, axis=1)
    previous_layer_input = input
    return previous_layer_input

# %%
for i in range(1, NUM_HICO_LAYER):
  print('Layer %d' %i)
  ensemble = []
  X_train_input_list = []
  X_test_input_list = []

  for j in range(NUM_TN[i]):
    # Build model of HiCo layer i
    connection = tuple(random.sample(range(len(hico_layers[i-1])), k=NUM_CONNECTION[i]))
    model = Sequential()
    model.add(Dense(64, activation='relu', input_dim=64*NUM_CONNECTION[i]))
    model.add(Dense(64, activation='relu'))
    model.add(Dense(NUM_CLASS, activation = 'softmax'))
    model.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])
    ensemble.append((model, connection))
  hico_layers.append(ensemble)
  print('HICO LENGTH')
  print(len(hico_layers))

  for j in range(NUM_TN[i]):
    # Get train hidden representation from HiCo layer i-1
    X_train_input = []
    for k in range(NUM_CONNECTION[i]):
      get_input = (K.function(hico_layers[i-1][hico_layers[i][j][1][k]][0].layers[0].input, hico_layers[i-1][hico_layers[i][j][1][k]][0].layers[1].output))
      X_train_input.append(get_input(get_previous_layer_input(hico_layers, i-1, hico_layers[i-1][hico_layers[i][j][1][k]], X_train_cropped_list)))
    X_train_input = np.array(X_train_input)
    X_train_input = np.concatenate(X_train_input, axis=1)
    X_train_input_list.append(X_train_input)

    # Get test hidden representation from HiCo layer i-1
    X_test_input = []
    for k in range(NUM_CONNECTION[i]):
      get_input = (K.function(hico_layers[i-1][hico_layers[i][j][1][k]][0].layers[0].input, hico_layers[i-1][hico_layers[i][j][1][k]][0].layers[1].output))
      X_test_input.append(get_input(get_previous_layer_input(hico_layers, i-1, hico_layers[i-1][hico_layers[i][j][1][k]], X_test_cropped_list)))
    X_test_input = np.array(X_test_input)
    X_test_input = np.concatenate(X_test_input, axis=1)
    X_test_input_list.append(X_test_input)

  #train model of HiCo layer i
  for j in range(NUM_TN[i]):
    print('Model %d' %j)
    hico_layers[i][j][0].fit(X_train_input_list[j], y_train_one_hot, validation_data=(X_test_input_list[j], y_test_one_hot), epochs=5, batch_size=128)
# Out:
# Layer 1
# HICO LENGTH
# 2
# Model 0
# Epoch 1/5
# 391/391 [==============================] - 2s 3ms/step - loss: 1.7893 - accuracy: 0.3531 - val_loss: 1.5669 - val_accuracy: 0.4378
# Epoch 2/5
# 391/391 [==============================] - 1s 2ms/step - loss: 1.5260 - accuracy: 0.4531 - val_loss: 1.5209 - val_accuracy: 0.4576
# Epoch 3/5
# 391/391 [==============================] - 1s 2ms/step - loss: 1.4916 - accuracy: 0.4689 - val_loss: 1.5083 - val_accuracy: 0.4550
# Epoch 4/5
# 391/391 [==============================] - 1s 2ms/step - loss: 1.4727 - accuracy: 0.4748 - val_loss: 1.4936 - val_accuracy: 0.4631
# Epoch 5/5
# 391/391 [==============================] - 1s 2ms/step - loss: 1.4535 - accuracy: 0.4801 - val_loss: 1.4811 - val_accuracy: 0.4689
# Model 1
# Epoch 1/5
# 391/391 [==============================] - 1s 2ms/step - loss: 1.9097 - accuracy: 0.3046 - val_loss: 1.7263 - val_accuracy: 0.3773
# Epoch 2/5
# 391/391 [==============================] - 1s 2ms/step - loss: 1.7144 - accuracy: 0.3830 - val_loss: 1.7005 - val_accuracy: 0.3863
# Epoch 3/5
# 391/391 [==============================] - 1s 2ms/step - loss: 1.6829 - accuracy: 0.3956 - val_loss: 1.6885 - val_accuracy: 0.3984
# Epoch 4/5
# 391/391 [==============================] - 1s 2ms/step - loss: 1.6676 - accuracy: 0.4004 - val_loss: 1.6729 - val_accuracy: 0.4009
# Epoch 5/5
# 391/391 [==============================] - 1s 2ms/step - loss: 1.6456 - accuracy: 0.4058 - val_loss: 1.6665 - val_accuracy: 0.4004
# Model 2
# Epoch 1/5
# 391/391 [==============================] - 1s 2ms/step - loss: 1.8688 - accuracy: 0.3225 - val_loss: 1.6776 - val_accuracy: 0.3993
# Epoch 2/5
# 391/391 [==============================] - 1s 2ms/step - loss: 1.6382 - accuracy: 0.4094 - val_loss: 1.6345 - val_accuracy: 0.4137
# Epoch 3/5
# 391/391 [==============================] - 1s 2ms/step - loss: 1.6052 - accuracy: 0.4245 - val_loss: 1.6295 - val_accuracy: 0.4196
# Epoch 4/5
# 391/391 [==============================] - 1s 2ms/step - loss: 1.5852 - accuracy: 0.4272 - val_loss: 1.6161 - val_accuracy: 0.4294
# Epoch 5/5
# 391/391 [==============================] - 1s 2ms/step - loss: 1.5770 - accuracy: 0.4330 - val_loss: 1.6175 - val_accuracy: 0.4229
# Model 3
# Epoch 1/5
# 391/391 [==============================] - 1s 2ms/step - loss: 1.8604 - accuracy: 0.3299 - val_loss: 1.6754 - val_accuracy: 0.3968
# Epoch 2/5
# 391/391 [==============================] - 1s 2ms/step - loss: 1.6438 - accuracy: 0.4074 - val_loss: 1.6503 - val_accuracy: 0.4058
# Epoch 3/5
# 391/391 [==============================] - 1s 2ms/step - loss: 1.6214 - accuracy: 0.4176 - val_loss: 1.6428 - val_accuracy: 0.4121
# Epoch 4/5
# 391/391 [==============================] - 1s 2ms/step - loss: 1.5996 - accuracy: 0.4274 - val_loss: 1.6228 - val_accuracy: 0.4199
# Epoch 5/5
# 391/391 [==============================] - 1s 2ms/step - loss: 1.5921 - accuracy: 0.4308 - val_loss: 1.6234 - val_accuracy: 0.4217
# Layer 2
# HICO LENGTH
# 3
# Model 0
# Epoch 1/5
# 391/391 [==============================] - 1s 2ms/step - loss: 1.7434 - accuracy: 0.3701 - val_loss: 1.5505 - val_accuracy: 0.4444
# Epoch 2/5
# 391/391 [==============================] - 1s 2ms/step - loss: 1.4939 - accuracy: 0.4685 - val_loss: 1.5458 - val_accuracy: 0.4497
# Epoch 3/5
# 391/391 [==============================] - 1s 2ms/step - loss: 1.4770 - accuracy: 0.4759 - val_loss: 1.5311 - val_accuracy: 0.4566
# Epoch 4/5
# 391/391 [==============================] - 1s 2ms/step - loss: 1.4604 - accuracy: 0.4795 - val_loss: 1.5307 - val_accuracy: 0.4605
# Epoch 5/5
# 391/391 [==============================] - 1s 2ms/step - loss: 1.4516 - accuracy: 0.4833 - val_loss: 1.5238 - val_accuracy: 0.4648
# Model 1
# Epoch 1/5
# 391/391 [==============================] - 1s 2ms/step - loss: 1.6639 - accuracy: 0.4048 - val_loss: 1.4335 - val_accuracy: 0.4912
# Epoch 2/5
# 391/391 [==============================] - 1s 2ms/step - loss: 1.3666 - accuracy: 0.5088 - val_loss: 1.4219 - val_accuracy: 0.4971
# Epoch 3/5
# 391/391 [==============================] - 1s 2ms/step - loss: 1.3509 - accuracy: 0.5165 - val_loss: 1.4082 - val_accuracy: 0.4949
# Epoch 4/5
# 391/391 [==============================] - 1s 2ms/step - loss: 1.3398 - accuracy: 0.5192 - val_loss: 1.4130 - val_accuracy: 0.4967
# Epoch 5/5
# 391/391 [==============================] - 1s 2ms/step - loss: 1.3363 - accuracy: 0.5240 - val_loss: 1.4077 - val_accuracy: 0.5016

# %% [markdown]
# ## Model Evaluation

# %%
# Predict on test image
y_pred_list = []
for j in range(NUM_TN[0]):
  y_pred = np.argmax(hico_layers[0][j][0].predict(X_test_cropped_list[j]), axis=1)
  y_pred_list.append(y_pred)

for i in range(1, NUM_HICO_LAYER):
  for j in range(NUM_TN[i]):

    # Get test hidden representation from HiCo layer i-1
    X_test_input = []
    for k in range(NUM_CONNECTION[i]):
      get_input = (K.function(hico_layers[i-1][hico_layers[i][j][1][k]][0].layers[0].input, hico_layers[i-1][hico_layers[i][j][1][k]][0].layers[1].output))
      X_test_input.append(get_input(get_previous_layer_input(hico_layers, i-1, hico_layers[i-1][hico_layers[i][j][1][k]], X_test_cropped_list)))
    X_test_input = np.array(X_test_input)
    X_test_input = np.concatenate(X_test_input, axis=1)
    y_pred = np.argmax(hico_layers[i][j][0].predict(X_test_input), axis=1)
    y_pred_list.append(y_pred)

# HiCo voting (mode)
y_pred_list = np.array(y_pred_list)
y_pred_list = np.transpose(y_pred_list, (1, 0))
y_pred_list = stats.mode(y_pred_list, axis=1)[0]
y_pred_list = np.squeeze(y_pred_list)

# %%
y_test = np.argmax(y_test_one_hot, axis=1)

# %%
accuracy = accuracy_score(y_test, y_pred_list)
accuracy
# Out:
# 0.468
