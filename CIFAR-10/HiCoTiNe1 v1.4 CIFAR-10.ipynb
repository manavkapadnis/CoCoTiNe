# %% [markdown]
# # Variants-Experiment 1.4
#
# ## Concatenated hidden representations and concatenated output logits.
# ## Mode. Compute classifications of all tiny networks, in all HiCo layers, and take the mode as the final classification.

# %%
from keras.models import Sequential
from keras.layers import Dense, Conv2D, Flatten
from keras.datasets import mnist
from keras.utils import to_categorical
import matplotlib.pyplot as plt
import numpy as np
import tensorflow as tf
import random
from scipy import stats
from sklearn.metrics import accuracy_score
from keras import backend as K

import os
import pickle
from google.colab import drive
drive.mount('/content/drive/')
# Out:
# Mounted at /content/drive/

# %%
SUB_REGION_SCALE = 14
NUM_HICO_LAYER = 5
NUM_TN = [10, 8, 6, 4, 2]
NUM_CONNECTION = [0, 5, 4, 3, 2]

#dataset specific parameters
NUM_CLASS = 10

# %% [markdown]
# ## Data Pre-Processing

# %%
with open('/content/drive/My Drive/fyp/CIFAR-10.pickle', 'rb') as f:
    X_train_cropped_list, y_train_one_hot, X_test_cropped_list, y_test_one_hot, coordinate_list, scale_list = pickle.load(f)

# %% [markdown]
# ## HiCo Layer 1

# %%
#build ANN model
ensemble = []
for i in range(NUM_TN[0]):
  model = Sequential()
  model.add(Dense(64, activation='relu', input_dim=SUB_REGION_SCALE*SUB_REGION_SCALE*3))
  model.add(Dense(64, activation='relu'))
  model.add(Dense(NUM_CLASS, activation = 'softmax'))
  model.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])
  ensemble.append((model, i, coordinate_list[i], scale_list[i]))

# %%
for i in range(NUM_TN[0]):
  ensemble[i][0].load_weights('/content/drive/My Drive/fyp/CIFAR-10_' + str(i) + '.h5')

# %%
hico_layers = []
hico_layers.append(ensemble)

# %%
del hico_layers[1:]

# %% [markdown]
# ## HiCo Layer 2+

# %%
# Function to get input of layer i-1
def get_previous_layer_input(hico_layers, layer, tn, train_image):
  input_hr = []
  input_ol = []
    
  if layer == 0:
    previous_layer_input = train_image[tn[1]]
    return previous_layer_input

  elif layer > 0:
    for i in range(NUM_CONNECTION[layer]):
      get_input = (K.function(hico_layers[layer-1][tn[1][i]][0].layers[0].input, hico_layers[layer-1][tn[1][i]][0].layers[1].output))
      input_hr.append(get_input(get_previous_layer_input(hico_layers, layer-1, hico_layers[layer-1][tn[1][i]], train_image)))
      
    input_hr = np.array(input_hr)
    input_hr = np.concatenate(input_hr, axis=1)

    for i in range(NUM_CONNECTION[layer]):
      get_input = (K.function(hico_layers[layer-1][tn[1][i]][0].layers[0].input, hico_layers[layer-1][tn[1][i]][0].layers[2].output))
      input_ol.append(get_input(get_previous_layer_input(hico_layers, layer-1, hico_layers[layer-1][tn[1][i]], train_image)))

    input_ol = np.array(input_ol)
    input_ol = np.concatenate(input_ol, axis=1)

    input = np.concatenate((input_hr, input_ol), axis=1)
    
    previous_layer_input = input
    return previous_layer_input

# %%
for i in range(1, NUM_HICO_LAYER):
  print('Layer %d' %i)
  ensemble = []
  X_train_input_list = []
  X_test_input_list = []

  for j in range(NUM_TN[i]):
    # Build model of HiCo layer i
    connection = tuple(random.sample(range(len(hico_layers[i-1])), k=NUM_CONNECTION[i]))
    model = Sequential()
    model.add(Dense(64, activation='relu', input_dim=64*NUM_CONNECTION[i]+NUM_CLASS*NUM_CONNECTION[i]))
    model.add(Dense(64, activation='relu'))
    model.add(Dense(NUM_CLASS, activation = 'softmax'))
    model.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])
    ensemble.append((model, connection))
  hico_layers.append(ensemble)
  print('HICO LENGTH')
  print(len(hico_layers))

  for j in range(NUM_TN[i]):
    # Get train hidden representation from HiCo layer i-1
    X_train_input_hr = []
    X_train_input_ol = []
    for k in range(NUM_CONNECTION[i]):
      get_input = (K.function(hico_layers[i-1][hico_layers[i][j][1][k]][0].layers[0].input, hico_layers[i-1][hico_layers[i][j][1][k]][0].layers[1].output))
      X_train_input_hr.append(get_input(get_previous_layer_input(hico_layers, i-1, hico_layers[i-1][hico_layers[i][j][1][k]], X_train_cropped_list)))
    X_train_input_hr = np.array(X_train_input_hr)
    X_train_input_hr = np.concatenate(X_train_input_hr, axis=1)

    for k in range(NUM_CONNECTION[i]):
      get_input = (K.function(hico_layers[i-1][hico_layers[i][j][1][k]][0].layers[0].input, hico_layers[i-1][hico_layers[i][j][1][k]][0].layers[2].output))
      X_train_input_ol.append(get_input(get_previous_layer_input(hico_layers, i-1, hico_layers[i-1][hico_layers[i][j][1][k]], X_train_cropped_list)))
    X_train_input_ol = np.array(X_train_input_ol)
    X_train_input_ol = np.concatenate(X_train_input_ol, axis=1)

    X_train_input = np.concatenate((X_train_input_hr, X_train_input_ol), axis=1)
    X_train_input_list.append(X_train_input)

    # Get test hidden representation from HiCo layer i-1
    X_test_input_hr = []
    X_test_input_ol = []
    for k in range(NUM_CONNECTION[i]):
      get_input = (K.function(hico_layers[i-1][hico_layers[i][j][1][k]][0].layers[0].input, hico_layers[i-1][hico_layers[i][j][1][k]][0].layers[1].output))
      X_test_input_hr.append(get_input(get_previous_layer_input(hico_layers, i-1, hico_layers[i-1][hico_layers[i][j][1][k]], X_test_cropped_list)))
    X_test_input_hr = np.array(X_test_input_hr)
    X_test_input_hr = np.concatenate(X_test_input_hr, axis=1)

    for k in range(NUM_CONNECTION[i]):
      get_input = (K.function(hico_layers[i-1][hico_layers[i][j][1][k]][0].layers[0].input, hico_layers[i-1][hico_layers[i][j][1][k]][0].layers[2].output))
      X_test_input_ol.append(get_input(get_previous_layer_input(hico_layers, i-1, hico_layers[i-1][hico_layers[i][j][1][k]], X_test_cropped_list)))
    X_test_input_ol = np.array(X_test_input_ol)
    X_test_input_ol = np.concatenate(X_test_input_ol, axis=1)

    X_test_input = np.concatenate((X_test_input_hr, X_test_input_ol), axis=1)
    X_test_input_list.append(X_test_input)

  #train model of HiCo layer i
  for j in range(NUM_TN[i]):
    print('Model %d' %j)
    hico_layers[i][j][0].fit(X_train_input_list[j], y_train_one_hot, validation_data=(X_test_input_list[j], y_test_one_hot), epochs=5, batch_size=128)
# Out:
# Layer 1
# HICO LENGTH
# 2
# Model 0
# Epoch 1/5
# 391/391 [==============================] - 2s 3ms/step - loss: 1.7419 - accuracy: 0.3751 - val_loss: 1.5142 - val_accuracy: 0.4560
# Epoch 2/5
# 391/391 [==============================] - 1s 2ms/step - loss: 1.4730 - accuracy: 0.4712 - val_loss: 1.4651 - val_accuracy: 0.4739
# Epoch 3/5
# 391/391 [==============================] - 1s 2ms/step - loss: 1.4262 - accuracy: 0.4895 - val_loss: 1.4524 - val_accuracy: 0.4799
# Epoch 4/5
# 391/391 [==============================] - 1s 2ms/step - loss: 1.3989 - accuracy: 0.5004 - val_loss: 1.4536 - val_accuracy: 0.4786
# Epoch 5/5
# 391/391 [==============================] - 1s 2ms/step - loss: 1.3826 - accuracy: 0.5099 - val_loss: 1.4360 - val_accuracy: 0.4880
# Model 1
# Epoch 1/5
# 391/391 [==============================] - 1s 2ms/step - loss: 1.7115 - accuracy: 0.3810 - val_loss: 1.4867 - val_accuracy: 0.4682
# Epoch 2/5
# 391/391 [==============================] - 1s 2ms/step - loss: 1.4278 - accuracy: 0.4890 - val_loss: 1.4330 - val_accuracy: 0.4888
# Epoch 3/5
# 391/391 [==============================] - 1s 2ms/step - loss: 1.3886 - accuracy: 0.5028 - val_loss: 1.4039 - val_accuracy: 0.5015
# Epoch 4/5
# 391/391 [==============================] - 1s 2ms/step - loss: 1.3710 - accuracy: 0.5126 - val_loss: 1.4002 - val_accuracy: 0.5028
# Epoch 5/5
# 391/391 [==============================] - 1s 2ms/step - loss: 1.3368 - accuracy: 0.5267 - val_loss: 1.3886 - val_accuracy: 0.5080
# Model 2
# Epoch 1/5
# 391/391 [==============================] - 1s 2ms/step - loss: 1.7136 - accuracy: 0.3841 - val_loss: 1.4908 - val_accuracy: 0.4700
# Epoch 2/5
# 391/391 [==============================] - 1s 2ms/step - loss: 1.4426 - accuracy: 0.4798 - val_loss: 1.4496 - val_accuracy: 0.4786
# Epoch 3/5
# 391/391 [==============================] - 1s 2ms/step - loss: 1.4111 - accuracy: 0.4962 - val_loss: 1.4458 - val_accuracy: 0.4780
# Epoch 4/5
# 391/391 [==============================] - 1s 2ms/step - loss: 1.3959 - accuracy: 0.4973 - val_loss: 1.4418 - val_accuracy: 0.4846
# Epoch 5/5
# 391/391 [==============================] - 1s 2ms/step - loss: 1.3675 - accuracy: 0.5133 - val_loss: 1.4331 - val_accuracy: 0.4908
# Model 3
# Epoch 1/5
# 391/391 [==============================] - 1s 2ms/step - loss: 1.7537 - accuracy: 0.3695 - val_loss: 1.5154 - val_accuracy: 0.4559
# Epoch 2/5
# 391/391 [==============================] - 1s 2ms/step - loss: 1.4704 - accuracy: 0.4727 - val_loss: 1.4822 - val_accuracy: 0.4708
# Epoch 3/5
# 391/391 [==============================] - 1s 2ms/step - loss: 1.4331 - accuracy: 0.4881 - val_loss: 1.4781 - val_accuracy: 0.4692
# Epoch 4/5
# 391/391 [==============================] - 1s 2ms/step - loss: 1.4218 - accuracy: 0.4911 - val_loss: 1.4637 - val_accuracy: 0.4769
# Epoch 5/5
# 391/391 [==============================] - 1s 2ms/step - loss: 1.3934 - accuracy: 0.4998 - val_loss: 1.4389 - val_accuracy: 0.4853
# Model 4
# Epoch 1/5
# 391/391 [==============================] - 1s 3ms/step - loss: 1.7610 - accuracy: 0.3631 - val_loss: 1.5428 - val_accuracy: 0.4497
# Epoch 2/5
# 391/391 [==============================] - 1s 2ms/step - loss: 1.5021 - accuracy: 0.4612 - val_loss: 1.5051 - val_accuracy: 0.4577
# Epoch 3/5
# 391/391 [==============================] - 1s 2ms/step - loss: 1.4750 - accuracy: 0.4694 - val_loss: 1.4853 - val_accuracy: 0.4702
# Epoch 4/5
# 391/391 [==============================] - 1s 2ms/step - loss: 1.4385 - accuracy: 0.4840 - val_loss: 1.4752 - val_accuracy: 0.4701
# Epoch 5/5
# 391/391 [==============================] - 1s 2ms/step - loss: 1.4246 - accuracy: 0.4881 - val_loss: 1.4564 - val_accuracy: 0.4795
# Model 5
# Epoch 1/5
# 391/391 [==============================] - 1s 2ms/step - loss: 1.7457 - accuracy: 0.3710 - val_loss: 1.5094 - val_accuracy: 0.4599
# Epoch 2/5
# 391/391 [==============================] - 1s 2ms/step - loss: 1.4749 - accuracy: 0.4687 - val_loss: 1.4723 - val_accuracy: 0.4729
# Epoch 3/5
# 391/391 [==============================] - 1s 2ms/step - loss: 1.4307 - accuracy: 0.4875 - val_loss: 1.4504 - val_accuracy: 0.4814
# Epoch 4/5
# 391/391 [==============================] - 1s 2ms/step - loss: 1.4136 - accuracy: 0.4951 - val_loss: 1.4397 - val_accuracy: 0.4835
# Epoch 5/5
# 391/391 [==============================] - 1s 2ms/step - loss: 1.3933 - accuracy: 0.5007 - val_loss: 1.4370 - val_accuracy: 0.4827
# Model 6
# Epoch 1/5
# 391/391 [==============================] - 1s 2ms/step - loss: 1.6877 - accuracy: 0.3859 - val_loss: 1.4805 - val_accuracy: 0.4676
# Epoch 2/5
# 391/391 [==============================] - 1s 2ms/step - loss: 1.4399 - accuracy: 0.4820 - val_loss: 1.4436 - val_accuracy: 0.4842
# Epoch 3/5
# 391/391 [==============================] - 1s 2ms/step - loss: 1.3990 - accuracy: 0.5015 - val_loss: 1.4312 - val_accuracy: 0.4867
# Epoch 4/5
# 391/391 [==============================] - 1s 2ms/step - loss: 1.3743 - accuracy: 0.5093 - val_loss: 1.4272 - val_accuracy: 0.4840
# Epoch 5/5
# 391/391 [==============================] - 1s 2ms/step - loss: 1.3481 - accuracy: 0.5160 - val_loss: 1.4108 - val_accuracy: 0.4952
# Model 7
# Epoch 1/5
# 391/391 [==============================] - 1s 2ms/step - loss: 1.7547 - accuracy: 0.3656 - val_loss: 1.5197 - val_accuracy: 0.4533
# Epoch 2/5
# 391/391 [==============================] - 1s 2ms/step - loss: 1.4713 - accuracy: 0.4729 - val_loss: 1.4686 - val_accuracy: 0.4722
# Epoch 3/5
# 391/391 [==============================] - 1s 2ms/step - loss: 1.4344 - accuracy: 0.4849 - val_loss: 1.4511 - val_accuracy: 0.4779
# Epoch 4/5
# 391/391 [==============================] - 1s 2ms/step - loss: 1.4097 - accuracy: 0.4959 - val_loss: 1.4547 - val_accuracy: 0.4789
# Epoch 5/5
# 391/391 [==============================] - 1s 2ms/step - loss: 1.3871 - accuracy: 0.5050 - val_loss: 1.4270 - val_accuracy: 0.4894
# Layer 2
# HICO LENGTH
# 3
# Model 0
# Epoch 1/5
# 391/391 [==============================] - 1s 2ms/step - loss: 1.5314 - accuracy: 0.4544 - val_loss: 1.3952 - val_accuracy: 0.5024
# Epoch 2/5
# 391/391 [==============================] - 1s 2ms/step - loss: 1.3130 - accuracy: 0.5322 - val_loss: 1.4119 - val_accuracy: 0.4967
# Epoch 3/5
# 391/391 [==============================] - 1s 2ms/step - loss: 1.2999 - accuracy: 0.5376 - val_loss: 1.3817 - val_accuracy: 0.5072
# Epoch 4/5
# 391/391 [==============================] - 1s 2ms/step - loss: 1.2847 - accuracy: 0.5415 - val_loss: 1.3718 - val_accuracy: 0.5169
# Epoch 5/5
# 391/391 [==============================] - 1s 2ms/step - loss: 1.2750 - accuracy: 0.5480 - val_loss: 1.3723 - val_accuracy: 0.5128
# Model 1
# Epoch 1/5
# 391/391 [==============================] - 1s 2ms/step - loss: 1.5426 - accuracy: 0.4542 - val_loss: 1.3677 - val_accuracy: 0.5149
# Epoch 2/5
# 391/391 [==============================] - 1s 2ms/step - loss: 1.2865 - accuracy: 0.5422 - val_loss: 1.3508 - val_accuracy: 0.5162
# Epoch 3/5
# 391/391 [==============================] - 1s 2ms/step - loss: 1.2702 - accuracy: 0.5461 - val_loss: 1.3598 - val_accuracy: 0.5140
# Epoch 4/5
# 391/391 [==============================] - 1s 2ms/step - loss: 1.2571 - accuracy: 0.5553 - val_loss: 1.3543 - val_accuracy: 0.5184
# Epoch 5/5
# 391/391 [==============================] - 1s 2ms/step - loss: 1.2486 - accuracy: 0.5570 - val_loss: 1.3451 - val_accuracy: 0.5227
# Model 2
# Epoch 1/5
# 391/391 [==============================] - 1s 2ms/step - loss: 1.5333 - accuracy: 0.4512 - val_loss: 1.4222 - val_accuracy: 0.4938
# Epoch 2/5
# 391/391 [==============================] - 1s 2ms/step - loss: 1.3395 - accuracy: 0.5218 - val_loss: 1.4099 - val_accuracy: 0.4985
# Epoch 3/5
# 391/391 [==============================] - 1s 2ms/step - loss: 1.3187 - accuracy: 0.5300 - val_loss: 1.4076 - val_accuracy: 0.4979
# Epoch 4/5
# 391/391 [==============================] - 1s 2ms/step - loss: 1.3109 - accuracy: 0.5373 - val_loss: 1.4120 - val_accuracy: 0.4989
# Epoch 5/5
# 391/391 [==============================] - 1s 2ms/step - loss: 1.2988 - accuracy: 0.5380 - val_loss: 1.3923 - val_accuracy: 0.5000
# Model 3
# Epoch 1/5
# 391/391 [==============================] - 1s 2ms/step - loss: 1.5047 - accuracy: 0.4664 - val_loss: 1.3735 - val_accuracy: 0.5111
# Epoch 2/5
# 391/391 [==============================] - 1s 2ms/step - loss: 1.2687 - accuracy: 0.5493 - val_loss: 1.3510 - val_accuracy: 0.5246
# Epoch 3/5
# 391/391 [==============================] - 1s 2ms/step - loss: 1.2523 - accuracy: 0.5549 - val_loss: 1.3460 - val_accuracy: 0.5238
# Epoch 4/5
# 391/391 [==============================] - 1s 2ms/step - loss: 1.2430 - accuracy: 0.5582 - val_loss: 1.3312 - val_accuracy: 0.5278
# Epoch 5/5
# 391/391 [==============================] - 1s 2ms/step - loss: 1.2266 - accuracy: 0.5639 - val_loss: 1.3292 - val_accuracy: 0.5294
# Model 4
# Epoch 1/5
# 391/391 [==============================] - 1s 2ms/step - loss: 1.5061 - accuracy: 0.4665 - val_loss: 1.3631 - val_accuracy: 0.5113
# Epoch 2/5
# 391/391 [==============================] - 1s 2ms/step - loss: 1.2762 - accuracy: 0.5446 - val_loss: 1.3528 - val_accuracy: 0.5193
# Epoch 3/5
# 391/391 [==============================] - 1s 2ms/step - loss: 1.2583 - accuracy: 0.5531 - val_loss: 1.3413 - val_accuracy: 0.5209
# Epoch 4/5
# 391/391 [==============================] - 1s 2ms/step - loss: 1.2380 - accuracy: 0.5608 - val_loss: 1.3334 - val_accuracy: 0.5282
# Epoch 5/5
# 391/391 [==============================] - 1s 2ms/step - loss: 1.2290 - accuracy: 0.5651 - val_loss: 1.3367 - val_accuracy: 0.5258
# Model 5
# Epoch 1/5
# 391/391 [==============================] - 1s 2ms/step - loss: 1.5275 - accuracy: 0.4579 - val_loss: 1.3901 - val_accuracy: 0.5033
# Epoch 2/5
# 391/391 [==============================] - 1s 2ms/step - loss: 1.2982 - accuracy: 0.5402 - val_loss: 1.3612 - val_accuracy: 0.5128
# Epoch 3/5
# 391/391 [==============================] - 1s 2ms/step - loss: 1.2749 - accuracy: 0.5459 - val_loss: 1.3560 - val_accuracy: 0.5165
# Epoch 4/5
# 391/391 [==============================] - 1s 2ms/step - loss: 1.2609 - accuracy: 0.5522 - val_loss: 1.3542 - val_accuracy: 0.5173
# Epoch 5/5
# 391/391 [==============================] - 1s 2ms/step - loss: 1.2516 - accuracy: 0.5599 - val_loss: 1.3521 - val_accuracy: 0.5188
# Layer 3
# HICO LENGTH
# 4
# Model 0
# Epoch 1/5
# 391/391 [==============================] - 1s 2ms/step - loss: 1.4562 - accuracy: 0.4913 - val_loss: 1.3528 - val_accuracy: 0.5224
# Epoch 2/5
# 391/391 [==============================] - 1s 2ms/step - loss: 1.2268 - accuracy: 0.5645 - val_loss: 1.3306 - val_accuracy: 0.5266
# Epoch 3/5
# 391/391 [==============================] - 1s 2ms/step - loss: 1.2127 - accuracy: 0.5689 - val_loss: 1.3348 - val_accuracy: 0.5237
# Epoch 4/5
# 391/391 [==============================] - 1s 2ms/step - loss: 1.2052 - accuracy: 0.5703 - val_loss: 1.3391 - val_accuracy: 0.5251
# Epoch 5/5
# 391/391 [==============================] - 1s 2ms/step - loss: 1.2001 - accuracy: 0.5749 - val_loss: 1.3275 - val_accuracy: 0.5292
# Model 1
# Epoch 1/5
# 391/391 [==============================] - 1s 2ms/step - loss: 1.4741 - accuracy: 0.4913 - val_loss: 1.3630 - val_accuracy: 0.5241
# Epoch 2/5
# 391/391 [==============================] - 1s 2ms/step - loss: 1.2277 - accuracy: 0.5651 - val_loss: 1.3398 - val_accuracy: 0.5269
# Epoch 3/5
# 391/391 [==============================] - 1s 2ms/step - loss: 1.2237 - accuracy: 0.5675 - val_loss: 1.3452 - val_accuracy: 0.5232
# Epoch 4/5
# 391/391 [==============================] - 1s 2ms/step - loss: 1.2078 - accuracy: 0.5716 - val_loss: 1.3341 - val_accuracy: 0.5260
# Epoch 5/5
# 391/391 [==============================] - 1s 2ms/step - loss: 1.2052 - accuracy: 0.5741 - val_loss: 1.3321 - val_accuracy: 0.5286
# Model 2
# Epoch 1/5
# 391/391 [==============================] - 1s 2ms/step - loss: 1.4405 - accuracy: 0.4968 - val_loss: 1.3428 - val_accuracy: 0.5243
# Epoch 2/5
# 391/391 [==============================] - 1s 2ms/step - loss: 1.2114 - accuracy: 0.5714 - val_loss: 1.3323 - val_accuracy: 0.5279
# Epoch 3/5
# 391/391 [==============================] - 1s 2ms/step - loss: 1.2038 - accuracy: 0.5747 - val_loss: 1.3297 - val_accuracy: 0.5285
# Epoch 4/5
# 391/391 [==============================] - 1s 2ms/step - loss: 1.2048 - accuracy: 0.5752 - val_loss: 1.3265 - val_accuracy: 0.5284
# Epoch 5/5
# 391/391 [==============================] - 1s 2ms/step - loss: 1.1942 - accuracy: 0.5752 - val_loss: 1.3197 - val_accuracy: 0.5308
# Model 3
# Epoch 1/5
# 391/391 [==============================] - 1s 2ms/step - loss: 1.4023 - accuracy: 0.5130 - val_loss: 1.3495 - val_accuracy: 0.5247
# Epoch 2/5
# 391/391 [==============================] - 1s 2ms/step - loss: 1.2193 - accuracy: 0.5668 - val_loss: 1.3282 - val_accuracy: 0.5262
# Epoch 3/5
# 391/391 [==============================] - 1s 2ms/step - loss: 1.2138 - accuracy: 0.5687 - val_loss: 1.3262 - val_accuracy: 0.5328
# Epoch 4/5
# 391/391 [==============================] - 1s 2ms/step - loss: 1.1987 - accuracy: 0.5738 - val_loss: 1.3245 - val_accuracy: 0.5310
# Epoch 5/5
# 391/391 [==============================] - 1s 2ms/step - loss: 1.1890 - accuracy: 0.5808 - val_loss: 1.3271 - val_accuracy: 0.5301
# Layer 4
# HICO LENGTH
# 5
# Model 0
# Epoch 1/5
# 391/391 [==============================] - 1s 2ms/step - loss: 1.4368 - accuracy: 0.4950 - val_loss: 1.3292 - val_accuracy: 0.5257
# Epoch 2/5
# 391/391 [==============================] - 1s 2ms/step - loss: 1.1996 - accuracy: 0.5771 - val_loss: 1.3369 - val_accuracy: 0.5255
# Epoch 3/5
# 391/391 [==============================] - 1s 2ms/step - loss: 1.1973 - accuracy: 0.5773 - val_loss: 1.3254 - val_accuracy: 0.5287
# Epoch 4/5
# 391/391 [==============================] - 1s 2ms/step - loss: 1.1952 - accuracy: 0.5763 - val_loss: 1.3347 - val_accuracy: 0.5295
# Epoch 5/5
# 391/391 [==============================] - 1s 2ms/step - loss: 1.1890 - accuracy: 0.5797 - val_loss: 1.3253 - val_accuracy: 0.5303
# Model 1
# Epoch 1/5
# 391/391 [==============================] - 1s 2ms/step - loss: 1.4166 - accuracy: 0.5030 - val_loss: 1.3332 - val_accuracy: 0.5335
# Epoch 2/5
# 391/391 [==============================] - 1s 2ms/step - loss: 1.1999 - accuracy: 0.5739 - val_loss: 1.3351 - val_accuracy: 0.5284
# Epoch 3/5
# 391/391 [==============================] - 1s 2ms/step - loss: 1.1944 - accuracy: 0.5764 - val_loss: 1.3171 - val_accuracy: 0.5311
# Epoch 4/5
# 391/391 [==============================] - 1s 2ms/step - loss: 1.1860 - accuracy: 0.5784 - val_loss: 1.3186 - val_accuracy: 0.5332
# Epoch 5/5
# 391/391 [==============================] - 1s 2ms/step - loss: 1.1904 - accuracy: 0.5766 - val_loss: 1.3180 - val_accuracy: 0.5305

# %% [markdown]
# ## Model Evaluation

# %%
# Predict on test image
y_pred_list = []
for j in range(NUM_TN[0]):
  y_pred = np.argmax(hico_layers[0][j][0].predict(X_test_cropped_list[j]), axis=1)
  y_pred_list.append(y_pred)

for i in range(1, NUM_HICO_LAYER):
  for j in range(NUM_TN[i]):

    # Get test hidden representation from HiCo layer i-1
    X_test_input_hr = []
    X_test_input_ol = []
    for k in range(NUM_CONNECTION[i]):
      get_input = (K.function(hico_layers[i-1][hico_layers[i][j][1][k]][0].layers[0].input, hico_layers[i-1][hico_layers[i][j][1][k]][0].layers[1].output))
      X_test_input_hr.append(get_input(get_previous_layer_input(hico_layers, i-1, hico_layers[i-1][hico_layers[i][j][1][k]], X_test_cropped_list)))
    X_test_input_hr = np.array(X_test_input_hr)
    X_test_input_hr = np.concatenate(X_test_input_hr, axis=1)

    for k in range(NUM_CONNECTION[i]):
      get_input = (K.function(hico_layers[i-1][hico_layers[i][j][1][k]][0].layers[0].input, hico_layers[i-1][hico_layers[i][j][1][k]][0].layers[2].output))
      X_test_input_ol.append(get_input(get_previous_layer_input(hico_layers, i-1, hico_layers[i-1][hico_layers[i][j][1][k]], X_test_cropped_list)))
    X_test_input_ol = np.array(X_test_input_ol)
    X_test_input_ol = np.concatenate(X_test_input_ol, axis=1)

    X_test_input = np.concatenate((X_test_input_hr, X_test_input_ol), axis=1)

    y_pred = np.argmax(hico_layers[i][j][0].predict(X_test_input), axis=1)
    y_pred_list.append(y_pred)

# HiCo voting (mode)
y_pred_list = np.array(y_pred_list)
y_pred_list = np.transpose(y_pred_list, (1, 0))
y_pred_list = stats.mode(y_pred_list, axis=1)[0]
y_pred_list = np.squeeze(y_pred_list)

# %%
y_test = np.argmax(y_test_one_hot, axis=1)

# %%
accuracy = accuracy_score(y_test, y_pred_list)
accuracy
# Out:
# 0.5261
