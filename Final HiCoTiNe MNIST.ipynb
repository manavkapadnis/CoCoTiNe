# %% [markdown]
# # Final HiCoTiNe implementation on MNIST dataset.

# %%
from keras.models import Sequential
from keras.layers import Dense, Conv2D, Flatten
from keras.datasets import mnist
from keras.utils import to_categorical
import matplotlib.pyplot as plt
import numpy as np
import tensorflow as tf
import random
from scipy import stats
from sklearn.metrics import accuracy_score
from keras import backend as K
import cv2

# %%
SUB_REGION_SCALE = 14
MIN_SUB_REGION_SCALE = 12
MAX_SUB_REGION_SCALE = 16
NUM_HICO_LAYER = 5
NUM_TN = [10, 8, 6, 4, 2]
NUM_CONNECTION = [0, 5, 4, 3, 2]
ALPHA = 0.1

#dataset specific parameters
NUM_CLASS = 10

# %% [markdown]
# ## Data Pre-Processing

# %%
#load dataset
(X_train, y_train), (X_test, y_test) = mnist.load_data()

# %%
#Generate cropped train image
X_train_cropped_list = []
coordinate_list = []
scale_list = []
for i in range(NUM_TN[0]):
  X_train_cropped = []
  sub_region_scale = random.randint(MIN_SUB_REGION_SCALE, MAX_SUB_REGION_SCALE)
  x = random.randint(0, X_train.shape[1] - sub_region_scale)
  y = random.randint(0, X_train.shape[1] - sub_region_scale)
  coordinate = (x, y)
  for j in range(X_train.shape[0]):
    image_cropped = []
    for row in range(y, y + sub_region_scale):
      image_cropped_row = []
      for column in range(x, x + sub_region_scale):
        image_cropped_row.append(X_train[j][row][column])
      image_cropped.append(image_cropped_row)
    X_train_cropped.append(image_cropped)
  
  X_train_cropped = np.array(X_train_cropped)
  X_train_cropped_list.append(X_train_cropped)
  coordinate_list.append(coordinate)
  scale_list.append(sub_region_scale)

# %%
#Generate cropped test image
X_test_cropped_list = []
for i in range(NUM_TN[0]):
  X_test_cropped = []
  sub_region_scale = scale_list[i]
  x = coordinate_list[i][0]
  y = coordinate_list[i][1]
  for j in range(X_test.shape[0]):
    image_cropped = []
    for row in range(y, y + sub_region_scale):
      image_cropped_row = []
      for column in range(x, x + sub_region_scale):
        image_cropped_row.append(X_test[j][row][column])
      image_cropped.append(image_cropped_row)
    X_test_cropped.append(image_cropped)

  X_test_cropped = np.array(X_test_cropped)
  X_test_cropped_list.append(X_test_cropped)

# %%
#rescaling dataset
for i in range(NUM_TN[0]):
  temp = []
  for j in range (X_train.shape[0]):
    temp.append(cv2.resize(X_train_cropped_list[i][j], (SUB_REGION_SCALE, SUB_REGION_SCALE)))
  temp = np.array(temp)
  X_train_cropped_list[i] = temp

  temp = []
  for j in range(X_test.shape[0]):
    temp.append(cv2.resize(X_test_cropped_list[i][j], (SUB_REGION_SCALE, SUB_REGION_SCALE)))
  temp = np.array(temp)
  X_test_cropped_list[i] = temp

# %%
#normalizing dataset
for i in range(NUM_TN[0]):
  X_train_cropped_list[i] = X_train_cropped_list[i]/255
  X_test_cropped_list[i] = X_test_cropped_list[i]/255

# %%
#transform to vector
for i in range(NUM_TN[0]):
  X_train_cropped_list[i] = X_train_cropped_list[i].reshape((-1, SUB_REGION_SCALE*SUB_REGION_SCALE))
  X_test_cropped_list[i] = X_test_cropped_list[i].reshape((-1, SUB_REGION_SCALE*SUB_REGION_SCALE))

# %%
#one-hot encoding
y_train_one_hot = to_categorical(y_train)
y_test_one_hot = to_categorical(y_test)

# %% [markdown]
# ## HiCo Layer 1

# %%
#build ANN model
ensemble = []
for i in range(NUM_TN[0]):
  model = Sequential()
  model.add(Dense(64, activation='relu', input_dim=SUB_REGION_SCALE*SUB_REGION_SCALE))
  model.add(Dense(64, activation='relu'))
  model.add(Dense(NUM_CLASS, activation = 'softmax'))
  model.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])
  ensemble.append((model, i, coordinate_list[i], scale_list[i]))

# %%
#train model
history = []
for i in range(NUM_TN[0]):
  print('Model %d' %i)
  hist = ensemble[i][0].fit(X_train_cropped_list[i], y_train_one_hot, validation_data=(X_test_cropped_list[i], y_test_one_hot), epochs=5, batch_size=128)
  history.append(hist)
# Out:
# Model 0
# Epoch 1/5
# 469/469 [==============================] - 2s 3ms/step - loss: 1.0545 - accuracy: 0.6803 - val_loss: 0.4388 - val_accuracy: 0.8639
# Epoch 2/5
# 469/469 [==============================] - 1s 2ms/step - loss: 0.4093 - accuracy: 0.8744 - val_loss: 0.3627 - val_accuracy: 0.8860
# Epoch 3/5
# 469/469 [==============================] - 1s 2ms/step - loss: 0.3405 - accuracy: 0.8944 - val_loss: 0.3346 - val_accuracy: 0.8916
# Epoch 4/5
# 469/469 [==============================] - 1s 2ms/step - loss: 0.3062 - accuracy: 0.9026 - val_loss: 0.3032 - val_accuracy: 0.9022
# Epoch 5/5
# 469/469 [==============================] - 1s 2ms/step - loss: 0.
# Model 5
# Epoch 1/5
# 469/469 [==============================] - 2s 3ms/step - loss: 0.3244 - accuracy: 0.9169 - val_loss: 0.0604 - val_accuracy: 0.9808
# Epoch 2/5
# 469/469 [==============================] - 1s 2ms/step - loss: 0.0433 - accuracy: 0.9864 - val_loss: 0.0636 - val_accuracy: 0.9814
# Epoch 3/5
# 469/469 [==============================] - 1s 2ms/step - loss: 0.0383 - accuracy: 0.9889 - val_loss: 0.0641 - val_accuracy: 0.9807
# Epoch 4/5
# 469/469 [==============================] - 1s 2ms/step - loss: 0.0386 - accuracy: 0.9883 - val_loss: 0.0602 - val_accuracy: 0.9818
# Epoch 5/5
# 469/469 [==============================] - 1s 2ms/step - loss: 0.0376 - accuracy: 0.9887 - val_loss: 0.0548 - val_accuracy: 0.9830
# Layer 3
# HICO LENGTH
# 4
# Model 0
# Epoch 1/5
# 469/469 [==============================] - 2s 3ms/step - loss: 0.2883 - accuracy: 0.9274 - val_loss: 0.0579 - val_accuracy: 0.9830
# Epoch 2/5
# 469/469 [==============================] - 1s 2ms/step - loss: 0.0330 - accuracy: 0.9900 - val_loss: 0.0586 - val_accuracy: 0.9829
# Epoch 3/5
# 469/469 [==============================] - 1s 2ms/step - loss: 0.0330 - accuracy: 0.9900 - val_loss: 0.0621 - val_accuracy: 0.9831
# Epoch 4/5
# 469/469 [==============================] - 1s 2ms/step - loss: 0.0302 - accuracy: 0.9909 - val_loss: 0.0593 - val_accuracy: 0.9830
# Epoch 5/5
# 469/469 [==============================] - 1s 2ms/step - loss: 0.0293 - accuracy: 0.9906 - val_loss: 0.0593 - val_accuracy: 0.9828
# Model 1
# Epoch 1/5
# 469/469 [==============================] - 2s 3ms/step - loss: 0.2490 - accuracy: 0.9447 - val_loss: 0.0546 - val_accuracy: 0.9847
# Epoch 2/5
# 469/469 [==============================] - 1s 2ms/step - loss: 0.0333 - accuracy: 0.9904 - val_loss: 0.0554 - val_accuracy: 0.9837
# Epoch 3/5
# 469/469 [==============================] - 1s 2ms/step - loss: 0.0295 - accuracy: 0.9906 - val_loss: 0.0642 - val_accuracy: 0.9819
# Epoch 4/5
# 469/469 [==============================] - 1s 2ms/step - loss: 0.0293 - accuracy: 0.9909 - val_loss: 0.0551 - val_accuracy: 0.9845
# Epoch 5/5
# 469/469 [==============================] - 1s 2ms/step - loss: 0.0284 - accuracy: 0.9914 - val_loss: 0.0604 - val_accuracy: 0.9825
# Model 2
# Epoch 1/5
# 469/469 [==============================] - 2s 3ms/step - loss: 0.2519 - accuracy: 0.9325 - val_loss: 0.0649 - val_accuracy: 0.9822
# Epoch 2/5
# 469/469 [==============================] - 1s 2ms/step - loss: 0.0335 - accuracy: 0.9902 - val_loss: 0.0653 - val_accuracy: 0.9823
# Epoch 3/5
# 469/469 [==============================] - 1s 2ms/step - loss: 0.0309 - accuracy: 0.9909 - val_loss: 0.0595 - val_accuracy: 0.9822
# Epoch 4/5
# 469/469 [==============================] - 1s 2ms/step - loss: 0.0313 - accuracy: 0.9905 - val_loss: 0.0573 - val_accuracy: 0.9835
# Epoch 5/5
# 469/469 [==============================] - 1s 2ms/step - loss: 0.0328 - accuracy: 0.9904 - val_loss: 0.0591 - val_accuracy: 0.9835
# Model 3
# Epoch 1/5
# 469/469 [==============================] - 2s 3ms/step - loss: 0.2667 - accuracy: 0.9375 - val_loss: 0.0572 - val_accuracy: 0.9842
# Epoch 2/5
# 469/469 [==============================] - 1s 2ms/step - loss: 0.0373 - accuracy: 0.9893 - val_loss: 0.0581 - val_accuracy: 0.9838
# Epoch 3/5
# 469/469 [==============================] - 1s 2ms/step - loss: 0.0333 - accuracy: 0.9902 - val_loss: 0.0613 - val_accuracy: 0.9826
# Epoch 4/5
# 469/469 [==============================] - 1s 2ms/step - loss: 0.0319 - accuracy: 0.9900 - val_loss: 0.0586 - val_accuracy: 0.9829
# Epoch 5/5
# 469/469 [==============================] - 1s 2ms/step - loss: 0.0309 - accuracy: 0.9907 - val_loss: 0.0572 - val_accuracy: 0.9838
# Layer 4
# HICO LENGTH
# 5
# Model 0
# Epoch 1/5
# 469/469 [==============================] - 2s 3ms/step - loss: 0.4300 - accuracy: 0.8962 - val_loss: 0.0621 - val_accuracy: 0.9827
# Epoch 2/5
# 469/469 [==============================] - 1s 2ms/step - loss: 0.0317 - accuracy: 0.9910 - val_loss: 0.0596 - val_accuracy: 0.9839
# Epoch 3/5
# 469/469 [==============================] - 1s 2ms/step - loss: 0.0307 - accuracy: 0.9906 - val_loss: 0.0614 - val_accuracy: 0.9831
# Epoch 4/5
# 469/469 [==============================] - 1s 2ms/step - loss: 0.0298 - accuracy: 0.9913 - val_loss: 0.0601 - val_accuracy: 0.9823
# Epoch 5/5
# 469/469 [==============================] - 1s 2ms/step - loss: 0.0294 - accuracy: 0.9909 - val_loss: 0.0596 - val_accuracy: 0.9834
# Model 1
# Epoch 1/5
# 469/469 [==============================] - 2s 2ms/step - loss: 0.2980 - accuracy: 0.9333 - val_loss: 0.0623 - val_accuracy: 0.9828
# Epoch 2/5
# 469/469 [==============================] - 1s 2ms/step - loss: 0.0307 - accuracy: 0.9909 - val_loss: 0.0605 - val_accuracy: 0.9836
# Epoch 3/5
# 469/469 [==============================] - 1s 2ms/step - loss: 0.0323 - accuracy: 0.9908 - val_loss: 0.0602 - val_accuracy: 0.9835
# Epoch 4/5
# 469/469 [==============================] - 1s 2ms/step - loss: 0.0274 - accuracy: 0.9922 - val_loss: 0.0618 - val_accuracy: 0.9828
# Epoch 5/5
# 469/469 [==============================] - 1s 2ms/step - loss: 0.0292 - accuracy: 0.9909 - val_loss: 0.0618 - val_accuracy: 0.9826

# %% [markdown]
# ## Model Evaluation

# %%
# Predict on test image
y_pred_list = []
for j in range(NUM_TN[0]):
  y_pred = hico_layers[0][j][0].predict(X_test_cropped_list[j])
  y_pred = y_pred * ((1 + ALPHA) - (NUM_TN[0] / max(NUM_TN)))
  y_pred_list.append(y_pred)

for i in range(1, NUM_HICO_LAYER):
  for j in range(NUM_TN[i]):

    # Get test hidden representation from HiCo layer i-1
    X_test_input = []
    for k in range(NUM_CONNECTION[i]):
      get_input = (K.function(hico_layers[i-1][hico_layers[i][j][1][k]][0].layers[0].input, hico_layers[i-1][hico_layers[i][j][1][k]][0].layers[1].output))
      X_test_input.append(get_input(get_previous_layer_input(hico_layers, i-1, hico_layers[i-1][hico_layers[i][j][1][k]], X_test_cropped_list)))
    X_test_input = np.array(X_test_input)
    X_test_input = np.concatenate(X_test_input, axis=1)
    y_pred = hico_layers[i][j][0].predict(X_test_input)
    y_pred = y_pred * ((1 + ALPHA) - (NUM_TN[i] / max(NUM_TN)))
    y_pred_list.append(y_pred)


# HiCo voting
y_pred_list = np.array(y_pred_list)
y_pred_list = np.transpose(y_pred_list, (1, 0, 2))
y_pred_list = np.argmax(np.sum(y_pred_list, axis=1), axis=1)

# %%
accuracy = accuracy_score(y_test, y_pred_list)
accuracy
# Out:
# 0.9847
