# %% [markdown]
# # Variants-Experiment 1.5
#
# ## Summed hidden representations and summed output logits.
# ## Mode. Compute classifications of all tiny networks, in all HiCo layers, and take the mode as the final classification.

# %%
from keras.models import Sequential
from keras.layers import Dense, Conv2D, Flatten
from keras.datasets import mnist
from keras.utils import to_categorical
import matplotlib.pyplot as plt
import numpy as np
import tensorflow as tf
import random
from scipy import stats
from sklearn.metrics import accuracy_score
from keras import backend as K

import os
import pickle
from google.colab import drive
drive.mount('/content/drive/')
# Out:
# Mounted at /content/drive/

# %%
SUB_REGION_SCALE = 14
NUM_HICO_LAYER = 5
NUM_TN = [10, 8, 6, 4, 2]
NUM_CONNECTION = [0, 5, 4, 3, 2]

#dataset specific parameters
NUM_CLASS = 10

# %% [markdown]
# ## Data Pre-Processing

# %%
with open('/content/drive/My Drive/fyp/MNIST.pickle', 'rb') as f:
    X_train_cropped_list, y_train_one_hot, X_test_cropped_list, y_test_one_hot, coordinate_list, scale_list = pickle.load(f)

# %% [markdown]
# ## HiCo Layer 1

# %%
#build ANN model
ensemble = []
for i in range(NUM_TN[0]):
  model = Sequential()
  model.add(Dense(64, activation='relu', input_dim=SUB_REGION_SCALE*SUB_REGION_SCALE))
  model.add(Dense(64, activation='relu'))
  model.add(Dense(NUM_CLASS, activation = 'softmax'))
  model.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])
  ensemble.append((model, i, coordinate_list[i], scale_list[i]))

# %%
for i in range(NUM_TN[0]):
  ensemble[i][0].load_weights('/content/drive/My Drive/fyp/MNIST_' + str(i) + '.h5')

# %%
hico_layers = []
hico_layers.append(ensemble)

# %%
del hico_layers[1:]

# %% [markdown]
# ## HiCo Layer 2+

# %%
# Function to get input of layer i-1
def get_previous_layer_input(hico_layers, layer, tn, train_image):
  input_hr = []
  input_ol = []
    
  if layer == 0:
    previous_layer_input = train_image[tn[1]]
    return previous_layer_input

  elif layer > 0:
    for i in range(NUM_CONNECTION[layer]):
      get_input = (K.function(hico_layers[layer-1][tn[1][i]][0].layers[0].input, hico_layers[layer-1][tn[1][i]][0].layers[1].output))
      input_hr.append(get_input(get_previous_layer_input(hico_layers, layer-1, hico_layers[layer-1][tn[1][i]], train_image)))
      
    input_hr = np.array(input_hr)
    input_hr = np.sum(input_hr, axis=0)

    for i in range(NUM_CONNECTION[layer]):
      get_input = (K.function(hico_layers[layer-1][tn[1][i]][0].layers[0].input, hico_layers[layer-1][tn[1][i]][0].layers[2].output))
      input_ol.append(get_input(get_previous_layer_input(hico_layers, layer-1, hico_layers[layer-1][tn[1][i]], train_image)))

    input_ol = np.array(input_ol)
    input_ol = np.sum(input_ol, axis=0)

    input = np.concatenate((input_hr, input_ol), axis=1)
    
    previous_layer_input = input
    return previous_layer_input

# %%
for i in range(1, NUM_HICO_LAYER):
  print('Layer %d' %i)
  ensemble = []
  X_train_input_list = []
  X_test_input_list = []

  for j in range(NUM_TN[i]):
    # Build model of HiCo layer i
    connection = tuple(random.sample(range(len(hico_layers[i-1])), k=NUM_CONNECTION[i]))
    model = Sequential()
    model.add(Dense(64, activation='relu', input_dim=64+NUM_CLASS))
    model.add(Dense(64, activation='relu'))
    model.add(Dense(NUM_CLASS, activation = 'softmax'))
    model.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])
    ensemble.append((model, connection))
  hico_layers.append(ensemble)
  print('HICO LENGTH')
  print(len(hico_layers))

  for j in range(NUM_TN[i]):
    # Get train hidden representation from HiCo layer i-1
    X_train_input_hr = []
    X_train_input_ol = []
    for k in range(NUM_CONNECTION[i]):
      get_input = (K.function(hico_layers[i-1][hico_layers[i][j][1][k]][0].layers[0].input, hico_layers[i-1][hico_layers[i][j][1][k]][0].layers[1].output))
      X_train_input_hr.append(get_input(get_previous_layer_input(hico_layers, i-1, hico_layers[i-1][hico_layers[i][j][1][k]], X_train_cropped_list)))
    X_train_input_hr = np.array(X_train_input_hr)
    X_train_input_hr = np.sum(X_train_input_hr, axis=0)

    for k in range(NUM_CONNECTION[i]):
      get_input = (K.function(hico_layers[i-1][hico_layers[i][j][1][k]][0].layers[0].input, hico_layers[i-1][hico_layers[i][j][1][k]][0].layers[2].output))
      X_train_input_ol.append(get_input(get_previous_layer_input(hico_layers, i-1, hico_layers[i-1][hico_layers[i][j][1][k]], X_train_cropped_list)))
    X_train_input_ol = np.array(X_train_input_ol)
    X_train_input_ol = np.sum(X_train_input_ol, axis=0)

    X_train_input = np.concatenate((X_train_input_hr, X_train_input_ol), axis=1)
    X_train_input_list.append(X_train_input)

    # Get test hidden representation from HiCo layer i-1
    X_test_input_hr = []
    X_test_input_ol = []
    for k in range(NUM_CONNECTION[i]):
      get_input = (K.function(hico_layers[i-1][hico_layers[i][j][1][k]][0].layers[0].input, hico_layers[i-1][hico_layers[i][j][1][k]][0].layers[1].output))
      X_test_input_hr.append(get_input(get_previous_layer_input(hico_layers, i-1, hico_layers[i-1][hico_layers[i][j][1][k]], X_test_cropped_list)))
    X_test_input_hr = np.array(X_test_input_hr)
    X_test_input_hr = np.sum(X_test_input_hr, axis=0)

    for k in range(NUM_CONNECTION[i]):
      get_input = (K.function(hico_layers[i-1][hico_layers[i][j][1][k]][0].layers[0].input, hico_layers[i-1][hico_layers[i][j][1][k]][0].layers[2].output))
      X_test_input_ol.append(get_input(get_previous_layer_input(hico_layers, i-1, hico_layers[i-1][hico_layers[i][j][1][k]], X_test_cropped_list)))
    X_test_input_ol = np.array(X_test_input_ol)
    X_test_input_ol = np.sum(X_test_input_ol, axis=0)

    X_test_input = np.concatenate((X_test_input_hr, X_test_input_ol), axis=1)
    X_test_input_list.append(X_test_input)

  #train model of HiCo layer i
  for j in range(NUM_TN[i]):
    print('Model %d' %j)
    hico_layers[i][j][0].fit(X_train_input_list[j], y_train_one_hot, validation_data=(X_test_input_list[j], y_test_one_hot), epochs=5, batch_size=128)
# Out:
# Layer 1
# HICO LENGTH
# 2
# Model 0
# Epoch 1/5
# 469/469 [==============================] - 2s 3ms/step - loss: 0.7177 - accuracy: 0.8069 - val_loss: 0.1380 - val_accuracy: 0.9561
# Epoch 2/5
# 469/469 [==============================] - 1s 2ms/step - loss: 0.1349 - accuracy: 0.9588 - val_loss: 0.1318 - val_accuracy: 0.9597
# Epoch 3/5
# 469/469 [==============================] - 1s 2ms/step - loss: 0.1177 - accuracy: 0.9637 - val_loss: 0.1162 - val_accuracy: 0.9634
# Epoch 4/5
# 469/469 [==============================] - 1s 2ms/step - loss: 0.1081 - accuracy: 0.9664 - val_loss: 0.1123 - val_accuracy: 0.9647
# Epoch 5/5
# 469/469 [==============================] - 1s 2ms/step - loss: 0.1010 - accuracy: 0.9685 - val_loss: 0.1095 - val_accuracy: 0.9659
# Model 1
# Epoch 1/5
# 469/469 [==============================] - 1s 2ms/step - loss: 0.8114 - accuracy: 0.7883 - val_loss: 0.1280 - val_accuracy: 0.9625
# Epoch 2/5
# 469/469 [==============================] - 1s 2ms/step - loss: 0.1219 - accuracy: 0.9638 - val_loss: 0.1073 - val_accuracy: 0.9686
# Epoch 3/5
# 469/469 [==============================] - 1s 2ms/step - loss: 0.1017 - accuracy: 0.9697 - val_loss: 0.0986 - val_accuracy: 0.9701
# Epoch 4/5
# 469/469 [==============================] - 1s 2ms/step - loss: 0.0903 - accuracy: 0.9720 - val_loss: 0.0899 - val_accuracy: 0.9724
# Epoch 5/5
# 469/469 [==============================] - 1s 2ms/step - loss: 0.0854 - accuracy: 0.9732 - val_loss: 0.0967 - val_accuracy: 0.9713
# Model 2
# Epoch 1/5
# 469/469 [==============================] - 1s 2ms/step - loss: 0.9397 - accuracy: 0.7904 - val_loss: 0.1143 - val_accuracy: 0.9670
# Epoch 2/5
# 469/469 [==============================] - 1s 2ms/step - loss: 0.1098 - accuracy: 0.9665 - val_loss: 0.1013 - val_accuracy: 0.9676
# Epoch 3/5
# 469/469 [==============================] - 1s 2ms/step - loss: 0.0974 - accuracy: 0.9699 - val_loss: 0.1088 - val_accuracy: 0.9679
# Epoch 4/5
# 469/469 [==============================] - 1s 2ms/step - loss: 0.0890 - accuracy: 0.9723 - val_loss: 0.0915 - val_accuracy: 0.9739
# Epoch 5/5
# 469/469 [==============================] - 1s 2ms/step - loss: 0.0832 - accuracy: 0.9748 - val_loss: 0.0883 - val_accuracy: 0.9738
# Model 3
# Epoch 1/5
# 469/469 [==============================] - 1s 2ms/step - loss: 0.7238 - accuracy: 0.8120 - val_loss: 0.1331 - val_accuracy: 0.9598
# Epoch 2/5
# 469/469 [==============================] - 1s 2ms/step - loss: 0.1067 - accuracy: 0.9687 - val_loss: 0.1012 - val_accuracy: 0.9685
# Epoch 3/5
# 469/469 [==============================] - 1s 2ms/step - loss: 0.0919 - accuracy: 0.9731 - val_loss: 0.0974 - val_accuracy: 0.9687
# Epoch 4/5
# 469/469 [==============================] - 1s 2ms/step - loss: 0.0906 - accuracy: 0.9730 - val_loss: 0.0996 - val_accuracy: 0.9704
# Epoch 5/5
# 469/469 [==============================] - 1s 2ms/step - loss: 0.0830 - accuracy: 0.9748 - val_loss: 0.0885 - val_accuracy: 0.9743
# Model 4
# Epoch 1/5
# 469/469 [==============================] - 1s 2ms/step - loss: 0.8234 - accuracy: 0.7949 - val_loss: 0.0998 - val_accuracy: 0.9724
# Epoch 2/5
# 469/469 [==============================] - 1s 2ms/step - loss: 0.0992 - accuracy: 0.9712 - val_loss: 0.0888 - val_accuracy: 0.9753
# Epoch 3/5
# 469/469 [==============================] - 1s 2ms/step - loss: 0.0889 - accuracy: 0.9734 - val_loss: 0.0870 - val_accuracy: 0.9746
# Epoch 4/5
# 469/469 [==============================] - 1s 2ms/step - loss: 0.0795 - accuracy: 0.9766 - val_loss: 0.0802 - val_accuracy: 0.9768
# Epoch 5/5
# 469/469 [==============================] - 1s 2ms/step - loss: 0.0731 - accuracy: 0.9780 - val_loss: 0.0801 - val_accuracy: 0.9765
# Model 5
# Epoch 1/5
# 469/469 [==============================] - 1s 2ms/step - loss: 0.7844 - accuracy: 0.7808 - val_loss: 0.1373 - val_accuracy: 0.9585
# Epoch 2/5
# 469/469 [==============================] - 1s 2ms/step - loss: 0.1251 - accuracy: 0.9631 - val_loss: 0.1346 - val_accuracy: 0.9608
# Epoch 3/5
# 469/469 [==============================] - 1s 2ms/step - loss: 0.1117 - accuracy: 0.9667 - val_loss: 0.1199 - val_accuracy: 0.9636
# Epoch 4/5
# 469/469 [==============================] - 1s 2ms/step - loss: 0.0972 - accuracy: 0.9709 - val_loss: 0.1031 - val_accuracy: 0.9686
# Epoch 5/5
# 469/469 [==============================] - 1s 2ms/step - loss: 0.0934 - accuracy: 0.9712 - val_loss: 0.1106 - val_accuracy: 0.9667
# Model 6
# Epoch 1/5
# 469/469 [==============================] - 1s 2ms/step - loss: 0.8276 - accuracy: 0.7825 - val_loss: 0.1126 - val_accuracy: 0.9665
# Epoch 2/5
# 469/469 [==============================] - 1s 2ms/step - loss: 0.1011 - accuracy: 0.9705 - val_loss: 0.0950 - val_accuracy: 0.9725
# Epoch 3/5
# 469/469 [==============================] - 1s 2ms/step - loss: 0.0852 - accuracy: 0.9740 - val_loss: 0.0917 - val_accuracy: 0.9717
# Epoch 4/5
# 469/469 [==============================] - 1s 2ms/step - loss: 0.0822 - accuracy: 0.9762 - val_loss: 0.0853 - val_accuracy: 0.9738
# Epoch 5/5
# 469/469 [==============================] - 1s 2ms/step - loss: 0.0748 - accuracy: 0.9772 - val_loss: 0.0814 - val_accuracy: 0.9753
# Model 7
# Epoch 1/5
# 469/469 [==============================] - 1s 2ms/step - loss: 0.7540 - accuracy: 0.7948 - val_loss: 0.1040 - val_accuracy: 0.9696
# Epoch 2/5
# 469/469 [==============================] - 1s 2ms/step - loss: 0.1006 - accuracy: 0.9696 - val_loss: 0.0910 - val_accuracy: 0.9732
# Epoch 3/5
# 469/469 [==============================] - 1s 2ms/step - loss: 0.0867 - accuracy: 0.9736 - val_loss: 0.0859 - val_accuracy: 0.9750
# Epoch 4/5
# 469/469 [==============================] - 1s 2ms/step - loss: 0.0782 - accuracy: 0.9759 - val_loss: 0.0817 - val_accuracy: 0.9764
# Epoch 5/5
# 469/469 [==============================] - 1s 2ms/step - loss: 0.0743 - accuracy: 0.9773 - val_loss: 0.0736 - val_accuracy: 0.9784
# Layer 2
# HICO LENGTH
# 3
# Model 0
# Epoch 1/5
# 469/469 [==============================] - 1s 2ms/step - loss: 1.0838 - accuracy: 0.8265 - val_loss: 0.0830 - val_accuracy: 0.9768
# Epoch 2/5
# 469/469 [==============================] - 1s 2ms/step - loss: 0.0775 - accuracy: 0.9777 - val_loss: 0.0813 - val_accuracy: 0.9773
# Epoch 3/5
# 469/469 [==============================] - 1s 2ms/step - loss: 0.0716 - accuracy: 0.9791 - val_loss: 0.0785 - val_accuracy: 0.9773
# Epoch 4/5
# 469/469 [==============================] - 1s 2ms/step - loss: 0.0662 - accuracy: 0.9803 - val_loss: 0.0753 - val_accuracy: 0.9789
# Epoch 5/5
# 469/469 [==============================] - 1s 2ms/step - loss: 0.0635 - accuracy: 0.9815 - val_loss: 0.0722 - val_accuracy: 0.9793
# Model 1
# Epoch 1/5
# 469/469 [==============================] - 1s 2ms/step - loss: 0.4405 - accuracy: 0.8838 - val_loss: 0.0830 - val_accuracy: 0.9761
# Epoch 2/5
# 469/469 [==============================] - 1s 2ms/step - loss: 0.0752 - accuracy: 0.9784 - val_loss: 0.0773 - val_accuracy: 0.9771
# Epoch 3/5
# 469/469 [==============================] - 1s 2ms/step - loss: 0.0670 - accuracy: 0.9802 - val_loss: 0.0771 - val_accuracy: 0.9766
# Epoch 4/5
# 469/469 [==============================] - 1s 2ms/step - loss: 0.0657 - accuracy: 0.9807 - val_loss: 0.0701 - val_accuracy: 0.9788
# Epoch 5/5
# 469/469 [==============================] - 1s 2ms/step - loss: 0.0608 - accuracy: 0.9818 - val_loss: 0.0734 - val_accuracy: 0.9774
# Model 2
# Epoch 1/5
# 469/469 [==============================] - 1s 2ms/step - loss: 1.0093 - accuracy: 0.8201 - val_loss: 0.0901 - val_accuracy: 0.9748
# Epoch 2/5
# 469/469 [==============================] - 1s 2ms/step - loss: 0.0788 - accuracy: 0.9782 - val_loss: 0.0802 - val_accuracy: 0.9771
# Epoch 3/5
# 469/469 [==============================] - 1s 2ms/step - loss: 0.0719 - accuracy: 0.9797 - val_loss: 0.0864 - val_accuracy: 0.9755
# Epoch 4/5
# 469/469 [==============================] - 1s 2ms/step - loss: 0.0674 - accuracy: 0.9809 - val_loss: 0.0831 - val_accuracy: 0.9770
# Epoch 5/5
# 469/469 [==============================] - 1s 2ms/step - loss: 0.0667 - accuracy: 0.9799 - val_loss: 0.0823 - val_accuracy: 0.9766
# Model 3
# Epoch 1/5
# 469/469 [==============================] - 1s 2ms/step - loss: 0.7981 - accuracy: 0.8370 - val_loss: 0.0765 - val_accuracy: 0.9779
# Epoch 2/5
# 469/469 [==============================] - 1s 2ms/step - loss: 0.0708 - accuracy: 0.9797 - val_loss: 0.0748 - val_accuracy: 0.9789
# Epoch 3/5
# 469/469 [==============================] - 1s 2ms/step - loss: 0.0667 - accuracy: 0.9801 - val_loss: 0.0734 - val_accuracy: 0.9797
# Epoch 4/5
# 469/469 [==============================] - 1s 2ms/step - loss: 0.0650 - accuracy: 0.9809 - val_loss: 0.0689 - val_accuracy: 0.9802
# Epoch 5/5
# 469/469 [==============================] - 1s 2ms/step - loss: 0.0618 - accuracy: 0.9821 - val_loss: 0.0688 - val_accuracy: 0.9813
# Model 4
# Epoch 1/5
# 469/469 [==============================] - 1s 2ms/step - loss: 0.3925 - accuracy: 0.8852 - val_loss: 0.0776 - val_accuracy: 0.9775
# Epoch 2/5
# 469/469 [==============================] - 1s 2ms/step - loss: 0.0711 - accuracy: 0.9802 - val_loss: 0.0736 - val_accuracy: 0.9781
# Epoch 3/5
# 469/469 [==============================] - 1s 2ms/step - loss: 0.0599 - accuracy: 0.9830 - val_loss: 0.0675 - val_accuracy: 0.9795
# Epoch 4/5
# 469/469 [==============================] - 1s 2ms/step - loss: 0.0615 - accuracy: 0.9821 - val_loss: 0.0658 - val_accuracy: 0.9810
# Epoch 5/5
# 469/469 [==============================] - 1s 2ms/step - loss: 0.0595 - accuracy: 0.9828 - val_loss: 0.0665 - val_accuracy: 0.9803
# Model 5
# Epoch 1/5
# 469/469 [==============================] - 1s 2ms/step - loss: 0.4487 - accuracy: 0.8902 - val_loss: 0.0848 - val_accuracy: 0.9761
# Epoch 2/5
# 469/469 [==============================] - 1s 2ms/step - loss: 0.0739 - accuracy: 0.9793 - val_loss: 0.0757 - val_accuracy: 0.9777
# Epoch 3/5
# 469/469 [==============================] - 1s 2ms/step - loss: 0.0644 - accuracy: 0.9821 - val_loss: 0.0742 - val_accuracy: 0.9775
# Epoch 4/5
# 469/469 [==============================] - 1s 2ms/step - loss: 0.0613 - accuracy: 0.9821 - val_loss: 0.0702 - val_accuracy: 0.9788
# Epoch 5/5
# 469/469 [==============================] - 1s 2ms/step - loss: 0.0602 - accuracy: 0.9818 - val_loss: 0.0771 - val_accuracy: 0.9773
# Layer 3
# HICO LENGTH
# 4
# Model 0
# Epoch 1/5
# 469/469 [==============================] - 1s 2ms/step - loss: 0.4457 - accuracy: 0.8971 - val_loss: 0.0707 - val_accuracy: 0.9809
# Epoch 2/5
# 469/469 [==============================] - 1s 2ms/step - loss: 0.0592 - accuracy: 0.9837 - val_loss: 0.0711 - val_accuracy: 0.9809
# Epoch 3/5
# 469/469 [==============================] - 1s 2ms/step - loss: 0.0576 - accuracy: 0.9832 - val_loss: 0.0645 - val_accuracy: 0.9813
# Epoch 4/5
# 469/469 [==============================] - 1s 2ms/step - loss: 0.0516 - accuracy: 0.9851 - val_loss: 0.0636 - val_accuracy: 0.9818
# Epoch 5/5
# 469/469 [==============================] - 1s 2ms/step - loss: 0.0546 - accuracy: 0.9841 - val_loss: 0.0656 - val_accuracy: 0.9816
# Model 1
# Epoch 1/5
# 469/469 [==============================] - 2s 2ms/step - loss: 0.7052 - accuracy: 0.8594 - val_loss: 0.0792 - val_accuracy: 0.9787
# Epoch 2/5
# 469/469 [==============================] - 1s 2ms/step - loss: 0.0619 - accuracy: 0.9827 - val_loss: 0.0720 - val_accuracy: 0.9797
# Epoch 3/5
# 469/469 [==============================] - 1s 2ms/step - loss: 0.0588 - accuracy: 0.9834 - val_loss: 0.0655 - val_accuracy: 0.9823
# Epoch 4/5
# 469/469 [==============================] - 1s 2ms/step - loss: 0.0587 - accuracy: 0.9835 - val_loss: 0.0673 - val_accuracy: 0.9814
# Epoch 5/5
# 469/469 [==============================] - 1s 2ms/step - loss: 0.0550 - accuracy: 0.9841 - val_loss: 0.0670 - val_accuracy: 0.9818
# Model 2
# Epoch 1/5
# 469/469 [==============================] - 1s 2ms/step - loss: 0.7050 - accuracy: 0.8674 - val_loss: 0.0708 - val_accuracy: 0.9805
# Epoch 2/5
# 469/469 [==============================] - 1s 2ms/step - loss: 0.0591 - accuracy: 0.9833 - val_loss: 0.0667 - val_accuracy: 0.9812
# Epoch 3/5
# 469/469 [==============================] - 1s 2ms/step - loss: 0.0592 - accuracy: 0.9839 - val_loss: 0.0654 - val_accuracy: 0.9811
# Epoch 4/5
# 469/469 [==============================] - 1s 2ms/step - loss: 0.0571 - accuracy: 0.9838 - val_loss: 0.0686 - val_accuracy: 0.9800
# Epoch 5/5
# 469/469 [==============================] - 1s 2ms/step - loss: 0.0550 - accuracy: 0.9848 - val_loss: 0.0658 - val_accuracy: 0.9806
# Model 3
# Epoch 1/5
# 469/469 [==============================] - 1s 2ms/step - loss: 0.6298 - accuracy: 0.8788 - val_loss: 0.0683 - val_accuracy: 0.9815
# Epoch 2/5
# 469/469 [==============================] - 1s 2ms/step - loss: 0.0630 - accuracy: 0.9820 - val_loss: 0.0681 - val_accuracy: 0.9807
# Epoch 3/5
# 469/469 [==============================] - 1s 2ms/step - loss: 0.0560 - accuracy: 0.9837 - val_loss: 0.0614 - val_accuracy: 0.9821
# Epoch 4/5
# 469/469 [==============================] - 1s 2ms/step - loss: 0.0529 - accuracy: 0.9843 - val_loss: 0.0654 - val_accuracy: 0.9808
# Epoch 5/5
# 469/469 [==============================] - 1s 2ms/step - loss: 0.0556 - accuracy: 0.9837 - val_loss: 0.0634 - val_accuracy: 0.9806
# Layer 4
# HICO LENGTH
# 5
# Model 0
# Epoch 1/5
# 469/469 [==============================] - 1s 2ms/step - loss: 0.3723 - accuracy: 0.9153 - val_loss: 0.0740 - val_accuracy: 0.9800
# Epoch 2/5
# 469/469 [==============================] - 1s 2ms/step - loss: 0.0547 - accuracy: 0.9846 - val_loss: 0.0656 - val_accuracy: 0.9816
# Epoch 3/5
# 469/469 [==============================] - 1s 2ms/step - loss: 0.0548 - accuracy: 0.9845 - val_loss: 0.0668 - val_accuracy: 0.9820
# Epoch 4/5
# 469/469 [==============================] - 1s 2ms/step - loss: 0.0526 - accuracy: 0.9851 - val_loss: 0.0672 - val_accuracy: 0.9810
# Epoch 5/5
# 469/469 [==============================] - 1s 2ms/step - loss: 0.0505 - accuracy: 0.9855 - val_loss: 0.0668 - val_accuracy: 0.9820
# Model 1
# Epoch 1/5
# 469/469 [==============================] - 1s 2ms/step - loss: 0.5177 - accuracy: 0.8872 - val_loss: 0.0715 - val_accuracy: 0.9809
# Epoch 2/5
# 469/469 [==============================] - 1s 2ms/step - loss: 0.0528 - accuracy: 0.9851 - val_loss: 0.0692 - val_accuracy: 0.9804
# Epoch 3/5
# 469/469 [==============================] - 1s 2ms/step - loss: 0.0524 - accuracy: 0.9854 - val_loss: 0.0698 - val_accuracy: 0.9801
# Epoch 4/5
# 469/469 [==============================] - 1s 2ms/step - loss: 0.0551 - accuracy: 0.9842 - val_loss: 0.0694 - val_accuracy: 0.9811
# Epoch 5/5
# 469/469 [==============================] - 1s 2ms/step - loss: 0.0513 - accuracy: 0.9852 - val_loss: 0.0654 - val_accuracy: 0.9817

# %% [markdown]
# ## Model Evaluation

# %%
# Predict on test image
y_pred_list = []
for j in range(NUM_TN[0]):
  y_pred = np.argmax(hico_layers[0][j][0].predict(X_test_cropped_list[j]), axis=1)
  y_pred_list.append(y_pred)

for i in range(1, NUM_HICO_LAYER):
  for j in range(NUM_TN[i]):

    # Get test hidden representation from HiCo layer i-1
    X_test_input_hr = []
    X_test_input_ol = []
    for k in range(NUM_CONNECTION[i]):
      get_input = (K.function(hico_layers[i-1][hico_layers[i][j][1][k]][0].layers[0].input, hico_layers[i-1][hico_layers[i][j][1][k]][0].layers[1].output))
      X_test_input_hr.append(get_input(get_previous_layer_input(hico_layers, i-1, hico_layers[i-1][hico_layers[i][j][1][k]], X_test_cropped_list)))
    X_test_input_hr = np.array(X_test_input_hr)
    X_test_input_hr = np.sum(X_test_input_hr, axis=0)

    for k in range(NUM_CONNECTION[i]):
      get_input = (K.function(hico_layers[i-1][hico_layers[i][j][1][k]][0].layers[0].input, hico_layers[i-1][hico_layers[i][j][1][k]][0].layers[2].output))
      X_test_input_ol.append(get_input(get_previous_layer_input(hico_layers, i-1, hico_layers[i-1][hico_layers[i][j][1][k]], X_test_cropped_list)))
    X_test_input_ol = np.array(X_test_input_ol)
    X_test_input_ol = np.sum(X_test_input_ol, axis=0)

    X_test_input = np.concatenate((X_test_input_hr, X_test_input_ol), axis=1)

    y_pred = np.argmax(hico_layers[i][j][0].predict(X_test_input), axis=1)
    y_pred_list.append(y_pred)

# HiCo voting (mode)
y_pred_list = np.array(y_pred_list)
y_pred_list = np.transpose(y_pred_list, (1, 0))
y_pred_list = stats.mode(y_pred_list, axis=1)[0]
y_pred_list = np.squeeze(y_pred_list)

# %%
y_test = np.argmax(y_test_one_hot, axis=1)

# %%
accuracy = accuracy_score(y_test, y_pred_list)
accuracy
# Out:
# 0.9809
