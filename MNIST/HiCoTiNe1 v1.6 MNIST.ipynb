# %% [markdown]
# # Variants-Experiment 1.6
#
# ## Summed hidden representations and concatenated output logits.
# ## Mode. Compute classifications of all tiny networks, in all HiCo layers, and take the mode as the final classification.

# %%
from keras.models import Sequential
from keras.layers import Dense, Conv2D, Flatten
from keras.datasets import mnist
from keras.utils import to_categorical
import matplotlib.pyplot as plt
import numpy as np
import tensorflow as tf
import random
from scipy import stats
from sklearn.metrics import accuracy_score
from keras import backend as K

import os
import pickle
from google.colab import drive
drive.mount('/content/drive/')
# Out:
# Mounted at /content/drive/

# %%
SUB_REGION_SCALE = 14
NUM_HICO_LAYER = 5
NUM_TN = [10, 8, 6, 4, 2]
NUM_CONNECTION = [0, 5, 4, 3, 2]

#dataset specific parameters
NUM_CLASS = 10

# %% [markdown]
# ## Data Pre-Processing

# %%
with open('/content/drive/My Drive/fyp/MNIST.pickle', 'rb') as f:
    X_train_cropped_list, y_train_one_hot, X_test_cropped_list, y_test_one_hot, coordinate_list, scale_list = pickle.load(f)

# %% [markdown]
# ## HiCo Layer 1

# %%
#build ANN model
ensemble = []
for i in range(NUM_TN[0]):
  model = Sequential()
  model.add(Dense(64, activation='relu', input_dim=SUB_REGION_SCALE*SUB_REGION_SCALE))
  model.add(Dense(64, activation='relu'))
  model.add(Dense(NUM_CLASS, activation = 'softmax'))
  model.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])
  ensemble.append((model, i, coordinate_list[i], scale_list[i]))

# %%
for i in range(NUM_TN[0]):
  ensemble[i][0].load_weights('/content/drive/My Drive/fyp/MNIST_' + str(i) + '.h5')

# %%
hico_layers = []
hico_layers.append(ensemble)

# %%
del hico_layers[1:]

# %% [markdown]
# ## HiCo Layer 2+

# %%
# Function to get input of layer i-1
def get_previous_layer_input(hico_layers, layer, tn, train_image):
  input_hr = []
  input_ol = []
    
  if layer == 0:
    previous_layer_input = train_image[tn[1]]
    return previous_layer_input

  elif layer > 0:
    for i in range(NUM_CONNECTION[layer]):
      get_input = (K.function(hico_layers[layer-1][tn[1][i]][0].layers[0].input, hico_layers[layer-1][tn[1][i]][0].layers[1].output))
      input_hr.append(get_input(get_previous_layer_input(hico_layers, layer-1, hico_layers[layer-1][tn[1][i]], train_image)))
      
    input_hr = np.array(input_hr)
    input_hr = np.sum(input_hr, axis=0)

    for i in range(NUM_CONNECTION[layer]):
      get_input = (K.function(hico_layers[layer-1][tn[1][i]][0].layers[0].input, hico_layers[layer-1][tn[1][i]][0].layers[2].output))
      input_ol.append(get_input(get_previous_layer_input(hico_layers, layer-1, hico_layers[layer-1][tn[1][i]], train_image)))

    input_ol = np.array(input_ol)
    input_ol = np.concatenate(input_ol, axis=1)

    input = np.concatenate((input_hr, input_ol), axis=1)
    
    previous_layer_input = input
    return previous_layer_input

# %%
for i in range(1, NUM_HICO_LAYER):
  print('Layer %d' %i)
  ensemble = []
  X_train_input_list = []
  X_test_input_list = []

  for j in range(NUM_TN[i]):
    # Build model of HiCo layer i
    connection = tuple(random.sample(range(len(hico_layers[i-1])), k=NUM_CONNECTION[i]))
    model = Sequential()
    model.add(Dense(64, activation='relu', input_dim=64+NUM_CLASS*NUM_CONNECTION[i]))
    model.add(Dense(64, activation='relu'))
    model.add(Dense(NUM_CLASS, activation = 'softmax'))
    model.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])
    ensemble.append((model, connection))
  hico_layers.append(ensemble)
  print('HICO LENGTH')
  print(len(hico_layers))

  for j in range(NUM_TN[i]):
    # Get train hidden representation from HiCo layer i-1
    X_train_input_hr = []
    X_train_input_ol = []
    for k in range(NUM_CONNECTION[i]):
      get_input = (K.function(hico_layers[i-1][hico_layers[i][j][1][k]][0].layers[0].input, hico_layers[i-1][hico_layers[i][j][1][k]][0].layers[1].output))
      X_train_input_hr.append(get_input(get_previous_layer_input(hico_layers, i-1, hico_layers[i-1][hico_layers[i][j][1][k]], X_train_cropped_list)))
    X_train_input_hr = np.array(X_train_input_hr)
    X_train_input_hr = np.sum(X_train_input_hr, axis=0)

    for k in range(NUM_CONNECTION[i]):
      get_input = (K.function(hico_layers[i-1][hico_layers[i][j][1][k]][0].layers[0].input, hico_layers[i-1][hico_layers[i][j][1][k]][0].layers[2].output))
      X_train_input_ol.append(get_input(get_previous_layer_input(hico_layers, i-1, hico_layers[i-1][hico_layers[i][j][1][k]], X_train_cropped_list)))
    X_train_input_ol = np.array(X_train_input_ol)
    X_train_input_ol = np.concatenate(X_train_input_ol, axis=1)

    X_train_input = np.concatenate((X_train_input_hr, X_train_input_ol), axis=1)
    X_train_input_list.append(X_train_input)

    # Get test hidden representation from HiCo layer i-1
    X_test_input_hr = []
    X_test_input_ol = []
    for k in range(NUM_CONNECTION[i]):
      get_input = (K.function(hico_layers[i-1][hico_layers[i][j][1][k]][0].layers[0].input, hico_layers[i-1][hico_layers[i][j][1][k]][0].layers[1].output))
      X_test_input_hr.append(get_input(get_previous_layer_input(hico_layers, i-1, hico_layers[i-1][hico_layers[i][j][1][k]], X_test_cropped_list)))
    X_test_input_hr = np.array(X_test_input_hr)
    X_test_input_hr = np.sum(X_test_input_hr, axis=0)

    for k in range(NUM_CONNECTION[i]):
      get_input = (K.function(hico_layers[i-1][hico_layers[i][j][1][k]][0].layers[0].input, hico_layers[i-1][hico_layers[i][j][1][k]][0].layers[2].output))
      X_test_input_ol.append(get_input(get_previous_layer_input(hico_layers, i-1, hico_layers[i-1][hico_layers[i][j][1][k]], X_test_cropped_list)))
    X_test_input_ol = np.array(X_test_input_ol)
    X_test_input_ol = np.concatenate(X_test_input_ol, axis=1)

    X_test_input = np.concatenate((X_test_input_hr, X_test_input_ol), axis=1)
    X_test_input_list.append(X_test_input)

  #train model of HiCo layer i
  for j in range(NUM_TN[i]):
    print('Model %d' %j)
    hico_layers[i][j][0].fit(X_train_input_list[j], y_train_one_hot, validation_data=(X_test_input_list[j], y_test_one_hot), epochs=5, batch_size=128)
# Out:
# Layer 1
# HICO LENGTH
# 2
# Model 0
# Epoch 1/5
# 469/469 [==============================] - 2s 3ms/step - loss: 0.8270 - accuracy: 0.7924 - val_loss: 0.1097 - val_accuracy: 0.9684
# Epoch 2/5
# 469/469 [==============================] - 1s 2ms/step - loss: 0.1018 - accuracy: 0.9698 - val_loss: 0.0921 - val_accuracy: 0.9735
# Epoch 3/5
# 469/469 [==============================] - 1s 2ms/step - loss: 0.0895 - accuracy: 0.9732 - val_loss: 0.0863 - val_accuracy: 0.9746
# Epoch 4/5
# 469/469 [==============================] - 1s 2ms/step - loss: 0.0795 - accuracy: 0.9762 - val_loss: 0.0769 - val_accuracy: 0.9772
# Epoch 5/5
# 469/469 [==============================] - 1s 2ms/step - loss: 0.0751 - accuracy: 0.9771 - val_loss: 0.0802 - val_accuracy: 0.9766
# Model 1
# Epoch 1/5
# 469/469 [==============================] - 1s 2ms/step - loss: 0.8796 - accuracy: 0.7930 - val_loss: 0.1136 - val_accuracy: 0.9637
# Epoch 2/5
# 469/469 [==============================] - 1s 2ms/step - loss: 0.1024 - accuracy: 0.9698 - val_loss: 0.0993 - val_accuracy: 0.9691
# Epoch 3/5
# 469/469 [==============================] - 1s 2ms/step - loss: 0.0884 - accuracy: 0.9742 - val_loss: 0.0840 - val_accuracy: 0.9758
# Epoch 4/5
# 469/469 [==============================] - 1s 2ms/step - loss: 0.0818 - accuracy: 0.9763 - val_loss: 0.0833 - val_accuracy: 0.9756
# Epoch 5/5
# 469/469 [==============================] - 1s 2ms/step - loss: 0.0737 - accuracy: 0.9773 - val_loss: 0.0765 - val_accuracy: 0.9767
# Model 2
# Epoch 1/5
# 469/469 [==============================] - 1s 2ms/step - loss: 0.6714 - accuracy: 0.8258 - val_loss: 0.1200 - val_accuracy: 0.9644
# Epoch 2/5
# 469/469 [==============================] - 1s 2ms/step - loss: 0.1045 - accuracy: 0.9692 - val_loss: 0.0950 - val_accuracy: 0.9715
# Epoch 3/5
# 469/469 [==============================] - 1s 2ms/step - loss: 0.0915 - accuracy: 0.9728 - val_loss: 0.1002 - val_accuracy: 0.9705
# Epoch 4/5
# 469/469 [==============================] - 1s 2ms/step - loss: 0.0821 - accuracy: 0.9761 - val_loss: 0.0869 - val_accuracy: 0.9751
# Epoch 5/5
# 469/469 [==============================] - 1s 2ms/step - loss: 0.0765 - accuracy: 0.9768 - val_loss: 0.0845 - val_accuracy: 0.9753
# Model 3
# Epoch 1/5
# 469/469 [==============================] - 1s 2ms/step - loss: 0.7525 - accuracy: 0.8155 - val_loss: 0.1047 - val_accuracy: 0.9695
# Epoch 2/5
# 469/469 [==============================] - 1s 2ms/step - loss: 0.0951 - accuracy: 0.9725 - val_loss: 0.0934 - val_accuracy: 0.9726
# Epoch 3/5
# 469/469 [==============================] - 1s 2ms/step - loss: 0.0811 - accuracy: 0.9758 - val_loss: 0.0885 - val_accuracy: 0.9742
# Epoch 4/5
# 469/469 [==============================] - 1s 2ms/step - loss: 0.0796 - accuracy: 0.9762 - val_loss: 0.0867 - val_accuracy: 0.9743
# Epoch 5/5
# 469/469 [==============================] - 1s 2ms/step - loss: 0.0721 - accuracy: 0.9780 - val_loss: 0.0770 - val_accuracy: 0.9777
# Model 4
# Epoch 1/5
# 469/469 [==============================] - 1s 2ms/step - loss: 0.9295 - accuracy: 0.7702 - val_loss: 0.1399 - val_accuracy: 0.9580
# Epoch 2/5
# 469/469 [==============================] - 1s 2ms/step - loss: 0.1234 - accuracy: 0.9629 - val_loss: 0.1221 - val_accuracy: 0.9647
# Epoch 3/5
# 469/469 [==============================] - 1s 2ms/step - loss: 0.1069 - accuracy: 0.9679 - val_loss: 0.1066 - val_accuracy: 0.9681
# Epoch 4/5
# 469/469 [==============================] - 1s 2ms/step - loss: 0.0962 - accuracy: 0.9702 - val_loss: 0.1089 - val_accuracy: 0.9667
# Epoch 5/5
# 469/469 [==============================] - 1s 2ms/step - loss: 0.0909 - accuracy: 0.9717 - val_loss: 0.0989 - val_accuracy: 0.9696
# Model 5
# Epoch 1/5
# 469/469 [==============================] - 1s 2ms/step - loss: 0.9081 - accuracy: 0.7776 - val_loss: 0.1219 - val_accuracy: 0.9614
# Epoch 2/5
# 469/469 [==============================] - 1s 2ms/step - loss: 0.1052 - accuracy: 0.9687 - val_loss: 0.0922 - val_accuracy: 0.9720
# Epoch 3/5
# 469/469 [==============================] - 1s 2ms/step - loss: 0.0881 - accuracy: 0.9743 - val_loss: 0.0904 - val_accuracy: 0.9718
# Epoch 4/5
# 469/469 [==============================] - 1s 2ms/step - loss: 0.0814 - accuracy: 0.9753 - val_loss: 0.1002 - val_accuracy: 0.9715
# Epoch 5/5
# 469/469 [==============================] - 1s 2ms/step - loss: 0.0788 - accuracy: 0.9761 - val_loss: 0.0976 - val_accuracy: 0.9721
# Model 6
# Epoch 1/5
# 469/469 [==============================] - 1s 2ms/step - loss: 0.6712 - accuracy: 0.8140 - val_loss: 0.0988 - val_accuracy: 0.9704
# Epoch 2/5
# 469/469 [==============================] - 1s 2ms/step - loss: 0.0944 - accuracy: 0.9717 - val_loss: 0.0830 - val_accuracy: 0.9745
# Epoch 3/5
# 469/469 [==============================] - 1s 2ms/step - loss: 0.0851 - accuracy: 0.9748 - val_loss: 0.0869 - val_accuracy: 0.9730
# Epoch 4/5
# 469/469 [==============================] - 1s 2ms/step - loss: 0.0785 - accuracy: 0.9768 - val_loss: 0.0678 - val_accuracy: 0.9780
# Epoch 5/5
# 469/469 [==============================] - 1s 2ms/step - loss: 0.0718 - accuracy: 0.9794 - val_loss: 0.0754 - val_accuracy: 0.9769
# Model 7
# Epoch 1/5
# 469/469 [==============================] - 1s 2ms/step - loss: 0.8138 - accuracy: 0.7761 - val_loss: 0.1300 - val_accuracy: 0.9622
# Epoch 2/5
# 469/469 [==============================] - 1s 2ms/step - loss: 0.1016 - accuracy: 0.9694 - val_loss: 0.0874 - val_accuracy: 0.9728
# Epoch 3/5
# 469/469 [==============================] - 1s 2ms/step - loss: 0.0827 - accuracy: 0.9750 - val_loss: 0.0842 - val_accuracy: 0.9755
# Epoch 4/5
# 469/469 [==============================] - 1s 2ms/step - loss: 0.0822 - accuracy: 0.9758 - val_loss: 0.0882 - val_accuracy: 0.9744
# Epoch 5/5
# 469/469 [==============================] - 1s 2ms/step - loss: 0.0748 - accuracy: 0.9776 - val_loss: 0.0762 - val_accuracy: 0.9764
# Layer 2
# HICO LENGTH
# 3
# Model 0
# Epoch 1/5
# 469/469 [==============================] - 1s 2ms/step - loss: 0.7442 - accuracy: 0.8539 - val_loss: 0.0741 - val_accuracy: 0.9790
# Epoch 2/5
# 469/469 [==============================] - 1s 2ms/step - loss: 0.0668 - accuracy: 0.9812 - val_loss: 0.0710 - val_accuracy: 0.9791
# Epoch 3/5
# 469/469 [==============================] - 1s 2ms/step - loss: 0.0614 - accuracy: 0.9827 - val_loss: 0.0648 - val_accuracy: 0.9825
# Epoch 4/5
# 469/469 [==============================] - 1s 2ms/step - loss: 0.0584 - accuracy: 0.9828 - val_loss: 0.0742 - val_accuracy: 0.9786
# Epoch 5/5
# 469/469 [==============================] - 1s 2ms/step - loss: 0.0571 - accuracy: 0.9827 - val_loss: 0.0764 - val_accuracy: 0.9798
# Model 1
# Epoch 1/5
# 469/469 [==============================] - 1s 2ms/step - loss: 0.9241 - accuracy: 0.8402 - val_loss: 0.0796 - val_accuracy: 0.9765
# Epoch 2/5
# 469/469 [==============================] - 1s 2ms/step - loss: 0.0661 - accuracy: 0.9812 - val_loss: 0.0721 - val_accuracy: 0.9793
# Epoch 3/5
# 469/469 [==============================] - 1s 2ms/step - loss: 0.0610 - accuracy: 0.9822 - val_loss: 0.0741 - val_accuracy: 0.9791
# Epoch 4/5
# 469/469 [==============================] - 1s 2ms/step - loss: 0.0641 - accuracy: 0.9811 - val_loss: 0.0660 - val_accuracy: 0.9808
# Epoch 5/5
# 469/469 [==============================] - 1s 2ms/step - loss: 0.0612 - accuracy: 0.9827 - val_loss: 0.0750 - val_accuracy: 0.9789
# Model 2
# Epoch 1/5
# 469/469 [==============================] - 1s 2ms/step - loss: 0.5051 - accuracy: 0.8790 - val_loss: 0.0804 - val_accuracy: 0.9771
# Epoch 2/5
# 469/469 [==============================] - 1s 2ms/step - loss: 0.0692 - accuracy: 0.9805 - val_loss: 0.0749 - val_accuracy: 0.9799
# Epoch 3/5
# 469/469 [==============================] - 1s 2ms/step - loss: 0.0635 - accuracy: 0.9816 - val_loss: 0.0824 - val_accuracy: 0.9778
# Epoch 4/5
# 469/469 [==============================] - 1s 2ms/step - loss: 0.0619 - accuracy: 0.9821 - val_loss: 0.0680 - val_accuracy: 0.9798
# Epoch 5/5
# 469/469 [==============================] - 1s 2ms/step - loss: 0.0607 - accuracy: 0.9825 - val_loss: 0.0655 - val_accuracy: 0.9813
# Model 3
# Epoch 1/5
# 469/469 [==============================] - 1s 2ms/step - loss: 0.4498 - accuracy: 0.8886 - val_loss: 0.0877 - val_accuracy: 0.9755
# Epoch 2/5
# 469/469 [==============================] - 1s 2ms/step - loss: 0.0689 - accuracy: 0.9809 - val_loss: 0.0738 - val_accuracy: 0.9790
# Epoch 3/5
# 469/469 [==============================] - 1s 2ms/step - loss: 0.0651 - accuracy: 0.9813 - val_loss: 0.0655 - val_accuracy: 0.9815
# Epoch 4/5
# 469/469 [==============================] - 1s 2ms/step - loss: 0.0604 - accuracy: 0.9822 - val_loss: 0.0688 - val_accuracy: 0.9813
# Epoch 5/5
# 469/469 [==============================] - 1s 2ms/step - loss: 0.0589 - accuracy: 0.9829 - val_loss: 0.0659 - val_accuracy: 0.9813
# Model 4
# Epoch 1/5
# 469/469 [==============================] - 1s 2ms/step - loss: 0.7187 - accuracy: 0.8540 - val_loss: 0.0868 - val_accuracy: 0.9764
# Epoch 2/5
# 469/469 [==============================] - 1s 2ms/step - loss: 0.0667 - accuracy: 0.9806 - val_loss: 0.0693 - val_accuracy: 0.9811
# Epoch 3/5
# 469/469 [==============================] - 1s 2ms/step - loss: 0.0659 - accuracy: 0.9813 - val_loss: 0.0746 - val_accuracy: 0.9800
# Epoch 4/5
# 469/469 [==============================] - 1s 2ms/step - loss: 0.0606 - accuracy: 0.9819 - val_loss: 0.0720 - val_accuracy: 0.9806
# Epoch 5/5
# 469/469 [==============================] - 1s 2ms/step - loss: 0.0624 - accuracy: 0.9823 - val_loss: 0.0751 - val_accuracy: 0.9804
# Model 5
# Epoch 1/5
# 469/469 [==============================] - 1s 2ms/step - loss: 0.6941 - accuracy: 0.8396 - val_loss: 0.0778 - val_accuracy: 0.9773
# Epoch 2/5
# 469/469 [==============================] - 1s 2ms/step - loss: 0.0726 - accuracy: 0.9789 - val_loss: 0.0828 - val_accuracy: 0.9768
# Epoch 3/5
# 469/469 [==============================] - 1s 2ms/step - loss: 0.0705 - accuracy: 0.9800 - val_loss: 0.0736 - val_accuracy: 0.9799
# Epoch 4/5
# 469/469 [==============================] - 1s 2ms/step - loss: 0.0615 - accuracy: 0.9826 - val_loss: 0.0740 - val_accuracy: 0.9786
# Epoch 5/5
# 469/469 [==============================] - 1s 2ms/step - loss: 0.0661 - accuracy: 0.9808 - val_loss: 0.0803 - val_accuracy: 0.9765
# Layer 3
# HICO LENGTH
# 4
# Model 0
# Epoch 1/5
# 469/469 [==============================] - 1s 2ms/step - loss: 0.7155 - accuracy: 0.8652 - val_loss: 0.0709 - val_accuracy: 0.9791
# Epoch 2/5
# 469/469 [==============================] - 1s 2ms/step - loss: 0.0622 - accuracy: 0.9823 - val_loss: 0.0679 - val_accuracy: 0.9812
# Epoch 3/5
# 469/469 [==============================] - 1s 2ms/step - loss: 0.0528 - accuracy: 0.9849 - val_loss: 0.0649 - val_accuracy: 0.9812
# Epoch 4/5
# 469/469 [==============================] - 1s 2ms/step - loss: 0.0509 - accuracy: 0.9846 - val_loss: 0.0669 - val_accuracy: 0.9822
# Epoch 5/5
# 469/469 [==============================] - 1s 2ms/step - loss: 0.0503 - accuracy: 0.9859 - val_loss: 0.0637 - val_accuracy: 0.9831
# Model 1
# Epoch 1/5
# 469/469 [==============================] - 2s 2ms/step - loss: 0.3505 - accuracy: 0.9146 - val_loss: 0.0678 - val_accuracy: 0.9799
# Epoch 2/5
# 469/469 [==============================] - 1s 2ms/step - loss: 0.0578 - accuracy: 0.9834 - val_loss: 0.0626 - val_accuracy: 0.9822
# Epoch 3/5
# 469/469 [==============================] - 1s 2ms/step - loss: 0.0575 - accuracy: 0.9830 - val_loss: 0.0642 - val_accuracy: 0.9822
# Epoch 4/5
# 469/469 [==============================] - 1s 2ms/step - loss: 0.0559 - accuracy: 0.9834 - val_loss: 0.0643 - val_accuracy: 0.9820
# Epoch 5/5
# 469/469 [==============================] - 1s 2ms/step - loss: 0.0555 - accuracy: 0.9844 - val_loss: 0.0628 - val_accuracy: 0.9828
# Model 2
# Epoch 1/5
# 469/469 [==============================] - 1s 2ms/step - loss: 0.5878 - accuracy: 0.8711 - val_loss: 0.0772 - val_accuracy: 0.9777
# Epoch 2/5
# 469/469 [==============================] - 1s 2ms/step - loss: 0.0599 - accuracy: 0.9830 - val_loss: 0.0648 - val_accuracy: 0.9807
# Epoch 3/5
# 469/469 [==============================] - 1s 2ms/step - loss: 0.0549 - accuracy: 0.9846 - val_loss: 0.0705 - val_accuracy: 0.9803
# Epoch 4/5
# 469/469 [==============================] - 1s 2ms/step - loss: 0.0517 - accuracy: 0.9856 - val_loss: 0.0629 - val_accuracy: 0.9820
# Epoch 5/5
# 469/469 [==============================] - 1s 2ms/step - loss: 0.0527 - accuracy: 0.9853 - val_loss: 0.0649 - val_accuracy: 0.9819
# Model 3
# Epoch 1/5
# 469/469 [==============================] - 1s 2ms/step - loss: 0.8113 - accuracy: 0.8469 - val_loss: 0.0722 - val_accuracy: 0.9807
# Epoch 2/5
# 469/469 [==============================] - 1s 2ms/step - loss: 0.0629 - accuracy: 0.9826 - val_loss: 0.0707 - val_accuracy: 0.9815
# Epoch 3/5
# 469/469 [==============================] - 1s 2ms/step - loss: 0.0595 - accuracy: 0.9827 - val_loss: 0.0626 - val_accuracy: 0.9826
# Epoch 4/5
# 469/469 [==============================] - 1s 2ms/step - loss: 0.0558 - accuracy: 0.9839 - val_loss: 0.0607 - val_accuracy: 0.9831
# Epoch 5/5
# 469/469 [==============================] - 1s 2ms/step - loss: 0.0535 - accuracy: 0.9848 - val_loss: 0.0645 - val_accuracy: 0.9827
# Layer 4
# HICO LENGTH
# 5
# Model 0
# Epoch 1/5
# 469/469 [==============================] - 1s 2ms/step - loss: 0.6040 - accuracy: 0.8814 - val_loss: 0.0631 - val_accuracy: 0.9823
# Epoch 2/5
# 469/469 [==============================] - 1s 2ms/step - loss: 0.0538 - accuracy: 0.9848 - val_loss: 0.0672 - val_accuracy: 0.9808
# Epoch 3/5
# 469/469 [==============================] - 1s 2ms/step - loss: 0.0516 - accuracy: 0.9853 - val_loss: 0.0669 - val_accuracy: 0.9807
# Epoch 4/5
# 469/469 [==============================] - 1s 2ms/step - loss: 0.0505 - accuracy: 0.9855 - val_loss: 0.0590 - val_accuracy: 0.9829
# Epoch 5/5
# 469/469 [==============================] - 1s 2ms/step - loss: 0.0508 - accuracy: 0.9853 - val_loss: 0.0589 - val_accuracy: 0.9827
# Model 1
# Epoch 1/5
# 469/469 [==============================] - 1s 2ms/step - loss: 0.3751 - accuracy: 0.9102 - val_loss: 0.0733 - val_accuracy: 0.9820
# Epoch 2/5
# 469/469 [==============================] - 1s 2ms/step - loss: 0.0544 - accuracy: 0.9847 - val_loss: 0.0657 - val_accuracy: 0.9820
# Epoch 3/5
# 469/469 [==============================] - 1s 2ms/step - loss: 0.0515 - accuracy: 0.9855 - val_loss: 0.0632 - val_accuracy: 0.9822
# Epoch 4/5
# 469/469 [==============================] - 1s 2ms/step - loss: 0.0512 - accuracy: 0.9854 - val_loss: 0.0695 - val_accuracy: 0.9815
# Epoch 5/5
# 469/469 [==============================] - 1s 2ms/step - loss: 0.0469 - accuracy: 0.9864 - val_loss: 0.0593 - val_accuracy: 0.9839

# %% [markdown]
# ## Model Evaluation

# %%
# Predict on test image
y_pred_list = []
for j in range(NUM_TN[0]):
  y_pred = np.argmax(hico_layers[0][j][0].predict(X_test_cropped_list[j]), axis=1)
  y_pred_list.append(y_pred)

for i in range(1, NUM_HICO_LAYER):
  for j in range(NUM_TN[i]):

    # Get test hidden representation from HiCo layer i-1
    X_test_input_hr = []
    X_test_input_ol = []
    for k in range(NUM_CONNECTION[i]):
      get_input = (K.function(hico_layers[i-1][hico_layers[i][j][1][k]][0].layers[0].input, hico_layers[i-1][hico_layers[i][j][1][k]][0].layers[1].output))
      X_test_input_hr.append(get_input(get_previous_layer_input(hico_layers, i-1, hico_layers[i-1][hico_layers[i][j][1][k]], X_test_cropped_list)))
    X_test_input_hr = np.array(X_test_input_hr)
    X_test_input_hr = np.sum(X_test_input_hr, axis=0)

    for k in range(NUM_CONNECTION[i]):
      get_input = (K.function(hico_layers[i-1][hico_layers[i][j][1][k]][0].layers[0].input, hico_layers[i-1][hico_layers[i][j][1][k]][0].layers[2].output))
      X_test_input_ol.append(get_input(get_previous_layer_input(hico_layers, i-1, hico_layers[i-1][hico_layers[i][j][1][k]], X_test_cropped_list)))
    X_test_input_ol = np.array(X_test_input_ol)
    X_test_input_ol = np.concatenate(X_test_input_ol, axis=1)

    X_test_input = np.concatenate((X_test_input_hr, X_test_input_ol), axis=1)

    y_pred = np.argmax(hico_layers[i][j][0].predict(X_test_input), axis=1)
    y_pred_list.append(y_pred)

# HiCo voting (mode)
y_pred_list = np.array(y_pred_list)
y_pred_list = np.transpose(y_pred_list, (1, 0))
y_pred_list = stats.mode(y_pred_list, axis=1)[0]
y_pred_list = np.squeeze(y_pred_list)

# %%
y_test = np.argmax(y_test_one_hot, axis=1)

# %%
accuracy = accuracy_score(y_test, y_pred_list)
accuracy
# Out:
# 0.9827
