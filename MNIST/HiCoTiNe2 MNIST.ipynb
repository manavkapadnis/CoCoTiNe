# %% [markdown]
# # HiCoTiNe 2. Adapted from HiCoTiNe v3.3.1
# ## Concatenated hidden representations.
# ## No raw input
# ## The weight of each TN is inversely proportional to the number of TNs in its HiCo layer, relative to the HiCo layer with the most TNs

# %%
from keras.models import Sequential
from keras.layers import Dense, Conv2D, Flatten
from keras.datasets import mnist
from keras.utils import to_categorical
import matplotlib.pyplot as plt
import numpy as np
import tensorflow as tf
import random
from scipy import stats
from sklearn.metrics import accuracy_score
from keras import backend as K
import cv2

# %%
NUM_BATCH = 469
BATCH_SIZE = 128
SUB_REGION_SCALE = 14
MIN_SUB_REGION_SCALE = 12
MAX_SUB_REGION_SCALE = 16
NUM_TEST_STEP = 10
NUM_HICO_LAYER = 5
NUM_TN = [10, 8, 6, 4, 2]
NUM_CONNECTION = [0, 5, 4, 3, 2]
ALPHA = 0.1

#dataset specific parameters
NUM_CLASS = 10

# %% [markdown]
# ## Data Pre-Processing

# %%
#load dataset
(X_train, y_train), (X_test, y_test) = mnist.load_data()
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/mnist.npz
# 11493376/11490434 [==============================] - 0s 0us/step

# %%
#Generate cropped train image
X_train_cropped_list = []
y_train_cropped_list = []
#coordinate_list = []
for i in range(NUM_TN[0]):
  X_train_cropped_batch = []
  y_train_cropped_batch = []
  for j in range(NUM_BATCH):
    X_train_cropped = []
    y_train_cropped = []
    sub_region_scale = random.randint(MIN_SUB_REGION_SCALE, MAX_SUB_REGION_SCALE)
    x = random.randint(0, X_train.shape[1] - sub_region_scale)
    y = random.randint(0, X_train.shape[1] - sub_region_scale)
    
    if (j == NUM_BATCH - 1) and ((len(X_train) - j*BATCH_SIZE) % BATCH_SIZE):
      for k in range(len(X_train) - j*BATCH_SIZE):
        image_cropped = []
        for row in range(y, y + sub_region_scale):
          image_cropped_row = []
          for column in range(x, x + sub_region_scale):
            image_cropped_row.append(X_train[(j*BATCH_SIZE)+k][row][column])
          image_cropped.append(image_cropped_row)
        X_train_cropped.append(image_cropped)
        y_train_cropped.append(y_train[(j*BATCH_SIZE)+k])
      
      X_train_cropped = np.array(X_train_cropped)
      y_train_cropped = np.array(y_train_cropped)
      X_train_cropped_batch.append(X_train_cropped)
      y_train_cropped_batch.append(y_train_cropped)
      break

    for k in range(BATCH_SIZE):
      image_cropped = []
      for row in range(y, y + sub_region_scale):
        image_cropped_row = []
        for column in range(x, x + sub_region_scale):
          image_cropped_row.append(X_train[(j*BATCH_SIZE)+k][row][column])
        image_cropped.append(image_cropped_row)
      X_train_cropped.append(image_cropped)
      y_train_cropped.append(y_train[(j*BATCH_SIZE)+k])

    X_train_cropped = np.array(X_train_cropped)
    y_train_cropped = np.array(y_train_cropped)
    X_train_cropped_batch.append(X_train_cropped)
    y_train_cropped_batch.append(y_train_cropped)
  X_train_cropped_list.append(X_train_cropped_batch)
  y_train_cropped_list.append(y_train_cropped_batch)

# %%
#Generate cropped test image
X_test_cropped_list = []
for i in range(NUM_TN[0] * NUM_TEST_STEP):
  X_test_cropped = []
  sub_region_scale = random.randint(MIN_SUB_REGION_SCALE, MAX_SUB_REGION_SCALE)
  x = random.randint(0, X_test.shape[1] - sub_region_scale)
  y = random.randint(0, X_test.shape[1] - sub_region_scale)
  for j in range(X_test.shape[0]):
    image_cropped = []
    for row in range(y, y + sub_region_scale):
      image_cropped_row = []
      for column in range(x, x + sub_region_scale):
        image_cropped_row.append(X_test[j][row][column])
      image_cropped.append(image_cropped_row)
    X_test_cropped.append(image_cropped)

  X_test_cropped = np.array(X_test_cropped)
  X_test_cropped_list.append(X_test_cropped)

# %%
#rescaling dataset
for i in range(NUM_TN[0]):
  for j in range(NUM_BATCH):
    temp = []
    for k in range (len(X_train_cropped_list[i][j])):
      temp.append(cv2.resize(X_train_cropped_list[i][j][k], (SUB_REGION_SCALE, SUB_REGION_SCALE)))
    temp = np.array(temp)
    X_train_cropped_list[i][j] = temp

for i in range(NUM_TN[0] * NUM_TEST_STEP):
  temp = []
  for j in range(X_test.shape[0]):
    temp.append(cv2.resize(X_test_cropped_list[i][j], (SUB_REGION_SCALE, SUB_REGION_SCALE)))
  temp = np.array(temp)
  X_test_cropped_list[i] = temp

# %%
#normalizing dataset
for i in range(NUM_TN[0]):
  for j in range(NUM_BATCH):
    X_train_cropped_list[i][j] = X_train_cropped_list[i][j]/255

for i in range(NUM_TN[0] * NUM_TEST_STEP):
  X_test_cropped_list[i] = X_test_cropped_list[i]/255

# %%
#transform to vector
for i in range(NUM_TN[0]):
  for j in range(NUM_BATCH):
    X_train_cropped_list[i][j] = X_train_cropped_list[i][j].reshape((-1, SUB_REGION_SCALE*SUB_REGION_SCALE))

for i in range(NUM_TN[0] * NUM_TEST_STEP):
  X_test_cropped_list[i] = X_test_cropped_list[i].reshape((-1, SUB_REGION_SCALE*SUB_REGION_SCALE))

# %%
#one-hot encoding
y_train_one_hot = []
for i in range(NUM_TN[0]):
  temp = []
  for j in range(NUM_BATCH):
    temp.append(to_categorical(y_train_cropped_list[i][j], num_classes=NUM_CLASS))
  y_train_one_hot.append(temp)

y_test_one_hot = to_categorical(y_test)

# %% [markdown]
# ## HiCo Layer 1

# %%
#build ANN model
ensemble = []
for i in range(NUM_TN[0]):
  model = Sequential()
  model.add(Dense(64, activation='relu', input_dim=SUB_REGION_SCALE*SUB_REGION_SCALE))
  model.add(Dense(64, activation='relu'))
  model.add(Dense(NUM_CLASS, activation = 'softmax'))
  model.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])
  ensemble.append((model, i))

# %%
for i in range(NUM_TN[0]):
  print('Model %d' %i)
  for j in range(5):
    print('Epoch %d' %j)
    for k in range(NUM_BATCH):
      ensemble[i][0].train_on_batch(X_train_cropped_list[i][k], y_train_one_hot[i][k])
# Out:
# Model 0
# Epoch 0
# Epoch 1
# Epoch 2
# Epoch 3
# Epoch 4
# Model 1
# Epoch 0
# Epoch 1
# Epoch 2
# Epoch 3
# Epoch 4
# Model 2
# Epoch 0
# Epoch 1
# Epoch 2
# Epoch 3
# Epoch 4
# Model 3
# Epoch 0
# Epoch 1
# Epoch 2
# Epoch 3
# Epoch 4
# Model 4
# Epoch 0
# Epoch 1
# Epoch 2
# Epoch 3
# Epoch 4
# Model 5
# Epoch 0
# Epoch 1
# Epoch 2
# Epoch 3
# Epoch 4
# Model 6
# Epoch 0
# Epoch 1
# Epoch 2
# Epoch 3
# Epoch 4
# Model 7
# Epoch 0
# Epoch 1
# Epoch 2
# Epoch 3
# Epoch 4
# Model 8
# Epoch 0
# Epoch 1
# Epoch 2
# Epoch 3
# Epoch 4
# Model 9
# Epoch 0
# Epoch 1
# Epoch 2
# Epoch 3
# Epoch 4

# %%
# Predict on test image
y_pred_list = []
for i in range(NUM_TN[0]):
  y_pred = np.argmax(ensemble[i][0].predict(X_test_cropped_list[i]), axis=1)
  y_pred_list.append(y_pred)
    
# Ensemble voting (mode)
y_pred_list = np.array(y_pred_list)
y_pred_list = np.transpose(y_pred_list, (1, 0))
y_pred_list = stats.mode(y_pred_list, axis=1)[0]
y_pred_list = np.squeeze(y_pred_list)

# %%
accuracy = accuracy_score(y_test, y_pred_list)
accuracy
# Out:
# 0.711

# %%
hico_layers = []
hico_layers.append(ensemble)

# %%
del hico_layers[1:]

# %% [markdown]
# ## HiCo Layer 2+

# %%
X_train_cropped_list_combined = []
for i in range(NUM_TN[0]):
  X_train_cropped_list_combined.append(np.concatenate(X_train_cropped_list[i], axis=0))

y_train_one_hot_combined = to_categorical(y_train)

# %%
# Function to get input of layer i-1
def get_previous_layer_input(hico_layers, layer, tn, train_image):
  input = []
    
  if layer == 0:
    previous_layer_input = train_image[tn[1]]
    return previous_layer_input

  elif layer > 0:
    for i in range(NUM_CONNECTION[layer]):
      get_input = (K.function(hico_layers[layer-1][tn[1][i]][0].layers[0].input, hico_layers[layer-1][tn[1][i]][0].layers[1].output))
      input.append(get_input(get_previous_layer_input(hico_layers, layer-1, hico_layers[layer-1][tn[1][i]], train_image)))
      
    input = np.array(input)
    input = np.concatenate(input, axis=1)
    previous_layer_input = input
    return previous_layer_input

# %%
for i in range(1, NUM_HICO_LAYER):
  print('Layer %d' %i)
  ensemble = []
  X_train_input_list = []
  X_test_input_list = []

  for j in range(NUM_TN[i]):
    # Build model of HiCo layer i
    connection = tuple(random.sample(range(len(hico_layers[i-1])), k=NUM_CONNECTION[i]))
    model = Sequential()
    model.add(Dense(64, activation='relu', input_dim=64*NUM_CONNECTION[i]))
    model.add(Dense(64, activation='relu'))
    model.add(Dense(NUM_CLASS, activation = 'softmax'))
    model.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])
    ensemble.append((model, connection))
  hico_layers.append(ensemble)
  print('HICO LENGTH')
  print(len(hico_layers))

  for j in range(NUM_TN[i]):
    # Get train hidden representation from HiCo layer i-1
    X_train_input = []
    for k in range(NUM_CONNECTION[i]):
      get_input = (K.function(hico_layers[i-1][hico_layers[i][j][1][k]][0].layers[0].input, hico_layers[i-1][hico_layers[i][j][1][k]][0].layers[1].output))
      X_train_input.append(get_input(get_previous_layer_input(hico_layers, i-1, hico_layers[i-1][hico_layers[i][j][1][k]], X_train_cropped_list_combined)))
    X_train_input = np.array(X_train_input)
    X_train_input = np.concatenate(X_train_input, axis=1)
    X_train_input_list.append(X_train_input)

    # Get test hidden representation from HiCo layer i-1
    X_test_input = []
    for k in range(NUM_CONNECTION[i]):
      get_input = (K.function(hico_layers[i-1][hico_layers[i][j][1][k]][0].layers[0].input, hico_layers[i-1][hico_layers[i][j][1][k]][0].layers[1].output))
      X_test_input.append(get_input(get_previous_layer_input(hico_layers, i-1, hico_layers[i-1][hico_layers[i][j][1][k]], X_test_cropped_list)))
    X_test_input = np.array(X_test_input)
    X_test_input = np.concatenate(X_test_input, axis=1)
    X_test_input_list.append(X_test_input)

  #train model of HiCo layer i
  for j in range(NUM_TN[i]):
    print('Model %d' %j)
    hico_layers[i][j][0].fit(X_train_input_list[j], y_train_one_hot_combined, validation_data=(X_test_input_list[j], y_test_one_hot), epochs=5)
# Out:
# Layer 1
# HICO LENGTH
# 2
# Model 0
# Epoch 1/5
# 1875/1875 [==============================] - 3s 2ms/step - loss: 0.8706 - accuracy: 0.7102 - val_loss: 0.8474 - val_accuracy: 0.7253
# Epoch 2/5
# 1875/1875 [==============================] - 3s 1ms/step - loss: 0.4740 - accuracy: 0.8461 - val_loss: 0.7587 - val_accuracy: 0.7575
# Epoch 3/5
# 1875/1875 [==============================] - 3s 1ms/step - loss: 0.4336 - accuracy: 0.8590 - val_loss: 0.8605 - val_accuracy: 0.7295
# Epoch 4/5
# 1875/1875 [==============================] - 3s 1ms/step - loss: 0.4044 - accuracy: 0.8659 - val_loss: 0.7784 - val_accuracy: 0.7527
# Epoch 5/5
# 1875/1875 [==============================] - 3s 1ms/step - loss: 0.3784 - accuracy: 0.8767 - val_loss: 0.7580 - val_accuracy: 0.7669
# Model 1
# Epoch 1/5
# 1875/1875 [==============================] - 3s 1ms/step - loss: 0.8760 - accuracy: 0.7073 - val_loss: 0.7526 - val_accuracy: 0.7477
# Epoch 2/5
# 1875/1875 [==============================] - 3s 1ms/step - loss: 0.4693 - accuracy: 0.8483 - val_loss: 0.7715 - val_accuracy: 0.7386
# Epoch 3/5
# 1875/1875 [==============================] - 3s 1ms/step - loss: 0.4307 - accuracy: 0.8610 - val_loss: 0.6862 - val_accuracy: 0.7691
# Epoch 4/5
# 1875/1875 [==============================] - 3s 1ms/step - loss: 0.3945 - accuracy: 0.8710 - val_loss: 0.6787 - val_accuracy: 0.7667
# Epoch 5/5
# 1875/1875 [==============================] - 3s 1ms/step - loss: 0.3715 - accuracy: 0.8767 - val_loss: 0.6680 - val_accuracy: 0.7785
# Model 2
# Epoch 1/5
# 1875/1875 [==============================] - 3s 2ms/step - loss: 0.8725 - accuracy: 0.7085 - val_loss: 0.5330 - val_accuracy: 0.8246
# Epoch 2/5
# 1875/1875 [==============================] - 3s 1ms/step - loss: 0.4605 - accuracy: 0.8505 - val_loss: 0.4388 - val_accuracy: 0.8574
# Epoch 3/5
# 1875/1875 [==============================] - 3s 1ms/step - loss: 0.4273 - accuracy: 0.8589 - val_loss: 0.4027 - val_accuracy: 0.8746
# Epoch 4/5
# 1875/1875 [==============================] - 3s 1ms/step - loss: 0.3940 - accuracy: 0.8723 - val_loss: 0.3824 - val_accuracy: 0.8818
# Epoch 5/5
# 1875/1875 [==============================] - 3s 1ms/step - loss: 0.3738 - accuracy: 0.8787 - val_loss: 0.4648 - val_accuracy: 0.8529
# Model 3
# Epoch 1/5
# 1875/1875 [==============================] - 3s 1ms/step - loss: 0.9211 - accuracy: 0.6905 - val_loss: 0.5990 - val_accuracy: 0.7984
# Epoch 2/5
# 1875/1875 [==============================] - 3s 1ms/step - loss: 0.4752 - accuracy: 0.8453 - val_loss: 0.5959 - val_accuracy: 0.7963
# Epoch 3/5
# 1875/1875 [==============================] - 3s 1ms/step - loss: 0.4328 - accuracy: 0.8579 - val_loss: 0.6147 - val_accuracy: 0.7910
# Epoch 4/5
# 1875/1875 [==============================] - 3s 1ms/step - loss: 0.4026 - accuracy: 0.8683 - val_loss: 0.5512 - val_accuracy: 0.8086
# Epoch 5/5
# 1875/1875 [==============================] - 3s 1ms/step - loss: 0.3771 - accuracy: 0.8763 - val_loss: 0.6871 - val_accuracy: 0.7664
# Model 4
# Epoch 1/5
# 1875/1875 [==============================] - 3s 1ms/step - loss: 0.8636 - accuracy: 0.7115 - val_loss: 0.8549 - val_accuracy: 0.7152
# Epoch 2/5
# 1875/1875 [==============================] - 3s 1ms/step - loss: 0.4687 - accuracy: 0.8475 - val_loss: 0.8236 - val_accuracy: 0.7273
# Epoch 3/5
# 1875/1875 [==============================] - 3s 1ms/step - loss: 0.4252 - accuracy: 0.8611 - val_loss: 0.8116 - val_accuracy: 0.7305
# Epoch 4/5
# 1875/1875 [==============================] - 3s 1ms/step - loss: 0.3933 - accuracy: 0.8708 - val_loss: 0.8012 - val_accuracy: 0.7299
# Epoch 5/5
# 1875/1875 [==============================] - 3s 1ms/step - loss: 0.3715 - accuracy: 0.8783 - val_loss: 0.7509 - val_accuracy: 0.7571
# Model 5
# Epoch 1/5
# 1875/1875 [==============================] - 3s 1ms/step - loss: 0.8903 - accuracy: 0.6974 - val_loss: 0.6413 - val_accuracy: 0.8023
# Epoch 2/5
# 1875/1875 [==============================] - 3s 1ms/step - loss: 0.4709 - accuracy: 0.8470 - val_loss: 0.6313 - val_accuracy: 0.8047
# Epoch 3/5
# 1875/1875 [==============================] - 3s 1ms/step - loss: 0.4326 - accuracy: 0.8587 - val_loss: 0.6487 - val_accuracy: 0.7991
# Epoch 4/5
# 1875/1875 [==============================] - 3s 1ms/step - loss: 0.4028 - accuracy: 0.8669 - val_loss: 0.6498 - val_accuracy: 0.7939
# Epoch 5/5
# 1875/1875 [==============================] - 3s 1ms/step - loss: 0.3773 - accuracy: 0.8758 - val_loss: 0.6038 - val_accuracy: 0.8139
# Model 6
# Epoch 1/5
# 1875/1875 [==============================] - 3s 1ms/step - loss: 0.9405 - accuracy: 0.6839 - val_loss: 0.8859 - val_accuracy: 0.6993
# Epoch 2/5
# 1875/1875 [==============================] - 3s 1ms/step - loss: 0.4704 - accuracy: 0.8491 - val_loss: 0.8052 - val_accuracy: 0.7237
# Epoch 3/5
# 1875/1875 [==============================] - 3s 1ms/step - loss: 0.4299 - accuracy: 0.8610 - val_loss: 0.7366 - val_accuracy: 0.7542
# Epoch 4/5
# 1875/1875 [==============================] - 3s 1ms/step - loss: 0.3992 - accuracy: 0.8709 - val_loss: 0.6655 - val_accuracy: 0.7768
# Epoch 5/5
# 1875/1875 [==============================] - 3s 1ms/step - loss: 0.3845 - accuracy: 0.8754 - val_loss: 0.7058 - val_accuracy: 0.7648
# Model 7
# Epoch 1/5
# 1875/1875 [==============================] - 3s 1ms/step - loss: 0.8477 - accuracy: 0.7208 - val_loss: 0.5594 - val_accuracy: 0.8227
# Epoch 2/5
# 1875/1875 [==============================] - 3s 1ms/step - loss: 0.4752 - accuracy: 0.8459 - val_loss: 0.4748 - val_accuracy: 0.8430
# Epoch 3/5
# 1875/1875 [==============================] - 3s 1ms/step - loss: 0.4311 - accuracy: 0.8592 - val_loss: 0.4768 - val_accuracy: 0.8457
# Epoch 4/5
# 1875/1875 [==============================] - 3s 1ms/step - loss: 0.4048 - accuracy: 0.8655 - val_loss: 0.4067 - val_accuracy: 0.8660
# Epoch 5/5
# 1875/1875 [==============================] - 3s 1ms/step - loss: 0.3765 - accuracy: 0.8757 - val_loss: 0.4471 - val_accuracy: 0.8500
# Layer 2
# HICO LENGTH
# 3
# Model 0
# Epoch 1/5
# 1875/1875 [==============================] - 3s 1ms/step - loss: 0.3689 - accuracy: 0.8844 - val_loss: 0.3981 - val_accuracy: 0.8743
# Epoch 2/5
# 1875/1875 [==============================] - 3s 1ms/step - loss: 0.2135 - accuracy: 0.9284 - val_loss: 0.3976 - val_accuracy: 0.8798
# Epoch 3/5
# 1875/1875 [==============================] - 3s 1ms/step - loss: 0.2042 - accuracy: 0.9330 - val_loss: 0.3977 - val_accuracy: 0.8775
# Epoch 4/5
# 1875/1875 [==============================] - 3s 1ms/step - loss: 0.1964 - accuracy: 0.9352 - val_loss: 0.3976 - val_accuracy: 0.8807
# Epoch 5/5
# 1875/1875 [==============================] - 3s 1ms/step - loss: 0.1901 - accuracy: 0.9369 - val_loss: 0.4466 - val_accuracy: 0.8702
# Model 1
# Epoch 1/5
# 1875/1875 [==============================] - 3s 1ms/step - loss: 0.3705 - accuracy: 0.8871 - val_loss: 0.4218 - val_accuracy: 0.8720
# Epoch 2/5
# 1875/1875 [==============================] - 3s 1ms/step - loss: 0.2197 - accuracy: 0.9281 - val_loss: 0.4293 - val_accuracy: 0.8762
# Epoch 3/5
# 1875/1875 [==============================] - 3s 1ms/step - loss: 0.1997 - accuracy: 0.9338 - val_loss: 0.4322 - val_accuracy: 0.8720
# Epoch 4/5
# 1875/1875 [==============================] - 3s 1ms/step - loss: 0.1939 - accuracy: 0.9360 - val_loss: 0.4345 - val_accuracy: 0.8693
# Epoch 5/5
# 1875/1875 [==============================] - 3s 1ms/step - loss: 0.1845 - accuracy: 0.9397 - val_loss: 0.4410 - val_accuracy: 0.8705
# Model 2
# Epoch 1/5
# 1875/1875 [==============================] - 3s 1ms/step - loss: 0.3699 - accuracy: 0.8870 - val_loss: 0.5020 - val_accuracy: 0.8468
# Epoch 2/5
# 1875/1875 [==============================] - 3s 1ms/step - loss: 0.2249 - accuracy: 0.9269 - val_loss: 0.4614 - val_accuracy: 0.8576
# Epoch 3/5
# 1875/1875 [==============================] - 3s 1ms/step - loss: 0.2113 - accuracy: 0.9308 - val_loss: 0.4513 - val_accuracy: 0.8616
# Epoch 4/5
# 1875/1875 [==============================] - 3s 1ms/step - loss: 0.1995 - accuracy: 0.9354 - val_loss: 0.4485 - val_accuracy: 0.8667
# Epoch 5/5
# 1875/1875 [==============================] - 3s 1ms/step - loss: 0.1982 - accuracy: 0.9358 - val_loss: 0.4823 - val_accuracy: 0.8546
# Model 3
# Epoch 1/5
# 1875/1875 [==============================] - 3s 1ms/step - loss: 0.4013 - accuracy: 0.8741 - val_loss: 0.4433 - val_accuracy: 0.8628
# Epoch 2/5
# 1875/1875 [==============================] - 3s 1ms/step - loss: 0.2336 - accuracy: 0.9249 - val_loss: 0.4956 - val_accuracy: 0.8505
# Epoch 3/5
# 1875/1875 [==============================] - 3s 1ms/step - loss: 0.2164 - accuracy: 0.9287 - val_loss: 0.4887 - val_accuracy: 0.8539
# Epoch 4/5
# 1875/1875 [==============================] - 3s 1ms/step - loss: 0.2045 - accuracy: 0.9334 - val_loss: 0.4678 - val_accuracy: 0.8619
# Epoch 5/5
# 1875/1875 [==============================] - 3s 1ms/step - loss: 0.1956 - accuracy: 0.9358 - val_loss: 0.4721 - val_accuracy: 0.8635
# Model 4
# Epoch 1/5
# 1875/1875 [==============================] - 3s 2ms/step - loss: 0.3734 - accuracy: 0.8851 - val_loss: 0.4124 - val_accuracy: 0.8645
# Epoch 2/5
# 1875/1875 [==============================] - 3s 1ms/step - loss: 0.2167 - accuracy: 0.9292 - val_loss: 0.4677 - val_accuracy: 0.8483
# Epoch 3/5
# 1875/1875 [==============================] - 3s 1ms/step - loss: 0.2035 - accuracy: 0.9330 - val_loss: 0.5030 - val_accuracy: 0.8451
# Epoch 4/5
# 1875/1875 [==============================] - 3s 1ms/step - loss: 0.1985 - accuracy: 0.9355 - val_loss: 0.4748 - val_accuracy: 0.8533
# Epoch 5/5
# 1875/1875 [==============================] - 3s 1ms/step - loss: 0.1858 - accuracy: 0.9377 - val_loss: 0.4610 - val_accuracy: 0.8520
# Model 5
# Epoch 1/5
# 1875/1875 [==============================] - 3s 2ms/step - loss: 0.3642 - accuracy: 0.8862 - val_loss: 0.4243 - val_accuracy: 0.8646
# Epoch 2/5
# 1875/1875 [==============================] - 3s 1ms/step - loss: 0.2268 - accuracy: 0.9260 - val_loss: 0.4039 - val_accuracy: 0.8694
# Epoch 3/5
# 1875/1875 [==============================] - 3s 1ms/step - loss: 0.2190 - accuracy: 0.9298 - val_loss: 0.4931 - val_accuracy: 0.8510
# Epoch 4/5
# 1875/1875 [==============================] - 3s 1ms/step - loss: 0.2144 - accuracy: 0.9297 - val_loss: 0.4073 - val_accuracy: 0.8721
# Epoch 5/5
# 1875/1875 [==============================] - 3s 1ms/step - loss: 0.1984 - accuracy: 0.9346 - val_loss: 0.4358 - val_accuracy: 0.8646
# Layer 3
# HICO LENGTH
# 4
# Model 0
# Epoch 1/5
# 1875/1875 [==============================] - 3s 1ms/step - loss: 0.2697 - accuracy: 0.9180 - val_loss: 0.4745 - val_accuracy: 0.8706
# Epoch 2/5
# 1875/1875 [==============================] - 3s 1ms/step - loss: 0.1734 - accuracy: 0.9440 - val_loss: 0.4462 - val_accuracy: 0.8754
# Epoch 3/5
# 1875/1875 [==============================] - 3s 1ms/step - loss: 0.1635 - accuracy: 0.9470 - val_loss: 0.4345 - val_accuracy: 0.8732
# Epoch 4/5
# 1875/1875 [==============================] - 3s 1ms/step - loss: 0.1658 - accuracy: 0.9457 - val_loss: 0.4361 - val_accuracy: 0.8744
# Epoch 5/5
# 1875/1875 [==============================] - 3s 1ms/step - loss: 0.1565 - accuracy: 0.9481 - val_loss: 0.4466 - val_accuracy: 0.8747
# Model 1
# Epoch 1/5
# 1875/1875 [==============================] - 3s 1ms/step - loss: 0.2777 - accuracy: 0.9159 - val_loss: 0.4211 - val_accuracy: 0.8789
# Epoch 2/5
# 1875/1875 [==============================] - 3s 1ms/step - loss: 0.1647 - accuracy: 0.9472 - val_loss: 0.4589 - val_accuracy: 0.8750
# Epoch 3/5
# 1875/1875 [==============================] - 3s 1ms/step - loss: 0.1609 - accuracy: 0.9479 - val_loss: 0.4656 - val_accuracy: 0.8674
# Epoch 4/5
# 1875/1875 [==============================] - 3s 1ms/step - loss: 0.1545 - accuracy: 0.9499 - val_loss: 0.4273 - val_accuracy: 0.8752
# Epoch 5/5
# 1875/1875 [==============================] - 3s 1ms/step - loss: 0.1489 - accuracy: 0.9502 - val_loss: 0.4328 - val_accuracy: 0.8787
# Model 2
# Epoch 1/5
# 1875/1875 [==============================] - 3s 1ms/step - loss: 0.3060 - accuracy: 0.9112 - val_loss: 0.4689 - val_accuracy: 0.8672
# Epoch 2/5
# 1875/1875 [==============================] - 3s 1ms/step - loss: 0.1703 - accuracy: 0.9455 - val_loss: 0.4229 - val_accuracy: 0.8772
# Epoch 3/5
# 1875/1875 [==============================] - 3s 1ms/step - loss: 0.1634 - accuracy: 0.9470 - val_loss: 0.4833 - val_accuracy: 0.8637
# Epoch 4/5
# 1875/1875 [==============================] - 3s 1ms/step - loss: 0.1562 - accuracy: 0.9490 - val_loss: 0.4352 - val_accuracy: 0.8758
# Epoch 5/5
# 1875/1875 [==============================] - 3s 1ms/step - loss: 0.1535 - accuracy: 0.9492 - val_loss: 0.4046 - val_accuracy: 0.8822
# Model 3
# Epoch 1/5
# 1875/1875 [==============================] - 3s 2ms/step - loss: 0.2949 - accuracy: 0.9176 - val_loss: 0.4792 - val_accuracy: 0.8681
# Epoch 2/5
# 1875/1875 [==============================] - 3s 1ms/step - loss: 0.1643 - accuracy: 0.9483 - val_loss: 0.4315 - val_accuracy: 0.8761
# Epoch 3/5
# 1875/1875 [==============================] - 3s 1ms/step - loss: 0.1614 - accuracy: 0.9470 - val_loss: 0.4393 - val_accuracy: 0.8737
# Epoch 4/5
# 1875/1875 [==============================] - 3s 1ms/step - loss: 0.1564 - accuracy: 0.9482 - val_loss: 0.4268 - val_accuracy: 0.8766
# Epoch 5/5
# 1875/1875 [==============================] - 3s 1ms/step - loss: 0.1500 - accuracy: 0.9508 - val_loss: 0.4483 - val_accuracy: 0.8788
# Layer 4
# HICO LENGTH
# 5
# Model 0
# Epoch 1/5
# 1875/1875 [==============================] - 3s 1ms/step - loss: 0.2805 - accuracy: 0.9221 - val_loss: 0.4572 - val_accuracy: 0.8747
# Epoch 2/5
# 1875/1875 [==============================] - 3s 1ms/step - loss: 0.1454 - accuracy: 0.9528 - val_loss: 0.4325 - val_accuracy: 0.8745
# Epoch 3/5
# 1875/1875 [==============================] - 3s 1ms/step - loss: 0.1424 - accuracy: 0.9534 - val_loss: 0.4251 - val_accuracy: 0.8758
# Epoch 4/5
# 1875/1875 [==============================] - 3s 1ms/step - loss: 0.1405 - accuracy: 0.9539 - val_loss: 0.4494 - val_accuracy: 0.8786
# Epoch 5/5
# 1875/1875 [==============================] - 3s 1ms/step - loss: 0.1412 - accuracy: 0.9523 - val_loss: 0.4271 - val_accuracy: 0.8764
# Model 1
# Epoch 1/5
# 1875/1875 [==============================] - 3s 1ms/step - loss: 0.2413 - accuracy: 0.9317 - val_loss: 0.4631 - val_accuracy: 0.8770
# Epoch 2/5
# 1875/1875 [==============================] - 3s 1ms/step - loss: 0.1502 - accuracy: 0.9520 - val_loss: 0.4410 - val_accuracy: 0.8756
# Epoch 3/5
# 1875/1875 [==============================] - 3s 1ms/step - loss: 0.1473 - accuracy: 0.9513 - val_loss: 0.4140 - val_accuracy: 0.8809
# Epoch 4/5
# 1875/1875 [==============================] - 3s 1ms/step - loss: 0.1399 - accuracy: 0.9536 - val_loss: 0.4174 - val_accuracy: 0.8788
# Epoch 5/5
# 1875/1875 [==============================] - 3s 1ms/step - loss: 0.1434 - accuracy: 0.9534 - val_loss: 0.4573 - val_accuracy: 0.8777

# %% [markdown]
# ## Model Evaluation

# %%
# Predict on test image
y_pred_list_2 = []
for h in range(NUM_TEST_STEP):
  y_pred_list = []
  for j in range(NUM_TN[0]):
    y_pred = hico_layers[0][j][0].predict(X_test_cropped_list[(h*NUM_TN[0])+j])
    y_pred = y_pred * ((1 + ALPHA) - (NUM_TN[0] / max(NUM_TN)))
    y_pred_list.append(y_pred)

  for i in range(1, NUM_HICO_LAYER):
    for j in range(NUM_TN[i]):

      # Get test hidden representation from HiCo layer i-1
      X_test_input = []
      for k in range(NUM_CONNECTION[i]):
        get_input = (K.function(hico_layers[i-1][hico_layers[i][j][1][k]][0].layers[0].input, hico_layers[i-1][hico_layers[i][j][1][k]][0].layers[1].output))
        X_test_input.append(get_input(get_previous_layer_input(hico_layers, i-1, hico_layers[i-1][hico_layers[i][j][1][k]], X_test_cropped_list[h*NUM_TN[0]:(h+1)*NUM_TN[0]])))
      X_test_input = np.array(X_test_input)
      X_test_input = np.concatenate(X_test_input, axis=1)
      y_pred = hico_layers[i][j][0].predict(X_test_input)
      y_pred = y_pred * ((1 + ALPHA) - (NUM_TN[i] / max(NUM_TN)))
      y_pred_list.append(y_pred)

  # HiCo voting
  y_pred_list = np.array(y_pred_list)
  y_pred_list = np.transpose(y_pred_list, (1, 0, 2))
  y_pred_list = np.sum(y_pred_list, axis=1)
  y_pred_list_2.append(y_pred_list)

y_pred_list_2 = np.array(y_pred_list_2)
y_pred_list_2 = np.transpose(y_pred_list_2, (1, 0, 2))
y_pred_list_2 = np.argmax(np.sum(y_pred_list_2, axis=1), axis=1)

# %%
accuracy = accuracy_score(y_test, y_pred_list_2)
accuracy
# Out:
# 0.9583
