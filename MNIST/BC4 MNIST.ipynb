# %% [markdown]
# # BC 4
# ## Flat ensemble of tiny networks
# ## Input = whole image

# %%
from keras.models import Sequential
from keras.layers import Dense, Conv2D, Flatten
from keras.datasets import mnist
from keras.utils import to_categorical
import matplotlib.pyplot as plt
import numpy as np
import tensorflow as tf
import random
from scipy import stats
from sklearn.metrics import accuracy_score

# %%
NUM_TN = 30

#dataset specific parameters
NUM_CLASS = 10
SCALE = 28

# %% [markdown]
# ## Data Pre-Processing

# %%
#load dataset
(X_train, y_train), (X_test, y_test) = mnist.load_data()

# %%
#Generate subset of train image
X_train_subset_list = []
y_train_subset_list = []
train_zipped = zip(X_train, y_train)
train_zipped = np.array(tuple(train_zipped))

for i in range(NUM_TN):
  train_zipped_subset = random.choices(train_zipped, k=int(len(train_zipped)*60/100))
  X_train_subset = []
  y_train_subset = []
  for a in train_zipped_subset:
    X_train_subset.append(a[0])
    y_train_subset.append(a[1])
  X_train_subset = np.array(X_train_subset)
  y_train_subset = np.array(y_train_subset)

  X_train_subset_list.append(X_train_subset)
  y_train_subset_list.append(y_train_subset)
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:5: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray
#   """

# %%
#normalizing dataset
for i in range(NUM_TN):
  X_train_subset_list[i] = X_train_subset_list[i]/255

X_test = X_test/255

# %%
#transform to vector
for i in range(NUM_TN):
  X_train_subset_list[i] = X_train_subset_list[i].reshape((-1, SCALE*SCALE))

X_test = X_test.reshape((-1, SCALE*SCALE))

# %%
#one-hot encoding
for i in range(NUM_TN):
  y_train_subset_list[i] = to_categorical(y_train_subset_list[i])

y_test_one_hot = to_categorical(y_test)

# %% [markdown]
# ## Model

# %%
#build ANN model
ensemble = []
for i in range(NUM_TN):
  model = Sequential()
  model.add(Dense(64, activation='relu', input_dim=SCALE*SCALE))
  model.add(Dense(64, activation='relu'))
  model.add(Dense(NUM_CLASS, activation = 'softmax'))
  model.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])
  ensemble.append(model)

# %%
#train model
history = []
for i in range(NUM_TN):
  print('Model %d' %i)
  hist = ensemble[i].fit(X_train_subset_list[i], y_train_subset_list[i], validation_data=(X_test, y_test_one_hot), epochs=5, batch_size=128)
  history.append(hist)
# Out:
# Model 0
# Epoch 1/5
# 282/282 [==============================] - 2s 4ms/step - loss: 0.9018 - accuracy: 0.7407 - val_loss: 0.2699 - val_accuracy: 0.9214
# Epoch 2/5
# 282/282 [==============================] - 1s 3ms/step - loss: 0.2110 - accuracy: 0.9375 - val_loss: 0.1865 - val_accuracy: 0.9458
# Epoch 3/5
# 282/282 [==============================] - 1s 3ms/step - loss: 0.1501 - accuracy: 0.9579 - val_loss: 0.1646 - val_accuracy: 0.9518
# Epoch 4/5
# 282/282 [==============================] - 1s 3ms/step - loss: 0.1199 - accuracy: 0.9658 - val_loss: 0.1410 - val_accuracy: 0.9578
# Epoch 5/5
# 282/282 [==============================] - 1s 3ms/step - loss: 0.0931 - accuracy: 0.9735 - val_loss: 0.1371 - val_accuracy: 0.9577
# Model 1
# Epoch 1/5
# 282/282 [==============================] - 1s 4ms/step - loss: 0.9454 - accuracy: 0.7330 - val_loss: 0.2314 - val_accuracy: 0.9331
# Epoch 2/5
# 282/282 [==============================] - 1s 3ms/step - loss: 0.2116 - accuracy: 0.9402 - val_loss: 0.1802 - val_accuracy: 0.9473
# Epoch 3/5
# 282/282 [==============================] - 1s 3ms/step - loss: 0.1549 - accuracy: 0.9555 - val_loss: 0.1581 - val_accuracy: 0.9529
# Epoch 4/5
# 282/282 [==============================] - 1s 3ms/step - loss: 0.1200 - accuracy: 0.9665 - val_loss: 0.1298 - val_accuracy: 0.9616
# Epoch 5/5
# 282/282 [==============================] - 1s 3ms/step - loss: 0.0931 - accuracy: 0.9728 - val_loss: 0.1254 - val_accuracy: 0.9616
# Model 2
# Epoch 1/5
# 282/282 [==============================] - 2s 4ms/step - loss: 0.8676 - accuracy: 0.7590 - val_loss: 0.2371 - val_accuracy: 0.9318
# Epoch 2/5
# 282/282 [==============================] - 1s 3ms/step - loss: 0.2219 - accuracy: 0.9366 - val_loss: 0.1785 - val_accuracy: 0.9466
# Epoch 3/5
# 282/282 [==============================] - 1s 3ms/step - loss: 0.1481 - accuracy: 0.9562 - val_loss: 0.1556 - val_accuracy: 0.9511
# Epoch 4/5
# 282/282 [==============================] - 1s 3ms/step - loss: 0.1110 - accuracy: 0.9666 - val_loss: 0.1350 - val_accuracy: 0.9583
# Epoch 5/5
# 282/282 [==============================] - 1s 3ms/step - loss: 0.0847 - accuracy: 0.9771 - val_loss: 0.1293 - val_accuracy: 0.9588
# Model 3
# Epoch 1/5
# 282/282 [==============================] - 1s 4ms/step - loss: 0.9095 - accuracy: 0.7348 - val_loss: 0.2439 - val_accuracy: 0.9308
# Epoch 2/5
# 282/282 [==============================] - 1s 3ms/step - loss: 0.2015 - accuracy: 0.9423 - val_loss: 0.1733 - val_accuracy: 0.9479
# Epoch 3/5
# 282/282 [==============================] - 1s 3ms/step - loss: 0.
# Epoch 1/5
# 282/282 [==============================] - 2s 4ms/step - loss: 0.9210 - accuracy: 0.7322 - val_loss: 0.2397 - val_accuracy: 0.9296
# Epoch 2/5
# 282/282 [==============================] - 1s 3ms/step - loss: 0.2176 - accuracy: 0.9377 - val_loss: 0.1892 - val_accuracy: 0.9460
# Epoch 3/5
# 282/282 [==============================] - 1s 3ms/step - loss: 0.1522 - accuracy: 0.9563 - val_loss: 0.1647 - val_accuracy: 0.9512
# Epoch 4/5
# 282/282 [==============================] - 1s 4ms/step - loss: 0.1170 - accuracy: 0.9666 - val_loss: 0.1597 - val_accuracy: 0.9532
# Epoch 5/5
# 282/282 [==============================] - 1s 3ms/step - loss: 0.0959 - accuracy: 0.9736 - val_loss: 0.1380 - val_accuracy: 0.9609
# Model 25
# Epoch 1/5
# 282/282 [==============================] - 2s 4ms/step - loss: 0.9084 - accuracy: 0.7515 - val_loss: 0.2378 - val_accuracy: 0.9291
# Epoch 2/5
# 282/282 [==============================] - 1s 4ms/step - loss: 0.2049 - accuracy: 0.9397 - val_loss: 0.1783 - val_accuracy: 0.9448
# Epoch 3/5
# 282/282 [==============================] - 1s 4ms/step - loss: 0.1515 - accuracy: 0.9556 - val_loss: 0.1477 - val_accuracy: 0.9560
# Epoch 4/5
# 282/282 [==============================] - 1s 4ms/step - loss: 0.1096 - accuracy: 0.9689 - val_loss: 0.1327 - val_accuracy: 0.9579
# Epoch 5/5
# 282/282 [==============================] - 1s 3ms/step - loss: 0.0900 - accuracy: 0.9731 - val_loss: 0.1159 - val_accuracy: 0.9632
# Model 26
# Epoch 1/5
# 282/282 [==============================] - 2s 4ms/step - loss: 0.9263 - accuracy: 0.7336 - val_loss: 0.2415 - val_accuracy: 0.9299
# Epoch 2/5
# 282/282 [==============================] - 1s 3ms/step - loss: 0.2170 - accuracy: 0.9360 - val_loss: 0.1824 - val_accuracy: 0.9450
# Epoch 3/5
# 282/282 [==============================] - 1s 3ms/step - loss: 0.1487 - accuracy: 0.9570 - val_loss: 0.1559 - val_accuracy: 0.9515
# Epoch 4/5
# 282/282 [==============================] - 1s 3ms/step - loss: 0.1129 - accuracy: 0.9677 - val_loss: 0.1442 - val_accuracy: 0.9563
# Epoch 5/5
# 282/282 [==============================] - 1s 3ms/step - loss: 0.0904 - accuracy: 0.9741 - val_loss: 0.1333 - val_accuracy: 0.9588
# Model 27
# Epoch 1/5
# 282/282 [==============================] - 1s 4ms/step - loss: 0.8461 - accuracy: 0.7556 - val_loss: 0.2530 - val_accuracy: 0.9283
# Epoch 2/5
# 282/282 [==============================] - 1s 3ms/step - loss: 0.2169 - accuracy: 0.9347 - val_loss: 0.1844 - val_accuracy: 0.9453
# Epoch 3/5
# 282/282 [==============================] - 1s 4ms/step - loss: 0.1512 - accuracy: 0.9545 - val_loss: 0.1650 - val_accuracy: 0.9509
# Epoch 4/5
# 282/282 [==============================] - 1s 3ms/step - loss: 0.1165 - accuracy: 0.9648 - val_loss: 0.1402 - val_accuracy: 0.9577
# Epoch 5/5
# 282/282 [==============================] - 1s 3ms/step - loss: 0.0933 - accuracy: 0.9719 - val_loss: 0.1263 - val_accuracy: 0.9631
# Model 28
# Epoch 1/5
# 282/282 [==============================] - 2s 4ms/step - loss: 0.8977 - accuracy: 0.7438 - val_loss: 0.2320 - val_accuracy: 0.9307
# Epoch 2/5
# 282/282 [==============================] - 1s 3ms/step - loss: 0.2085 - accuracy: 0.9409 - val_loss: 0.1782 - val_accuracy: 0.9463
# Epoch 3/5
# 282/282 [==============================] - 1s 4ms/step - loss: 0.1430 - accuracy: 0.9588 - val_loss: 0.1419 - val_accuracy: 0.9566
# Epoch 4/5
# 282/282 [==============================] - 1s 3ms/step - loss: 0.1087 - accuracy: 0.9673 - val_loss: 0.1311 - val_accuracy: 0.9596
# Epoch 5/5
# 282/282 [==============================] - 1s 3ms/step - loss: 0.0875 - accuracy: 0.9739 - val_loss: 0.1237 - val_accuracy: 0.9637
# Model 29
# Epoch 1/5
# 282/282 [==============================] - 2s 4ms/step - loss: 0.8971 - accuracy: 0.7390 - val_loss: 0.2478 - val_accuracy: 0.9294
# Epoch 2/5
# 282/282 [==============================] - 1s 3ms/step - loss: 0.2148 - accuracy: 0.9384 - val_loss: 0.1860 - val_accuracy: 0.9460
# Epoch 3/5
# 282/282 [==============================] - 1s 4ms/step - loss: 0.1542 - accuracy: 0.9568 - val_loss: 0.1518 - val_accuracy: 0.9562
# Epoch 4/5
# 282/282 [==============================] - 1s 4ms/step - loss: 0.1139 - accuracy: 0.9689 - val_loss: 0.1483 - val_accuracy: 0.9563
# Epoch 5/5
# 282/282 [==============================] - 1s 3ms/step - loss: 0.0897 - accuracy: 0.9749 - val_loss: 0.1339 - val_accuracy: 0.9595

# %% [markdown]
# ## Model Evaluation

# %%
# Predict on test image
y_pred_list = []
for i in range(NUM_TN):
  y_pred = ensemble[i].predict(X_test)
  y_pred_list.append(y_pred)

# Ensemble voting
y_pred_list = np.array(y_pred_list)
y_pred_list = np.argmax(np.sum(y_pred_list, axis=0), axis=1)

# %%
accuracy = accuracy_score(y_test, y_pred_list)
accuracy
# Out:
# 0.9693
