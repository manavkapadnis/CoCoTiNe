# %% [markdown]
# # Variants-Experiment 1.4
#
# ## Concatenated hidden representations and concatenated output logits.
# ## Mode. Compute classifications of all tiny networks, in all HiCo layers, and take the mode as the final classification.

# %%
from keras.models import Sequential
from keras.layers import Dense, Conv2D, Flatten
from keras.datasets import mnist
from keras.utils import to_categorical
import matplotlib.pyplot as plt
import numpy as np
import tensorflow as tf
import random
from scipy import stats
from sklearn.metrics import accuracy_score
from keras import backend as K

import os
import pickle
from google.colab import drive
drive.mount('/content/drive/')
# Out:
# Mounted at /content/drive/

# %%
SUB_REGION_SCALE = 14
NUM_HICO_LAYER = 5
NUM_TN = [10, 8, 6, 4, 2]
NUM_CONNECTION = [0, 5, 4, 3, 2]

#dataset specific parameters
NUM_CLASS = 10

# %% [markdown]
# ## Data Pre-Processing

# %%
with open('/content/drive/My Drive/fyp/MNIST.pickle', 'rb') as f:
    X_train_cropped_list, y_train_one_hot, X_test_cropped_list, y_test_one_hot, coordinate_list, scale_list = pickle.load(f)

# %% [markdown]
# ## HiCo Layer 1

# %%
#build ANN model
ensemble = []
for i in range(NUM_TN[0]):
  model = Sequential()
  model.add(Dense(64, activation='relu', input_dim=SUB_REGION_SCALE*SUB_REGION_SCALE))
  model.add(Dense(64, activation='relu'))
  model.add(Dense(NUM_CLASS, activation = 'softmax'))
  model.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])
  ensemble.append((model, i, coordinate_list[i], scale_list[i]))

# %%
for i in range(NUM_TN[0]):
  ensemble[i][0].load_weights('/content/drive/My Drive/fyp/MNIST_' + str(i) + '.h5')

# %%
hico_layers = []
hico_layers.append(ensemble)

# %%
del hico_layers[1:]

# %% [markdown]
# ## HiCo Layer 2+

# %%
# Function to get input of layer i-1
def get_previous_layer_input(hico_layers, layer, tn, train_image):
  input_hr = []
  input_ol = []
    
  if layer == 0:
    previous_layer_input = train_image[tn[1]]
    return previous_layer_input

  elif layer > 0:
    for i in range(NUM_CONNECTION[layer]):
      get_input = (K.function(hico_layers[layer-1][tn[1][i]][0].layers[0].input, hico_layers[layer-1][tn[1][i]][0].layers[1].output))
      input_hr.append(get_input(get_previous_layer_input(hico_layers, layer-1, hico_layers[layer-1][tn[1][i]], train_image)))
      
    input_hr = np.array(input_hr)
    input_hr = np.concatenate(input_hr, axis=1)

    for i in range(NUM_CONNECTION[layer]):
      get_input = (K.function(hico_layers[layer-1][tn[1][i]][0].layers[0].input, hico_layers[layer-1][tn[1][i]][0].layers[2].output))
      input_ol.append(get_input(get_previous_layer_input(hico_layers, layer-1, hico_layers[layer-1][tn[1][i]], train_image)))

    input_ol = np.array(input_ol)
    input_ol = np.concatenate(input_ol, axis=1)

    input = np.concatenate((input_hr, input_ol), axis=1)
    
    previous_layer_input = input
    return previous_layer_input

# %%
for i in range(1, NUM_HICO_LAYER):
  print('Layer %d' %i)
  ensemble = []
  X_train_input_list = []
  X_test_input_list = []

  for j in range(NUM_TN[i]):
    # Build model of HiCo layer i
    connection = tuple(random.sample(range(len(hico_layers[i-1])), k=NUM_CONNECTION[i]))
    model = Sequential()
    model.add(Dense(64, activation='relu', input_dim=64*NUM_CONNECTION[i]+NUM_CLASS*NUM_CONNECTION[i]))
    model.add(Dense(64, activation='relu'))
    model.add(Dense(NUM_CLASS, activation = 'softmax'))
    model.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])
    ensemble.append((model, connection))
  hico_layers.append(ensemble)
  print('HICO LENGTH')
  print(len(hico_layers))

  for j in range(NUM_TN[i]):
    # Get train hidden representation from HiCo layer i-1
    X_train_input_hr = []
    X_train_input_ol = []
    for k in range(NUM_CONNECTION[i]):
      get_input = (K.function(hico_layers[i-1][hico_layers[i][j][1][k]][0].layers[0].input, hico_layers[i-1][hico_layers[i][j][1][k]][0].layers[1].output))
      X_train_input_hr.append(get_input(get_previous_layer_input(hico_layers, i-1, hico_layers[i-1][hico_layers[i][j][1][k]], X_train_cropped_list)))
    X_train_input_hr = np.array(X_train_input_hr)
    X_train_input_hr = np.concatenate(X_train_input_hr, axis=1)

    for k in range(NUM_CONNECTION[i]):
      get_input = (K.function(hico_layers[i-1][hico_layers[i][j][1][k]][0].layers[0].input, hico_layers[i-1][hico_layers[i][j][1][k]][0].layers[2].output))
      X_train_input_ol.append(get_input(get_previous_layer_input(hico_layers, i-1, hico_layers[i-1][hico_layers[i][j][1][k]], X_train_cropped_list)))
    X_train_input_ol = np.array(X_train_input_ol)
    X_train_input_ol = np.concatenate(X_train_input_ol, axis=1)

    X_train_input = np.concatenate((X_train_input_hr, X_train_input_ol), axis=1)
    X_train_input_list.append(X_train_input)

    # Get test hidden representation from HiCo layer i-1
    X_test_input_hr = []
    X_test_input_ol = []
    for k in range(NUM_CONNECTION[i]):
      get_input = (K.function(hico_layers[i-1][hico_layers[i][j][1][k]][0].layers[0].input, hico_layers[i-1][hico_layers[i][j][1][k]][0].layers[1].output))
      X_test_input_hr.append(get_input(get_previous_layer_input(hico_layers, i-1, hico_layers[i-1][hico_layers[i][j][1][k]], X_test_cropped_list)))
    X_test_input_hr = np.array(X_test_input_hr)
    X_test_input_hr = np.concatenate(X_test_input_hr, axis=1)

    for k in range(NUM_CONNECTION[i]):
      get_input = (K.function(hico_layers[i-1][hico_layers[i][j][1][k]][0].layers[0].input, hico_layers[i-1][hico_layers[i][j][1][k]][0].layers[2].output))
      X_test_input_ol.append(get_input(get_previous_layer_input(hico_layers, i-1, hico_layers[i-1][hico_layers[i][j][1][k]], X_test_cropped_list)))
    X_test_input_ol = np.array(X_test_input_ol)
    X_test_input_ol = np.concatenate(X_test_input_ol, axis=1)

    X_test_input = np.concatenate((X_test_input_hr, X_test_input_ol), axis=1)
    X_test_input_list.append(X_test_input)

  #train model of HiCo layer i
  for j in range(NUM_TN[i]):
    print('Model %d' %j)
    hico_layers[i][j][0].fit(X_train_input_list[j], y_train_one_hot, validation_data=(X_test_input_list[j], y_test_one_hot), epochs=5, batch_size=128)
# Out:
# Layer 1
# HICO LENGTH
# 2
# Model 0
# Epoch 1/5
# 469/469 [==============================] - 2s 4ms/step - loss: 0.3591 - accuracy: 0.8991 - val_loss: 0.0878 - val_accuracy: 0.9714
# Epoch 2/5
# 469/469 [==============================] - 1s 3ms/step - loss: 0.0734 - accuracy: 0.9778 - val_loss: 0.0711 - val_accuracy: 0.9764
# Epoch 3/5
# 469/469 [==============================] - 1s 3ms/step - loss: 0.0653 - accuracy: 0.9795 - val_loss: 0.0777 - val_accuracy: 0.9750
# Epoch 4/5
# 469/469 [==============================] - 1s 3ms/step - loss: 0.0593 - accuracy: 0.9809 - val_loss: 0.0702 - val_accuracy: 0.9782
# Epoch 5/5
# 469/469 [==============================] - 1s 3ms/step - loss: 0.0550 - accuracy: 0.9823 - val_loss: 0.0783 - val_accuracy: 0.9747
# Model 1
# Epoch 1/5
# 469/469 [==============================] - 2s 3ms/step - loss: 0.3520 - accuracy: 0.9006 - val_loss: 0.0787 - val_accuracy: 0.9766
# Epoch 2/5
# 469/469 [==============================] - 1s 3ms/step - loss: 0.0700 - accuracy: 0.9782 - val_loss: 0.0640 - val_accuracy: 0.9803
# Epoch 3/5
# 469/469 [==============================] - 1s 3ms/step - loss: 0.0650 - accuracy: 0.9802 - val_loss: 0.0585 - val_accuracy: 0.9813
# Epoch 4/5
# 469/469 [==============================] - 1s 3ms/step - loss: 0.0588 - accuracy: 0.9816 - val_loss: 0.0638 - val_accuracy: 0.9786
# Epoch 5/5
# 469/469 [==============================] - 1s 3ms/step - loss: 0.0512 - accuracy: 0.9837 - val_loss: 0.0613 - val_accuracy: 0.9815
# Model 2
# Epoch 1/5
# 469/469 [==============================] - 2s 3ms/step - loss: 0.4367 - accuracy: 0.8682 - val_loss: 0.0951 - val_accuracy: 0.9693
# Epoch 2/5
# 469/469 [==============================] - 1s 3ms/step - loss: 0.0893 - accuracy: 0.9724 - val_loss: 0.0810 - val_accuracy: 0.9746
# Epoch 3/5
# 469/469 [==============================] - 1s 3ms/step - loss: 0.0759 - accuracy: 0.9761 - val_loss: 0.0795 - val_accuracy: 0.9738
# Epoch 4/5
# 469/469 [==============================] - 1s 3ms/step - loss: 0.0697 - accuracy: 0.9784 - val_loss: 0.0754 - val_accuracy: 0.9771
# Epoch 5/5
# 469/469 [==============================] - 1s 3ms/step - loss: 0.0671 - accuracy: 0.9796 - val_loss: 0.0763 - val_accuracy: 0.9757
# Model 3
# Epoch 1/5
# 469/469 [==============================] - 2s 3ms/step - loss: 0.3879 - accuracy: 0.8945 - val_loss: 0.0831 - val_accuracy: 0.9744
# Epoch 2/5
# 469/469 [==============================] - 1s 3ms/step - loss: 0.0767 - accuracy: 0.9766 - val_loss: 0.0771 - val_accuracy: 0.9759
# Epoch 3/5
# 469/469 [==============================] - 1s 3ms/step - loss: 0.0656 - accuracy: 0.9791 - val_loss: 0.0767 - val_accuracy: 0.9758
# Epoch 4/5
# 469/469 [==============================] - 1s 3ms/step - loss: 0.0651 - accuracy: 0.9793 - val_loss: 0.0654 - val_accuracy: 0.9800
# Epoch 5/5
# 469/469 [==============================] - 1s 3ms/step - loss: 0.0551 - accuracy: 0.9829 - val_loss: 0.0741 - val_accuracy: 0.9778
# Model 4
# Epoch 1/5
# 469/469 [==============================] - 2s 4ms/step - loss: 0.4038 - accuracy: 0.8915 - val_loss: 0.0879 - val_accuracy: 0.9740
# Epoch 2/5
# 469/469 [==============================] - 1s 3ms/step - loss: 0.0777 - accuracy: 0.9759 - val_loss: 0.0787 - val_accuracy: 0.9762
# Epoch 3/5
# 469/469 [==============================] - 1s 3ms/step - loss: 0.0622 - accuracy: 0.9810 - val_loss: 0.0752 - val_accuracy: 0.9775
# Epoch 4/5
# 469/469 [==============================] - 1s 3ms/step - loss: 0.0585 - accuracy: 0.9813 - val_loss: 0.0775 - val_accuracy: 0.9776
# Epoch 5/5
# 469/469 [==============================] - 1s 3ms/step - loss: 0.0545 - accuracy: 0.9831 - val_loss: 0.0845 - val_accuracy: 0.9744
# Model 5
# Epoch 1/5
# 469/469 [==============================] - 2s 3ms/step - loss: 0.3963 - accuracy: 0.8992 - val_loss: 0.0675 - val_accuracy: 0.9789
# Epoch 2/5
# 469/469 [==============================] - 1s 3ms/step - loss: 0.0690 - accuracy: 0.9788 - val_loss: 0.0573 - val_accuracy: 0.9819
# Epoch 3/5
# 469/469 [==============================] - 1s 3ms/step - loss: 0.0600 - accuracy: 0.9817 - val_loss: 0.0601 - val_accuracy: 0.9805
# Epoch 4/5
# 469/469 [==============================] - 1s 3ms/step - loss: 0.0536 - accuracy: 0.9835 - val_loss: 0.0578 - val_accuracy: 0.9818
# Epoch 5/5
# 469/469 [==============================] - 1s 3ms/step - loss: 0.0498 - accuracy: 0.9844 - val_loss: 0.0586 - val_accuracy: 0.9816
# Model 6
# Epoch 1/5
# 469/469 [==============================] - 2s 3ms/step - loss: 0.3843 - accuracy: 0.8889 - val_loss: 0.1009 - val_accuracy: 0.9695
# Epoch 2/5
# 469/469 [==============================] - 1s 3ms/step - loss: 0.0784 - accuracy: 0.9757 - val_loss: 0.0735 - val_accuracy: 0.9773
# Epoch 3/5
# 469/469 [==============================] - 1s 3ms/step - loss: 0.0705 - accuracy: 0.9783 - val_loss: 0.0738 - val_accuracy: 0.9785
# Epoch 4/5
# 469/469 [==============================] - 1s 3ms/step - loss: 0.0610 - accuracy: 0.9815 - val_loss: 0.0753 - val_accuracy: 0.9787
# Epoch 5/5
# 469/469 [==============================] - 1s 3ms/step - loss: 0.0582 - accuracy: 0.9817 - val_loss: 0.0748 - val_accuracy: 0.9778
# Model 7
# Epoch 1/5
# 469/469 [==============================] - 2s 3ms/step - loss: 0.3482 - accuracy: 0.9027 - val_loss: 0.0922 - val_accuracy: 0.9736
# Epoch 2/5
# 469/469 [==============================] - 1s 3ms/step - loss: 0.0687 - accuracy: 0.9793 - val_loss: 0.0616 - val_accuracy: 0.9804
# Epoch 3/5
# 469/469 [==============================] - 1s 3ms/step - loss: 0.0579 - accuracy: 0.9825 - val_loss: 0.0659 - val_accuracy: 0.9810
# Epoch 4/5
# 469/469 [==============================] - 1s 3ms/step - loss: 0.0562 - accuracy: 0.9829 - val_loss: 0.0538 - val_accuracy: 0.9825
# Epoch 5/5
# 469/469 [==============================] - 1s 3ms/step - loss: 0.0480 - accuracy: 0.9849 - val_loss: 0.0625 - val_accuracy: 0.9807
# Layer 2
# HICO LENGTH
# 3
# Model 0
# Epoch 1/5
# 469/469 [==============================] - 2s 3ms/step - loss: 0.2923 - accuracy: 0.9233 - val_loss: 0.0624 - val_accuracy: 0.9812
# Epoch 2/5
# 469/469 [==============================] - 1s 3ms/step - loss: 0.0429 - accuracy: 0.9869 - val_loss: 0.0584 - val_accuracy: 0.9825
# Epoch 3/5
# 469/469 [==============================] - 1s 3ms/step - loss: 0.0440 - accuracy: 0.9867 - val_loss: 0.0581 - val_accuracy: 0.9838
# Epoch 4/5
# 469/469 [==============================] - 1s 3ms/step - loss: 0.0395 - accuracy: 0.9878 - val_loss: 0.0528 - val_accuracy: 0.9841
# Epoch 5/5
# 469/469 [==============================] - 1s 3ms/step - loss: 0.0366 - accuracy: 0.9888 - val_loss: 0.0532 - val_accuracy: 0.9837
# Model 1
# Epoch 1/5
# 469/469 [==============================] - 2s 3ms/step - loss: 0.2268 - accuracy: 0.9395 - val_loss: 0.0567 - val_accuracy: 0.9831
# Epoch 2/5
# 469/469 [==============================] - 1s 3ms/step - loss: 0.0408 - accuracy: 0.9878 - val_loss: 0.0568 - val_accuracy: 0.9827
# Epoch 3/5
# 469/469 [==============================] - 1s 3ms/step - loss: 0.0376 - accuracy: 0.9880 - val_loss: 0.0539 - val_accuracy: 0.9831
# Epoch 4/5
# 469/469 [==============================] - 1s 3ms/step - loss: 0.0366 - accuracy: 0.9886 - val_loss: 0.0560 - val_accuracy: 0.9839
# Epoch 5/5
# 469/469 [==============================] - 1s 3ms/step - loss: 0.0315 - accuracy: 0.9896 - val_loss: 0.0572 - val_accuracy: 0.9828
# Model 2
# Epoch 1/5
# 469/469 [==============================] - 2s 3ms/step - loss: 0.2667 - accuracy: 0.9289 - val_loss: 0.0518 - val_accuracy: 0.9838
# Epoch 2/5
# 469/469 [==============================] - 1s 3ms/step - loss: 0.0376 - accuracy: 0.9880 - val_loss: 0.0480 - val_accuracy: 0.9854
# Epoch 3/5
# 469/469 [==============================] - 1s 3ms/step - loss: 0.0357 - accuracy: 0.9890 - val_loss: 0.0551 - val_accuracy: 0.9829
# Epoch 4/5
# 469/469 [==============================] - 1s 3ms/step - loss: 0.0351 - accuracy: 0.9890 - val_loss: 0.0495 - val_accuracy: 0.9848
# Epoch 5/5
# 469/469 [==============================] - 1s 3ms/step - loss: 0.0347 - accuracy: 0.9891 - val_loss: 0.0584 - val_accuracy: 0.9815
# Model 3
# Epoch 1/5
# 469/469 [==============================] - 2s 3ms/step - loss: 0.2911 - accuracy: 0.9256 - val_loss: 0.0555 - val_accuracy: 0.9837
# Epoch 2/5
# 469/469 [==============================] - 1s 3ms/step - loss: 0.0415 - accuracy: 0.9874 - val_loss: 0.0535 - val_accuracy: 0.9845
# Epoch 3/5
# 469/469 [==============================] - 1s 3ms/step - loss: 0.0358 - accuracy: 0.9889 - val_loss: 0.0513 - val_accuracy: 0.9850
# Epoch 4/5
# 469/469 [==============================] - 1s 3ms/step - loss: 0.0337 - accuracy: 0.9892 - val_loss: 0.0481 - val_accuracy: 0.9852
# Epoch 5/5
# 469/469 [==============================] - 1s 3ms/step - loss: 0.0341 - accuracy: 0.9889 - val_loss: 0.0488 - val_accuracy: 0.9863
# Model 4
# Epoch 1/5
# 469/469 [==============================] - 2s 3ms/step - loss: 0.2881 - accuracy: 0.9222 - val_loss: 0.0527 - val_accuracy: 0.9851
# Epoch 2/5
# 469/469 [==============================] - 1s 3ms/step - loss: 0.0425 - accuracy: 0.9870 - val_loss: 0.0510 - val_accuracy: 0.9837
# Epoch 3/5
# 469/469 [==============================] - 1s 3ms/step - loss: 0.0402 - accuracy: 0.9874 - val_loss: 0.0571 - val_accuracy: 0.9832
# Epoch 4/5
# 469/469 [==============================] - 1s 3ms/step - loss: 0.0376 - accuracy: 0.9883 - val_loss: 0.0502 - val_accuracy: 0.9857
# Epoch 5/5
# 469/469 [==============================] - 1s 3ms/step - loss: 0.0342 - accuracy: 0.9892 - val_loss: 0.0501 - val_accuracy: 0.9849
# Model 5
# Epoch 1/5
# 469/469 [==============================] - 2s 3ms/step - loss: 0.2567 - accuracy: 0.9296 - val_loss: 0.0508 - val_accuracy: 0.9850
# Epoch 2/5
# 469/469 [==============================] - 1s 3ms/step - loss: 0.0415 - accuracy: 0.9869 - val_loss: 0.0500 - val_accuracy: 0.9849
# Epoch 3/5
# 469/469 [==============================] - 1s 3ms/step - loss: 0.0384 - accuracy: 0.9879 - val_loss: 0.0512 - val_accuracy: 0.9855
# Epoch 4/5
# 469/469 [==============================] - 1s 3ms/step - loss: 0.0340 - accuracy: 0.9892 - val_loss: 0.0490 - val_accuracy: 0.9845
# Epoch 5/5
# 469/469 [==============================] - 1s 3ms/step - loss: 0.0327 - accuracy: 0.9900 - val_loss: 0.0463 - val_accuracy: 0.9850
# Layer 3
# HICO LENGTH
# 4
# Model 0
# Epoch 1/5
# 469/469 [==============================] - 2s 3ms/step - loss: 0.2242 - accuracy: 0.9385 - val_loss: 0.0507 - val_accuracy: 0.9855
# Epoch 2/5
# 469/469 [==============================] - 1s 2ms/step - loss: 0.0329 - accuracy: 0.9896 - val_loss: 0.0547 - val_accuracy: 0.9841
# Epoch 3/5
# 469/469 [==============================] - 1s 2ms/step - loss: 0.0294 - accuracy: 0.9910 - val_loss: 0.0551 - val_accuracy: 0.9851
# Epoch 4/5
# 469/469 [==============================] - 1s 2ms/step - loss: 0.0310 - accuracy: 0.9904 - val_loss: 0.0552 - val_accuracy: 0.9855
# Epoch 5/5
# 469/469 [==============================] - 1s 2ms/step - loss: 0.0280 - accuracy: 0.9911 - val_loss: 0.0526 - val_accuracy: 0.9853
# Model 1
# Epoch 1/5
# 469/469 [==============================] - 2s 3ms/step - loss: 0.2794 - accuracy: 0.9316 - val_loss: 0.0546 - val_accuracy: 0.9849
# Epoch 2/5
# 469/469 [==============================] - 1s 2ms/step - loss: 0.0345 - accuracy: 0.9900 - val_loss: 0.0501 - val_accuracy: 0.9857
# Epoch 3/5
# 469/469 [==============================] - 1s 2ms/step - loss: 0.0332 - accuracy: 0.9893 - val_loss: 0.0501 - val_accuracy: 0.9856
# Epoch 4/5
# 469/469 [==============================] - 1s 2ms/step - loss: 0.0295 - accuracy: 0.9912 - val_loss: 0.0479 - val_accuracy: 0.9864
# Epoch 5/5
# 469/469 [==============================] - 1s 3ms/step - loss: 0.0317 - accuracy: 0.9902 - val_loss: 0.0571 - val_accuracy: 0.9844
# Model 2
# Epoch 1/5
# 469/469 [==============================] - 2s 3ms/step - loss: 0.1899 - accuracy: 0.9501 - val_loss: 0.0509 - val_accuracy: 0.9853
# Epoch 2/5
# 469/469 [==============================] - 1s 2ms/step - loss: 0.0307 - accuracy: 0.9902 - val_loss: 0.0531 - val_accuracy: 0.9847
# Epoch 3/5
# 469/469 [==============================] - 1s 2ms/step - loss: 0.0292 - accuracy: 0.9910 - val_loss: 0.0480 - val_accuracy: 0.9861
# Epoch 4/5
# 469/469 [==============================] - 1s 3ms/step - loss: 0.0269 - accuracy: 0.9916 - val_loss: 0.0491 - val_accuracy: 0.9850
# Epoch 5/5
# 469/469 [==============================] - 1s 2ms/step - loss: 0.0291 - accuracy: 0.9910 - val_loss: 0.0483 - val_accuracy: 0.9854
# Model 3
# Epoch 1/5
# 469/469 [==============================] - 2s 3ms/step - loss: 0.2331 - accuracy: 0.9371 - val_loss: 0.0520 - val_accuracy: 0.9851
# Epoch 2/5
# 469/469 [==============================] - 1s 3ms/step - loss: 0.0311 - accuracy: 0.9905 - val_loss: 0.0503 - val_accuracy: 0.9862
# Epoch 3/5
# 469/469 [==============================] - 1s 2ms/step - loss: 0.0320 - accuracy: 0.9896 - val_loss: 0.0502 - val_accuracy: 0.9859
# Epoch 4/5
# 469/469 [==============================] - 1s 3ms/step - loss: 0.0277 - accuracy: 0.9918 - val_loss: 0.0475 - val_accuracy: 0.9871
# Epoch 5/5
# 469/469 [==============================] - 1s 2ms/step - loss: 0.0286 - accuracy: 0.9914 - val_loss: 0.0525 - val_accuracy: 0.9852
# Layer 4
# HICO LENGTH
# 5
# Model 0
# Epoch 1/5
# 469/469 [==============================] - 2s 3ms/step - loss: 0.2030 - accuracy: 0.9444 - val_loss: 0.0496 - val_accuracy: 0.9860
# Epoch 2/5
# 469/469 [==============================] - 1s 2ms/step - loss: 0.0241 - accuracy: 0.9923 - val_loss: 0.0498 - val_accuracy: 0.9860
# Epoch 3/5
# 469/469 [==============================] - 1s 3ms/step - loss: 0.0260 - accuracy: 0.9920 - val_loss: 0.0505 - val_accuracy: 0.9858
# Epoch 4/5
# 469/469 [==============================] - 1s 2ms/step - loss: 0.0267 - accuracy: 0.9920 - val_loss: 0.0496 - val_accuracy: 0.9858
# Epoch 5/5
# 469/469 [==============================] - 1s 3ms/step - loss: 0.0263 - accuracy: 0.9921 - val_loss: 0.0491 - val_accuracy: 0.9865
# Model 1
# Epoch 1/5
# 469/469 [==============================] - 2s 3ms/step - loss: 0.3740 - accuracy: 0.9240 - val_loss: 0.0526 - val_accuracy: 0.9860
# Epoch 2/5
# 469/469 [==============================] - 1s 2ms/step - loss: 0.0273 - accuracy: 0.9916 - val_loss: 0.0531 - val_accuracy: 0.9854
# Epoch 3/5
# 469/469 [==============================] - 1s 2ms/step - loss: 0.0252 - accuracy: 0.9918 - val_loss: 0.0507 - val_accuracy: 0.9859
# Epoch 4/5
# 469/469 [==============================] - 1s 3ms/step - loss: 0.0277 - accuracy: 0.9916 - val_loss: 0.0524 - val_accuracy: 0.9855
# Epoch 5/5
# 469/469 [==============================] - 1s 2ms/step - loss: 0.0222 - accuracy: 0.9930 - val_loss: 0.0509 - val_accuracy: 0.9856

# %% [markdown]
# ## Model Evaluation

# %%
# Predict on test image
y_pred_list = []
for j in range(NUM_TN[0]):
  y_pred = np.argmax(hico_layers[0][j][0].predict(X_test_cropped_list[j]), axis=1)
  y_pred_list.append(y_pred)

for i in range(1, NUM_HICO_LAYER):
  for j in range(NUM_TN[i]):

    # Get test hidden representation from HiCo layer i-1
    X_test_input_hr = []
    X_test_input_ol = []
    for k in range(NUM_CONNECTION[i]):
      get_input = (K.function(hico_layers[i-1][hico_layers[i][j][1][k]][0].layers[0].input, hico_layers[i-1][hico_layers[i][j][1][k]][0].layers[1].output))
      X_test_input_hr.append(get_input(get_previous_layer_input(hico_layers, i-1, hico_layers[i-1][hico_layers[i][j][1][k]], X_test_cropped_list)))
    X_test_input_hr = np.array(X_test_input_hr)
    X_test_input_hr = np.concatenate(X_test_input_hr, axis=1)

    for k in range(NUM_CONNECTION[i]):
      get_input = (K.function(hico_layers[i-1][hico_layers[i][j][1][k]][0].layers[0].input, hico_layers[i-1][hico_layers[i][j][1][k]][0].layers[2].output))
      X_test_input_ol.append(get_input(get_previous_layer_input(hico_layers, i-1, hico_layers[i-1][hico_layers[i][j][1][k]], X_test_cropped_list)))
    X_test_input_ol = np.array(X_test_input_ol)
    X_test_input_ol = np.concatenate(X_test_input_ol, axis=1)

    X_test_input = np.concatenate((X_test_input_hr, X_test_input_ol), axis=1)

    y_pred = np.argmax(hico_layers[i][j][0].predict(X_test_input), axis=1)
    y_pred_list.append(y_pred)

# HiCo voting (mode)
y_pred_list = np.array(y_pred_list)
y_pred_list = np.transpose(y_pred_list, (1, 0))
y_pred_list = stats.mode(y_pred_list, axis=1)[0]
y_pred_list = np.squeeze(y_pred_list)

# %%
y_test = np.argmax(y_test_one_hot, axis=1)

# %%
accuracy = accuracy_score(y_test, y_pred_list)
accuracy
# Out:
# 0.9855
