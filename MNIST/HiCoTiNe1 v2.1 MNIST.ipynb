# %% [markdown]
# # Variants-Experiment 2.1. Adapted from HiCoTiNe v1.1
#
# ## Concatenated hidden representations.
# ## No raw input
# ## Mode. Compute classifications of all tiny networks, in all HiCo layers, and take the mode as the final classification.

# %%
from keras.models import Sequential
from keras.layers import Dense, Conv2D, Flatten
from keras.datasets import mnist
from keras.utils import to_categorical
import matplotlib.pyplot as plt
import numpy as np
import tensorflow as tf
import random
from scipy import stats
from sklearn.metrics import accuracy_score
from keras import backend as K

import os
import pickle
from google.colab import drive
drive.mount('/content/drive/')
# Out:
# Drive already mounted at /content/drive/; to attempt to forcibly remount, call drive.mount("/content/drive/", force_remount=True).

# %%
SUB_REGION_SCALE = 14
NUM_HICO_LAYER = 3
NUM_TN = [10, 4, 2]
NUM_CONNECTION = [0, 2, 2]

#dataset specific parameters
NUM_CLASS = 10

# %% [markdown]
# ## Data Pre-Processing

# %%
with open('/content/drive/My Drive/fyp/MNIST.pickle', 'rb') as f:
    X_train_cropped_list, y_train_one_hot, X_test_cropped_list, y_test_one_hot, coordinate_list, scale_list = pickle.load(f)

# %% [markdown]
# ## HiCo Layer 1

# %%
#build ANN model
ensemble = []
for i in range(NUM_TN[0]):
  model = Sequential()
  model.add(Dense(64, activation='relu', input_dim=SUB_REGION_SCALE*SUB_REGION_SCALE))
  model.add(Dense(64, activation='relu'))
  model.add(Dense(NUM_CLASS, activation = 'softmax'))
  model.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])
  ensemble.append((model, i, coordinate_list[i], scale_list[i]))

# %%
for i in range(NUM_TN[0]):
  ensemble[i][0].load_weights('/content/drive/My Drive/fyp/MNIST_' + str(i) + '.h5')

# %%
hico_layers = []
hico_layers.append(ensemble)

# %%
del hico_layers[1:]

# %% [markdown]
# ## HiCo Layer 2+

# %%
# Function to get input of layer i-1
def get_previous_layer_input(hico_layers, layer, tn, train_image):
  input = []
    
  if layer == 0:
    previous_layer_input = train_image[tn[1]]
    return previous_layer_input

  elif layer > 0:
    for i in range(NUM_CONNECTION[layer]):
      get_input = (K.function(hico_layers[layer-1][tn[1][i]][0].layers[0].input, hico_layers[layer-1][tn[1][i]][0].layers[1].output))
      input.append(get_input(get_previous_layer_input(hico_layers, layer-1, hico_layers[layer-1][tn[1][i]], train_image)))
      
    input = np.array(input)
    input = np.concatenate(input, axis=1)
    previous_layer_input = input
    return previous_layer_input

# %%
for i in range(1, NUM_HICO_LAYER):
  print('Layer %d' %i)
  ensemble = []
  X_train_input_list = []
  X_test_input_list = []

  for j in range(NUM_TN[i]):
    # Build model of HiCo layer i
    connection = tuple(random.sample(range(len(hico_layers[i-1])), k=NUM_CONNECTION[i]))
    model = Sequential()
    model.add(Dense(64, activation='relu', input_dim=64*NUM_CONNECTION[i]))
    model.add(Dense(64, activation='relu'))
    model.add(Dense(NUM_CLASS, activation = 'softmax'))
    model.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])
    ensemble.append((model, connection))
  hico_layers.append(ensemble)
  print('HICO LENGTH')
  print(len(hico_layers))

  for j in range(NUM_TN[i]):
    # Get train hidden representation from HiCo layer i-1
    X_train_input = []
    for k in range(NUM_CONNECTION[i]):
      get_input = (K.function(hico_layers[i-1][hico_layers[i][j][1][k]][0].layers[0].input, hico_layers[i-1][hico_layers[i][j][1][k]][0].layers[1].output))
      X_train_input.append(get_input(get_previous_layer_input(hico_layers, i-1, hico_layers[i-1][hico_layers[i][j][1][k]], X_train_cropped_list)))
    X_train_input = np.array(X_train_input)
    X_train_input = np.concatenate(X_train_input, axis=1)
    X_train_input_list.append(X_train_input)

    # Get test hidden representation from HiCo layer i-1
    X_test_input = []
    for k in range(NUM_CONNECTION[i]):
      get_input = (K.function(hico_layers[i-1][hico_layers[i][j][1][k]][0].layers[0].input, hico_layers[i-1][hico_layers[i][j][1][k]][0].layers[1].output))
      X_test_input.append(get_input(get_previous_layer_input(hico_layers, i-1, hico_layers[i-1][hico_layers[i][j][1][k]], X_test_cropped_list)))
    X_test_input = np.array(X_test_input)
    X_test_input = np.concatenate(X_test_input, axis=1)
    X_test_input_list.append(X_test_input)

  #train model of HiCo layer i
  for j in range(NUM_TN[i]):
    print('Model %d' %j)
    hico_layers[i][j][0].fit(X_train_input_list[j], y_train_one_hot, validation_data=(X_test_input_list[j], y_test_one_hot), epochs=5, batch_size=128)
# Out:
# Layer 1
# HICO LENGTH
# 2
# Model 0
# Epoch 1/5
# 469/469 [==============================] - 1s 2ms/step - loss: 0.6248 - accuracy: 0.8010 - val_loss: 0.2368 - val_accuracy: 0.9214
# Epoch 2/5
# 469/469 [==============================] - 1s 2ms/step - loss: 0.2223 - accuracy: 0.9249 - val_loss: 0.2249 - val_accuracy: 0.9232
# Epoch 3/5
# 469/469 [==============================] - 1s 2ms/step - loss: 0.2030 - accuracy: 0.9308 - val_loss: 0.2314 - val_accuracy: 0.9237
# Epoch 4/5
# 469/469 [==============================] - 1s 2ms/step - loss: 0.2025 - accuracy: 0.9315 - val_loss: 0.2051 - val_accuracy: 0.9307
# Epoch 5/5
# 469/469 [==============================] - 1s 2ms/step - loss: 0.1906 - accuracy: 0.9345 - val_loss: 0.2139 - val_accuracy: 0.9267
# Model 1
# Epoch 1/5
# 469/469 [==============================] - 2s 3ms/step - loss: 0.4700 - accuracy: 0.8639 - val_loss: 0.1208 - val_accuracy: 0.9618
# Epoch 2/5
# 469/469 [==============================] - 1s 2ms/step - loss: 0.1099 - accuracy: 0.9655 - val_loss: 0.1078 - val_accuracy: 0.9661
# Epoch 3/5
# 469/469 [==============================] - 1s 2ms/step - loss: 0.0938 - accuracy: 0.9702 - val_loss: 0.1004 - val_accuracy: 0.9663
# Epoch 4/5
# 469/469 [==============================] - 1s 2ms/step - loss: 0.0885 - accuracy: 0.9716 - val_loss: 0.0975 - val_accuracy: 0.9689
# Epoch 5/5
# 469/469 [==============================] - 1s 2ms/step - loss: 0.0841 - accuracy: 0.9724 - val_loss: 0.1000 - val_accuracy: 0.9672
# Model 2
# Epoch 1/5
# 469/469 [==============================] - 1s 2ms/step - loss: 0.5576 - accuracy: 0.8450 - val_loss: 0.1126 - val_accuracy: 0.9637
# Epoch 2/5
# 469/469 [==============================] - 1s 2ms/step - loss: 0.1139 - accuracy: 0.9643 - val_loss: 0.1095 - val_accuracy: 0.9645
# Epoch 3/5
# 469/469 [==============================] - 1s 2ms/step - loss: 0.0970 - accuracy: 0.9695 - val_loss: 0.1033 - val_accuracy: 0.9675
# Epoch 4/5
# 469/469 [==============================] - 1s 2ms/step - loss: 0.0920 - accuracy: 0.9716 - val_loss: 0.0949 - val_accuracy: 0.9683
# Epoch 5/5
# 469/469 [==============================] - 1s 2ms/step - loss: 0.0881 - accuracy: 0.9714 - val_loss: 0.0918 - val_accuracy: 0.9692
# Model 3
# Epoch 1/5
# 469/469 [==============================] - 2s 2ms/step - loss: 0.5109 - accuracy: 0.8516 - val_loss: 0.1227 - val_accuracy: 0.9615
# Epoch 2/5
# 469/469 [==============================] - 1s 2ms/step - loss: 0.1218 - accuracy: 0.9631 - val_loss: 0.1088 - val_accuracy: 0.9650
# Epoch 3/5
# 469/469 [==============================] - 1s 2ms/step - loss: 0.1032 - accuracy: 0.9678 - val_loss: 0.1099 - val_accuracy: 0.9648
# Epoch 4/5
# 469/469 [==============================] - 1s 2ms/step - loss: 0.1043 - accuracy: 0.9679 - val_loss: 0.1004 - val_accuracy: 0.9667
# Epoch 5/5
# 469/469 [==============================] - 1s 2ms/step - loss: 0.0952 - accuracy: 0.9701 - val_loss: 0.1002 - val_accuracy: 0.9687
# Layer 2
# HICO LENGTH
# 3
# Model 0
# Epoch 1/5
# 469/469 [==============================] - 2s 2ms/step - loss: 0.3111 - accuracy: 0.9131 - val_loss: 0.1127 - val_accuracy: 0.9633
# Epoch 2/5
# 469/469 [==============================] - 1s 2ms/step - loss: 0.0911 - accuracy: 0.9719 - val_loss: 0.1014 - val_accuracy: 0.9689
# Epoch 3/5
# 469/469 [==============================] - 1s 2ms/step - loss: 0.0886 - accuracy: 0.9737 - val_loss: 0.1137 - val_accuracy: 0.9660
# Epoch 4/5
# 469/469 [==============================] - 1s 2ms/step - loss: 0.0819 - accuracy: 0.9746 - val_loss: 0.1024 - val_accuracy: 0.9682
# Epoch 5/5
# 469/469 [==============================] - 1s 2ms/step - loss: 0.0787 - accuracy: 0.9748 - val_loss: 0.1047 - val_accuracy: 0.9667
# Model 1
# Epoch 1/5
# 469/469 [==============================] - 1s 2ms/step - loss: 0.4517 - accuracy: 0.8864 - val_loss: 0.0699 - val_accuracy: 0.9769
# Epoch 2/5
# 469/469 [==============================] - 1s 2ms/step - loss: 0.0595 - accuracy: 0.9810 - val_loss: 0.0661 - val_accuracy: 0.9796
# Epoch 3/5
# 469/469 [==============================] - 1s 2ms/step - loss: 0.0538 - accuracy: 0.9831 - val_loss: 0.0608 - val_accuracy: 0.9810
# Epoch 4/5
# 469/469 [==============================] - 1s 2ms/step - loss: 0.0554 - accuracy: 0.9831 - val_loss: 0.0645 - val_accuracy: 0.9801
# Epoch 5/5
# 469/469 [==============================] - 1s 2ms/step - loss: 0.0516 - accuracy: 0.9838 - val_loss: 0.0640 - val_accuracy: 0.9789

# %% [markdown]
# ## Model Evaluation

# %%
# Predict on test image
y_pred_list = []
for j in range(NUM_TN[0]):
  y_pred = np.argmax(hico_layers[0][j][0].predict(X_test_cropped_list[j]), axis=1)
  y_pred_list.append(y_pred)

for i in range(1, NUM_HICO_LAYER):
  for j in range(NUM_TN[i]):

    # Get test hidden representation from HiCo layer i-1
    X_test_input = []
    for k in range(NUM_CONNECTION[i]):
      get_input = (K.function(hico_layers[i-1][hico_layers[i][j][1][k]][0].layers[0].input, hico_layers[i-1][hico_layers[i][j][1][k]][0].layers[1].output))
      X_test_input.append(get_input(get_previous_layer_input(hico_layers, i-1, hico_layers[i-1][hico_layers[i][j][1][k]], X_test_cropped_list)))
    X_test_input = np.array(X_test_input)
    X_test_input = np.concatenate(X_test_input, axis=1)
    y_pred = np.argmax(hico_layers[i][j][0].predict(X_test_input), axis=1)
    y_pred_list.append(y_pred)

# HiCo voting (mode)
y_pred_list = np.array(y_pred_list)
y_pred_list = np.transpose(y_pred_list, (1, 0))
y_pred_list = stats.mode(y_pred_list, axis=1)[0]
y_pred_list = np.squeeze(y_pred_list)

# %%
y_test = np.argmax(y_test_one_hot, axis=1)

# %%
accuracy = accuracy_score(y_test, y_pred_list)
accuracy
# Out:
# 0.9749
