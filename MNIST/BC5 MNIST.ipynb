# %% [markdown]
# # BC 5
# ## Flat ensemble of tiny networks
# ## Input = sub-region

# %%
from keras.models import Sequential
from keras.layers import Dense, Conv2D, Flatten
from keras.datasets import mnist
from keras.utils import to_categorical
import matplotlib.pyplot as plt
import numpy as np
import tensorflow as tf
import random
from scipy import stats
from sklearn.metrics import accuracy_score

# %%
NUM_TN = 30
SUB_REGION_SCALE = 14

#dataset specific parameters
NUM_CLASS = 10

# %% [markdown]
# ## Data Pre-Processing

# %%
#load dataset
(X_train, y_train), (X_test, y_test) = mnist.load_data()
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/mnist.npz
# 11493376/11490434 [==============================] - 0s 0us/step

# %%
#Generate cropped train image
X_train_cropped_list = []
y_train_cropped_list = []

for i in range(NUM_TN):
  X_train_cropped = []
  y_train_cropped = []
  for i in range (X_train.shape[0]):
    image_cropped = tf.image.random_crop(X_train[i], size=[SUB_REGION_SCALE, SUB_REGION_SCALE])
    image_cropped = np.array(image_cropped)
    X_train_cropped.append(image_cropped)
    y_train_cropped.append(y_train[i])
  X_train_cropped = np.array(X_train_cropped)
  y_train_cropped = np.array(y_train_cropped)

  X_train_cropped_list.append(X_train_cropped)
  y_train_cropped_list.append(y_train_cropped)

# %%
#Generate cropped test image
X_test_cropped_list = []
y_test_cropped_list = []

for i in range(NUM_TN):
  X_test_cropped = []
  y_test_cropped = []
  for i in range (X_test.shape[0]):
    image_cropped = tf.image.random_crop(X_test[i], size=[SUB_REGION_SCALE, SUB_REGION_SCALE])
    image_cropped = np.array(image_cropped)
    X_test_cropped.append(image_cropped)
    y_test_cropped.append(y_test[i])
  X_test_cropped = np.array(X_test_cropped)
  y_test_cropped = np.array(y_test_cropped)

  X_test_cropped_list.append(X_test_cropped)
  y_test_cropped_list.append(y_test_cropped)

# %%
#normalizing dataset
for i in range(NUM_TN):
  X_train_cropped_list[i] = X_train_cropped_list[i]/255
  X_test_cropped_list[i] = X_test_cropped_list[i]/255

# %%
#transform to vector
for i in range(NUM_TN):
  X_train_cropped_list[i] = X_train_cropped_list[i].reshape((-1, SUB_REGION_SCALE*SUB_REGION_SCALE))
  X_test_cropped_list[i] = X_test_cropped_list[i].reshape((-1, SUB_REGION_SCALE*SUB_REGION_SCALE))

# %%
#one-hot encoding
for i in range(NUM_TN):
  y_train_cropped_list[i] = to_categorical(y_train_cropped_list[i])
  y_test_cropped_list[i] = to_categorical(y_test_cropped_list[i])

# %% [markdown]
# ## Model

# %%
#build ANN model
ensemble = []
for i in range(NUM_TN):
  model = Sequential()
  model.add(Dense(64, activation='relu', input_dim=SUB_REGION_SCALE*SUB_REGION_SCALE))
  model.add(Dense(64, activation='relu'))
  model.add(Dense(NUM_CLASS, activation = 'softmax'))
  model.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])
  ensemble.append(model)

# %%
#train model
history = []
for i in range(NUM_TN):
  print('Model %d' %i)
  hist = ensemble[i].fit(X_train_cropped_list[i], y_train_cropped_list[i], validation_data=(X_test_cropped_list[i], y_test_cropped_list[i]), epochs=5, batch_size=128)
  history.append(hist)
# Out:
# Model 0
# Epoch 1/5
# 469/469 [==============================] - 2s 3ms/step - loss: 2.0713 - accuracy: 0.2535 - val_loss: 1.4916 - val_accuracy: 0.4889
# Epoch 2/5
# 469/469 [==============================] - 1s 2ms/step - loss: 1.4199 - accuracy: 0.5168 - val_loss: 1.2740 - val_accuracy: 0.5630
# Epoch 3/5
# 469/469 [==============================] - 1s 2ms/step - loss: 1.2307 - accuracy: 0.5821 - val_loss: 1.1823 - val_accuracy: 0.5914
# Epoch 4/5
# 469/469 [==============================] - 1s 2ms/step - loss: 1.1408 - accuracy: 0.6139 - val_loss: 1.1219 - val_accuracy: 0.6163
# Epoch 5/5
# 469/469 [==============================] - 1s 2ms/step - loss: 1.0778 - accuracy: 0.6392 - val_loss: 1.0821 - val_accuracy: 0.6287
# Model 1
# Epoch 1/5
# 469/469 [==============================] - 1s 2ms/step - loss: 2.0740 - accuracy: 0.2565 - val_loss: 1.4993 - val_accuracy: 0.4929
# Epoch 2/5
# 469/469 [==============================] - 1s 2ms/step - loss: 1.4385 - accuracy: 0.5103 - val_loss: 1.2732 - val_accuracy: 0.5665
# Epoch 3/5
# 469/469 [==============================] - 1s 2ms/step - loss: 1.2552 - accuracy: 0.5772 - val_loss: 1.1957 - val_accuracy: 0.5884
# Epoch 4/5
# 469/469 [==============================] - 1s 2ms/step - loss: 1.1641 - accuracy: 0.6035 - val_loss: 1.1371 - val_accuracy: 0.6115
# Epoch 5/5
# 469/469 [==============================] - 1s 2ms/step - loss: 1.1014 - accuracy: 0.6276 - val_loss: 1.0902 - val_accuracy: 0.6248
# Model 2
# Epoch 1/5
# 469/469 [==============================] - 1s 2ms/step - loss: 2.
# Epoch 3/5
# 469/469 [==============================] - 1s 2ms/step - loss: 1.2492 - accuracy: 0.5770 - val_loss: 1.1747 - val_accuracy: 0.5953
# Epoch 4/5
# 469/469 [==============================] - 1s 2ms/step - loss: 1.1594 - accuracy: 0.6072 - val_loss: 1.1269 - val_accuracy: 0.6148
# Epoch 5/5
# 469/469 [==============================] - 1s 2ms/step - loss: 1.0916 - accuracy: 0.6324 - val_loss: 1.0774 - val_accuracy: 0.6294
# Model 24
# Epoch 1/5
# 469/469 [==============================] - 2s 2ms/step - loss: 2.0727 - accuracy: 0.2532 - val_loss: 1.4974 - val_accuracy: 0.4893
# Epoch 2/5
# 469/469 [==============================] - 1s 2ms/step - loss: 1.4301 - accuracy: 0.5176 - val_loss: 1.2939 - val_accuracy: 0.5639
# Epoch 3/5
# 469/469 [==============================] - 1s 2ms/step - loss: 1.2510 - accuracy: 0.5786 - val_loss: 1.2061 - val_accuracy: 0.5908
# Epoch 4/5
# 469/469 [==============================] - 1s 2ms/step - loss: 1.1552 - accuracy: 0.6111 - val_loss: 1.1250 - val_accuracy: 0.6127
# Epoch 5/5
# 469/469 [==============================] - 1s 2ms/step - loss: 1.0854 - accuracy: 0.6319 - val_loss: 1.0858 - val_accuracy: 0.6348
# Model 25
# Epoch 1/5
# 469/469 [==============================] - 1s 2ms/step - loss: 2.0529 - accuracy: 0.2659 - val_loss: 1.5048 - val_accuracy: 0.4896
# Epoch 2/5
# 469/469 [==============================] - 1s 2ms/step - loss: 1.4308 - accuracy: 0.5122 - val_loss: 1.2897 - val_accuracy: 0.5600
# Epoch 3/5
# 469/469 [==============================] - 1s 2ms/step - loss: 1.2556 - accuracy: 0.5754 - val_loss: 1.1908 - val_accuracy: 0.5929
# Epoch 4/5
# 469/469 [==============================] - 1s 2ms/step - loss: 1.1453 - accuracy: 0.6144 - val_loss: 1.1196 - val_accuracy: 0.6196
# Epoch 5/5
# 469/469 [==============================] - 1s 2ms/step - loss: 1.0784 - accuracy: 0.6396 - val_loss: 1.0739 - val_accuracy: 0.6360
# Model 26
# Epoch 1/5
# 469/469 [==============================] - 1s 2ms/step - loss: 2.0868 - accuracy: 0.2398 - val_loss: 1.5308 - val_accuracy: 0.4661
# Epoch 2/5
# 469/469 [==============================] - 1s 2ms/step - loss: 1.4595 - accuracy: 0.5005 - val_loss: 1.2988 - val_accuracy: 0.5541
# Epoch 3/5
# 469/469 [==============================] - 1s 2ms/step - loss: 1.2459 - accuracy: 0.5766 - val_loss: 1.1811 - val_accuracy: 0.6011
# Epoch 4/5
# 469/469 [==============================] - 1s 2ms/step - loss: 1.1539 - accuracy: 0.6083 - val_loss: 1.1202 - val_accuracy: 0.6156
# Epoch 5/5
# 469/469 [==============================] - 1s 2ms/step - loss: 1.0871 - accuracy: 0.6312 - val_loss: 1.0831 - val_accuracy: 0.6265
# Model 27
# Epoch 1/5
# 469/469 [==============================] - 1s 2ms/step - loss: 2.0907 - accuracy: 0.2506 - val_loss: 1.5064 - val_accuracy: 0.4882
# Epoch 2/5
# 469/469 [==============================] - 1s 2ms/step - loss: 1.4436 - accuracy: 0.5091 - val_loss: 1.2988 - val_accuracy: 0.5506
# Epoch 3/5
# 469/469 [==============================] - 1s 2ms/step - loss: 1.2443 - accuracy: 0.5783 - val_loss: 1.1956 - val_accuracy: 0.5926
# Epoch 4/5
# 469/469 [==============================] - 1s 2ms/step - loss: 1.1474 - accuracy: 0.6142 - val_loss: 1.1285 - val_accuracy: 0.6155
# Epoch 5/5
# 469/469 [==============================] - 1s 2ms/step - loss: 1.0796 - accuracy: 0.6353 - val_loss: 1.0754 - val_accuracy: 0.6311
# Model 28
# Epoch 1/5
# 469/469 [==============================] - 2s 2ms/step - loss: 2.0653 - accuracy: 0.2580 - val_loss: 1.4908 - val_accuracy: 0.4855
# Epoch 2/5
# 469/469 [==============================] - 1s 2ms/step - loss: 1.4369 - accuracy: 0.5089 - val_loss: 1.2837 - val_accuracy: 0.5557
# Epoch 3/5
# 469/469 [==============================] - 1s 2ms/step - loss: 1.2510 - accuracy: 0.5729 - val_loss: 1.1577 - val_accuracy: 0.6035
# Epoch 4/5
# 469/469 [==============================] - 1s 2ms/step - loss: 1.1448 - accuracy: 0.6133 - val_loss: 1.0971 - val_accuracy: 0.6239
# Epoch 5/5
# 469/469 [==============================] - 1s 3ms/step - loss: 1.0882 - accuracy: 0.6342 - val_loss: 1.0535 - val_accuracy: 0.6390
# Model 29
# Epoch 1/5
# 469/469 [==============================] - 2s 3ms/step - loss: 2.0750 - accuracy: 0.2502 - val_loss: 1.5029 - val_accuracy: 0.4828
# Epoch 2/5
# 469/469 [==============================] - 1s 3ms/step - loss: 1.4330 - accuracy: 0.5196 - val_loss: 1.2832 - val_accuracy: 0.5583
# Epoch 3/5
# 469/469 [==============================] - 1s 3ms/step - loss: 1.2423 - accuracy: 0.5816 - val_loss: 1.1890 - val_accuracy: 0.5906
# Epoch 4/5
# 469/469 [==============================] - 1s 3ms/step - loss: 1.1546 - accuracy: 0.6122 - val_loss: 1.1203 - val_accuracy: 0.6149
# Epoch 5/5
# 469/469 [==============================] - 1s 3ms/step - loss: 1.0840 - accuracy: 0.6401 - val_loss: 1.0764 - val_accuracy: 0.6275

# %% [markdown]
# ## Model Evaluation

# %%
# Predict on test image
y_pred_list = []
for i in range(NUM_TN):
  y_pred = ensemble[i].predict(X_test_cropped_list[i])
  y_pred_list.append(y_pred)
    
# Ensemble voting
y_pred_list = np.array(y_pred_list)
y_pred_list = np.argmax(np.sum(y_pred_list, axis=0), axis=1)

# %%
accuracy = accuracy_score(y_test, y_pred_list)
accuracy
# Out:
# 0.9002
