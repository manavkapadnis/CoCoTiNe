# %% [markdown]
# # BC 2
# ## Single tiny network
# ## Input = whole image

# %%
from keras.models import Sequential
from keras.layers import Dense, Conv2D, Flatten
from keras.datasets import mnist
from keras.utils import to_categorical
import matplotlib.pyplot as plt
import numpy as np
from sklearn.metrics import accuracy_score

# %%
#dataset specific parameters
NUM_CLASS = 10
SCALE = 28

# %%
#load dataset
(X_train, y_train), (X_test, y_test) = mnist.load_data()
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/mnist.npz
# 11493376/11490434 [==============================] - 0s 0us/step

# %%
#normalizing dataset
X_train = X_train/255
X_test = X_test/255

# %%
#transform to vector
X_train = X_train.reshape((-1, SCALE*SCALE))
X_test = X_test.reshape((-1, SCALE*SCALE))

# %%
X_train.shape
# Out:
# (60000, 784)

# %%
#one-hot encoding
y_train_one_hot = to_categorical(y_train)
y_test_one_hot = to_categorical(y_test)

# %%
#build ANN model
model = Sequential()
model.add(Dense(64, activation='relu', input_dim=SCALE*SCALE))
model.add(Dense(64, activation='relu'))
model.add(Dense(NUM_CLASS, activation = 'softmax'))
model.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])

# %%
#train model
hist = model.fit(X_train, y_train_one_hot, validation_data=(X_test, y_test_one_hot), epochs=5, batch_size=128)
# Out:
# Epoch 1/5
# 469/469 [==============================] - 2s 3ms/step - loss: 0.7093 - accuracy: 0.7983 - val_loss: 0.2012 - val_accuracy: 0.9442
# Epoch 2/5
# 469/469 [==============================] - 1s 2ms/step - loss: 0.1795 - accuracy: 0.9487 - val_loss: 0.1374 - val_accuracy: 0.9595
# Epoch 3/5
# 469/469 [==============================] - 1s 2ms/step - loss: 0.1303 - accuracy: 0.9639 - val_loss: 0.1174 - val_accuracy: 0.9623
# Epoch 4/5
# 469/469 [==============================] - 1s 2ms/step - loss: 0.0987 - accuracy: 0.9713 - val_loss: 0.1026 - val_accuracy: 0.9681
# Epoch 5/5
# 469/469 [==============================] - 1s 2ms/step - loss: 0.0816 - accuracy: 0.9758 - val_loss: 0.1010 - val_accuracy: 0.9682

# %% [markdown]
# ## Model Evaluation

# %%
y_pred = np.argmax(model.predict(X_test), axis=1)
accuracy = accuracy_score(y_test, y_pred)
accuracy
# Out:
# 0.9682
