# %% [markdown]
# # Variants-Experiment 1.5
#
# ## Summed hidden representations and summed output logits.
# ## Mode. Compute classifications of all tiny networks, in all HiCo layers, and take the mode as the final classification.

# %%
from keras.models import Sequential
from keras.layers import Dense, Conv2D, Flatten
from keras.datasets import mnist
from keras.utils import to_categorical
import matplotlib.pyplot as plt
import numpy as np
import tensorflow as tf
import random
from scipy import stats
from sklearn.metrics import accuracy_score
from keras import backend as K

import os
import pickle
from google.colab import drive
drive.mount('/content/drive/')
# Out:
# Mounted at /content/drive/

# %%
SUB_REGION_SCALE = 14
NUM_HICO_LAYER = 5
NUM_TN = [10, 8, 6, 4, 2]
NUM_CONNECTION = [0, 5, 4, 3, 2]

#dataset specific parameters
NUM_CLASS = 10

# %% [markdown]
# ## Data Pre-Processing

# %%
with open('/content/drive/My Drive/fyp/Fashion MNIST.pickle', 'rb') as f:
    X_train_cropped_list, y_train_one_hot, X_test_cropped_list, y_test_one_hot, coordinate_list, scale_list = pickle.load(f)

# %% [markdown]
# ## HiCo Layer 1

# %%
#build ANN model
ensemble = []
for i in range(NUM_TN[0]):
  model = Sequential()
  model.add(Dense(64, activation='relu', input_dim=SUB_REGION_SCALE*SUB_REGION_SCALE))
  model.add(Dense(64, activation='relu'))
  model.add(Dense(NUM_CLASS, activation = 'softmax'))
  model.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])
  ensemble.append((model, i, coordinate_list[i], scale_list[i]))

# %%
for i in range(NUM_TN[0]):
  ensemble[i][0].load_weights('/content/drive/My Drive/fyp/Fashion MNIST_' + str(i) + '.h5')

# %%
hico_layers = []
hico_layers.append(ensemble)

# %%
del hico_layers[1:]

# %% [markdown]
# ## HiCo Layer 2+

# %%
# Function to get input of layer i-1
def get_previous_layer_input(hico_layers, layer, tn, train_image):
  input_hr = []
  input_ol = []
    
  if layer == 0:
    previous_layer_input = train_image[tn[1]]
    return previous_layer_input

  elif layer > 0:
    for i in range(NUM_CONNECTION[layer]):
      get_input = (K.function(hico_layers[layer-1][tn[1][i]][0].layers[0].input, hico_layers[layer-1][tn[1][i]][0].layers[1].output))
      input_hr.append(get_input(get_previous_layer_input(hico_layers, layer-1, hico_layers[layer-1][tn[1][i]], train_image)))
      
    input_hr = np.array(input_hr)
    input_hr = np.sum(input_hr, axis=0)

    for i in range(NUM_CONNECTION[layer]):
      get_input = (K.function(hico_layers[layer-1][tn[1][i]][0].layers[0].input, hico_layers[layer-1][tn[1][i]][0].layers[2].output))
      input_ol.append(get_input(get_previous_layer_input(hico_layers, layer-1, hico_layers[layer-1][tn[1][i]], train_image)))

    input_ol = np.array(input_ol)
    input_ol = np.sum(input_ol, axis=0)

    input = np.concatenate((input_hr, input_ol), axis=1)
    
    previous_layer_input = input
    return previous_layer_input

# %%
for i in range(1, NUM_HICO_LAYER):
  print('Layer %d' %i)
  ensemble = []
  X_train_input_list = []
  X_test_input_list = []

  for j in range(NUM_TN[i]):
    # Build model of HiCo layer i
    connection = tuple(random.sample(range(len(hico_layers[i-1])), k=NUM_CONNECTION[i]))
    model = Sequential()
    model.add(Dense(64, activation='relu', input_dim=64+NUM_CLASS))
    model.add(Dense(64, activation='relu'))
    model.add(Dense(NUM_CLASS, activation = 'softmax'))
    model.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])
    ensemble.append((model, connection))
  hico_layers.append(ensemble)
  print('HICO LENGTH')
  print(len(hico_layers))

  for j in range(NUM_TN[i]):
    # Get train hidden representation from HiCo layer i-1
    X_train_input_hr = []
    X_train_input_ol = []
    for k in range(NUM_CONNECTION[i]):
      get_input = (K.function(hico_layers[i-1][hico_layers[i][j][1][k]][0].layers[0].input, hico_layers[i-1][hico_layers[i][j][1][k]][0].layers[1].output))
      X_train_input_hr.append(get_input(get_previous_layer_input(hico_layers, i-1, hico_layers[i-1][hico_layers[i][j][1][k]], X_train_cropped_list)))
    X_train_input_hr = np.array(X_train_input_hr)
    X_train_input_hr = np.sum(X_train_input_hr, axis=0)

    for k in range(NUM_CONNECTION[i]):
      get_input = (K.function(hico_layers[i-1][hico_layers[i][j][1][k]][0].layers[0].input, hico_layers[i-1][hico_layers[i][j][1][k]][0].layers[2].output))
      X_train_input_ol.append(get_input(get_previous_layer_input(hico_layers, i-1, hico_layers[i-1][hico_layers[i][j][1][k]], X_train_cropped_list)))
    X_train_input_ol = np.array(X_train_input_ol)
    X_train_input_ol = np.sum(X_train_input_ol, axis=0)

    X_train_input = np.concatenate((X_train_input_hr, X_train_input_ol), axis=1)
    X_train_input_list.append(X_train_input)

    # Get test hidden representation from HiCo layer i-1
    X_test_input_hr = []
    X_test_input_ol = []
    for k in range(NUM_CONNECTION[i]):
      get_input = (K.function(hico_layers[i-1][hico_layers[i][j][1][k]][0].layers[0].input, hico_layers[i-1][hico_layers[i][j][1][k]][0].layers[1].output))
      X_test_input_hr.append(get_input(get_previous_layer_input(hico_layers, i-1, hico_layers[i-1][hico_layers[i][j][1][k]], X_test_cropped_list)))
    X_test_input_hr = np.array(X_test_input_hr)
    X_test_input_hr = np.sum(X_test_input_hr, axis=0)

    for k in range(NUM_CONNECTION[i]):
      get_input = (K.function(hico_layers[i-1][hico_layers[i][j][1][k]][0].layers[0].input, hico_layers[i-1][hico_layers[i][j][1][k]][0].layers[2].output))
      X_test_input_ol.append(get_input(get_previous_layer_input(hico_layers, i-1, hico_layers[i-1][hico_layers[i][j][1][k]], X_test_cropped_list)))
    X_test_input_ol = np.array(X_test_input_ol)
    X_test_input_ol = np.sum(X_test_input_ol, axis=0)

    X_test_input = np.concatenate((X_test_input_hr, X_test_input_ol), axis=1)
    X_test_input_list.append(X_test_input)

  #train model of HiCo layer i
  for j in range(NUM_TN[i]):
    print('Model %d' %j)
    hico_layers[i][j][0].fit(X_train_input_list[j], y_train_one_hot, validation_data=(X_test_input_list[j], y_test_one_hot), epochs=5, batch_size=128)
# Out:
# Layer 1
# HICO LENGTH
# 2
# Model 0
# Epoch 1/5
# 469/469 [==============================] - 2s 3ms/step - loss: 1.0323 - accuracy: 0.6844 - val_loss: 0.4956 - val_accuracy: 0.8146
# Epoch 2/5
# 469/469 [==============================] - 1s 2ms/step - loss: 0.4553 - accuracy: 0.8305 - val_loss: 0.4766 - val_accuracy: 0.8211
# Epoch 3/5
# 469/469 [==============================] - 1s 2ms/step - loss: 0.4382 - accuracy: 0.8373 - val_loss: 0.4651 - val_accuracy: 0.8276
# Epoch 4/5
# 469/469 [==============================] - 1s 2ms/step - loss: 0.4277 - accuracy: 0.8421 - val_loss: 0.4662 - val_accuracy: 0.8277
# Epoch 5/5
# 469/469 [==============================] - 1s 2ms/step - loss: 0.4219 - accuracy: 0.8449 - val_loss: 0.4608 - val_accuracy: 0.8243
# Model 1
# Epoch 1/5
# 469/469 [==============================] - 1s 2ms/step - loss: 1.0549 - accuracy: 0.6828 - val_loss: 0.5356 - val_accuracy: 0.7972
# Epoch 2/5
# 469/469 [==============================] - 1s 3ms/step - loss: 0.4623 - accuracy: 0.8256 - val_loss: 0.4737 - val_accuracy: 0.8184
# Epoch 3/5
# 469/469 [==============================] - 1s 2ms/step - loss: 0.4410 - accuracy: 0.8358 - val_loss: 0.4661 - val_accuracy: 0.8234
# Epoch 4/5
# 469/469 [==============================] - 1s 2ms/step - loss: 0.4253 - accuracy: 0.8408 - val_loss: 0.4595 - val_accuracy: 0.8271
# Epoch 5/5
# 469/469 [==============================] - 1s 2ms/step - loss: 0.4194 - accuracy: 0.8415 - val_loss: 0.4659 - val_accuracy: 0.8270
# Model 2
# Epoch 1/5
# 469/469 [==============================] - 2s 3ms/step - loss: 0.8365 - accuracy: 0.7078 - val_loss: 0.5046 - val_accuracy: 0.8137
# Epoch 2/5
# 469/469 [==============================] - 1s 2ms/step - loss: 0.4694 - accuracy: 0.8269 - val_loss: 0.4823 - val_accuracy: 0.8219
# Epoch 3/5
# 469/469 [==============================] - 1s 2ms/step - loss: 0.4409 - accuracy: 0.8364 - val_loss: 0.4727 - val_accuracy: 0.8232
# Epoch 4/5
# 469/469 [==============================] - 1s 2ms/step - loss: 0.4297 - accuracy: 0.8399 - val_loss: 0.4629 - val_accuracy: 0.8277
# Epoch 5/5
# 469/469 [==============================] - 1s 2ms/step - loss: 0.4240 - accuracy: 0.8416 - val_loss: 0.4648 - val_accuracy: 0.8254
# Model 3
# Epoch 1/5
# 469/469 [==============================] - 1s 2ms/step - loss: 0.9823 - accuracy: 0.6779 - val_loss: 0.4982 - val_accuracy: 0.8141
# Epoch 2/5
# 469/469 [==============================] - 1s 2ms/step - loss: 0.4700 - accuracy: 0.8223 - val_loss: 0.4726 - val_accuracy: 0.8241
# Epoch 3/5
# 469/469 [==============================] - 1s 2ms/step - loss: 0.4447 - accuracy: 0.8341 - val_loss: 0.4753 - val_accuracy: 0.8240
# Epoch 4/5
# 469/469 [==============================] - 1s 2ms/step - loss: 0.4349 - accuracy: 0.8388 - val_loss: 0.4634 - val_accuracy: 0.8318
# Epoch 5/5
# 469/469 [==============================] - 1s 2ms/step - loss: 0.4241 - accuracy: 0.8415 - val_loss: 0.4614 - val_accuracy: 0.8273
# Model 4
# Epoch 1/5
# 469/469 [==============================] - 2s 3ms/step - loss: 1.1020 - accuracy: 0.6597 - val_loss: 0.4935 - val_accuracy: 0.8140
# Epoch 2/5
# 469/469 [==============================] - 1s 2ms/step - loss: 0.4588 - accuracy: 0.8283 - val_loss: 0.4955 - val_accuracy: 0.8159
# Epoch 3/5
# 469/469 [==============================] - 1s 2ms/step - loss: 0.4421 - accuracy: 0.8363 - val_loss: 0.4626 - val_accuracy: 0.8251
# Epoch 4/5
# 469/469 [==============================] - 1s 2ms/step - loss: 0.4324 - accuracy: 0.8387 - val_loss: 0.4534 - val_accuracy: 0.8322
# Epoch 5/5
# 469/469 [==============================] - 1s 2ms/step - loss: 0.4232 - accuracy: 0.8412 - val_loss: 0.4548 - val_accuracy: 0.8327
# Model 5
# Epoch 1/5
# 469/469 [==============================] - 1s 2ms/step - loss: 0.8923 - accuracy: 0.6978 - val_loss: 0.4932 - val_accuracy: 0.8188
# Epoch 2/5
# 469/469 [==============================] - 1s 2ms/step - loss: 0.4368 - accuracy: 0.8390 - val_loss: 0.4607 - val_accuracy: 0.8291
# Epoch 3/5
# 469/469 [==============================] - 1s 2ms/step - loss: 0.4187 - accuracy: 0.8438 - val_loss: 0.4668 - val_accuracy: 0.8287
# Epoch 4/5
# 469/469 [==============================] - 1s 2ms/step - loss: 0.4130 - accuracy: 0.8458 - val_loss: 0.4528 - val_accuracy: 0.8300
# Epoch 5/5
# 469/469 [==============================] - 1s 2ms/step - loss: 0.4038 - accuracy: 0.8481 - val_loss: 0.4627 - val_accuracy: 0.8255
# Model 6
# Epoch 1/5
# 469/469 [==============================] - 1s 2ms/step - loss: 1.0672 - accuracy: 0.6898 - val_loss: 0.5135 - val_accuracy: 0.8104
# Epoch 2/5
# 469/469 [==============================] - 1s 2ms/step - loss: 0.4827 - accuracy: 0.8205 - val_loss: 0.5112 - val_accuracy: 0.8125
# Epoch 3/5
# 469/469 [==============================] - 1s 3ms/step - loss: 0.4582 - accuracy: 0.8319 - val_loss: 0.4854 - val_accuracy: 0.8200
# Epoch 4/5
# 469/469 [==============================] - 1s 2ms/step - loss: 0.4474 - accuracy: 0.8326 - val_loss: 0.4660 - val_accuracy: 0.8242
# Epoch 5/5
# 469/469 [==============================] - 1s 2ms/step - loss: 0.4385 - accuracy: 0.8363 - val_loss: 0.4740 - val_accuracy: 0.8222
# Model 7
# Epoch 1/5
# 469/469 [==============================] - 2s 2ms/step - loss: 0.8605 - accuracy: 0.7122 - val_loss: 0.4938 - val_accuracy: 0.8176
# Epoch 2/5
# 469/469 [==============================] - 1s 2ms/step - loss: 0.4429 - accuracy: 0.8325 - val_loss: 0.4683 - val_accuracy: 0.8252
# Epoch 3/5
# 469/469 [==============================] - 1s 2ms/step - loss: 0.4228 - accuracy: 0.8400 - val_loss: 0.4640 - val_accuracy: 0.8265
# Epoch 4/5
# 469/469 [==============================] - 1s 2ms/step - loss: 0.4117 - accuracy: 0.8450 - val_loss: 0.4565 - val_accuracy: 0.8288
# Epoch 5/5
# 469/469 [==============================] - 1s 2ms/step - loss: 0.4103 - accuracy: 0.8452 - val_loss: 0.4583 - val_accuracy: 0.8273
# Layer 2
# HICO LENGTH
# 3
# Model 0
# Epoch 1/5
# 469/469 [==============================] - 2s 3ms/step - loss: 1.0426 - accuracy: 0.7240 - val_loss: 0.4730 - val_accuracy: 0.8303
# Epoch 2/5
# 469/469 [==============================] - 1s 3ms/step - loss: 0.4086 - accuracy: 0.8493 - val_loss: 0.4418 - val_accuracy: 0.8373
# Epoch 3/5
# 469/469 [==============================] - 1s 2ms/step - loss: 0.3946 - accuracy: 0.8544 - val_loss: 0.4315 - val_accuracy: 0.8398
# Epoch 4/5
# 469/469 [==============================] - 1s 2ms/step - loss: 0.3909 - accuracy: 0.8556 - val_loss: 0.4507 - val_accuracy: 0.8376
# Epoch 5/5
# 469/469 [==============================] - 1s 2ms/step - loss: 0.3822 - accuracy: 0.8586 - val_loss: 0.4299 - val_accuracy: 0.8428
# Model 1
# Epoch 1/5
# 469/469 [==============================] - 2s 2ms/step - loss: 1.1271 - accuracy: 0.7141 - val_loss: 0.4658 - val_accuracy: 0.8328
# Epoch 2/5
# 469/469 [==============================] - 1s 2ms/step - loss: 0.4151 - accuracy: 0.8477 - val_loss: 0.4671 - val_accuracy: 0.8279
# Epoch 3/5
# 469/469 [==============================] - 1s 2ms/step - loss: 0.4082 - accuracy: 0.8514 - val_loss: 0.4440 - val_accuracy: 0.8385
# Epoch 4/5
# 469/469 [==============================] - 1s 2ms/step - loss: 0.3924 - accuracy: 0.8544 - val_loss: 0.4334 - val_accuracy: 0.8393
# Epoch 5/5
# 469/469 [==============================] - 1s 2ms/step - loss: 0.3955 - accuracy: 0.8544 - val_loss: 0.4408 - val_accuracy: 0.8366
# Model 2
# Epoch 1/5
# 469/469 [==============================] - 2s 3ms/step - loss: 0.8447 - accuracy: 0.7488 - val_loss: 0.4649 - val_accuracy: 0.8297
# Epoch 2/5
# 469/469 [==============================] - 1s 2ms/step - loss: 0.4038 - accuracy: 0.8490 - val_loss: 0.4335 - val_accuracy: 0.8423
# Epoch 3/5
# 469/469 [==============================] - 1s 2ms/step - loss: 0.3882 - accuracy: 0.8557 - val_loss: 0.4283 - val_accuracy: 0.8400
# Epoch 4/5
# 469/469 [==============================] - 1s 2ms/step - loss: 0.3902 - accuracy: 0.8542 - val_loss: 0.4311 - val_accuracy: 0.8404
# Epoch 5/5
# 469/469 [==============================] - 1s 2ms/step - loss: 0.3853 - accuracy: 0.8551 - val_loss: 0.4254 - val_accuracy: 0.8410
# Model 3
# Epoch 1/5
# 469/469 [==============================] - 2s 3ms/step - loss: 0.8436 - accuracy: 0.7489 - val_loss: 0.4541 - val_accuracy: 0.8362
# Epoch 2/5
# 469/469 [==============================] - 1s 2ms/step - loss: 0.4071 - accuracy: 0.8495 - val_loss: 0.4466 - val_accuracy: 0.8347
# Epoch 3/5
# 469/469 [==============================] - 1s 2ms/step - loss: 0.3976 - accuracy: 0.8522 - val_loss: 0.4435 - val_accuracy: 0.8379
# Epoch 4/5
# 469/469 [==============================] - 1s 2ms/step - loss: 0.4000 - accuracy: 0.8498 - val_loss: 0.4347 - val_accuracy: 0.8384
# Epoch 5/5
# 469/469 [==============================] - 1s 2ms/step - loss: 0.3889 - accuracy: 0.8552 - val_loss: 0.4329 - val_accuracy: 0.8381
# Model 4
# Epoch 1/5
# 469/469 [==============================] - 2s 3ms/step - loss: 0.7417 - accuracy: 0.7575 - val_loss: 0.4601 - val_accuracy: 0.8307
# Epoch 2/5
# 469/469 [==============================] - 1s 2ms/step - loss: 0.4027 - accuracy: 0.8501 - val_loss: 0.4405 - val_accuracy: 0.8360
# Epoch 3/5
# 469/469 [==============================] - 1s 2ms/step - loss: 0.3955 - accuracy: 0.8537 - val_loss: 0.4398 - val_accuracy: 0.8358
# Epoch 4/5
# 469/469 [==============================] - 1s 2ms/step - loss: 0.3868 - accuracy: 0.8561 - val_loss: 0.4414 - val_accuracy: 0.8366
# Epoch 5/5
# 469/469 [==============================] - 1s 2ms/step - loss: 0.3839 - accuracy: 0.8564 - val_loss: 0.4211 - val_accuracy: 0.8427
# Model 5
# Epoch 1/5
# 469/469 [==============================] - 2s 3ms/step - loss: 0.8036 - accuracy: 0.7654 - val_loss: 0.4385 - val_accuracy: 0.8394
# Epoch 2/5
# 469/469 [==============================] - 1s 2ms/step - loss: 0.3993 - accuracy: 0.8531 - val_loss: 0.4535 - val_accuracy: 0.8325
# Epoch 3/5
# 469/469 [==============================] - 2s 4ms/step - loss: 0.3961 - accuracy: 0.8553 - val_loss: 0.4336 - val_accuracy: 0.8401
# Epoch 4/5
# 469/469 [==============================] - 1s 2ms/step - loss: 0.3867 - accuracy: 0.8566 - val_loss: 0.4493 - val_accuracy: 0.8351
# Epoch 5/5
# 469/469 [==============================] - 1s 2ms/step - loss: 0.3867 - accuracy: 0.8553 - val_loss: 0.4266 - val_accuracy: 0.8415
# Layer 3
# HICO LENGTH
# 4
# Model 0
# Epoch 1/5
# 469/469 [==============================] - 2s 3ms/step - loss: 0.9533 - accuracy: 0.7409 - val_loss: 0.4358 - val_accuracy: 0.8416
# Epoch 2/5
# 469/469 [==============================] - 1s 2ms/step - loss: 0.3911 - accuracy: 0.8573 - val_loss: 0.4302 - val_accuracy: 0.8438
# Epoch 3/5
# 469/469 [==============================] - 1s 2ms/step - loss: 0.3849 - accuracy: 0.8620 - val_loss: 0.4247 - val_accuracy: 0.8412
# Epoch 4/5
# 469/469 [==============================] - 1s 2ms/step - loss: 0.3761 - accuracy: 0.8606 - val_loss: 0.4225 - val_accuracy: 0.8430
# Epoch 5/5
# 469/469 [==============================] - 1s 3ms/step - loss: 0.3725 - accuracy: 0.8629 - val_loss: 0.4269 - val_accuracy: 0.8417
# Model 1
# Epoch 1/5
# 469/469 [==============================] - 3s 4ms/step - loss: 0.9807 - accuracy: 0.7517 - val_loss: 0.4516 - val_accuracy: 0.8368
# Epoch 2/5
# 469/469 [==============================] - 1s 2ms/step - loss: 0.3861 - accuracy: 0.8590 - val_loss: 0.4400 - val_accuracy: 0.8381
# Epoch 3/5
# 469/469 [==============================] - 1s 2ms/step - loss: 0.3777 - accuracy: 0.8594 - val_loss: 0.4289 - val_accuracy: 0.8401
# Epoch 4/5
# 469/469 [==============================] - 1s 2ms/step - loss: 0.3674 - accuracy: 0.8634 - val_loss: 0.4196 - val_accuracy: 0.8443
# Epoch 5/5
# 469/469 [==============================] - 1s 2ms/step - loss: 0.3781 - accuracy: 0.8588 - val_loss: 0.4312 - val_accuracy: 0.8401
# Model 2
# Epoch 1/5
# 469/469 [==============================] - 2s 3ms/step - loss: 0.5822 - accuracy: 0.8047 - val_loss: 0.4308 - val_accuracy: 0.8392
# Epoch 2/5
# 469/469 [==============================] - 2s 3ms/step - loss: 0.3803 - accuracy: 0.8593 - val_loss: 0.4300 - val_accuracy: 0.8407
# Epoch 3/5
# 469/469 [==============================] - 2s 4ms/step - loss: 0.3793 - accuracy: 0.8590 - val_loss: 0.4261 - val_accuracy: 0.8411
# Epoch 4/5
# 469/469 [==============================] - 2s 4ms/step - loss: 0.3699 - accuracy: 0.8618 - val_loss: 0.4147 - val_accuracy: 0.8429
# Epoch 5/5
# 469/469 [==============================] - 1s 2ms/step - loss: 0.3715 - accuracy: 0.8619 - val_loss: 0.4197 - val_accuracy: 0.8434
# Model 3
# Epoch 1/5
# 469/469 [==============================] - 2s 3ms/step - loss: 0.9138 - accuracy: 0.7470 - val_loss: 0.4291 - val_accuracy: 0.8421
# Epoch 2/5
# 469/469 [==============================] - 1s 2ms/step - loss: 0.3826 - accuracy: 0.8593 - val_loss: 0.4318 - val_accuracy: 0.8422
# Epoch 3/5
# 469/469 [==============================] - 1s 2ms/step - loss: 0.3790 - accuracy: 0.8620 - val_loss: 0.4264 - val_accuracy: 0.8426
# Epoch 4/5
# 469/469 [==============================] - 1s 3ms/step - loss: 0.3717 - accuracy: 0.8619 - val_loss: 0.4204 - val_accuracy: 0.8427
# Epoch 5/5
# 469/469 [==============================] - 1s 3ms/step - loss: 0.3719 - accuracy: 0.8593 - val_loss: 0.4224 - val_accuracy: 0.8438
# Layer 4
# HICO LENGTH
# 5
# Model 0
# Epoch 1/5
# 469/469 [==============================] - 2s 3ms/step - loss: 0.7356 - accuracy: 0.7861 - val_loss: 0.4271 - val_accuracy: 0.8428
# Epoch 2/5
# 469/469 [==============================] - 1s 2ms/step - loss: 0.3746 - accuracy: 0.8617 - val_loss: 0.4225 - val_accuracy: 0.8423
# Epoch 3/5
# 469/469 [==============================] - 1s 2ms/step - loss: 0.3683 - accuracy: 0.8624 - val_loss: 0.4262 - val_accuracy: 0.8422
# Epoch 4/5
# 469/469 [==============================] - 1s 3ms/step - loss: 0.3672 - accuracy: 0.8618 - val_loss: 0.4235 - val_accuracy: 0.8411
# Epoch 5/5
# 469/469 [==============================] - 1s 2ms/step - loss: 0.3673 - accuracy: 0.8627 - val_loss: 0.4151 - val_accuracy: 0.8447
# Model 1
# Epoch 1/5
# 469/469 [==============================] - 2s 2ms/step - loss: 0.7947 - accuracy: 0.7697 - val_loss: 0.4306 - val_accuracy: 0.8426
# Epoch 2/5
# 469/469 [==============================] - 1s 2ms/step - loss: 0.3728 - accuracy: 0.8628 - val_loss: 0.4304 - val_accuracy: 0.8411
# Epoch 3/5
# 469/469 [==============================] - 1s 3ms/step - loss: 0.3679 - accuracy: 0.8638 - val_loss: 0.4408 - val_accuracy: 0.8377
# Epoch 4/5
# 469/469 [==============================] - 1s 2ms/step - loss: 0.3658 - accuracy: 0.8646 - val_loss: 0.4132 - val_accuracy: 0.8447
# Epoch 5/5
# 469/469 [==============================] - 1s 3ms/step - loss: 0.3601 - accuracy: 0.8643 - val_loss: 0.4135 - val_accuracy: 0.8449

# %% [markdown]
# ## Model Evaluation

# %%
# Predict on test image
y_pred_list = []
for j in range(NUM_TN[0]):
  y_pred = np.argmax(hico_layers[0][j][0].predict(X_test_cropped_list[j]), axis=1)
  y_pred_list.append(y_pred)

for i in range(1, NUM_HICO_LAYER):
  for j in range(NUM_TN[i]):

    # Get test hidden representation from HiCo layer i-1
    X_test_input_hr = []
    X_test_input_ol = []
    for k in range(NUM_CONNECTION[i]):
      get_input = (K.function(hico_layers[i-1][hico_layers[i][j][1][k]][0].layers[0].input, hico_layers[i-1][hico_layers[i][j][1][k]][0].layers[1].output))
      X_test_input_hr.append(get_input(get_previous_layer_input(hico_layers, i-1, hico_layers[i-1][hico_layers[i][j][1][k]], X_test_cropped_list)))
    X_test_input_hr = np.array(X_test_input_hr)
    X_test_input_hr = np.sum(X_test_input_hr, axis=0)

    for k in range(NUM_CONNECTION[i]):
      get_input = (K.function(hico_layers[i-1][hico_layers[i][j][1][k]][0].layers[0].input, hico_layers[i-1][hico_layers[i][j][1][k]][0].layers[2].output))
      X_test_input_ol.append(get_input(get_previous_layer_input(hico_layers, i-1, hico_layers[i-1][hico_layers[i][j][1][k]], X_test_cropped_list)))
    X_test_input_ol = np.array(X_test_input_ol)
    X_test_input_ol = np.sum(X_test_input_ol, axis=0)

    X_test_input = np.concatenate((X_test_input_hr, X_test_input_ol), axis=1)

    y_pred = np.argmax(hico_layers[i][j][0].predict(X_test_input), axis=1)
    y_pred_list.append(y_pred)

# HiCo voting (mode)
y_pred_list = np.array(y_pred_list)
y_pred_list = np.transpose(y_pred_list, (1, 0))
y_pred_list = stats.mode(y_pred_list, axis=1)[0]
y_pred_list = np.squeeze(y_pred_list)

# %%
y_test = np.argmax(y_test_one_hot, axis=1)

# %%
accuracy = accuracy_score(y_test, y_pred_list)
accuracy
# Out:
# 0.8409
