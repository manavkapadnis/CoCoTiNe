# %% [markdown]
# # Variants-Experiment 1.6
#
# ## Summed hidden representations and concatenated output logits.
# ## Mode. Compute classifications of all tiny networks, in all HiCo layers, and take the mode as the final classification.

# %%
from keras.models import Sequential
from keras.layers import Dense, Conv2D, Flatten
from keras.datasets import mnist
from keras.utils import to_categorical
import matplotlib.pyplot as plt
import numpy as np
import tensorflow as tf
import random
from scipy import stats
from sklearn.metrics import accuracy_score
from keras import backend as K

import os
import pickle
from google.colab import drive
drive.mount('/content/drive/')
# Out:
# Mounted at /content/drive/

# %%
SUB_REGION_SCALE = 14
NUM_HICO_LAYER = 5
NUM_TN = [10, 8, 6, 4, 2]
NUM_CONNECTION = [0, 5, 4, 3, 2]

#dataset specific parameters
NUM_CLASS = 10

# %% [markdown]
# ## Data Pre-Processing

# %%
with open('/content/drive/My Drive/fyp/Fashion MNIST.pickle', 'rb') as f:
    X_train_cropped_list, y_train_one_hot, X_test_cropped_list, y_test_one_hot, coordinate_list, scale_list = pickle.load(f)

# %% [markdown]
# ## HiCo Layer 1

# %%
#build ANN model
ensemble = []
for i in range(NUM_TN[0]):
  model = Sequential()
  model.add(Dense(64, activation='relu', input_dim=SUB_REGION_SCALE*SUB_REGION_SCALE))
  model.add(Dense(64, activation='relu'))
  model.add(Dense(NUM_CLASS, activation = 'softmax'))
  model.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])
  ensemble.append((model, i, coordinate_list[i], scale_list[i]))

# %%
for i in range(NUM_TN[0]):
  ensemble[i][0].load_weights('/content/drive/My Drive/fyp/Fashion MNIST_' + str(i) + '.h5')

# %%
hico_layers = []
hico_layers.append(ensemble)

# %%
del hico_layers[1:]

# %% [markdown]
# ## HiCo Layer 2+

# %%
# Function to get input of layer i-1
def get_previous_layer_input(hico_layers, layer, tn, train_image):
  input_hr = []
  input_ol = []
    
  if layer == 0:
    previous_layer_input = train_image[tn[1]]
    return previous_layer_input

  elif layer > 0:
    for i in range(NUM_CONNECTION[layer]):
      get_input = (K.function(hico_layers[layer-1][tn[1][i]][0].layers[0].input, hico_layers[layer-1][tn[1][i]][0].layers[1].output))
      input_hr.append(get_input(get_previous_layer_input(hico_layers, layer-1, hico_layers[layer-1][tn[1][i]], train_image)))
      
    input_hr = np.array(input_hr)
    input_hr = np.sum(input_hr, axis=0)

    for i in range(NUM_CONNECTION[layer]):
      get_input = (K.function(hico_layers[layer-1][tn[1][i]][0].layers[0].input, hico_layers[layer-1][tn[1][i]][0].layers[2].output))
      input_ol.append(get_input(get_previous_layer_input(hico_layers, layer-1, hico_layers[layer-1][tn[1][i]], train_image)))

    input_ol = np.array(input_ol)
    input_ol = np.concatenate(input_ol, axis=1)

    input = np.concatenate((input_hr, input_ol), axis=1)
    
    previous_layer_input = input
    return previous_layer_input

# %%
for i in range(1, NUM_HICO_LAYER):
  print('Layer %d' %i)
  ensemble = []
  X_train_input_list = []
  X_test_input_list = []

  for j in range(NUM_TN[i]):
    # Build model of HiCo layer i
    connection = tuple(random.sample(range(len(hico_layers[i-1])), k=NUM_CONNECTION[i]))
    model = Sequential()
    model.add(Dense(64, activation='relu', input_dim=64+NUM_CLASS*NUM_CONNECTION[i]))
    model.add(Dense(64, activation='relu'))
    model.add(Dense(NUM_CLASS, activation = 'softmax'))
    model.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])
    ensemble.append((model, connection))
  hico_layers.append(ensemble)
  print('HICO LENGTH')
  print(len(hico_layers))

  for j in range(NUM_TN[i]):
    # Get train hidden representation from HiCo layer i-1
    X_train_input_hr = []
    X_train_input_ol = []
    for k in range(NUM_CONNECTION[i]):
      get_input = (K.function(hico_layers[i-1][hico_layers[i][j][1][k]][0].layers[0].input, hico_layers[i-1][hico_layers[i][j][1][k]][0].layers[1].output))
      X_train_input_hr.append(get_input(get_previous_layer_input(hico_layers, i-1, hico_layers[i-1][hico_layers[i][j][1][k]], X_train_cropped_list)))
    X_train_input_hr = np.array(X_train_input_hr)
    X_train_input_hr = np.sum(X_train_input_hr, axis=0)

    for k in range(NUM_CONNECTION[i]):
      get_input = (K.function(hico_layers[i-1][hico_layers[i][j][1][k]][0].layers[0].input, hico_layers[i-1][hico_layers[i][j][1][k]][0].layers[2].output))
      X_train_input_ol.append(get_input(get_previous_layer_input(hico_layers, i-1, hico_layers[i-1][hico_layers[i][j][1][k]], X_train_cropped_list)))
    X_train_input_ol = np.array(X_train_input_ol)
    X_train_input_ol = np.concatenate(X_train_input_ol, axis=1)

    X_train_input = np.concatenate((X_train_input_hr, X_train_input_ol), axis=1)
    X_train_input_list.append(X_train_input)

    # Get test hidden representation from HiCo layer i-1
    X_test_input_hr = []
    X_test_input_ol = []
    for k in range(NUM_CONNECTION[i]):
      get_input = (K.function(hico_layers[i-1][hico_layers[i][j][1][k]][0].layers[0].input, hico_layers[i-1][hico_layers[i][j][1][k]][0].layers[1].output))
      X_test_input_hr.append(get_input(get_previous_layer_input(hico_layers, i-1, hico_layers[i-1][hico_layers[i][j][1][k]], X_test_cropped_list)))
    X_test_input_hr = np.array(X_test_input_hr)
    X_test_input_hr = np.sum(X_test_input_hr, axis=0)

    for k in range(NUM_CONNECTION[i]):
      get_input = (K.function(hico_layers[i-1][hico_layers[i][j][1][k]][0].layers[0].input, hico_layers[i-1][hico_layers[i][j][1][k]][0].layers[2].output))
      X_test_input_ol.append(get_input(get_previous_layer_input(hico_layers, i-1, hico_layers[i-1][hico_layers[i][j][1][k]], X_test_cropped_list)))
    X_test_input_ol = np.array(X_test_input_ol)
    X_test_input_ol = np.concatenate(X_test_input_ol, axis=1)

    X_test_input = np.concatenate((X_test_input_hr, X_test_input_ol), axis=1)
    X_test_input_list.append(X_test_input)

  #train model of HiCo layer i
  for j in range(NUM_TN[i]):
    print('Model %d' %j)
    hico_layers[i][j][0].fit(X_train_input_list[j], y_train_one_hot, validation_data=(X_test_input_list[j], y_test_one_hot), epochs=5, batch_size=128)
# Out:
# Layer 1
# HICO LENGTH
# 2
# Model 0
# Epoch 1/5
# 469/469 [==============================] - 2s 3ms/step - loss: 1.1386 - accuracy: 0.6629 - val_loss: 0.5338 - val_accuracy: 0.8001
# Epoch 2/5
# 469/469 [==============================] - 1s 2ms/step - loss: 0.4867 - accuracy: 0.8147 - val_loss: 0.4845 - val_accuracy: 0.8211
# Epoch 3/5
# 469/469 [==============================] - 1s 2ms/step - loss: 0.4591 - accuracy: 0.8289 - val_loss: 0.4713 - val_accuracy: 0.8248
# Epoch 4/5
# 469/469 [==============================] - 1s 2ms/step - loss: 0.4552 - accuracy: 0.8296 - val_loss: 0.4658 - val_accuracy: 0.8265
# Epoch 5/5
# 469/469 [==============================] - 1s 2ms/step - loss: 0.4402 - accuracy: 0.8328 - val_loss: 0.4738 - val_accuracy: 0.8216
# Model 1
# Epoch 1/5
# 469/469 [==============================] - 1s 2ms/step - loss: 1.0952 - accuracy: 0.6681 - val_loss: 0.5387 - val_accuracy: 0.7961
# Epoch 2/5
# 469/469 [==============================] - 1s 2ms/step - loss: 0.4982 - accuracy: 0.8122 - val_loss: 0.5394 - val_accuracy: 0.7981
# Epoch 3/5
# 469/469 [==============================] - 1s 2ms/step - loss: 0.4760 - accuracy: 0.8198 - val_loss: 0.4894 - val_accuracy: 0.8158
# Epoch 4/5
# 469/469 [==============================] - 1s 2ms/step - loss: 0.4641 - accuracy: 0.8242 - val_loss: 0.4855 - val_accuracy: 0.8181
# Epoch 5/5
# 469/469 [==============================] - 1s 2ms/step - loss: 0.4564 - accuracy: 0.8286 - val_loss: 0.4930 - val_accuracy: 0.8183
# Model 2
# Epoch 1/5
# 469/469 [==============================] - 1s 2ms/step - loss: 1.0951 - accuracy: 0.6566 - val_loss: 0.4996 - val_accuracy: 0.8130
# Epoch 2/5
# 469/469 [==============================] - 1s 2ms/step - loss: 0.4680 - accuracy: 0.8260 - val_loss: 0.4689 - val_accuracy: 0.8235
# Epoch 3/5
# 469/469 [==============================] - 1s 2ms/step - loss: 0.4427 - accuracy: 0.8362 - val_loss: 0.4570 - val_accuracy: 0.8299
# Epoch 4/5
# 469/469 [==============================] - 1s 2ms/step - loss: 0.4274 - accuracy: 0.8410 - val_loss: 0.4642 - val_accuracy: 0.8261
# Epoch 5/5
# 469/469 [==============================] - 1s 2ms/step - loss: 0.4202 - accuracy: 0.8436 - val_loss: 0.4536 - val_accuracy: 0.8348
# Model 3
# Epoch 1/5
# 469/469 [==============================] - 1s 2ms/step - loss: 0.8366 - accuracy: 0.7139 - val_loss: 0.5130 - val_accuracy: 0.8068
# Epoch 2/5
# 469/469 [==============================] - 1s 2ms/step - loss: 0.4593 - accuracy: 0.8289 - val_loss: 0.4665 - val_accuracy: 0.8229
# Epoch 3/5
# 469/469 [==============================] - 1s 2ms/step - loss: 0.4325 - accuracy: 0.8393 - val_loss: 0.4561 - val_accuracy: 0.8282
# Epoch 4/5
# 469/469 [==============================] - 1s 2ms/step - loss: 0.4222 - accuracy: 0.8406 - val_loss: 0.4506 - val_accuracy: 0.8295
# Epoch 5/5
# 469/469 [==============================] - 1s 2ms/step - loss: 0.4165 - accuracy: 0.8431 - val_loss: 0.4355 - val_accuracy: 0.8330
# Model 4
# Epoch 1/5
# 469/469 [==============================] - 2s 3ms/step - loss: 0.8589 - accuracy: 0.7201 - val_loss: 0.4820 - val_accuracy: 0.8223
# Epoch 2/5
# 469/469 [==============================] - 1s 2ms/step - loss: 0.4601 - accuracy: 0.8292 - val_loss: 0.5008 - val_accuracy: 0.8159
# Epoch 3/5
# 469/469 [==============================] - 1s 2ms/step - loss: 0.4391 - accuracy: 0.8365 - val_loss: 0.4802 - val_accuracy: 0.8257
# Epoch 4/5
# 469/469 [==============================] - 1s 2ms/step - loss: 0.4263 - accuracy: 0.8394 - val_loss: 0.4572 - val_accuracy: 0.8340
# Epoch 5/5
# 469/469 [==============================] - 1s 2ms/step - loss: 0.4185 - accuracy: 0.8451 - val_loss: 0.4602 - val_accuracy: 0.8322
# Model 5
# Epoch 1/5
# 469/469 [==============================] - 1s 2ms/step - loss: 0.9759 - accuracy: 0.6932 - val_loss: 0.5035 - val_accuracy: 0.8133
# Epoch 2/5
# 469/469 [==============================] - 1s 2ms/step - loss: 0.4668 - accuracy: 0.8253 - val_loss: 0.4723 - val_accuracy: 0.8221
# Epoch 3/5
# 469/469 [==============================] - 1s 2ms/step - loss: 0.4292 - accuracy: 0.8388 - val_loss: 0.4487 - val_accuracy: 0.8287
# Epoch 4/5
# 469/469 [==============================] - 1s 2ms/step - loss: 0.4137 - accuracy: 0.8427 - val_loss: 0.4559 - val_accuracy: 0.8256
# Epoch 5/5
# 469/469 [==============================] - 1s 2ms/step - loss: 0.4108 - accuracy: 0.8457 - val_loss: 0.4357 - val_accuracy: 0.8324
# Model 6
# Epoch 1/5
# 469/469 [==============================] - 1s 2ms/step - loss: 0.8145 - accuracy: 0.7205 - val_loss: 0.5073 - val_accuracy: 0.8070
# Epoch 2/5
# 469/469 [==============================] - 1s 2ms/step - loss: 0.4589 - accuracy: 0.8299 - val_loss: 0.4855 - val_accuracy: 0.8176
# Epoch 3/5
# 469/469 [==============================] - 1s 2ms/step - loss: 0.4350 - accuracy: 0.8384 - val_loss: 0.4807 - val_accuracy: 0.8163
# Epoch 4/5
# 469/469 [==============================] - 1s 2ms/step - loss: 0.4174 - accuracy: 0.8432 - val_loss: 0.4585 - val_accuracy: 0.8268
# Epoch 5/5
# 469/469 [==============================] - 1s 2ms/step - loss: 0.4169 - accuracy: 0.8432 - val_loss: 0.4533 - val_accuracy: 0.8290
# Model 7
# Epoch 1/5
# 469/469 [==============================] - 1s 2ms/step - loss: 0.9349 - accuracy: 0.6993 - val_loss: 0.5178 - val_accuracy: 0.8051
# Epoch 2/5
# 469/469 [==============================] - 1s 2ms/step - loss: 0.4669 - accuracy: 0.8271 - val_loss: 0.4774 - val_accuracy: 0.8188
# Epoch 3/5
# 469/469 [==============================] - 1s 2ms/step - loss: 0.4312 - accuracy: 0.8392 - val_loss: 0.4735 - val_accuracy: 0.8200
# Epoch 4/5
# 469/469 [==============================] - 1s 2ms/step - loss: 0.4364 - accuracy: 0.8375 - val_loss: 0.4590 - val_accuracy: 0.8265
# Epoch 5/5
# 469/469 [==============================] - 1s 2ms/step - loss: 0.4093 - accuracy: 0.8484 - val_loss: 0.4476 - val_accuracy: 0.8294
# Layer 2
# HICO LENGTH
# 3
# Model 0
# Epoch 1/5
# 469/469 [==============================] - 1s 2ms/step - loss: 0.7743 - accuracy: 0.7570 - val_loss: 0.4645 - val_accuracy: 0.8304
# Epoch 2/5
# 469/469 [==============================] - 1s 2ms/step - loss: 0.4064 - accuracy: 0.8494 - val_loss: 0.4558 - val_accuracy: 0.8327
# Epoch 3/5
# 469/469 [==============================] - 1s 2ms/step - loss: 0.3959 - accuracy: 0.8543 - val_loss: 0.4305 - val_accuracy: 0.8394
# Epoch 4/5
# 469/469 [==============================] - 1s 2ms/step - loss: 0.3860 - accuracy: 0.8562 - val_loss: 0.4286 - val_accuracy: 0.8416
# Epoch 5/5
# 469/469 [==============================] - 1s 2ms/step - loss: 0.3791 - accuracy: 0.8594 - val_loss: 0.4280 - val_accuracy: 0.8410
# Model 1
# Epoch 1/5
# 469/469 [==============================] - 1s 2ms/step - loss: 0.7209 - accuracy: 0.7645 - val_loss: 0.4377 - val_accuracy: 0.8367
# Epoch 2/5
# 469/469 [==============================] - 1s 2ms/step - loss: 0.3914 - accuracy: 0.8556 - val_loss: 0.4482 - val_accuracy: 0.8380
# Epoch 3/5
# 469/469 [==============================] - 1s 2ms/step - loss: 0.3856 - accuracy: 0.8571 - val_loss: 0.4248 - val_accuracy: 0.8395
# Epoch 4/5
# 469/469 [==============================] - 1s 2ms/step - loss: 0.3828 - accuracy: 0.8575 - val_loss: 0.4401 - val_accuracy: 0.8354
# Epoch 5/5
# 469/469 [==============================] - 1s 2ms/step - loss: 0.3752 - accuracy: 0.8599 - val_loss: 0.4261 - val_accuracy: 0.8402
# Model 2
# Epoch 1/5
# 469/469 [==============================] - 1s 2ms/step - loss: 0.8114 - accuracy: 0.7465 - val_loss: 0.4354 - val_accuracy: 0.8402
# Epoch 2/5
# 469/469 [==============================] - 1s 2ms/step - loss: 0.3915 - accuracy: 0.8548 - val_loss: 0.4258 - val_accuracy: 0.8440
# Epoch 3/5
# 469/469 [==============================] - 1s 2ms/step - loss: 0.3759 - accuracy: 0.8598 - val_loss: 0.4303 - val_accuracy: 0.8433
# Epoch 4/5
# 469/469 [==============================] - 1s 2ms/step - loss: 0.3780 - accuracy: 0.8597 - val_loss: 0.4171 - val_accuracy: 0.8436
# Epoch 5/5
# 469/469 [==============================] - 1s 2ms/step - loss: 0.3680 - accuracy: 0.8644 - val_loss: 0.4389 - val_accuracy: 0.8411
# Model 3
# Epoch 1/5
# 469/469 [==============================] - 1s 2ms/step - loss: 0.7237 - accuracy: 0.7633 - val_loss: 0.4464 - val_accuracy: 0.8372
# Epoch 2/5
# 469/469 [==============================] - 1s 2ms/step - loss: 0.3872 - accuracy: 0.8576 - val_loss: 0.4148 - val_accuracy: 0.8444
# Epoch 3/5
# 469/469 [==============================] - 1s 2ms/step - loss: 0.3832 - accuracy: 0.8594 - val_loss: 0.4157 - val_accuracy: 0.8460
# Epoch 4/5
# 469/469 [==============================] - 1s 2ms/step - loss: 0.3741 - accuracy: 0.8620 - val_loss: 0.4163 - val_accuracy: 0.8461
# Epoch 5/5
# 469/469 [==============================] - 1s 2ms/step - loss: 0.3720 - accuracy: 0.8617 - val_loss: 0.4110 - val_accuracy: 0.8471
# Model 4
# Epoch 1/5
# 469/469 [==============================] - 1s 2ms/step - loss: 0.6732 - accuracy: 0.7834 - val_loss: 0.4365 - val_accuracy: 0.8432
# Epoch 2/5
# 469/469 [==============================] - 1s 2ms/step - loss: 0.3981 - accuracy: 0.8529 - val_loss: 0.4291 - val_accuracy: 0.8417
# Epoch 3/5
# 469/469 [==============================] - 1s 2ms/step - loss: 0.3865 - accuracy: 0.8592 - val_loss: 0.4189 - val_accuracy: 0.8456
# Epoch 4/5
# 469/469 [==============================] - 1s 2ms/step - loss: 0.3732 - accuracy: 0.8606 - val_loss: 0.4241 - val_accuracy: 0.8451
# Epoch 5/5
# 469/469 [==============================] - 1s 2ms/step - loss: 0.3767 - accuracy: 0.8607 - val_loss: 0.4120 - val_accuracy: 0.8458
# Model 5
# Epoch 1/5
# 469/469 [==============================] - 1s 2ms/step - loss: 0.7699 - accuracy: 0.7676 - val_loss: 0.4544 - val_accuracy: 0.8359
# Epoch 2/5
# 469/469 [==============================] - 1s 2ms/step - loss: 0.4111 - accuracy: 0.8500 - val_loss: 0.4329 - val_accuracy: 0.8381
# Epoch 3/5
# 469/469 [==============================] - 1s 2ms/step - loss: 0.3958 - accuracy: 0.8524 - val_loss: 0.4230 - val_accuracy: 0.8424
# Epoch 4/5
# 469/469 [==============================] - 1s 2ms/step - loss: 0.3867 - accuracy: 0.8576 - val_loss: 0.4251 - val_accuracy: 0.8421
# Epoch 5/5
# 469/469 [==============================] - 1s 2ms/step - loss: 0.3834 - accuracy: 0.8571 - val_loss: 0.4236 - val_accuracy: 0.8419
# Layer 3
# HICO LENGTH
# 4
# Model 0
# Epoch 1/5
# 469/469 [==============================] - 2s 2ms/step - loss: 0.6660 - accuracy: 0.7912 - val_loss: 0.4244 - val_accuracy: 0.8419
# Epoch 2/5
# 469/469 [==============================] - 1s 2ms/step - loss: 0.3795 - accuracy: 0.8601 - val_loss: 0.4263 - val_accuracy: 0.8447
# Epoch 3/5
# 469/469 [==============================] - 1s 2ms/step - loss: 0.3698 - accuracy: 0.8618 - val_loss: 0.4130 - val_accuracy: 0.8466
# Epoch 4/5
# 469/469 [==============================] - 1s 2ms/step - loss: 0.3688 - accuracy: 0.8594 - val_loss: 0.4066 - val_accuracy: 0.8478
# Epoch 5/5
# 469/469 [==============================] - 1s 2ms/step - loss: 0.3607 - accuracy: 0.8654 - val_loss: 0.4102 - val_accuracy: 0.8466
# Model 1
# Epoch 1/5
# 469/469 [==============================] - 2s 3ms/step - loss: 0.7858 - accuracy: 0.7635 - val_loss: 0.4309 - val_accuracy: 0.8438
# Epoch 2/5
# 469/469 [==============================] - 1s 2ms/step - loss: 0.3745 - accuracy: 0.8612 - val_loss: 0.4178 - val_accuracy: 0.8448
# Epoch 3/5
# 469/469 [==============================] - 1s 2ms/step - loss: 0.3698 - accuracy: 0.8624 - val_loss: 0.4194 - val_accuracy: 0.8455
# Epoch 4/5
# 469/469 [==============================] - 1s 2ms/step - loss: 0.3626 - accuracy: 0.8636 - val_loss: 0.4099 - val_accuracy: 0.8478
# Epoch 5/5
# 469/469 [==============================] - 1s 2ms/step - loss: 0.3656 - accuracy: 0.8622 - val_loss: 0.4132 - val_accuracy: 0.8444
# Model 2
# Epoch 1/5
# 469/469 [==============================] - 2s 3ms/step - loss: 0.5461 - accuracy: 0.8161 - val_loss: 0.4157 - val_accuracy: 0.8461
# Epoch 2/5
# 469/469 [==============================] - 1s 2ms/step - loss: 0.3801 - accuracy: 0.8597 - val_loss: 0.4216 - val_accuracy: 0.8420
# Epoch 3/5
# 469/469 [==============================] - 1s 2ms/step - loss: 0.3719 - accuracy: 0.8623 - val_loss: 0.4156 - val_accuracy: 0.8478
# Epoch 4/5
# 469/469 [==============================] - 1s 2ms/step - loss: 0.3635 - accuracy: 0.8636 - val_loss: 0.4123 - val_accuracy: 0.8487
# Epoch 5/5
# 469/469 [==============================] - 1s 2ms/step - loss: 0.3670 - accuracy: 0.8628 - val_loss: 0.4033 - val_accuracy: 0.8508
# Model 3
# Epoch 1/5
# 469/469 [==============================] - 1s 2ms/step - loss: 0.6250 - accuracy: 0.8031 - val_loss: 0.4169 - val_accuracy: 0.8450
# Epoch 2/5
# 469/469 [==============================] - 1s 2ms/step - loss: 0.3675 - accuracy: 0.8635 - val_loss: 0.4191 - val_accuracy: 0.8470
# Epoch 3/5
# 469/469 [==============================] - 1s 2ms/step - loss: 0.3651 - accuracy: 0.8647 - val_loss: 0.4090 - val_accuracy: 0.8481
# Epoch 4/5
# 469/469 [==============================] - 1s 2ms/step - loss: 0.3628 - accuracy: 0.8666 - val_loss: 0.4021 - val_accuracy: 0.8494
# Epoch 5/5
# 469/469 [==============================] - 1s 2ms/step - loss: 0.3576 - accuracy: 0.8659 - val_loss: 0.4064 - val_accuracy: 0.8495
# Layer 4
# HICO LENGTH
# 5
# Model 0
# Epoch 1/5
# 469/469 [==============================] - 2s 2ms/step - loss: 0.6745 - accuracy: 0.7857 - val_loss: 0.4233 - val_accuracy: 0.8448
# Epoch 2/5
# 469/469 [==============================] - 1s 2ms/step - loss: 0.3631 - accuracy: 0.8624 - val_loss: 0.4141 - val_accuracy: 0.8473
# Epoch 3/5
# 469/469 [==============================] - 1s 2ms/step - loss: 0.3582 - accuracy: 0.8660 - val_loss: 0.4055 - val_accuracy: 0.8507
# Epoch 4/5
# 469/469 [==============================] - 1s 2ms/step - loss: 0.3549 - accuracy: 0.8677 - val_loss: 0.4074 - val_accuracy: 0.8486
# Epoch 5/5
# 469/469 [==============================] - 1s 2ms/step - loss: 0.3522 - accuracy: 0.8681 - val_loss: 0.4001 - val_accuracy: 0.8494
# Model 1
# Epoch 1/5
# 469/469 [==============================] - 1s 2ms/step - loss: 0.6625 - accuracy: 0.7992 - val_loss: 0.4116 - val_accuracy: 0.8466
# Epoch 2/5
# 469/469 [==============================] - 1s 2ms/step - loss: 0.3642 - accuracy: 0.8638 - val_loss: 0.4104 - val_accuracy: 0.8477
# Epoch 3/5
# 469/469 [==============================] - 1s 2ms/step - loss: 0.3564 - accuracy: 0.8674 - val_loss: 0.4067 - val_accuracy: 0.8490
# Epoch 4/5
# 469/469 [==============================] - 1s 2ms/step - loss: 0.3558 - accuracy: 0.8674 - val_loss: 0.4091 - val_accuracy: 0.8485
# Epoch 5/5
# 469/469 [==============================] - 1s 2ms/step - loss: 0.3511 - accuracy: 0.8686 - val_loss: 0.4064 - val_accuracy: 0.8492

# %% [markdown]
# ## Model Evaluation

# %%
# Predict on test image
y_pred_list = []
for j in range(NUM_TN[0]):
  y_pred = np.argmax(hico_layers[0][j][0].predict(X_test_cropped_list[j]), axis=1)
  y_pred_list.append(y_pred)

for i in range(1, NUM_HICO_LAYER):
  for j in range(NUM_TN[i]):

    # Get test hidden representation from HiCo layer i-1
    X_test_input_hr = []
    X_test_input_ol = []
    for k in range(NUM_CONNECTION[i]):
      get_input = (K.function(hico_layers[i-1][hico_layers[i][j][1][k]][0].layers[0].input, hico_layers[i-1][hico_layers[i][j][1][k]][0].layers[1].output))
      X_test_input_hr.append(get_input(get_previous_layer_input(hico_layers, i-1, hico_layers[i-1][hico_layers[i][j][1][k]], X_test_cropped_list)))
    X_test_input_hr = np.array(X_test_input_hr)
    X_test_input_hr = np.sum(X_test_input_hr, axis=0)

    for k in range(NUM_CONNECTION[i]):
      get_input = (K.function(hico_layers[i-1][hico_layers[i][j][1][k]][0].layers[0].input, hico_layers[i-1][hico_layers[i][j][1][k]][0].layers[2].output))
      X_test_input_ol.append(get_input(get_previous_layer_input(hico_layers, i-1, hico_layers[i-1][hico_layers[i][j][1][k]], X_test_cropped_list)))
    X_test_input_ol = np.array(X_test_input_ol)
    X_test_input_ol = np.concatenate(X_test_input_ol, axis=1)

    X_test_input = np.concatenate((X_test_input_hr, X_test_input_ol), axis=1)

    y_pred = np.argmax(hico_layers[i][j][0].predict(X_test_input), axis=1)
    y_pred_list.append(y_pred)

# HiCo voting (mode)
y_pred_list = np.array(y_pred_list)
y_pred_list = np.transpose(y_pred_list, (1, 0))
y_pred_list = stats.mode(y_pred_list, axis=1)[0]
y_pred_list = np.squeeze(y_pred_list)

# %%
y_test = np.argmax(y_test_one_hot, axis=1)

# %%
accuracy = accuracy_score(y_test, y_pred_list)
accuracy
# Out:
# 0.8485
