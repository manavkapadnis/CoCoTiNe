# %% [markdown]
# # Variants-Experiment 1.3
#
# ## Concatenated hidden representations and summed output logits.
# ## Mode. Compute classifications of all tiny networks, in all HiCo layers, and take the mode as the final classification.

# %%
from keras.models import Sequential
from keras.layers import Dense, Conv2D, Flatten
from keras.datasets import mnist
from keras.utils import to_categorical
import matplotlib.pyplot as plt
import numpy as np
import tensorflow as tf
import random
from scipy import stats
from sklearn.metrics import accuracy_score
from keras import backend as K

import os
import pickle
from google.colab import drive
drive.mount('/content/drive/')
# Out:
# Mounted at /content/drive/

# %%
SUB_REGION_SCALE = 14
NUM_HICO_LAYER = 5
NUM_TN = [10, 8, 6, 4, 2]
NUM_CONNECTION = [0, 5, 4, 3, 2]

#dataset specific parameters
NUM_CLASS = 10

# %% [markdown]
# ## Data Pre-Processing

# %%
with open('/content/drive/My Drive/fyp/Fashion MNIST.pickle', 'rb') as f:
    X_train_cropped_list, y_train_one_hot, X_test_cropped_list, y_test_one_hot, coordinate_list, scale_list = pickle.load(f)

# %% [markdown]
# ## HiCo Layer 1

# %%
#build ANN model
ensemble = []
for i in range(NUM_TN[0]):
  model = Sequential()
  model.add(Dense(64, activation='relu', input_dim=SUB_REGION_SCALE*SUB_REGION_SCALE))
  model.add(Dense(64, activation='relu'))
  model.add(Dense(NUM_CLASS, activation = 'softmax'))
  model.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])
  ensemble.append((model, i, coordinate_list[i], scale_list[i]))

# %%
for i in range(NUM_TN[0]):
  ensemble[i][0].load_weights('/content/drive/My Drive/fyp/Fashion MNIST_' + str(i) + '.h5')

# %%
hico_layers = []
hico_layers.append(ensemble)

# %%
del hico_layers[1:]

# %% [markdown]
# ## HiCo Layer 2+

# %%
# Function to get input of layer i-1
def get_previous_layer_input(hico_layers, layer, tn, train_image):
  input_hr = []
  input_ol = []
    
  if layer == 0:
    previous_layer_input = train_image[tn[1]]
    return previous_layer_input

  elif layer > 0:
    for i in range(NUM_CONNECTION[layer]):
      get_input = (K.function(hico_layers[layer-1][tn[1][i]][0].layers[0].input, hico_layers[layer-1][tn[1][i]][0].layers[1].output))
      input_hr.append(get_input(get_previous_layer_input(hico_layers, layer-1, hico_layers[layer-1][tn[1][i]], train_image)))
      
    input_hr = np.array(input_hr)
    input_hr = np.concatenate(input_hr, axis=1)

    for i in range(NUM_CONNECTION[layer]):
      get_input = (K.function(hico_layers[layer-1][tn[1][i]][0].layers[0].input, hico_layers[layer-1][tn[1][i]][0].layers[2].output))
      input_ol.append(get_input(get_previous_layer_input(hico_layers, layer-1, hico_layers[layer-1][tn[1][i]], train_image)))

    input_ol = np.array(input_ol)
    input_ol = np.sum(input_ol, axis=0)

    input = np.concatenate((input_hr, input_ol), axis=1)
    
    previous_layer_input = input
    return previous_layer_input

# %%
for i in range(1, NUM_HICO_LAYER):
  print('Layer %d' %i)
  ensemble = []
  X_train_input_list = []
  X_test_input_list = []

  for j in range(NUM_TN[i]):
    # Build model of HiCo layer i
    connection = tuple(random.sample(range(len(hico_layers[i-1])), k=NUM_CONNECTION[i]))
    model = Sequential()
    model.add(Dense(64, activation='relu', input_dim=64*NUM_CONNECTION[i]+NUM_CLASS))
    model.add(Dense(64, activation='relu'))
    model.add(Dense(NUM_CLASS, activation = 'softmax'))
    model.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])
    ensemble.append((model, connection))
  hico_layers.append(ensemble)
  print('HICO LENGTH')
  print(len(hico_layers))

  for j in range(NUM_TN[i]):
    # Get train hidden representation from HiCo layer i-1
    X_train_input_hr = []
    X_train_input_ol = []
    for k in range(NUM_CONNECTION[i]):
      get_input = (K.function(hico_layers[i-1][hico_layers[i][j][1][k]][0].layers[0].input, hico_layers[i-1][hico_layers[i][j][1][k]][0].layers[1].output))
      X_train_input_hr.append(get_input(get_previous_layer_input(hico_layers, i-1, hico_layers[i-1][hico_layers[i][j][1][k]], X_train_cropped_list)))
    X_train_input_hr = np.array(X_train_input_hr)
    X_train_input_hr = np.concatenate(X_train_input_hr, axis=1)

    for k in range(NUM_CONNECTION[i]):
      get_input = (K.function(hico_layers[i-1][hico_layers[i][j][1][k]][0].layers[0].input, hico_layers[i-1][hico_layers[i][j][1][k]][0].layers[2].output))
      X_train_input_ol.append(get_input(get_previous_layer_input(hico_layers, i-1, hico_layers[i-1][hico_layers[i][j][1][k]], X_train_cropped_list)))
    X_train_input_ol = np.array(X_train_input_ol)
    X_train_input_ol = np.sum(X_train_input_ol, axis=0)

    X_train_input = np.concatenate((X_train_input_hr, X_train_input_ol), axis=1)
    X_train_input_list.append(X_train_input)

    # Get test hidden representation from HiCo layer i-1
    X_test_input_hr = []
    X_test_input_ol = []
    for k in range(NUM_CONNECTION[i]):
      get_input = (K.function(hico_layers[i-1][hico_layers[i][j][1][k]][0].layers[0].input, hico_layers[i-1][hico_layers[i][j][1][k]][0].layers[1].output))
      X_test_input_hr.append(get_input(get_previous_layer_input(hico_layers, i-1, hico_layers[i-1][hico_layers[i][j][1][k]], X_test_cropped_list)))
    X_test_input_hr = np.array(X_test_input_hr)
    X_test_input_hr = np.concatenate(X_test_input_hr, axis=1)

    for k in range(NUM_CONNECTION[i]):
      get_input = (K.function(hico_layers[i-1][hico_layers[i][j][1][k]][0].layers[0].input, hico_layers[i-1][hico_layers[i][j][1][k]][0].layers[2].output))
      X_test_input_ol.append(get_input(get_previous_layer_input(hico_layers, i-1, hico_layers[i-1][hico_layers[i][j][1][k]], X_test_cropped_list)))
    X_test_input_ol = np.array(X_test_input_ol)
    X_test_input_ol = np.sum(X_test_input_ol, axis=0)

    X_test_input = np.concatenate((X_test_input_hr, X_test_input_ol), axis=1)
    X_test_input_list.append(X_test_input)

  #train model of HiCo layer i
  for j in range(NUM_TN[i]):
    print('Model %d' %j)
    hico_layers[i][j][0].fit(X_train_input_list[j], y_train_one_hot, validation_data=(X_test_input_list[j], y_test_one_hot), epochs=5, batch_size=128)
# Out:
# Layer 1
# HICO LENGTH
# 2
# Model 0
# Epoch 1/5
# 469/469 [==============================] - 2s 2ms/step - loss: 0.6900 - accuracy: 0.7575 - val_loss: 0.4590 - val_accuracy: 0.8345
# Epoch 2/5
# 469/469 [==============================] - 1s 2ms/step - loss: 0.4170 - accuracy: 0.8459 - val_loss: 0.4370 - val_accuracy: 0.8370
# Epoch 3/5
# 469/469 [==============================] - 1s 2ms/step - loss: 0.3977 - accuracy: 0.8527 - val_loss: 0.4255 - val_accuracy: 0.8418
# Epoch 4/5
# 469/469 [==============================] - 1s 2ms/step - loss: 0.3924 - accuracy: 0.8540 - val_loss: 0.4232 - val_accuracy: 0.8440
# Epoch 5/5
# 469/469 [==============================] - 1s 2ms/step - loss: 0.3786 - accuracy: 0.8573 - val_loss: 0.4130 - val_accuracy: 0.8470
# Model 1
# Epoch 1/5
# 469/469 [==============================] - 1s 2ms/step - loss: 0.7100 - accuracy: 0.7613 - val_loss: 0.4484 - val_accuracy: 0.8320
# Epoch 2/5
# 469/469 [==============================] - 1s 2ms/step - loss: 0.4087 - accuracy: 0.8474 - val_loss: 0.4312 - val_accuracy: 0.8408
# Epoch 3/5
# 469/469 [==============================] - 1s 2ms/step - loss: 0.3910 - accuracy: 0.8556 - val_loss: 0.4196 - val_accuracy: 0.8452
# Epoch 4/5
# 469/469 [==============================] - 1s 2ms/step - loss: 0.3802 - accuracy: 0.8602 - val_loss: 0.4310 - val_accuracy: 0.8385
# Epoch 5/5
# 469/469 [==============================] - 1s 2ms/step - loss: 0.3720 - accuracy: 0.8608 - val_loss: 0.4231 - val_accuracy: 0.8422
# Model 2
# Epoch 1/5
# 469/469 [==============================] - 1s 2ms/step - loss: 0.6679 - accuracy: 0.7683 - val_loss: 0.4413 - val_accuracy: 0.8358
# Epoch 2/5
# 469/469 [==============================] - 1s 2ms/step - loss: 0.4006 - accuracy: 0.8517 - val_loss: 0.4195 - val_accuracy: 0.8460
# Epoch 3/5
# 469/469 [==============================] - 1s 2ms/step - loss: 0.3758 - accuracy: 0.8587 - val_loss: 0.4103 - val_accuracy: 0.8487
# Epoch 4/5
# 469/469 [==============================] - 1s 2ms/step - loss: 0.3717 - accuracy: 0.8600 - val_loss: 0.4240 - val_accuracy: 0.8451
# Epoch 5/5
# 469/469 [==============================] - 1s 2ms/step - loss: 0.3610 - accuracy: 0.8619 - val_loss: 0.4223 - val_accuracy: 0.8445
# Model 3
# Epoch 1/5
# 469/469 [==============================] - 1s 2ms/step - loss: 0.6819 - accuracy: 0.7653 - val_loss: 0.4594 - val_accuracy: 0.8273
# Epoch 2/5
# 469/469 [==============================] - 1s 2ms/step - loss: 0.4117 - accuracy: 0.8467 - val_loss: 0.4323 - val_accuracy: 0.8373
# Epoch 3/5
# 469/469 [==============================] - 1s 2ms/step - loss: 0.3918 - accuracy: 0.8537 - val_loss: 0.4258 - val_accuracy: 0.8439
# Epoch 4/5
# 469/469 [==============================] - 1s 2ms/step - loss: 0.3814 - accuracy: 0.8563 - val_loss: 0.4131 - val_accuracy: 0.8464
# Epoch 5/5
# 469/469 [==============================] - 1s 2ms/step - loss: 0.3713 - accuracy: 0.8607 - val_loss: 0.4144 - val_accuracy: 0.8464
# Model 4
# Epoch 1/5
# 469/469 [==============================] - 2s 3ms/step - loss: 0.6325 - accuracy: 0.7786 - val_loss: 0.4673 - val_accuracy: 0.8277
# Epoch 2/5
# 469/469 [==============================] - 1s 2ms/step - loss: 0.4117 - accuracy: 0.8477 - val_loss: 0.4450 - val_accuracy: 0.8333
# Epoch 3/5
# 469/469 [==============================] - 1s 2ms/step - loss: 0.3937 - accuracy: 0.8527 - val_loss: 0.4358 - val_accuracy: 0.8415
# Epoch 4/5
# 469/469 [==============================] - 1s 2ms/step - loss: 0.3718 - accuracy: 0.8601 - val_loss: 0.4269 - val_accuracy: 0.8402
# Epoch 5/5
# 469/469 [==============================] - 1s 2ms/step - loss: 0.3748 - accuracy: 0.8590 - val_loss: 0.4136 - val_accuracy: 0.8483
# Model 5
# Epoch 1/5
# 469/469 [==============================] - 1s 2ms/step - loss: 0.7602 - accuracy: 0.7413 - val_loss: 0.4508 - val_accuracy: 0.8288
# Epoch 2/5
# 469/469 [==============================] - 1s 2ms/step - loss: 0.4194 - accuracy: 0.8439 - val_loss: 0.4288 - val_accuracy: 0.8395
# Epoch 3/5
# 469/469 [==============================] - 1s 2ms/step - loss: 0.3854 - accuracy: 0.8558 - val_loss: 0.4197 - val_accuracy: 0.8410
# Epoch 4/5
# 469/469 [==============================] - 1s 2ms/step - loss: 0.3789 - accuracy: 0.8571 - val_loss: 0.4129 - val_accuracy: 0.8462
# Epoch 5/5
# 469/469 [==============================] - 1s 2ms/step - loss: 0.3735 - accuracy: 0.8600 - val_loss: 0.4087 - val_accuracy: 0.8485
# Model 6
# Epoch 1/5
# 469/469 [==============================] - 1s 2ms/step - loss: 0.7223 - accuracy: 0.7592 - val_loss: 0.4692 - val_accuracy: 0.8271
# Epoch 2/5
# 469/469 [==============================] - 1s 2ms/step - loss: 0.4163 - accuracy: 0.8460 - val_loss: 0.4400 - val_accuracy: 0.8388
# Epoch 3/5
# 469/469 [==============================] - 1s 2ms/step - loss: 0.3962 - accuracy: 0.8514 - val_loss: 0.4381 - val_accuracy: 0.8349
# Epoch 4/5
# 469/469 [==============================] - 1s 2ms/step - loss: 0.3857 - accuracy: 0.8563 - val_loss: 0.4157 - val_accuracy: 0.8468
# Epoch 5/5
# 469/469 [==============================] - 1s 2ms/step - loss: 0.3767 - accuracy: 0.8584 - val_loss: 0.4210 - val_accuracy: 0.8457
# Model 7
# Epoch 1/5
# 469/469 [==============================] - 1s 2ms/step - loss: 0.6729 - accuracy: 0.7659 - val_loss: 0.4619 - val_accuracy: 0.8280
# Epoch 2/5
# 469/469 [==============================] - 1s 2ms/step - loss: 0.4220 - accuracy: 0.8403 - val_loss: 0.4498 - val_accuracy: 0.8337
# Epoch 3/5
# 469/469 [==============================] - 1s 2ms/step - loss: 0.4062 - accuracy: 0.8479 - val_loss: 0.4357 - val_accuracy: 0.8382
# Epoch 4/5
# 469/469 [==============================] - 1s 2ms/step - loss: 0.3898 - accuracy: 0.8510 - val_loss: 0.4244 - val_accuracy: 0.8436
# Epoch 5/5
# 469/469 [==============================] - 1s 2ms/step - loss: 0.3754 - accuracy: 0.8564 - val_loss: 0.4224 - val_accuracy: 0.8458
# Layer 2
# HICO LENGTH
# 3
# Model 0
# Epoch 1/5
# 469/469 [==============================] - 1s 2ms/step - loss: 0.5684 - accuracy: 0.8114 - val_loss: 0.4028 - val_accuracy: 0.8526
# Epoch 2/5
# 469/469 [==============================] - 1s 2ms/step - loss: 0.3488 - accuracy: 0.8705 - val_loss: 0.3888 - val_accuracy: 0.8593
# Epoch 3/5
# 469/469 [==============================] - 1s 2ms/step - loss: 0.3411 - accuracy: 0.8709 - val_loss: 0.3808 - val_accuracy: 0.8584
# Epoch 4/5
# 469/469 [==============================] - 1s 2ms/step - loss: 0.3325 - accuracy: 0.8742 - val_loss: 0.3996 - val_accuracy: 0.8508
# Epoch 5/5
# 469/469 [==============================] - 1s 2ms/step - loss: 0.3220 - accuracy: 0.8780 - val_loss: 0.3768 - val_accuracy: 0.8601
# Model 1
# Epoch 1/5
# 469/469 [==============================] - 1s 2ms/step - loss: 0.5208 - accuracy: 0.8236 - val_loss: 0.4040 - val_accuracy: 0.8499
# Epoch 2/5
# 469/469 [==============================] - 1s 2ms/step - loss: 0.3427 - accuracy: 0.8692 - val_loss: 0.3869 - val_accuracy: 0.8582
# Epoch 3/5
# 469/469 [==============================] - 1s 2ms/step - loss: 0.3307 - accuracy: 0.8743 - val_loss: 0.4154 - val_accuracy: 0.8432
# Epoch 4/5
# 469/469 [==============================] - 1s 2ms/step - loss: 0.3314 - accuracy: 0.8771 - val_loss: 0.3864 - val_accuracy: 0.8590
# Epoch 5/5
# 469/469 [==============================] - 1s 2ms/step - loss: 0.3236 - accuracy: 0.8780 - val_loss: 0.3924 - val_accuracy: 0.8562
# Model 2
# Epoch 1/5
# 469/469 [==============================] - 1s 2ms/step - loss: 0.5521 - accuracy: 0.8090 - val_loss: 0.4137 - val_accuracy: 0.8520
# Epoch 2/5
# 469/469 [==============================] - 1s 2ms/step - loss: 0.3507 - accuracy: 0.8698 - val_loss: 0.3843 - val_accuracy: 0.8584
# Epoch 3/5
# 469/469 [==============================] - 1s 2ms/step - loss: 0.3312 - accuracy: 0.8767 - val_loss: 0.3917 - val_accuracy: 0.8581
# Epoch 4/5
# 469/469 [==============================] - 1s 2ms/step - loss: 0.3350 - accuracy: 0.8741 - val_loss: 0.3858 - val_accuracy: 0.8553
# Epoch 5/5
# 469/469 [==============================] - 1s 2ms/step - loss: 0.3266 - accuracy: 0.8753 - val_loss: 0.3866 - val_accuracy: 0.8602
# Model 3
# Epoch 1/5
# 469/469 [==============================] - 1s 2ms/step - loss: 0.6362 - accuracy: 0.7967 - val_loss: 0.4084 - val_accuracy: 0.8490
# Epoch 2/5
# 469/469 [==============================] - 1s 2ms/step - loss: 0.3419 - accuracy: 0.8714 - val_loss: 0.3917 - val_accuracy: 0.8520
# Epoch 3/5
# 469/469 [==============================] - 1s 2ms/step - loss: 0.3330 - accuracy: 0.8764 - val_loss: 0.3899 - val_accuracy: 0.8574
# Epoch 4/5
# 469/469 [==============================] - 1s 2ms/step - loss: 0.3321 - accuracy: 0.8756 - val_loss: 0.3777 - val_accuracy: 0.8595
# Epoch 5/5
# 469/469 [==============================] - 1s 2ms/step - loss: 0.3275 - accuracy: 0.8775 - val_loss: 0.3793 - val_accuracy: 0.8601
# Model 4
# Epoch 1/5
# 469/469 [==============================] - 1s 2ms/step - loss: 0.5827 - accuracy: 0.8029 - val_loss: 0.3923 - val_accuracy: 0.8564
# Epoch 2/5
# 469/469 [==============================] - 1s 2ms/step - loss: 0.3387 - accuracy: 0.8725 - val_loss: 0.3866 - val_accuracy: 0.8591
# Epoch 3/5
# 469/469 [==============================] - 1s 2ms/step - loss: 0.3311 - accuracy: 0.8765 - val_loss: 0.3788 - val_accuracy: 0.8606
# Epoch 4/5
# 469/469 [==============================] - 1s 2ms/step - loss: 0.3338 - accuracy: 0.8746 - val_loss: 0.3877 - val_accuracy: 0.8587
# Epoch 5/5
# 469/469 [==============================] - 1s 2ms/step - loss: 0.3217 - accuracy: 0.8788 - val_loss: 0.3811 - val_accuracy: 0.8586
# Model 5
# Epoch 1/5
# 469/469 [==============================] - 1s 2ms/step - loss: 0.6343 - accuracy: 0.7997 - val_loss: 0.4044 - val_accuracy: 0.8521
# Epoch 2/5
# 469/469 [==============================] - 1s 2ms/step - loss: 0.3485 - accuracy: 0.8706 - val_loss: 0.3953 - val_accuracy: 0.8595
# Epoch 3/5
# 469/469 [==============================] - 1s 2ms/step - loss: 0.3374 - accuracy: 0.8737 - val_loss: 0.3896 - val_accuracy: 0.8572
# Epoch 4/5
# 469/469 [==============================] - 1s 2ms/step - loss: 0.3341 - accuracy: 0.8735 - val_loss: 0.3905 - val_accuracy: 0.8582
# Epoch 5/5
# 469/469 [==============================] - 1s 2ms/step - loss: 0.3272 - accuracy: 0.8762 - val_loss: 0.4015 - val_accuracy: 0.8535
# Layer 3
# HICO LENGTH
# 4
# Model 0
# Epoch 1/5
# 469/469 [==============================] - 1s 2ms/step - loss: 0.5389 - accuracy: 0.8217 - val_loss: 0.3780 - val_accuracy: 0.8613
# Epoch 2/5
# 469/469 [==============================] - 1s 2ms/step - loss: 0.3233 - accuracy: 0.8781 - val_loss: 0.3781 - val_accuracy: 0.8608
# Epoch 3/5
# 469/469 [==============================] - 1s 2ms/step - loss: 0.3190 - accuracy: 0.8786 - val_loss: 0.3796 - val_accuracy: 0.8586
# Epoch 4/5
# 469/469 [==============================] - 1s 2ms/step - loss: 0.3179 - accuracy: 0.8792 - val_loss: 0.3815 - val_accuracy: 0.8568
# Epoch 5/5
# 469/469 [==============================] - 1s 2ms/step - loss: 0.3155 - accuracy: 0.8793 - val_loss: 0.3764 - val_accuracy: 0.8611
# Model 1
# Epoch 1/5
# 469/469 [==============================] - 2s 2ms/step - loss: 0.5532 - accuracy: 0.8247 - val_loss: 0.3873 - val_accuracy: 0.8606
# Epoch 2/5
# 469/469 [==============================] - 1s 2ms/step - loss: 0.3221 - accuracy: 0.8794 - val_loss: 0.3817 - val_accuracy: 0.8604
# Epoch 3/5
# 469/469 [==============================] - 1s 2ms/step - loss: 0.3176 - accuracy: 0.8795 - val_loss: 0.3970 - val_accuracy: 0.8571
# Epoch 4/5
# 469/469 [==============================] - 1s 2ms/step - loss: 0.3189 - accuracy: 0.8795 - val_loss: 0.3758 - val_accuracy: 0.8624
# Epoch 5/5
# 469/469 [==============================] - 1s 2ms/step - loss: 0.3182 - accuracy: 0.8798 - val_loss: 0.3723 - val_accuracy: 0.8637
# Model 2
# Epoch 1/5
# 469/469 [==============================] - 1s 2ms/step - loss: 0.5222 - accuracy: 0.8214 - val_loss: 0.3791 - val_accuracy: 0.8619
# Epoch 2/5
# 469/469 [==============================] - 1s 2ms/step - loss: 0.3203 - accuracy: 0.8777 - val_loss: 0.3722 - val_accuracy: 0.8636
# Epoch 3/5
# 469/469 [==============================] - 1s 2ms/step - loss: 0.3163 - accuracy: 0.8810 - val_loss: 0.3734 - val_accuracy: 0.8618
# Epoch 4/5
# 469/469 [==============================] - 1s 2ms/step - loss: 0.3155 - accuracy: 0.8798 - val_loss: 0.3729 - val_accuracy: 0.8644
# Epoch 5/5
# 469/469 [==============================] - 1s 2ms/step - loss: 0.3099 - accuracy: 0.8816 - val_loss: 0.3728 - val_accuracy: 0.8612
# Model 3
# Epoch 1/5
# 469/469 [==============================] - 1s 2ms/step - loss: 0.4845 - accuracy: 0.8387 - val_loss: 0.3808 - val_accuracy: 0.8615
# Epoch 2/5
# 469/469 [==============================] - 1s 2ms/step - loss: 0.3236 - accuracy: 0.8784 - val_loss: 0.3827 - val_accuracy: 0.8634
# Epoch 3/5
# 469/469 [==============================] - 1s 2ms/step - loss: 0.3185 - accuracy: 0.8803 - val_loss: 0.3796 - val_accuracy: 0.8612
# Epoch 4/5
# 469/469 [==============================] - 1s 2ms/step - loss: 0.3244 - accuracy: 0.8780 - val_loss: 0.3809 - val_accuracy: 0.8624
# Epoch 5/5
# 469/469 [==============================] - 1s 2ms/step - loss: 0.3163 - accuracy: 0.8798 - val_loss: 0.3831 - val_accuracy: 0.8611
# Layer 4
# HICO LENGTH
# 5
# Model 0
# Epoch 1/5
# 469/469 [==============================] - 1s 2ms/step - loss: 0.5626 - accuracy: 0.8120 - val_loss: 0.3845 - val_accuracy: 0.8624
# Epoch 2/5
# 469/469 [==============================] - 1s 2ms/step - loss: 0.3190 - accuracy: 0.8801 - val_loss: 0.3761 - val_accuracy: 0.8650
# Epoch 3/5
# 469/469 [==============================] - 1s 2ms/step - loss: 0.3173 - accuracy: 0.8810 - val_loss: 0.3727 - val_accuracy: 0.8644
# Epoch 4/5
# 469/469 [==============================] - 1s 2ms/step - loss: 0.3067 - accuracy: 0.8842 - val_loss: 0.3716 - val_accuracy: 0.8653
# Epoch 5/5
# 469/469 [==============================] - 1s 2ms/step - loss: 0.3095 - accuracy: 0.8805 - val_loss: 0.3709 - val_accuracy: 0.8641
# Model 1
# Epoch 1/5
# 469/469 [==============================] - 1s 2ms/step - loss: 0.5161 - accuracy: 0.8259 - val_loss: 0.3739 - val_accuracy: 0.8651
# Epoch 2/5
# 469/469 [==============================] - 1s 2ms/step - loss: 0.3153 - accuracy: 0.8796 - val_loss: 0.3702 - val_accuracy: 0.8641
# Epoch 3/5
# 469/469 [==============================] - 1s 2ms/step - loss: 0.3149 - accuracy: 0.8797 - val_loss: 0.3744 - val_accuracy: 0.8651
# Epoch 4/5
# 469/469 [==============================] - 1s 2ms/step - loss: 0.3114 - accuracy: 0.8815 - val_loss: 0.3768 - val_accuracy: 0.8615
# Epoch 5/5
# 469/469 [==============================] - 1s 2ms/step - loss: 0.3041 - accuracy: 0.8851 - val_loss: 0.3744 - val_accuracy: 0.8624

# %% [markdown]
# ## Model Evaluation

# %%
# Predict on test image
y_pred_list = []
for j in range(NUM_TN[0]):
  y_pred = np.argmax(hico_layers[0][j][0].predict(X_test_cropped_list[j]), axis=1)
  y_pred_list.append(y_pred)

for i in range(1, NUM_HICO_LAYER):
  for j in range(NUM_TN[i]):

    # Get test hidden representation from HiCo layer i-1
    X_test_input_hr = []
    X_test_input_ol = []
    for k in range(NUM_CONNECTION[i]):
      get_input = (K.function(hico_layers[i-1][hico_layers[i][j][1][k]][0].layers[0].input, hico_layers[i-1][hico_layers[i][j][1][k]][0].layers[1].output))
      X_test_input_hr.append(get_input(get_previous_layer_input(hico_layers, i-1, hico_layers[i-1][hico_layers[i][j][1][k]], X_test_cropped_list)))
    X_test_input_hr = np.array(X_test_input_hr)
    X_test_input_hr = np.concatenate(X_test_input_hr, axis=1)

    for k in range(NUM_CONNECTION[i]):
      get_input = (K.function(hico_layers[i-1][hico_layers[i][j][1][k]][0].layers[0].input, hico_layers[i-1][hico_layers[i][j][1][k]][0].layers[2].output))
      X_test_input_ol.append(get_input(get_previous_layer_input(hico_layers, i-1, hico_layers[i-1][hico_layers[i][j][1][k]], X_test_cropped_list)))
    X_test_input_ol = np.array(X_test_input_ol)
    X_test_input_ol = np.sum(X_test_input_ol, axis=0)

    X_test_input = np.concatenate((X_test_input_hr, X_test_input_ol), axis=1)

    y_pred = np.argmax(hico_layers[i][j][0].predict(X_test_input), axis=1)
    y_pred_list.append(y_pred)

# HiCo voting (mode)
y_pred_list = np.array(y_pred_list)
y_pred_list = np.transpose(y_pred_list, (1, 0))
y_pred_list = stats.mode(y_pred_list, axis=1)[0]
y_pred_list = np.squeeze(y_pred_list)

# %%
y_test = np.argmax(y_test_one_hot, axis=1)

# %%
accuracy = accuracy_score(y_test, y_pred_list)
accuracy
# Out:
# 0.8626
