# %% [markdown]
# # Fashion MNIST HiCo Layer 1

# %%
from keras.models import Sequential
from keras.layers import Dense, Conv2D, Flatten
from keras.datasets import fashion_mnist
from keras.utils import to_categorical
import matplotlib.pyplot as plt
import numpy as np
import tensorflow as tf
import random
from scipy import stats
from sklearn.metrics import accuracy_score
from keras import backend as K
import cv2

import os
import pickle
from google.colab import drive
drive.mount('/content/drive/')
# Out:
# Drive already mounted at /content/drive/; to attempt to forcibly remount, call drive.mount("/content/drive/", force_remount=True).

# %%
NUM_TN = 10
SUB_REGION_SCALE = 14
MIN_SUB_REGION_SCALE = 12
MAX_SUB_REGION_SCALE = 16
NUM_HICO_LAYER = 5

#dataset specific parameters
NUM_CLASS = 10

# %% [markdown]
# ## Data Pre-Processing

# %%
#load dataset
(X_train, y_train), (X_test, y_test) = fashion_mnist.load_data()

# %%
#Generate cropped train image
X_train_cropped_list = []
coordinate_list = []
scale_list = []
for i in range(NUM_TN):
  X_train_cropped = []
  sub_region_scale = random.randint(MIN_SUB_REGION_SCALE, MAX_SUB_REGION_SCALE)
  x = random.randint(0, X_train.shape[1] - sub_region_scale)
  y = random.randint(0, X_train.shape[1] - sub_region_scale)
  coordinate = (x, y)
  for j in range(X_train.shape[0]):
    image_cropped = []
    for row in range(y, y + sub_region_scale):
      image_cropped_row = []
      for column in range(x, x + sub_region_scale):
        image_cropped_row.append(X_train[j][row][column])
      image_cropped.append(image_cropped_row)
    X_train_cropped.append(image_cropped)
  
  X_train_cropped = np.array(X_train_cropped)
  X_train_cropped_list.append(X_train_cropped)
  coordinate_list.append(coordinate)
  scale_list.append(sub_region_scale)

# %%
#Generate cropped test image
X_test_cropped_list = []
for i in range(NUM_TN):
  X_test_cropped = []
  sub_region_scale = scale_list[i]
  x = coordinate_list[i][0]
  y = coordinate_list[i][1]
  for j in range(X_test.shape[0]):
    image_cropped = []
    for row in range(y, y + sub_region_scale):
      image_cropped_row = []
      for column in range(x, x + sub_region_scale):
        image_cropped_row.append(X_test[j][row][column])
      image_cropped.append(image_cropped_row)
    X_test_cropped.append(image_cropped)

  X_test_cropped = np.array(X_test_cropped)
  X_test_cropped_list.append(X_test_cropped)

# %%
#rescaling dataset
for i in range(NUM_TN):
  temp = []
  for j in range (X_train.shape[0]):
    temp.append(cv2.resize(X_train_cropped_list[i][j], (SUB_REGION_SCALE, SUB_REGION_SCALE)))
  temp = np.array(temp)
  X_train_cropped_list[i] = temp

  temp = []
  for j in range(X_test.shape[0]):
    temp.append(cv2.resize(X_test_cropped_list[i][j], (SUB_REGION_SCALE, SUB_REGION_SCALE)))
  temp = np.array(temp)
  X_test_cropped_list[i] = temp

# %%
#normalizing dataset
for i in range(NUM_TN):
  X_train_cropped_list[i] = X_train_cropped_list[i]/255
  X_test_cropped_list[i] = X_test_cropped_list[i]/255

# %%
#transform to vector
for i in range(NUM_TN):
  X_train_cropped_list[i] = X_train_cropped_list[i].reshape((-1, SUB_REGION_SCALE*SUB_REGION_SCALE))
  X_test_cropped_list[i] = X_test_cropped_list[i].reshape((-1, SUB_REGION_SCALE*SUB_REGION_SCALE))

# %%
#one-hot encoding
y_train_one_hot = to_categorical(y_train)
y_test_one_hot = to_categorical(y_test)

# %% [markdown]
# ## HiCo Layer 1

# %%
#build ANN model
ensemble = []
for i in range(NUM_TN):
  model = Sequential()
  model.add(Dense(64, activation='relu', input_dim=SUB_REGION_SCALE*SUB_REGION_SCALE))
  model.add(Dense(64, activation='relu'))
  model.add(Dense(NUM_CLASS, activation = 'softmax'))
  model.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])
  ensemble.append((model, i, coordinate_list[i], scale_list[i]))

# %%
#train model
history = []
for i in range(NUM_TN):
  print('Model %d' %i)
  hist = ensemble[i][0].fit(X_train_cropped_list[i], y_train_one_hot, validation_data=(X_test_cropped_list[i], y_test_one_hot), epochs=5, batch_size=128)
  history.append(hist)
# Out:
# Model 0
# Epoch 1/5
# 469/469 [==============================] - 2s 3ms/step - loss: 1.3295 - accuracy: 0.5327 - val_loss: 0.8818 - val_accuracy: 0.6692
# Epoch 2/5
# 469/469 [==============================] - 1s 2ms/step - loss: 0.8409 - accuracy: 0.6898 - val_loss: 0.8019 - val_accuracy: 0.7046
# Epoch 3/5
# 469/469 [==============================] - 1s 2ms/step - loss: 0.7755 - accuracy: 0.7139 - val_loss: 0.7722 - val_accuracy: 0.7136
# Epoch 4/5
# 469/469 [==============================] - 1s 2ms/step - loss: 0.7563 - accuracy: 0.7146 - val_loss: 0.7629 - val_accuracy: 0.7222
# Epoch 5/5
# 469/469 [==============================] - 1s 2ms/step - loss: 0.7216 - accuracy: 0.7309 - val_loss: 0.7316 - val_accuracy: 0.7282
# Model 1
# Epoch 1/5
# 469/469 [==============================] - 2s 3ms/step - loss: 1.2961 - accuracy: 0.5300 - val_loss: 0.9048 - val_accuracy: 0.6544
# Epoch 2/5
# 469/469 [==============================] - 1s 2ms/step - loss: 0.8726 - accuracy: 0.6703 - val_loss: 0.8504 - val_accuracy: 0.6816
# Epoch 3/5
# 469/469 [==============================] - 1s 2ms/step - loss: 0.8219 - accuracy: 0.6858 - val_loss: 0.8137 - val_accuracy: 0.6912
# Epoch 4/5
# 469/469 [==============================] - 1s 2ms/step - loss: 0.7967 - accuracy: 0.6954 - val_loss: 0.7920 - val_accuracy: 0.7017
# Epoch 5/5
# 469/469 [==============================] - 1s 2ms/step - loss: 0.7697 - accuracy: 0.7068 - val_loss: 0.7922 - val_accuracy: 0.6980
# Model 2
# Epoch 1/5
# 469/469 [==============================] - 2s 3ms/step - loss: 1.2289 - accuracy: 0.5854 - val_loss: 0.7606 - val_accuracy: 0.7220
# Epoch 2/5
# 469/469 [==============================] - 1s 2ms/step - loss: 0.7283 - accuracy: 0.7314 - val_loss: 0.7045 - val_accuracy: 0.7411
# Epoch 3/5
# 469/469 [==============================] - 1s 2ms/step - loss: 0.6831 - accuracy: 0.7463 - val_loss: 0.6702 - val_accuracy: 0.7537
# Epoch 4/5
# 469/469 [==============================] - 1s 2ms/step - loss: 0.6478 - accuracy: 0.7609 - val_loss: 0.6488 - val_accuracy: 0.7585
# Epoch 5/5
# 469/469 [==============================] - 1s 2ms/step - loss: 0.6286 - accuracy: 0.7685 - val_loss: 0.6362 - val_accuracy: 0.7625
# Model 3
# Epoch 1/5
# 469/469 [==============================] - 2s 3ms/step - loss: 1.3091 - accuracy: 0.5481 - val_loss: 0.8641 - val_accuracy: 0.6941
# Epoch 2/5
# 469/469 [==============================] - 1s 2ms/step - loss: 0.8294 - accuracy: 0.7077 - val_loss: 0.7998 - val_accuracy: 0.7139
# Epoch 3/5
# 469/469 [==============================] - 1s 2ms/step - loss: 0.7562 - accuracy: 0.7315 - val_loss: 0.7774 - val_accuracy: 0.7267
# Epoch 4/5
# 469/469 [==============================] - 1s 2ms/step - loss: 0.7224 - accuracy: 0.7389 - val_loss: 0.7444 - val_accuracy: 0.7344
# Epoch 5/5
# 469/469 [==============================] - 1s 2ms/step - loss: 0.7050 - accuracy: 0.7445 - val_loss: 0.7361 - val_accuracy: 0.7366
# Model 4
# Epoch 1/5
# 469/469 [==============================] - 2s 3ms/step - loss: 1.2654 - accuracy: 0.5491 - val_loss: 0.8322 - val_accuracy: 0.6915
# Epoch 2/5
# 469/469 [==============================] - 1s 3ms/step - loss: 0.7887 - accuracy: 0.7163 - val_loss: 0.7493 - val_accuracy: 0.7257
# Epoch 3/5
# 469/469 [==============================] - 1s 2ms/step - loss: 0.7171 - accuracy: 0.7402 - val_loss: 0.7192 - val_accuracy: 0.7366
# Epoch 4/5
# 469/469 [==============================] - 1s 2ms/step - loss: 0.6811 - accuracy: 0.7523 - val_loss: 0.6982 - val_accuracy: 0.7447
# Epoch 5/5
# 469/469 [==============================] - 1s 2ms/step - loss: 0.6554 - accuracy: 0.7576 - val_loss: 0.6740 - val_accuracy: 0.7541
# Model 5
# Epoch 1/5
# 469/469 [==============================] - 2s 3ms/step - loss: 1.3663 - accuracy: 0.5046 - val_loss: 0.9963 - val_accuracy: 0.6168
# Epoch 2/5
# 469/469 [==============================] - 1s 2ms/step - loss: 0.9645 - accuracy: 0.6221 - val_loss: 0.9639 - val_accuracy: 0.6283
# Epoch 3/5
# 469/469 [==============================] - 1s 2ms/step - loss: 0.9272 - accuracy: 0.6370 - val_loss: 0.9157 - val_accuracy: 0.6435
# Epoch 4/5
# 469/469 [==============================] - 1s 2ms/step - loss: 0.8932 - accuracy: 0.6459 - val_loss: 0.9010 - val_accuracy: 0.6491
# Epoch 5/5
# 469/469 [==============================] - 1s 2ms/step - loss: 0.8714 - accuracy: 0.6559 - val_loss: 0.8773 - val_accuracy: 0.6529
# Model 6
# Epoch 1/5
# 469/469 [==============================] - 2s 3ms/step - loss: 1.1358 - accuracy: 0.6097 - val_loss: 0.7265 - val_accuracy: 0.7324
# Epoch 2/5
# 469/469 [==============================] - 1s 2ms/step - loss: 0.6673 - accuracy: 0.7489 - val_loss: 0.6556 - val_accuracy: 0.7530
# Epoch 3/5
# 469/469 [==============================] - 1s 2ms/step - loss: 0.6131 - accuracy: 0.7697 - val_loss: 0.6336 - val_accuracy: 0.7644
# Epoch 4/5
# 469/469 [==============================] - 1s 2ms/step - loss: 0.5814 - accuracy: 0.7814 - val_loss: 0.6121 - val_accuracy: 0.7725
# Epoch 5/5
# 469/469 [==============================] - 1s 2ms/step - loss: 0.5637 - accuracy: 0.7870 - val_loss: 0.6197 - val_accuracy: 0.7664
# Model 7
# Epoch 1/5
# 469/469 [==============================] - 2s 3ms/step - loss: 1.3260 - accuracy: 0.5401 - val_loss: 0.8629 - val_accuracy: 0.6840
# Epoch 2/5
# 469/469 [==============================] - 1s 2ms/step - loss: 0.8142 - accuracy: 0.7002 - val_loss: 0.7898 - val_accuracy: 0.7066
# Epoch 3/5
# 469/469 [==============================] - 1s 2ms/step - loss: 0.7673 - accuracy: 0.7151 - val_loss: 0.7555 - val_accuracy: 0.7190
# Epoch 4/5
# 469/469 [==============================] - 1s 2ms/step - loss: 0.7272 - accuracy: 0.7307 - val_loss: 0.7365 - val_accuracy: 0.7233
# Epoch 5/5
# 469/469 [==============================] - 1s 2ms/step - loss: 0.7044 - accuracy: 0.7382 - val_loss: 0.7283 - val_accuracy: 0.7308
# Model 8
# Epoch 1/5
# 469/469 [==============================] - 2s 3ms/step - loss: 1.1459 - accuracy: 0.6115 - val_loss: 0.7219 - val_accuracy: 0.7303
# Epoch 2/5
# 469/469 [==============================] - 1s 2ms/step - loss: 0.6864 - accuracy: 0.7431 - val_loss: 0.6565 - val_accuracy: 0.7577
# Epoch 3/5
# 469/469 [==============================] - 1s 2ms/step - loss: 0.6352 - accuracy: 0.7639 - val_loss: 0.6316 - val_accuracy: 0.7664
# Epoch 4/5
# 469/469 [==============================] - 1s 2ms/step - loss: 0.6158 - accuracy: 0.7696 - val_loss: 0.6103 - val_accuracy: 0.7751
# Epoch 5/5
# 469/469 [==============================] - 1s 2ms/step - loss: 0.5890 - accuracy: 0.7783 - val_loss: 0.6098 - val_accuracy: 0.7729
# Model 9
# Epoch 1/5
# 469/469 [==============================] - 2s 3ms/step - loss: 1.3300 - accuracy: 0.5098 - val_loss: 0.8805 - val_accuracy: 0.6710
# Epoch 2/5
# 469/469 [==============================] - 1s 2ms/step - loss: 0.8502 - accuracy: 0.6864 - val_loss: 0.8180 - val_accuracy: 0.6920
# Epoch 3/5
# 469/469 [==============================] - 1s 2ms/step - loss: 0.7888 - accuracy: 0.7084 - val_loss: 0.7821 - val_accuracy: 0.7000
# Epoch 4/5
# 469/469 [==============================] - 1s 2ms/step - loss: 0.7499 - accuracy: 0.7220 - val_loss: 0.7663 - val_accuracy: 0.7073
# Epoch 5/5
# 469/469 [==============================] - 1s 2ms/step - loss: 0.7298 - accuracy: 0.7269 - val_loss: 0.7505 - val_accuracy: 0.7164

# %%
if not os.path.isdir('/content/drive/My Drive/fyp/') :
  os.mkdir('/content/drive/My Drive/fyp/')

with open('/content/drive/My Drive/fyp/Fashion MNIST.pickle', 'wb') as f:
    pickle.dump([X_train_cropped_list, y_train_one_hot, X_test_cropped_list, y_test_one_hot, coordinate_list, scale_list], f)

# %%
for i in range(NUM_TN):
  ensemble[i][0].save_weights('/content/drive/My Drive/fyp/Fashion MNIST_' + str(i) + '.h5')
