# %% [markdown]
# # Variants-Experiment 1.4
#
# ## Concatenated hidden representations and concatenated output logits.
# ## Mode. Compute classifications of all tiny networks, in all HiCo layers, and take the mode as the final classification.

# %%
from keras.models import Sequential
from keras.layers import Dense, Conv2D, Flatten
from keras.datasets import mnist
from keras.utils import to_categorical
import matplotlib.pyplot as plt
import numpy as np
import tensorflow as tf
import random
from scipy import stats
from sklearn.metrics import accuracy_score
from keras import backend as K

import os
import pickle
from google.colab import drive
drive.mount('/content/drive/')
# Out:
# Mounted at /content/drive/

# %%
SUB_REGION_SCALE = 14
NUM_HICO_LAYER = 5
NUM_TN = [10, 8, 6, 4, 2]
NUM_CONNECTION = [0, 5, 4, 3, 2]

#dataset specific parameters
NUM_CLASS = 10

# %% [markdown]
# ## Data Pre-Processing

# %%
with open('/content/drive/My Drive/fyp/Fashion MNIST.pickle', 'rb') as f:
    X_train_cropped_list, y_train_one_hot, X_test_cropped_list, y_test_one_hot, coordinate_list, scale_list = pickle.load(f)

# %% [markdown]
# ## HiCo Layer 1

# %%
#build ANN model
ensemble = []
for i in range(NUM_TN[0]):
  model = Sequential()
  model.add(Dense(64, activation='relu', input_dim=SUB_REGION_SCALE*SUB_REGION_SCALE))
  model.add(Dense(64, activation='relu'))
  model.add(Dense(NUM_CLASS, activation = 'softmax'))
  model.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])
  ensemble.append((model, i, coordinate_list[i], scale_list[i]))

# %%
for i in range(NUM_TN[0]):
  ensemble[i][0].load_weights('/content/drive/My Drive/fyp/Fashion MNIST_' + str(i) + '.h5')

# %%
hico_layers = []
hico_layers.append(ensemble)

# %%
del hico_layers[1:]

# %% [markdown]
# ## HiCo Layer 2+

# %%
# Function to get input of layer i-1
def get_previous_layer_input(hico_layers, layer, tn, train_image):
  input_hr = []
  input_ol = []
    
  if layer == 0:
    previous_layer_input = train_image[tn[1]]
    return previous_layer_input

  elif layer > 0:
    for i in range(NUM_CONNECTION[layer]):
      get_input = (K.function(hico_layers[layer-1][tn[1][i]][0].layers[0].input, hico_layers[layer-1][tn[1][i]][0].layers[1].output))
      input_hr.append(get_input(get_previous_layer_input(hico_layers, layer-1, hico_layers[layer-1][tn[1][i]], train_image)))
      
    input_hr = np.array(input_hr)
    input_hr = np.concatenate(input_hr, axis=1)

    for i in range(NUM_CONNECTION[layer]):
      get_input = (K.function(hico_layers[layer-1][tn[1][i]][0].layers[0].input, hico_layers[layer-1][tn[1][i]][0].layers[2].output))
      input_ol.append(get_input(get_previous_layer_input(hico_layers, layer-1, hico_layers[layer-1][tn[1][i]], train_image)))

    input_ol = np.array(input_ol)
    input_ol = np.concatenate(input_ol, axis=1)

    input = np.concatenate((input_hr, input_ol), axis=1)
    
    previous_layer_input = input
    return previous_layer_input

# %%
for i in range(1, NUM_HICO_LAYER):
  print('Layer %d' %i)
  ensemble = []
  X_train_input_list = []
  X_test_input_list = []

  for j in range(NUM_TN[i]):
    # Build model of HiCo layer i
    connection = tuple(random.sample(range(len(hico_layers[i-1])), k=NUM_CONNECTION[i]))
    model = Sequential()
    model.add(Dense(64, activation='relu', input_dim=64*NUM_CONNECTION[i]+NUM_CLASS*NUM_CONNECTION[i]))
    model.add(Dense(64, activation='relu'))
    model.add(Dense(NUM_CLASS, activation = 'softmax'))
    model.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])
    ensemble.append((model, connection))
  hico_layers.append(ensemble)
  print('HICO LENGTH')
  print(len(hico_layers))

  for j in range(NUM_TN[i]):
    # Get train hidden representation from HiCo layer i-1
    X_train_input_hr = []
    X_train_input_ol = []
    for k in range(NUM_CONNECTION[i]):
      get_input = (K.function(hico_layers[i-1][hico_layers[i][j][1][k]][0].layers[0].input, hico_layers[i-1][hico_layers[i][j][1][k]][0].layers[1].output))
      X_train_input_hr.append(get_input(get_previous_layer_input(hico_layers, i-1, hico_layers[i-1][hico_layers[i][j][1][k]], X_train_cropped_list)))
    X_train_input_hr = np.array(X_train_input_hr)
    X_train_input_hr = np.concatenate(X_train_input_hr, axis=1)

    for k in range(NUM_CONNECTION[i]):
      get_input = (K.function(hico_layers[i-1][hico_layers[i][j][1][k]][0].layers[0].input, hico_layers[i-1][hico_layers[i][j][1][k]][0].layers[2].output))
      X_train_input_ol.append(get_input(get_previous_layer_input(hico_layers, i-1, hico_layers[i-1][hico_layers[i][j][1][k]], X_train_cropped_list)))
    X_train_input_ol = np.array(X_train_input_ol)
    X_train_input_ol = np.concatenate(X_train_input_ol, axis=1)

    X_train_input = np.concatenate((X_train_input_hr, X_train_input_ol), axis=1)
    X_train_input_list.append(X_train_input)

    # Get test hidden representation from HiCo layer i-1
    X_test_input_hr = []
    X_test_input_ol = []
    for k in range(NUM_CONNECTION[i]):
      get_input = (K.function(hico_layers[i-1][hico_layers[i][j][1][k]][0].layers[0].input, hico_layers[i-1][hico_layers[i][j][1][k]][0].layers[1].output))
      X_test_input_hr.append(get_input(get_previous_layer_input(hico_layers, i-1, hico_layers[i-1][hico_layers[i][j][1][k]], X_test_cropped_list)))
    X_test_input_hr = np.array(X_test_input_hr)
    X_test_input_hr = np.concatenate(X_test_input_hr, axis=1)

    for k in range(NUM_CONNECTION[i]):
      get_input = (K.function(hico_layers[i-1][hico_layers[i][j][1][k]][0].layers[0].input, hico_layers[i-1][hico_layers[i][j][1][k]][0].layers[2].output))
      X_test_input_ol.append(get_input(get_previous_layer_input(hico_layers, i-1, hico_layers[i-1][hico_layers[i][j][1][k]], X_test_cropped_list)))
    X_test_input_ol = np.array(X_test_input_ol)
    X_test_input_ol = np.concatenate(X_test_input_ol, axis=1)

    X_test_input = np.concatenate((X_test_input_hr, X_test_input_ol), axis=1)
    X_test_input_list.append(X_test_input)

  #train model of HiCo layer i
  for j in range(NUM_TN[i]):
    print('Model %d' %j)
    hico_layers[i][j][0].fit(X_train_input_list[j], y_train_one_hot, validation_data=(X_test_input_list[j], y_test_one_hot), epochs=5, batch_size=128)
# Out:
# Layer 1
# HICO LENGTH
# 2
# Model 0
# Epoch 1/5
# 469/469 [==============================] - 2s 4ms/step - loss: 0.7341 - accuracy: 0.7455 - val_loss: 0.4823 - val_accuracy: 0.8212
# Epoch 2/5
# 469/469 [==============================] - 1s 3ms/step - loss: 0.
# Epoch 4/5
# 469/469 [==============================] - 1s 3ms/step - loss: 0.3943 - accuracy: 0.8519 - val_loss: 0.4294 - val_accuracy: 0.8402
# Epoch 5/5
# 469/469 [==============================] - 1s 3ms/step - loss: 0.3835 - accuracy: 0.8539 - val_loss: 0.4236 - val_accuracy: 0.8434
# Layer 2
# HICO LENGTH
# 3
# Model 0
# Epoch 1/5
# 469/469 [==============================] - 2s 3ms/step - loss: 0.5653 - accuracy: 0.8115 - val_loss: 0.3944 - val_accuracy: 0.8536
# Epoch 2/5
# 469/469 [==============================] - 1s 3ms/step - loss: 0.3392 - accuracy: 0.8724 - val_loss: 0.4020 - val_accuracy: 0.8541
# Epoch 3/5
# 469/469 [==============================] - 1s 3ms/step - loss: 0.3354 - accuracy: 0.8742 - val_loss: 0.4211 - val_accuracy: 0.8469
# Epoch 4/5
# 469/469 [==============================] - 1s 2ms/step - loss: 0.3253 - accuracy: 0.8775 - val_loss: 0.3775 - val_accuracy: 0.8601
# Epoch 5/5
# 469/469 [==============================] - 1s 2ms/step - loss: 0.3209 - accuracy: 0.8777 - val_loss: 0.3799 - val_accuracy: 0.8591
# Model 1
# Epoch 1/5
# 469/469 [==============================] - 2s 3ms/step - loss: 0.6059 - accuracy: 0.8012 - val_loss: 0.3975 - val_accuracy: 0.8562
# Epoch 2/5
# 469/469 [==============================] - 1s 2ms/step - loss: 0.3477 - accuracy: 0.8711 - val_loss: 0.3951 - val_accuracy: 0.8546
# Epoch 3/5
# 469/469 [==============================] - 1s 2ms/step - loss: 0.3323 - accuracy: 0.8752 - val_loss: 0.3905 - val_accuracy: 0.8545
# Epoch 4/5
# 469/469 [==============================] - 1s 2ms/step - loss: 0.3309 - accuracy: 0.8746 - val_loss: 0.3865 - val_accuracy: 0.8572
# Epoch 5/5
# 469/469 [==============================] - 1s 2ms/step - loss: 0.3210 - accuracy: 0.8776 - val_loss: 0.3806 - val_accuracy: 0.8605
# Model 2
# Epoch 1/5
# 469/469 [==============================] - 2s 3ms/step - loss: 0.6117 - accuracy: 0.8045 - val_loss: 0.4011 - val_accuracy: 0.8547
# Epoch 2/5
# 469/469 [==============================] - 1s 2ms/step - loss: 0.3399 - accuracy: 0.8724 - val_loss: 0.3880 - val_accuracy: 0.8561
# Epoch 3/5
# 469/469 [==============================] - 1s 3ms/step - loss: 0.3317 - accuracy: 0.8771 - val_loss: 0.3937 - val_accuracy: 0.8532
# Epoch 4/5
# 469/469 [==============================] - 1s 3ms/step - loss: 0.3238 - accuracy: 0.8789 - val_loss: 0.3755 - val_accuracy: 0.8634
# Epoch 5/5
# 469/469 [==============================] - 1s 3ms/step - loss: 0.3240 - accuracy: 0.8798 - val_loss: 0.3861 - val_accuracy: 0.8593
# Model 3
# Epoch 1/5
# 469/469 [==============================] - 2s 3ms/step - loss: 0.5448 - accuracy: 0.8173 - val_loss: 0.4128 - val_accuracy: 0.8462
# Epoch 2/5
# 469/469 [==============================] - 1s 3ms/step - loss: 0.3460 - accuracy: 0.8721 - val_loss: 0.3948 - val_accuracy: 0.8538
# Epoch 3/5
# 469/469 [==============================] - 1s 3ms/step - loss: 0.3350 - accuracy: 0.8737 - val_loss: 0.3903 - val_accuracy: 0.8560
# Epoch 4/5
# 469/469 [==============================] - 1s 2ms/step - loss: 0.3312 - accuracy: 0.8764 - val_loss: 0.3811 - val_accuracy: 0.8588
# Epoch 5/5
# 469/469 [==============================] - 1s 3ms/step - loss: 0.3268 - accuracy: 0.8793 - val_loss: 0.3836 - val_accuracy: 0.8595
# Model 4
# Epoch 1/5
# 469/469 [==============================] - 2s 3ms/step - loss: 0.5428 - accuracy: 0.8143 - val_loss: 0.3885 - val_accuracy: 0.8582
# Epoch 2/5
# 469/469 [==============================] - 1s 3ms/step - loss: 0.3314 - accuracy: 0.8757 - val_loss: 0.3789 - val_accuracy: 0.8601
# Epoch 3/5
# 469/469 [==============================] - 1s 2ms/step - loss: 0.3304 - accuracy: 0.8745 - val_loss: 0.3780 - val_accuracy: 0.8604
# Epoch 4/5
# 469/469 [==============================] - 1s 2ms/step - loss: 0.3260 - accuracy: 0.8765 - val_loss: 0.3734 - val_accuracy: 0.8610
# Epoch 5/5
# 469/469 [==============================] - 1s 3ms/step - loss: 0.3206 - accuracy: 0.8779 - val_loss: 0.3744 - val_accuracy: 0.8608
# Model 5
# Epoch 1/5
# 469/469 [==============================] - 2s 3ms/step - loss: 0.5701 - accuracy: 0.8112 - val_loss: 0.3902 - val_accuracy: 0.8567
# Epoch 2/5
# 469/469 [==============================] - 1s 3ms/step - loss: 0.3422 - accuracy: 0.8721 - val_loss: 0.3888 - val_accuracy: 0.8567
# Epoch 3/5
# 469/469 [==============================] - 1s 3ms/step - loss: 0.3213 - accuracy: 0.8792 - val_loss: 0.3838 - val_accuracy: 0.8576
# Epoch 4/5
# 469/469 [==============================] - 1s 3ms/step - loss: 0.3308 - accuracy: 0.8766 - val_loss: 0.3911 - val_accuracy: 0.8573
# Epoch 5/5
# 469/469 [==============================] - 1s 3ms/step - loss: 0.3240 - accuracy: 0.8778 - val_loss: 0.3805 - val_accuracy: 0.8604
# Layer 3
# HICO LENGTH
# 4
# Model 0
# Epoch 1/5
# 469/469 [==============================] - 2s 3ms/step - loss: 0.5542 - accuracy: 0.8181 - val_loss: 0.3803 - val_accuracy: 0.8593
# Epoch 2/5
# 469/469 [==============================] - 1s 2ms/step - loss: 0.3168 - accuracy: 0.8814 - val_loss: 0.3795 - val_accuracy: 0.8604
# Epoch 3/5
# 469/469 [==============================] - 1s 2ms/step - loss: 0.3104 - accuracy: 0.8833 - val_loss: 0.3740 - val_accuracy: 0.8605
# Epoch 4/5
# 469/469 [==============================] - 1s 2ms/step - loss: 0.3091 - accuracy: 0.8820 - val_loss: 0.3762 - val_accuracy: 0.8615
# Epoch 5/5
# 469/469 [==============================] - 1s 2ms/step - loss: 0.3087 - accuracy: 0.8816 - val_loss: 0.3762 - val_accuracy: 0.8632
# Model 1
# Epoch 1/5
# 469/469 [==============================] - 2s 3ms/step - loss: 0.5630 - accuracy: 0.8169 - val_loss: 0.3805 - val_accuracy: 0.8576
# Epoch 2/5
# 469/469 [==============================] - 1s 2ms/step - loss: 0.3235 - accuracy: 0.8786 - val_loss: 0.3750 - val_accuracy: 0.8596
# Epoch 3/5
# 469/469 [==============================] - 1s 3ms/step - loss: 0.3148 - accuracy: 0.8808 - val_loss: 0.3751 - val_accuracy: 0.8601
# Epoch 4/5
# 469/469 [==============================] - 1s 3ms/step - loss: 0.3108 - accuracy: 0.8819 - val_loss: 0.3737 - val_accuracy: 0.8601
# Epoch 5/5
# 469/469 [==============================] - 1s 3ms/step - loss: 0.3107 - accuracy: 0.8816 - val_loss: 0.3729 - val_accuracy: 0.8586
# Model 2
# Epoch 1/5
# 469/469 [==============================] - 2s 3ms/step - loss: 0.5600 - accuracy: 0.8258 - val_loss: 0.3867 - val_accuracy: 0.8577
# Epoch 2/5
# 469/469 [==============================] - 1s 2ms/step - loss: 0.3156 - accuracy: 0.8799 - val_loss: 0.3863 - val_accuracy: 0.8604
# Epoch 3/5
# 469/469 [==============================] - 1s 3ms/step - loss: 0.3218 - accuracy: 0.8767 - val_loss: 0.3819 - val_accuracy: 0.8588
# Epoch 4/5
# 469/469 [==============================] - 1s 3ms/step - loss: 0.3089 - accuracy: 0.8836 - val_loss: 0.3716 - val_accuracy: 0.8599
# Epoch 5/5
# 469/469 [==============================] - 1s 2ms/step - loss: 0.3084 - accuracy: 0.8821 - val_loss: 0.3727 - val_accuracy: 0.8594
# Model 3
# Epoch 1/5
# 469/469 [==============================] - 2s 3ms/step - loss: 0.5472 - accuracy: 0.8203 - val_loss: 0.3807 - val_accuracy: 0.8616
# Epoch 2/5
# 469/469 [==============================] - 1s 3ms/step - loss: 0.3163 - accuracy: 0.8816 - val_loss: 0.3778 - val_accuracy: 0.8602
# Epoch 3/5
# 469/469 [==============================] - 1s 2ms/step - loss: 0.3191 - accuracy: 0.8811 - val_loss: 0.3728 - val_accuracy: 0.8635
# Epoch 4/5
# 469/469 [==============================] - 1s 2ms/step - loss: 0.3130 - accuracy: 0.8823 - val_loss: 0.3755 - val_accuracy: 0.8595
# Epoch 5/5
# 469/469 [==============================] - 1s 2ms/step - loss: 0.3109 - accuracy: 0.8820 - val_loss: 0.3763 - val_accuracy: 0.8605
# Layer 4
# HICO LENGTH
# 5
# Model 0
# Epoch 1/5
# 469/469 [==============================] - 2s 3ms/step - loss: 0.5228 - accuracy: 0.8297 - val_loss: 0.3912 - val_accuracy: 0.8522
# Epoch 2/5
# 469/469 [==============================] - 1s 2ms/step - loss: 0.3107 - accuracy: 0.8826 - val_loss: 0.3770 - val_accuracy: 0.8608
# Epoch 3/5
# 469/469 [==============================] - 1s 2ms/step - loss: 0.3136 - accuracy: 0.8816 - val_loss: 0.3869 - val_accuracy: 0.8616
# Epoch 4/5
# 469/469 [==============================] - 1s 2ms/step - loss: 0.3056 - accuracy: 0.8844 - val_loss: 0.3807 - val_accuracy: 0.8574
# Epoch 5/5
# 469/469 [==============================] - 1s 2ms/step - loss: 0.3040 - accuracy: 0.8849 - val_loss: 0.3724 - val_accuracy: 0.8603
# Model 1
# Epoch 1/5
# 469/469 [==============================] - 2s 3ms/step - loss: 0.5983 - accuracy: 0.8150 - val_loss: 0.3835 - val_accuracy: 0.8624
# Epoch 2/5
# 469/469 [==============================] - 1s 2ms/step - loss: 0.3125 - accuracy: 0.8822 - val_loss: 0.3807 - val_accuracy: 0.8585
# Epoch 3/5
# 469/469 [==============================] - 1s 2ms/step - loss: 0.3084 - accuracy: 0.8843 - val_loss: 0.3713 - val_accuracy: 0.8616
# Epoch 4/5
# 469/469 [==============================] - 1s 2ms/step - loss: 0.3102 - accuracy: 0.8833 - val_loss: 0.3763 - val_accuracy: 0.8609
# Epoch 5/5
# 469/469 [==============================] - 1s 2ms/step - loss: 0.3050 - accuracy: 0.8846 - val_loss: 0.3718 - val_accuracy: 0.8636

# %% [markdown]
# ## Model Evaluation

# %%
# Predict on test image
y_pred_list = []
for j in range(NUM_TN[0]):
  y_pred = np.argmax(hico_layers[0][j][0].predict(X_test_cropped_list[j]), axis=1)
  y_pred_list.append(y_pred)

for i in range(1, NUM_HICO_LAYER):
  for j in range(NUM_TN[i]):

    # Get test hidden representation from HiCo layer i-1
    X_test_input_hr = []
    X_test_input_ol = []
    for k in range(NUM_CONNECTION[i]):
      get_input = (K.function(hico_layers[i-1][hico_layers[i][j][1][k]][0].layers[0].input, hico_layers[i-1][hico_layers[i][j][1][k]][0].layers[1].output))
      X_test_input_hr.append(get_input(get_previous_layer_input(hico_layers, i-1, hico_layers[i-1][hico_layers[i][j][1][k]], X_test_cropped_list)))
    X_test_input_hr = np.array(X_test_input_hr)
    X_test_input_hr = np.concatenate(X_test_input_hr, axis=1)

    for k in range(NUM_CONNECTION[i]):
      get_input = (K.function(hico_layers[i-1][hico_layers[i][j][1][k]][0].layers[0].input, hico_layers[i-1][hico_layers[i][j][1][k]][0].layers[2].output))
      X_test_input_ol.append(get_input(get_previous_layer_input(hico_layers, i-1, hico_layers[i-1][hico_layers[i][j][1][k]], X_test_cropped_list)))
    X_test_input_ol = np.array(X_test_input_ol)
    X_test_input_ol = np.concatenate(X_test_input_ol, axis=1)

    X_test_input = np.concatenate((X_test_input_hr, X_test_input_ol), axis=1)

    y_pred = np.argmax(hico_layers[i][j][0].predict(X_test_input), axis=1)
    y_pred_list.append(y_pred)

# HiCo voting (mode)
y_pred_list = np.array(y_pred_list)
y_pred_list = np.transpose(y_pred_list, (1, 0))
y_pred_list = stats.mode(y_pred_list, axis=1)[0]
y_pred_list = np.squeeze(y_pred_list)

# %%
y_test = np.argmax(y_test_one_hot, axis=1)

# %%
accuracy = accuracy_score(y_test, y_pred_list)
accuracy
# Out:
# 0.8594
