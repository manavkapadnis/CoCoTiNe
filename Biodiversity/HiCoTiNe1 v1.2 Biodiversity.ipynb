# %% [markdown]
# # Variants-Experiment 1.2
#
# ## Summed hidden representations.
# ## Mode. Compute classifications of all tiny networks, in all HiCo layers, and take the mode as the final classification.

# %%
import tensorflow as tf
from tensorflow import keras
from keras.models import Sequential
from keras.layers import Dense, Conv2D, Flatten, MaxPooling2D
from keras.utils import to_categorical
import matplotlib.pyplot as plt
import numpy as np
from os import listdir
from os.path import join
import cv2
import pandas as pd
import os
import random as rn
from scipy import stats
from sklearn.preprocessing import OneHotEncoder
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score
import pickle
from keras import backend as K

# %%
SEED = 321
rn.seed(SEED)
np.random.seed(SEED)
tf.random.set_seed(SEED)

# %%
SUB_REGION_SCALE = 14
NUM_HICO_LAYER = 5
NUM_TN = [10, 8, 6, 4, 2]
NUM_CONNECTION = [0, 5, 4, 3, 2]

#dataset specific parameters
NUM_CLASS = 5

# %% [markdown]
# ## Data Pre-Processing

# %%
with open('../input/hicotine1-layer1-biodiversity/fyp/CIFAR-10.pickle', 'rb') as f:
    X_train_cropped_list, y_train_one_hot, X_val_cropped_list, y_val_one_hot, X_test_cropped_list, y_test_one_hot, coordinate_list, scale_list = pickle.load(f)

# %% [markdown]
# ## HiCo Layer 1

# %%
#build ANN model
ensemble = []
for i in range(NUM_TN[0]):
  model = Sequential()
  model.add(Dense(64, activation='relu', input_dim=SUB_REGION_SCALE*SUB_REGION_SCALE*3))
  model.add(Dense(64, activation='relu'))
  model.add(Dense(NUM_CLASS, activation = 'softmax'))
  model.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])
  ensemble.append((model, i, coordinate_list[i], scale_list[i]))

# %%
for i in range(NUM_TN[0]):
  ensemble[i][0].load_weights('../input/hicotine1-layer1-biodiversity/fyp/CIFAR-10_' + str(i) + '.h5')

# %%
hico_layers = []
hico_layers.append(ensemble)

# %% [markdown]
# ## HiCo Layer 2+

# %%
# Function to get input of layer i-1
def get_previous_layer_input(hico_layers, layer, tn, train_image):
  input = []
    
  if layer == 0:
    previous_layer_input = train_image[tn[1]]
    return previous_layer_input

  elif layer > 0:
    for i in range(NUM_CONNECTION[layer]):
      get_input = (K.function(hico_layers[layer-1][tn[1][i]][0].layers[0].input, hico_layers[layer-1][tn[1][i]][0].layers[1].output))
      input.append(get_input(get_previous_layer_input(hico_layers, layer-1, hico_layers[layer-1][tn[1][i]], train_image)))
      
    input = np.array(input)
    input = np.sum(input, axis=0)
    previous_layer_input = input
    return previous_layer_input

# %%
for i in range(1, NUM_HICO_LAYER):
  print('Layer %d' %i)
  ensemble = []
  X_train_input_list = []
  X_test_input_list = []

  for j in range(NUM_TN[i]):
    # Build model of HiCo layer i
    connection = tuple(rn.sample(range(len(hico_layers[i-1])), k=NUM_CONNECTION[i]))
    model = Sequential()
    model.add(Dense(64, activation='relu', input_dim=64))
    model.add(Dense(64, activation='relu'))
    model.add(Dense(NUM_CLASS, activation = 'softmax'))
    model.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])
    ensemble.append((model, connection))
  hico_layers.append(ensemble)
  print('HICO LENGTH')
  print(len(hico_layers))

  for j in range(NUM_TN[i]):
    # Get train hidden representation from HiCo layer i-1
    X_train_input = []
    for k in range(NUM_CONNECTION[i]):
      get_input = (K.function(hico_layers[i-1][hico_layers[i][j][1][k]][0].layers[0].input, hico_layers[i-1][hico_layers[i][j][1][k]][0].layers[1].output))
      X_train_input.append(get_input(get_previous_layer_input(hico_layers, i-1, hico_layers[i-1][hico_layers[i][j][1][k]], X_train_cropped_list)))
    X_train_input = np.array(X_train_input)
    X_train_input = np.sum(X_train_input, axis=0)
    X_train_input_list.append(X_train_input)


    # Get test hidden representation from HiCo layer i-1
    X_test_input = []
    for k in range(NUM_CONNECTION[i]):
      get_input = (K.function(hico_layers[i-1][hico_layers[i][j][1][k]][0].layers[0].input, hico_layers[i-1][hico_layers[i][j][1][k]][0].layers[1].output))
      X_test_input.append(get_input(get_previous_layer_input(hico_layers, i-1, hico_layers[i-1][hico_layers[i][j][1][k]], X_test_cropped_list)))
    X_test_input = np.array(X_test_input)
    X_test_input = np.sum(X_test_input, axis=0)
    X_test_input_list.append(X_test_input)

  #train model of HiCo layer i
  for j in range(NUM_TN[i]):
    print('Model %d' %j)
    hico_layers[i][j][0].fit(X_train_input_list[j], y_train_one_hot, validation_data=(X_test_input_list[j], y_test_one_hot), epochs=5, batch_size=128)
# Out:
# Layer 1
# HICO LENGTH
# 2
# Model 0
# Epoch 1/5
# 28/28 [==============================] - 1s 21ms/step - loss: 2.1402 - accuracy: 0.2357 - val_loss: 1.4227 - val_accuracy: 0.3487
# Epoch 2/5
# 28/28 [==============================] - 0s 4ms/step - loss: 1.3610 - accuracy: 0.3936 - val_loss: 1.3129 - val_accuracy: 0.4157
# Epoch 3/5
# 28/28 [==============================] - 0s 4ms/step - loss: 1.3057 - accuracy: 0.4404 - val_loss: 1.3007 - val_accuracy: 0.4480
# Epoch 4/5
# 28/28 [==============================] - 0s 4ms/step - loss: 1.2668 - accuracy: 0.4465 - val_loss: 1.2844 - val_accuracy: 0.4457
# Epoch 5/5
# 28/28 [==============================] - 0s 3ms/step - loss: 1.2197 - accuracy: 0.4731 - val_loss: 1.2865 - val_accuracy: 0.4342
# Model 1
# Epoch 1/5
# 28/28 [==============================] - 1s 9ms/step - loss: 1.5766 - accuracy: 0.2872 - val_loss: 1.3366 - val_accuracy: 0.3903
# Epoch 2/5
# 28/28 [==============================] - 0s 4ms/step - loss: 1.2960 - accuracy: 0.4157 - val_loss: 1.2913 - val_accuracy: 0.4180
# Epoch 3/5
# 28/28 [==============================] - 0s 4ms/step - loss: 1.2946 - accuracy: 0.4376 - val_loss: 1.2864 - val_accuracy: 0.4273
# Epoch 4/5
# 28/28 [==============================] - 0s 4ms/step - loss: 1.2514 - accuracy: 0.4576 - val_loss: 1.2778 - val_accuracy: 0.4157
# Epoch 5/5
# 28/28 [==============================] - 0s 4ms/step - loss: 1.2164 - accuracy: 0.4640 - val_loss: 1.2813 - val_accuracy: 0.4273
# Model 2
# Epoch 1/5
# 28/28 [==============================] - 1s 9ms/step - loss: 1.7197 - accuracy: 0.3288 - val_loss: 1.3583 - val_accuracy: 0.3672
# Epoch 2/5
# 28/28 [==============================] - 0s 4ms/step - loss: 1.2650 - accuracy: 0.4342 - val_loss: 1.3195 - val_accuracy: 0.4273
# Epoch 3/5
# 28/28 [==============================] - 0s 4ms/step - loss: 1.2678 - accuracy: 0.4521 - val_loss: 1.3163 - val_accuracy: 0.4226
# Epoch 4/5
# 28/28 [==============================] - 0s 3ms/step - loss: 1.2476 - accuracy: 0.4603 - val_loss: 1.2950 - val_accuracy: 0.4503
# Epoch 5/5
# 28/28 [==============================] - 0s 5ms/step - loss: 1.1988 - accuracy: 0.4713 - val_loss: 1.2988 - val_accuracy: 0.4319
# Model 3
# Epoch 1/5
# 28/28 [==============================] - 1s 9ms/step - loss: 1.8552 - accuracy: 0.2559 - val_loss: 1.4184 - val_accuracy: 0.3741
# Epoch 2/5
# 28/28 [==============================] - 0s 3ms/step - loss: 1.3615 - accuracy: 0.3982 - val_loss: 1.3353 - val_accuracy: 0.3949
# Epoch 3/5
# 28/28 [==============================] - 0s 4ms/step - loss: 1.3162 - accuracy: 0.4160 - val_loss: 1.3207 - val_accuracy: 0.3949
# Epoch 4/5
# 28/28 [==============================] - 0s 4ms/step - loss: 1.2609 - accuracy: 0.4526 - val_loss: 1.3127 - val_accuracy: 0.4273
# Epoch 5/5
# 28/28 [==============================] - 0s 3ms/step - loss: 1.2448 - accuracy: 0.4558 - val_loss: 1.3141 - val_accuracy: 0.4018
# Model 4
# Epoch 1/5
# 28/28 [==============================] - 1s 9ms/step - loss: 1.6668 - accuracy: 0.2640 - val_loss: 1.3338 - val_accuracy: 0.4180
# Epoch 2/5
# 28/28 [==============================] - 0s 4ms/step - loss: 1.2865 - accuracy: 0.4288 - val_loss: 1.3015 - val_accuracy: 0.4111
# Epoch 3/5
# 28/28 [==============================] - 0s 4ms/step - loss: 1.2682 - accuracy: 0.4519 - val_loss: 1.2973 - val_accuracy: 0.4573
# Epoch 4/5
# 28/28 [==============================] - 0s 3ms/step - loss: 1.2319 - accuracy: 0.4582 - val_loss: 1.2891 - val_accuracy: 0.4273
# Epoch 5/5
# 28/28 [==============================] - 0s 3ms/step - loss: 1.2037 - accuracy: 0.4777 - val_loss: 1.2989 - val_accuracy: 0.4503
# Model 5
# Epoch 1/5
# 28/28 [==============================] - 1s 9ms/step - loss: 2.4077 - accuracy: 0.2607 - val_loss: 1.3820 - val_accuracy: 0.3995
# Epoch 2/5
# 28/28 [==============================] - 0s 4ms/step - loss: 1.
# Epoch 5/5
# 28/28 [==============================] - 0s 3ms/step - loss: 1.2027 - accuracy: 0.4794 - val_loss: 1.2870 - val_accuracy: 0.4503
# Model 3
# Epoch 1/5
# 28/28 [==============================] - 1s 8ms/step - loss: 1.8511 - accuracy: 0.2760 - val_loss: 1.3561 - val_accuracy: 0.4134
# Epoch 2/5
# 28/28 [==============================] - 0s 4ms/step - loss: 1.2920 - accuracy: 0.4530 - val_loss: 1.2903 - val_accuracy: 0.4457
# Epoch 3/5
# 28/28 [==============================] - 0s 3ms/step - loss: 1.2604 - accuracy: 0.4614 - val_loss: 1.3098 - val_accuracy: 0.4180
# Epoch 4/5
# 28/28 [==============================] - 0s 3ms/step - loss: 1.2417 - accuracy: 0.4742 - val_loss: 1.2841 - val_accuracy: 0.4365
# Epoch 5/5
# 28/28 [==============================] - 0s 3ms/step - loss: 1.2021 - accuracy: 0.4793 - val_loss: 1.2886 - val_accuracy: 0.4619
# Layer 4
# HICO LENGTH
# 5
# Model 0
# Epoch 1/5
# 28/28 [==============================] - 1s 8ms/step - loss: 1.8187 - accuracy: 0.2382 - val_loss: 1.3443 - val_accuracy: 0.4319
# Epoch 2/5
# 28/28 [==============================] - 0s 4ms/step - loss: 1.2847 - accuracy: 0.4306 - val_loss: 1.2966 - val_accuracy: 0.4296
# Epoch 3/5
# 28/28 [==============================] - 0s 3ms/step - loss: 1.2628 - accuracy: 0.4381 - val_loss: 1.2827 - val_accuracy: 0.4480
# Epoch 4/5
# 28/28 [==============================] - 0s 3ms/step - loss: 1.2454 - accuracy: 0.4512 - val_loss: 1.2787 - val_accuracy: 0.4319
# Epoch 5/5
# 28/28 [==============================] - 0s 3ms/step - loss: 1.2075 - accuracy: 0.4711 - val_loss: 1.2870 - val_accuracy: 0.4388
# Model 1
# Epoch 1/5
# 28/28 [==============================] - 1s 8ms/step - loss: 1.5073 - accuracy: 0.3513 - val_loss: 1.3405 - val_accuracy: 0.4018
# Epoch 2/5
# 28/28 [==============================] - 0s 3ms/step - loss: 1.2442 - accuracy: 0.4572 - val_loss: 1.3051 - val_accuracy: 0.4157
# Epoch 3/5
# 28/28 [==============================] - 0s 3ms/step - loss: 1.2513 - accuracy: 0.4553 - val_loss: 1.2980 - val_accuracy: 0.4365
# Epoch 4/5
# 28/28 [==============================] - 0s 3ms/step - loss: 1.2358 - accuracy: 0.4682 - val_loss: 1.2846 - val_accuracy: 0.4365
# Epoch 5/5
# 28/28 [==============================] - 0s 3ms/step - loss: 1.1993 - accuracy: 0.4684 - val_loss: 1.2983 - val_accuracy: 0.4226

# %% [markdown]
# # Model Evaluation

# %%
# Predict on test image
y_pred_list = []
for j in range(NUM_TN[0]):
  y_pred = np.argmax(hico_layers[0][j][0].predict(X_test_cropped_list[j]), axis=1)
  y_pred_list.append(y_pred)

for i in range(1, NUM_HICO_LAYER):
  for j in range(NUM_TN[i]):

    # Get test hidden representation from HiCo layer i-1
    X_test_input = []
    for k in range(NUM_CONNECTION[i]):
      get_input = (K.function(hico_layers[i-1][hico_layers[i][j][1][k]][0].layers[0].input, hico_layers[i-1][hico_layers[i][j][1][k]][0].layers[1].output))
      X_test_input.append(get_input(get_previous_layer_input(hico_layers, i-1, hico_layers[i-1][hico_layers[i][j][1][k]], X_test_cropped_list)))
    X_test_input = np.array(X_test_input)
    X_test_input = np.sum(X_test_input, axis=0)

    y_pred = np.argmax(hico_layers[i][j][0].predict(X_test_input), axis=1)
    y_pred_list.append(y_pred)

# HiCo voting (mode)
y_pred_list = np.array(y_pred_list)
y_pred_list = np.transpose(y_pred_list, (1, 0))
y_pred_list = stats.mode(y_pred_list, axis=1)[0]
y_pred_list = np.squeeze(y_pred_list)

# %%
y_test = np.argmax(y_test_one_hot, axis=1)

# %%
accuracy = accuracy_score(y_test, y_pred_list)
accuracy
# Out:
# 0.4503464203233256
