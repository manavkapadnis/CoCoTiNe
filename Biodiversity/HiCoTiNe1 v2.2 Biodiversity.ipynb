# %% [markdown]
# # Variants-Experiment 2.2. Adapted from HiCoTiNe v1.1 + raw input
#
# ## Concatenated hidden representations.
# ## With raw input
# ## Mode. Compute classifications of all tiny networks, in all HiCo layers, and take the mode as the final classification.

# %%
import tensorflow as tf
from tensorflow import keras
from keras.models import Sequential
from keras.layers import Dense, Conv2D, Flatten, MaxPooling2D
from keras.utils import to_categorical
import matplotlib.pyplot as plt
import numpy as np
from os import listdir
from os.path import join
import cv2
import pandas as pd
import os
import random as rn
from scipy import stats
from sklearn.preprocessing import OneHotEncoder
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score
import pickle
from keras import backend as K

# %%
SEED = 321
rn.seed(SEED)
np.random.seed(SEED)
tf.random.set_seed(SEED)

# %%
SUB_REGION_SCALE = 14
NUM_HICO_LAYER = 3
NUM_TN = [10, 4, 2]
NUM_CONNECTION = [0, 2, 2]

#dataset specific parameters
NUM_CLASS = 5

# %% [markdown]
# ## Data Pre-Processing

# %%
with open('../input/hicotine1-layer1-biodiversity/fyp/CIFAR-10.pickle', 'rb') as f:
    X_train_cropped_list, y_train_one_hot, X_val_cropped_list, y_val_one_hot, X_test_cropped_list, y_test_one_hot, coordinate_list, scale_list = pickle.load(f)

# %% [markdown]
# ## HiCo Layer 1

# %%
#build ANN model
ensemble = []
for i in range(NUM_TN[0]):
  model = Sequential()
  model.add(Dense(64, activation='relu', input_dim=SUB_REGION_SCALE*SUB_REGION_SCALE*3))
  model.add(Dense(64, activation='relu'))
  model.add(Dense(NUM_CLASS, activation = 'softmax'))
  model.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])
  ensemble.append((model, i, coordinate_list[i], scale_list[i]))

# %%
for i in range(NUM_TN[0]):
  ensemble[i][0].load_weights('../input/hicotine1-layer1-biodiversity/fyp/CIFAR-10_' + str(i) + '.h5')

# %%
hico_layers = []
hico_layers.append(ensemble)

# %%
del hico_layers[1:]

# %% [markdown]
# ## HiCo Layer 2+

# %%
# Function to get input of layer i-1
def get_previous_layer_input(hico_layers, layer, tn, train_image):
  inputs = []
  raw_input_list_2 = []
    
  if layer == 0:
    previous_layer_input = train_image[tn[1]]
    raw_input_list_2.append(previous_layer_input)
    raw_input_list_2 = np.array(raw_input_list_2)
    raw_input_list_2 = np.squeeze(raw_input_list_2, axis=0)
    return previous_layer_input, raw_input_list_2


  elif layer > 0:
    for i in range(NUM_CONNECTION[layer]):
      get_input = (K.function(hico_layers[layer-1][tn[1][i]][0].layers[0].input, hico_layers[layer-1][tn[1][i]][0].layers[1].output))
      previous_layer_input, raw_input_list = get_previous_layer_input(hico_layers, layer-1, hico_layers[layer-1][tn[1][i]], train_image)
      input = np.concatenate((get_input(previous_layer_input), raw_input_list), axis=1)
      inputs.append(input)
      raw_input_list_2.append(raw_input_list)
      
    inputs = np.array(inputs)
    inputs = np.concatenate(inputs, axis=1)
    previous_layer_input = inputs
    raw_input_list_2 = np.array(raw_input_list_2)
    raw_input_list_2 = np.concatenate(raw_input_list_2, axis=1)
    return previous_layer_input, raw_input_list_2

# %%
raw_input_dim_list = []
raw_input_dim_list.append(SUB_REGION_SCALE*SUB_REGION_SCALE*3)
for i in range(1, NUM_HICO_LAYER):
  print('Layer %d' %i)
  ensemble = []
  X_train_input_list = []
  X_test_input_list = []
  raw_input_dim_list.append(raw_input_dim_list[i-1]*NUM_CONNECTION[i])

  for j in range(NUM_TN[i]):
    # Build model of HiCo layer i
    connection = tuple(rn.sample(range(len(hico_layers[i-1])), k=NUM_CONNECTION[i]))
    model = Sequential()
    model.add(Dense(64, activation='relu', input_dim=64*NUM_CONNECTION[i]+raw_input_dim_list[i]))
    model.add(Dense(64, activation='relu'))
    model.add(Dense(NUM_CLASS, activation = 'softmax'))
    model.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])
    ensemble.append((model, connection))
  hico_layers.append(ensemble)
  print('HICO LENGTH')
  print(len(hico_layers))

  for j in range(NUM_TN[i]):
    # Get train hidden representation from HiCo layer i-1
    X_train_input = []
    for k in range(NUM_CONNECTION[i]):
      get_input = (K.function(hico_layers[i-1][hico_layers[i][j][1][k]][0].layers[0].input, hico_layers[i-1][hico_layers[i][j][1][k]][0].layers[1].output))
      previous_layer_input, raw_input_list = get_previous_layer_input(hico_layers, i-1, hico_layers[i-1][hico_layers[i][j][1][k]], X_train_cropped_list)
      input = np.concatenate((get_input(previous_layer_input), raw_input_list), axis=1)
      X_train_input.append(input)

    X_train_input = np.array(X_train_input)
    X_train_input = np.concatenate(X_train_input, axis=1)
    X_train_input_list.append(X_train_input)

    # Get test hidden representation from HiCo layer i-1
    X_test_input = []
    for k in range(NUM_CONNECTION[i]):
      get_input = (K.function(hico_layers[i-1][hico_layers[i][j][1][k]][0].layers[0].input, hico_layers[i-1][hico_layers[i][j][1][k]][0].layers[1].output))
      previous_layer_input, raw_input_list = get_previous_layer_input(hico_layers, i-1, hico_layers[i-1][hico_layers[i][j][1][k]], X_test_cropped_list)
      input = np.concatenate((get_input(previous_layer_input), raw_input_list), axis=1)
      X_test_input.append(input)

    X_test_input = np.array(X_test_input)
    X_test_input = np.concatenate(X_test_input, axis=1)
    X_test_input_list.append(X_test_input)

  #train model of HiCo layer i
  for j in range(NUM_TN[i]):
    print('Model %d' %j)
    hico_layers[i][j][0].fit(X_train_input_list[j], y_train_one_hot, validation_data=(X_test_input_list[j], y_test_one_hot), epochs=5, batch_size=128)
# Out:
# Layer 1
# HICO LENGTH
# 2
# Model 0
# Epoch 1/5
# 28/28 [==============================] - 1s 21ms/step - loss: 1.4923 - accuracy: 0.3209 - val_loss: 1.3059 - val_accuracy: 0.4249
# Epoch 2/5
# 28/28 [==============================] - 0s 4ms/step - loss: 1.2789 - accuracy: 0.4330 - val_loss: 1.2865 - val_accuracy: 0.4365
# Epoch 3/5
# 28/28 [==============================] - 0s 4ms/step - loss: 1.2726 - accuracy: 0.4377 - val_loss: 1.4259 - val_accuracy: 0.4088
# Epoch 4/5
# 28/28 [==============================] - 0s 4ms/step - loss: 1.3687 - accuracy: 0.4065 - val_loss: 1.3109 - val_accuracy: 0.3926
# Epoch 5/5
# 28/28 [==============================] - 0s 4ms/step - loss: 1.2223 - accuracy: 0.4627 - val_loss: 1.2952 - val_accuracy: 0.4434
# Model 1
# Epoch 1/5
# 28/28 [==============================] - 1s 9ms/step - loss: 1.5667 - accuracy: 0.2876 - val_loss: 1.3542 - val_accuracy: 0.3926
# Epoch 2/5
# 28/28 [==============================] - 0s 4ms/step - loss: 1.3018 - accuracy: 0.4264 - val_loss: 1.3002 - val_accuracy: 0.4157
# Epoch 3/5
# 28/28 [==============================] - 0s 4ms/step - loss: 1.2840 - accuracy: 0.4428 - val_loss: 1.2975 - val_accuracy: 0.3995
# Epoch 4/5
# 28/28 [==============================] - 0s 4ms/step - loss: 1.2758 - accuracy: 0.4429 - val_loss: 1.3001 - val_accuracy: 0.3834
# Epoch 5/5
# 28/28 [==============================] - 0s 4ms/step - loss: 1.2231 - accuracy: 0.4623 - val_loss: 1.2912 - val_accuracy: 0.3880
# Model 2
# Epoch 1/5
# 28/28 [==============================] - 1s 9ms/step - loss: 1.5897 - accuracy: 0.2782 - val_loss: 1.3437 - val_accuracy: 0.4111
# Epoch 2/5
# 28/28 [==============================] - 0s 4ms/step - loss: 1.3265 - accuracy: 0.4178 - val_loss: 1.3120 - val_accuracy: 0.4296
# Epoch 3/5
# 28/28 [==============================] - 0s 4ms/step - loss: 1.3059 - accuracy: 0.4317 - val_loss: 1.3333 - val_accuracy: 0.4365
# Epoch 4/5
# 28/28 [==============================] - 0s 4ms/step - loss: 1.3214 - accuracy: 0.4152 - val_loss: 1.3048 - val_accuracy: 0.4180
# Epoch 5/5
# 28/28 [==============================] - 0s 4ms/step - loss: 1.2473 - accuracy: 0.4430 - val_loss: 1.3142 - val_accuracy: 0.4203
# Model 3
# Epoch 1/5
# 28/28 [==============================] - 1s 9ms/step - loss: 1.5693 - accuracy: 0.2908 - val_loss: 1.3957 - val_accuracy: 0.3533
# Epoch 2/5
# 28/28 [==============================] - 0s 4ms/step - loss: 1.3138 - accuracy: 0.4176 - val_loss: 1.2996 - val_accuracy: 0.4180
# Epoch 3/5
# 28/28 [==============================] - 0s 4ms/step - loss: 1.2850 - accuracy: 0.4544 - val_loss: 1.3267 - val_accuracy: 0.4319
# Epoch 4/5
# 28/28 [==============================] - 0s 4ms/step - loss: 1.2807 - accuracy: 0.4365 - val_loss: 1.3092 - val_accuracy: 0.4226
# Epoch 5/5
# 28/28 [==============================] - 0s 4ms/step - loss: 1.2252 - accuracy: 0.4716 - val_loss: 1.3310 - val_accuracy: 0.4157
# Layer 2
# HICO LENGTH
# 3
# Model 0
# Epoch 1/5
# 28/28 [==============================] - 1s 9ms/step - loss: 1.5310 - accuracy: 0.2910 - val_loss: 1.3417 - val_accuracy: 0.4018
# Epoch 2/5
# 28/28 [==============================] - 0s 4ms/step - loss: 1.2704 - accuracy: 0.4365 - val_loss: 1.3021 - val_accuracy: 0.4550
# Epoch 3/5
# 28/28 [==============================] - 0s 5ms/step - loss: 1.2904 - accuracy: 0.4408 - val_loss: 1.3915 - val_accuracy: 0.4042
# Epoch 4/5
# 28/28 [==============================] - 0s 8ms/step - loss: 1.3130 - accuracy: 0.4306 - val_loss: 1.3147 - val_accuracy: 0.4249
# Epoch 5/5
# 28/28 [==============================] - 0s 7ms/step - loss: 1.2216 - accuracy: 0.4691 - val_loss: 1.3331 - val_accuracy: 0.4249
# Model 1
# Epoch 1/5
# 28/28 [==============================] - 1s 10ms/step - loss: 1.5147 - accuracy: 0.3044 - val_loss: 1.3116 - val_accuracy: 0.4157
# Epoch 2/5
# 28/28 [==============================] - 0s 4ms/step - loss: 1.2732 - accuracy: 0.4298 - val_loss: 1.3211 - val_accuracy: 0.4365
# Epoch 3/5
# 28/28 [==============================] - 0s 4ms/step - loss: 1.3156 - accuracy: 0.4270 - val_loss: 1.3814 - val_accuracy: 0.3857
# Epoch 4/5
# 28/28 [==============================] - 0s 4ms/step - loss: 1.3336 - accuracy: 0.4119 - val_loss: 1.3228 - val_accuracy: 0.3926
# Epoch 5/5
# 28/28 [==============================] - 0s 4ms/step - loss: 1.2233 - accuracy: 0.4632 - val_loss: 1.3349 - val_accuracy: 0.4342

# %% [markdown]
# # Model Evaluation

# %%
# Predict on test image
y_pred_list = []
for j in range(NUM_TN[0]):
  y_pred = np.argmax(hico_layers[0][j][0].predict(X_test_cropped_list[j]), axis=1)
  y_pred_list.append(y_pred)

for i in range(1, NUM_HICO_LAYER):
  for j in range(NUM_TN[i]):

    # Get test hidden representation from HiCo layer i-1
    X_test_input = []
    for k in range(NUM_CONNECTION[i]):
      get_input = (K.function(hico_layers[i-1][hico_layers[i][j][1][k]][0].layers[0].input, hico_layers[i-1][hico_layers[i][j][1][k]][0].layers[1].output))
      previous_layer_input, raw_input = get_previous_layer_input(hico_layers, i-1, hico_layers[i-1][hico_layers[i][j][1][k]], X_test_cropped_list)
      input = np.concatenate((get_input(previous_layer_input), raw_input), axis=1)
      X_test_input.append(input)
    X_test_input = np.array(X_test_input)
    X_test_input = np.concatenate(X_test_input, axis=1)
    y_pred = np.argmax(hico_layers[i][j][0].predict(X_test_input), axis=1)
    y_pred_list.append(y_pred)

# HiCo voting (mode)
y_pred_list = np.array(y_pred_list)
y_pred_list = np.transpose(y_pred_list, (1, 0))
y_pred_list = stats.mode(y_pred_list, axis=1)[0]
y_pred_list = np.squeeze(y_pred_list)

# %%
y_test = np.argmax(y_test_one_hot, axis=1)

# %%
accuracy = accuracy_score(y_test, y_pred_list)
accuracy
# Out:
# 0.44110854503464203
