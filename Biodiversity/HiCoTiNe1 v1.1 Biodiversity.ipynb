# %% [markdown]
# # Variants-Experiment 1.1
#
# ## Concatenated hidden representations.
# ## Mode. Compute classifications of all tiny networks, in all HiCo layers, and take the mode as the final classification.

# %%
import tensorflow as tf
from tensorflow import keras
from keras.models import Sequential
from keras.layers import Dense, Conv2D, Flatten, MaxPooling2D
from keras.utils import to_categorical
import matplotlib.pyplot as plt
import numpy as np
from os import listdir
from os.path import join
import cv2
import pandas as pd
import os
import random as rn
from scipy import stats
from sklearn.preprocessing import OneHotEncoder
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score
import pickle
from keras import backend as K

# %%
SEED = 321
rn.seed(SEED)
np.random.seed(SEED)
tf.random.set_seed(SEED)

# %%
SUB_REGION_SCALE = 14
NUM_HICO_LAYER = 5
NUM_TN = [10, 8, 6, 4, 2]
NUM_CONNECTION = [0, 5, 4, 3, 2]

#dataset specific parameters
NUM_CLASS = 5

# %% [markdown]
# ## Data Pre-Processing

# %%
with open('../input/hicotine1-layer1-biodiversity/fyp/CIFAR-10.pickle', 'rb') as f:
    X_train_cropped_list, y_train_one_hot, X_val_cropped_list, y_val_one_hot, X_test_cropped_list, y_test_one_hot, coordinate_list, scale_list = pickle.load(f)

# %% [markdown]
# ## HiCo Layer 1

# %%
#build ANN model
ensemble = []
for i in range(NUM_TN[0]):
  model = Sequential()
  model.add(Dense(64, activation='relu', input_dim=SUB_REGION_SCALE*SUB_REGION_SCALE*3))
  model.add(Dense(64, activation='relu'))
  model.add(Dense(NUM_CLASS, activation = 'softmax'))
  model.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])
  ensemble.append((model, i, coordinate_list[i], scale_list[i]))

# %%
for i in range(NUM_TN[0]):
  ensemble[i][0].load_weights('../input/hicotine1-layer1-biodiversity/fyp/CIFAR-10_' + str(i) + '.h5')

# %%
hico_layers = []
hico_layers.append(ensemble)

# %% [markdown]
# ## HiCo Layer 2+

# %%
del hico_layers[1:]

# %%
# Function to get input of layer i-1
def get_previous_layer_input(hico_layers, layer, tn, train_image):
  input = []
    
  if layer == 0:
    previous_layer_input = train_image[tn[1]]
    return previous_layer_input

  elif layer > 0:
    for i in range(NUM_CONNECTION[layer]):
      get_input = (K.function(hico_layers[layer-1][tn[1][i]][0].layers[0].input, hico_layers[layer-1][tn[1][i]][0].layers[1].output))
      input.append(get_input(get_previous_layer_input(hico_layers, layer-1, hico_layers[layer-1][tn[1][i]], train_image)))
      
    input = np.array(input)
    input = np.concatenate(input, axis=1)
    previous_layer_input = input
    return previous_layer_input

# %%
for i in range(1, NUM_HICO_LAYER):
  print('Layer %d' %i)
  ensemble = []
  X_train_input_list = []
  X_test_input_list = []

  for j in range(NUM_TN[i]):
    # Build model of HiCo layer i
    connection = tuple(rn.sample(range(len(hico_layers[i-1])), k=NUM_CONNECTION[i]))
    model = Sequential()
    model.add(Dense(64, activation='relu', input_dim=64*NUM_CONNECTION[i]))
    model.add(Dense(64, activation='relu'))
    model.add(Dense(NUM_CLASS, activation = 'softmax'))
    model.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])
    ensemble.append((model, connection))
  hico_layers.append(ensemble)
  print('HICO LENGTH')
  print(len(hico_layers))

  for j in range(NUM_TN[i]):
    # Get train hidden representation from HiCo layer i-1
    X_train_input = []
    for k in range(NUM_CONNECTION[i]):
      get_input = (K.function(hico_layers[i-1][hico_layers[i][j][1][k]][0].layers[0].input, hico_layers[i-1][hico_layers[i][j][1][k]][0].layers[1].output))
      X_train_input.append(get_input(get_previous_layer_input(hico_layers, i-1, hico_layers[i-1][hico_layers[i][j][1][k]], X_train_cropped_list)))
    X_train_input = np.array(X_train_input)
    X_train_input = np.concatenate(X_train_input, axis=1)
    X_train_input_list.append(X_train_input)

    # Get test hidden representation from HiCo layer i-1
    X_test_input = []
    for k in range(NUM_CONNECTION[i]):
      get_input = (K.function(hico_layers[i-1][hico_layers[i][j][1][k]][0].layers[0].input, hico_layers[i-1][hico_layers[i][j][1][k]][0].layers[1].output))
      X_test_input.append(get_input(get_previous_layer_input(hico_layers, i-1, hico_layers[i-1][hico_layers[i][j][1][k]], X_test_cropped_list)))
    X_test_input = np.array(X_test_input)
    X_test_input = np.concatenate(X_test_input, axis=1)
    X_test_input_list.append(X_test_input)

  #train model of HiCo layer i
  for j in range(NUM_TN[i]):
    print('Model %d' %j)
    hico_layers[i][j][0].fit(X_train_input_list[j], y_train_one_hot, validation_data=(X_test_input_list[j], y_test_one_hot), epochs=5, batch_size=128)
# Out:
# Layer 1
# HICO LENGTH
# 2
# Model 0
# Epoch 1/5
# 28/28 [==============================] - 1s 27ms/step - loss: 1.5587 - accuracy: 0.2993 - val_loss: 1.2995 - val_accuracy: 0.4226
# Epoch 2/5
# 28/28 [==============================] - 0s 5ms/step - loss: 1.2395 - accuracy: 0.4446 - val_loss: 1.2655 - val_accuracy: 0.4527
# Epoch 3/5
# 28/28 [==============================] - 0s 5ms/step - loss: 1.2379 - accuracy: 0.4746 - val_loss: 1.2649 - val_accuracy: 0.4457
# Epoch 4/5
# 28/28 [==============================] - 0s 4ms/step - loss: 1.2068 - accuracy: 0.4837 - val_loss: 1.2479 - val_accuracy: 0.4642
# Epoch 5/5
# 28/28 [==============================] - 0s 4ms/step - loss: 1.1540 - accuracy: 0.4939 - val_loss: 1.2548 - val_accuracy: 0.4550
# Model 1
# Epoch 1/5
# 28/28 [==============================] - 1s 11ms/step - loss: 1.5465 - accuracy: 0.2989 - val_loss: 1.3044 - val_accuracy: 0.3972
# Epoch 2/5
# 28/28 [==============================] - 0s 5ms/step - loss: 1.2366 - accuracy: 0.4505 - val_loss: 1.2675 - val_accuracy: 0.4480
# Epoch 3/5
# 28/28 [==============================] - 0s 5ms/step - loss: 1.2320 - accuracy: 0.4606 - val_loss: 1.2777 - val_accuracy: 0.4642
# Epoch 4/5
# 28/28 [==============================] - 0s 5ms/step - loss: 1.2041 - accuracy: 0.4963 - val_loss: 1.2528 - val_accuracy: 0.4527
# Epoch 5/5
# 28/28 [==============================] - 0s 4ms/step - loss: 1.1502 - accuracy: 0.5042 - val_loss: 1.2661 - val_accuracy: 0.4503
# Model 2
# Epoch 1/5
# 28/28 [==============================] - 1s 11ms/step - loss: 1.4771 - accuracy: 0.3506 - val_loss: 1.3064 - val_accuracy: 0.4134
# Epoch 2/5
# 28/28 [==============================] - 0s 5ms/step - loss: 1.2371 - accuracy: 0.4512 - val_loss: 1.2734 - val_accuracy: 0.4365
# Epoch 3/5
# 28/28 [==============================] - 0s 4ms/step - loss: 1.2333 - accuracy: 0.4769 - val_loss: 1.2791 - val_accuracy: 0.4503
# Epoch 4/5
# 28/28 [==============================] - 0s 4ms/step - loss: 1.2149 - accuracy: 0.4752 - val_loss: 1.2588 - val_accuracy: 0.4734
# Epoch 5/5
# 28/28 [==============================] - 0s 4ms/step - loss: 1.1668 - accuracy: 0.4895 - val_loss: 1.2683 - val_accuracy: 0.4342
# Model 3
# Epoch 1/5
# 28/28 [==============================] - 1s 11ms/step - loss: 1.5319 - accuracy: 0.2951 - val_loss: 1.3201 - val_accuracy: 0.3995
# Epoch 2/5
# 28/28 [==============================] - 0s 5ms/step - loss: 1.2506 - accuracy: 0.4424 - val_loss: 1.2827 - val_accuracy: 0.4388
# Epoch 3/5
# 28/28 [==============================] - 0s 5ms/step - loss: 1.2362 - accuracy: 0.4730 - val_loss: 1.2808 - val_accuracy: 0.4388
# Epoch 4/5
# 28/28 [==============================] - 0s 4ms/step - loss: 1.2058 - accuracy: 0.4905 - val_loss: 1.2595 - val_accuracy: 0.4342
# Epoch 5/5
# 28/28 [==============================] - 0s 4ms/step - loss: 1.1699 - accuracy: 0.4958 - val_loss: 1.2689 - val_accuracy: 0.4527
# Model 4
# Epoch 1/5
# 28/28 [==============================] - 1s 10ms/step - loss: 1.5019 - accuracy: 0.3046 - val_loss: 1.3253 - val_accuracy: 0.4203
# Epoch 2/5
# 28/28 [==============================] - 0s 5ms/step - loss: 1.2382 - accuracy: 0.4488 - val_loss: 1.2825 - val_accuracy: 0.4527
# Epoch 3/5
# 28/28 [==============================] - 0s 5ms/step - loss: 1.2338 - accuracy: 0.4820 - val_loss: 1.2786 - val_accuracy: 0.4619
# Epoch 4/5
# 28/28 [==============================] - 0s 5ms/step - loss: 1.1993 - accuracy: 0.4917 - val_loss: 1.2631 - val_accuracy: 0.4642
# Epoch 5/5
# 28/28 [==============================] - 0s 5ms/step - loss: 1.1634 - accuracy: 0.5066 - val_loss: 1.2679 - val_accuracy: 0.4642
# Model 5
# Epoch 1/5
# 28/28 [==============================] - 1s 11ms/step - loss: 1.5359 - accuracy: 0.3011 - val_loss: 1.3107 - val_accuracy: 0.4180
# Epoch 2/5
# 28/28 [==============================] - 0s 5ms/step - loss: 1.2503 - accuracy: 0.4250 - val_loss: 1.2862 - val_accuracy: 0.4434
# Epoch 3/5
# 28/28 [==============================] - 0s 5ms/step - loss: 1.2528 - accuracy: 0.4507 - val_loss: 1.3061 - val_accuracy: 0.4480
# Epoch 4/5
# 28/28 [==============================] - 0s 5ms/step - loss: 1.2327 - accuracy: 0.4706 - val_loss: 1.2595 - val_accuracy: 0.4642
# Epoch 5/5
# 28/28 [==============================] - 0s 5ms/step - loss: 1.1755 - accuracy: 0.4873 - val_loss: 1.2727 - val_accuracy: 0.4457
# Model 6
# Epoch 1/5
# 28/28 [==============================] - 1s 17ms/step - loss: 1.4722 - accuracy: 0.3488 - val_loss: 1.3187 - val_accuracy: 0.4065
# Epoch 2/5
# 28/28 [==============================] - 0s 7ms/step - loss: 1.2110 - accuracy: 0.4663 - val_loss: 1.2826 - val_accuracy: 0.4457
# Epoch 3/5
# 28/28 [==============================] - 0s 5ms/step - loss: 1.2123 - accuracy: 0.4735 - val_loss: 1.2975 - val_accuracy: 0.4573
# Epoch 4/5
# 28/28 [==============================] - 0s 4ms/step - loss: 1.1826 - accuracy: 0.4936 - val_loss: 1.2654 - val_accuracy: 0.4480
# Epoch 5/5
# 28/28 [==============================] - 0s 5ms/step - loss: 1.1370 - accuracy: 0.5070 - val_loss: 1.2484 - val_accuracy: 0.4527
# Model 7
# Epoch 1/5
# 28/28 [==============================] - 1s 11ms/step - loss: 1.4466 - accuracy: 0.3554 - val_loss: 1.3122 - val_accuracy: 0.4273
# Epoch 2/5
# 28/28 [==============================] - 0s 5ms/step - loss: 1.2321 - accuracy: 0.4509 - val_loss: 1.2619 - val_accuracy: 0.4457
# Epoch 3/5
# 28/28 [==============================] - 0s 5ms/step - loss: 1.2277 - accuracy: 0.4907 - val_loss: 1.2682 - val_accuracy: 0.4596
# Epoch 4/5
# 28/28 [==============================] - 0s 4ms/step - loss: 1.2011 - accuracy: 0.4863 - val_loss: 1.2481 - val_accuracy: 0.4642
# Epoch 5/5
# 28/28 [==============================] - 0s 4ms/step - loss: 1.1608 - accuracy: 0.4975 - val_loss: 1.2456 - val_accuracy: 0.4781
# Layer 2
# HICO LENGTH
# 3
# Model 0
# Epoch 1/5
# 28/28 [==============================] - 1s 10ms/step - loss: 1.5025 - accuracy: 0.3363 - val_loss: 1.2908 - val_accuracy: 0.4273
# Epoch 2/5
# 28/28 [==============================] - 0s 5ms/step - loss: 1.1961 - accuracy: 0.4763 - val_loss: 1.2618 - val_accuracy: 0.4550
# Epoch 3/5
# 28/28 [==============================] - 0s 5ms/step - loss: 1.1926 - accuracy: 0.5076 - val_loss: 1.2607 - val_accuracy: 0.4550
# Epoch 4/5
# 28/28 [==============================] - 0s 4ms/step - loss: 1.1663 - accuracy: 0.5176 - val_loss: 1.2512 - val_accuracy: 0.4711
# Epoch 5/5
# 28/28 [==============================] - 0s 5ms/step - loss: 1.1267 - accuracy: 0.5273 - val_loss: 1.2572 - val_accuracy: 0.4573
# Model 1
# Epoch 1/5
# 28/28 [==============================] - 1s 11ms/step - loss: 1.5202 - accuracy: 0.3141 - val_loss: 1.2924 - val_accuracy: 0.4273
# Epoch 2/5
# 28/28 [==============================] - 0s 5ms/step - loss: 1.1926 - accuracy: 0.4934 - val_loss: 1.2618 - val_accuracy: 0.4688
# Epoch 3/5
# 28/28 [==============================] - 0s 5ms/step - loss: 1.1865 - accuracy: 0.5041 - val_loss: 1.2568 - val_accuracy: 0.4896
# Epoch 4/5
# 28/28 [==============================] - 0s 5ms/step - loss: 1.1576 - accuracy: 0.5273 - val_loss: 1.2418 - val_accuracy: 0.4711
# Epoch 5/5
# 28/28 [==============================] - 0s 5ms/step - loss: 1.1145 - accuracy: 0.5282 - val_loss: 1.2444 - val_accuracy: 0.4758
# Model 2
# Epoch 1/5
# 28/28 [==============================] - 1s 11ms/step - loss: 1.4744 - accuracy: 0.3500 - val_loss: 1.2750 - val_accuracy: 0.4550
# Epoch 2/5
# 28/28 [==============================] - 0s 5ms/step - loss: 1.1767 - accuracy: 0.4954 - val_loss: 1.2589 - val_accuracy: 0.4688
# Epoch 3/5
# 28/28 [==============================] - 0s 5ms/step - loss: 1.1825 - accuracy: 0.4989 - val_loss: 1.2559 - val_accuracy: 0.4550
# Epoch 4/5
# 28/28 [==============================] - 0s 5ms/step - loss: 1.1580 - accuracy: 0.5306 - val_loss: 1.2463 - val_accuracy: 0.4873
# Epoch 5/5
# 28/28 [==============================] - 0s 5ms/step - loss: 1.1110 - accuracy: 0.5277 - val_loss: 1.2545 - val_accuracy: 0.4781
# Model 3
# Epoch 1/5
# 28/28 [==============================] - 1s 28ms/step - loss: 1.4552 - accuracy: 0.3635 - val_loss: 1.2821 - val_accuracy: 0.4411
# Epoch 2/5
# 28/28 [==============================] - 0s 7ms/step - loss: 1.1869 - accuracy: 0.4898 - val_loss: 1.2482 - val_accuracy: 0.4665
# Epoch 3/5
# 28/28 [==============================] - 0s 7ms/step - loss: 1.1872 - accuracy: 0.4923 - val_loss: 1.2414 - val_accuracy: 0.4734
# Epoch 4/5
# 28/28 [==============================] - 0s 5ms/step - loss: 1.1581 - accuracy: 0.5241 - val_loss: 1.2351 - val_accuracy: 0.4781
# Epoch 5/5
# 28/28 [==============================] - 0s 5ms/step - loss: 1.1110 - accuracy: 0.5300 - val_loss: 1.2418 - val_accuracy: 0.4850
# Model 4
# Epoch 1/5
# 28/28 [==============================] - 1s 10ms/step - loss: 1.4616 - accuracy: 0.3664 - val_loss: 1.2821 - val_accuracy: 0.4434
# Epoch 2/5
# 28/28 [==============================] - 0s 5ms/step - loss: 1.1944 - accuracy: 0.4854 - val_loss: 1.2500 - val_accuracy: 0.4688
# Epoch 3/5
# 28/28 [==============================] - 0s 7ms/step - loss: 1.1928 - accuracy: 0.4965 - val_loss: 1.2507 - val_accuracy: 0.4503
# Epoch 4/5
# 28/28 [==============================] - 0s 9ms/step - loss: 1.1594 - accuracy: 0.5210 - val_loss: 1.2383 - val_accuracy: 0.4919
# Epoch 5/5
# 28/28 [==============================] - 0s 7ms/step - loss: 1.1138 - accuracy: 0.5250 - val_loss: 1.2396 - val_accuracy: 0.4827
# Model 5
# Epoch 1/5
# 28/28 [==============================] - 1s 11ms/step - loss: 1.4569 - accuracy: 0.3800 - val_loss: 1.2947 - val_accuracy: 0.4342
# Epoch 2/5
# 28/28 [==============================] - 0s 5ms/step - loss: 1.1781 - accuracy: 0.4838 - val_loss: 1.2628 - val_accuracy: 0.4734
# Epoch 3/5
# 28/28 [==============================] - 0s 5ms/step - loss: 1.1753 - accuracy: 0.5201 - val_loss: 1.2641 - val_accuracy: 0.4596
# Epoch 4/5
# 28/28 [==============================] - 0s 5ms/step - loss: 1.1541 - accuracy: 0.5210 - val_loss: 1.2572 - val_accuracy: 0.4665
# Epoch 5/5
# 28/28 [==============================] - 0s 4ms/step - loss: 1.1097 - accuracy: 0.5302 - val_loss: 1.2482 - val_accuracy: 0.4619
# Layer 3
# HICO LENGTH
# 4
# Model 0
# Epoch 1/5
# 28/28 [==============================] - 1s 11ms/step - loss: 1.4008 - accuracy: 0.4142 - val_loss: 1.2671 - val_accuracy: 0.4550
# Epoch 2/5
# 28/28 [==============================] - 0s 5ms/step - loss: 1.1468 - accuracy: 0.5070 - val_loss: 1.2483 - val_accuracy: 0.4781
# Epoch 3/5
# 28/28 [==============================] - 0s 5ms/step - loss: 1.1643 - accuracy: 0.5131 - val_loss: 1.2497 - val_accuracy: 0.4850
# Epoch 4/5
# 28/28 [==============================] - 0s 5ms/step - loss: 1.1383 - accuracy: 0.5299 - val_loss: 1.2349 - val_accuracy: 0.4804
# Epoch 5/5
# 28/28 [==============================] - 0s 5ms/step - loss: 1.0884 - accuracy: 0.5409 - val_loss: 1.2495 - val_accuracy: 0.4480
# Model 1
# Epoch 1/5
# 28/28 [==============================] - 1s 11ms/step - loss: 1.5136 - accuracy: 0.3792 - val_loss: 1.2606 - val_accuracy: 0.4434
# Epoch 2/5
# 28/28 [==============================] - 0s 4ms/step - loss: 1.1515 - accuracy: 0.5140 - val_loss: 1.2388 - val_accuracy: 0.4688
# Epoch 3/5
# 28/28 [==============================] - 0s 4ms/step - loss: 1.1552 - accuracy: 0.5208 - val_loss: 1.2358 - val_accuracy: 0.4457
# Epoch 4/5
# 28/28 [==============================] - 0s 4ms/step - loss: 1.1272 - accuracy: 0.5506 - val_loss: 1.2391 - val_accuracy: 0.4781
# Epoch 5/5
# 28/28 [==============================] - 0s 4ms/step - loss: 1.0849 - accuracy: 0.5449 - val_loss: 1.2491 - val_accuracy: 0.4527
# Model 2
# Epoch 1/5
# 28/28 [==============================] - 1s 10ms/step - loss: 1.4492 - accuracy: 0.3730 - val_loss: 1.2804 - val_accuracy: 0.4296
# Epoch 2/5
# 28/28 [==============================] - 0s 5ms/step - loss: 1.1577 - accuracy: 0.5054 - val_loss: 1.2308 - val_accuracy: 0.4758
# Epoch 3/5
# 28/28 [==============================] - 0s 5ms/step - loss: 1.1536 - accuracy: 0.5217 - val_loss: 1.2273 - val_accuracy: 0.4734
# Epoch 4/5
# 28/28 [==============================] - 0s 5ms/step - loss: 1.1289 - accuracy: 0.5350 - val_loss: 1.2264 - val_accuracy: 0.4942
# Epoch 5/5
# 28/28 [==============================] - 0s 4ms/step - loss: 1.0850 - accuracy: 0.5445 - val_loss: 1.2282 - val_accuracy: 0.4758
# Model 3
# Epoch 1/5
# 28/28 [==============================] - 1s 11ms/step - loss: 1.4273 - accuracy: 0.3509 - val_loss: 1.2585 - val_accuracy: 0.4503
# Epoch 2/5
# 28/28 [==============================] - 0s 5ms/step - loss: 1.1537 - accuracy: 0.5111 - val_loss: 1.2319 - val_accuracy: 0.4988
# Epoch 3/5
# 28/28 [==============================] - 0s 5ms/step - loss: 1.1538 - accuracy: 0.5249 - val_loss: 1.2374 - val_accuracy: 0.4873
# Epoch 4/5
# 28/28 [==============================] - 0s 4ms/step - loss: 1.1318 - accuracy: 0.5394 - val_loss: 1.2301 - val_accuracy: 0.4988
# Epoch 5/5
# 28/28 [==============================] - 0s 4ms/step - loss: 1.0860 - accuracy: 0.5481 - val_loss: 1.2409 - val_accuracy: 0.4619
# Layer 4
# HICO LENGTH
# 5
# Model 0
# Epoch 1/5
# 28/28 [==============================] - 1s 11ms/step - loss: 1.5116 - accuracy: 0.3502 - val_loss: 1.2542 - val_accuracy: 0.4665
# Epoch 2/5
# 28/28 [==============================] - 0s 4ms/step - loss: 1.1365 - accuracy: 0.5324 - val_loss: 1.2478 - val_accuracy: 0.4919
# Epoch 3/5
# 28/28 [==============================] - 0s 4ms/step - loss: 1.1375 - accuracy: 0.5302 - val_loss: 1.2505 - val_accuracy: 0.4873
# Epoch 4/5
# 28/28 [==============================] - 0s 5ms/step - loss: 1.1156 - accuracy: 0.5527 - val_loss: 1.2466 - val_accuracy: 0.5012
# Epoch 5/5
# 28/28 [==============================] - 0s 5ms/step - loss: 1.0754 - accuracy: 0.5525 - val_loss: 1.2591 - val_accuracy: 0.4688
# Model 1
# Epoch 1/5
# 28/28 [==============================] - 1s 11ms/step - loss: 1.3934 - accuracy: 0.3856 - val_loss: 1.2537 - val_accuracy: 0.4734
# Epoch 2/5
# 28/28 [==============================] - 0s 5ms/step - loss: 1.1302 - accuracy: 0.5334 - val_loss: 1.2430 - val_accuracy: 0.4758
# Epoch 3/5
# 28/28 [==============================] - 0s 4ms/step - loss: 1.1374 - accuracy: 0.5416 - val_loss: 1.2502 - val_accuracy: 0.4573
# Epoch 4/5
# 28/28 [==============================] - 0s 5ms/step - loss: 1.1168 - accuracy: 0.5428 - val_loss: 1.2399 - val_accuracy: 0.4873
# Epoch 5/5
# 28/28 [==============================] - 0s 5ms/step - loss: 1.0735 - accuracy: 0.5492 - val_loss: 1.2501 - val_accuracy: 0.4596

# %% [markdown]
# # Model Evaluation

# %%
# Predict on test image
y_pred_list = []
for j in range(NUM_TN[0]):
  y_pred = np.argmax(hico_layers[0][j][0].predict(X_test_cropped_list[j]), axis=1)
  y_pred_list.append(y_pred)

for i in range(1, NUM_HICO_LAYER):
  for j in range(NUM_TN[i]):

    # Get test hidden representation from HiCo layer i-1
    X_test_input = []
    for k in range(NUM_CONNECTION[i]):
      get_input = (K.function(hico_layers[i-1][hico_layers[i][j][1][k]][0].layers[0].input, hico_layers[i-1][hico_layers[i][j][1][k]][0].layers[1].output))
      X_test_input.append(get_input(get_previous_layer_input(hico_layers, i-1, hico_layers[i-1][hico_layers[i][j][1][k]], X_test_cropped_list)))
    X_test_input = np.array(X_test_input)
    X_test_input = np.concatenate(X_test_input, axis=1)
    y_pred = np.argmax(hico_layers[i][j][0].predict(X_test_input), axis=1)
    y_pred_list.append(y_pred)

# HiCo voting (mode)
y_pred_list = np.array(y_pred_list)
y_pred_list = np.transpose(y_pred_list, (1, 0))
y_pred_list = stats.mode(y_pred_list, axis=1)[0]
y_pred_list = np.squeeze(y_pred_list)

# %%
y_test = np.argmax(y_test_one_hot, axis=1)

# %%
accuracy = accuracy_score(y_test, y_pred_list)
accuracy
# Out:
# 0.4665127020785219
