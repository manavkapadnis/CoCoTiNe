# %% [markdown]
# # Variants-Experiment 1.5
#
# ## Summed hidden representations and summed output logits.
# ## Mode. Compute classifications of all tiny networks, in all HiCo layers, and take the mode as the final classification.

# %%
import tensorflow as tf
from tensorflow import keras
from keras.models import Sequential
from keras.layers import Dense, Conv2D, Flatten, MaxPooling2D
from keras.utils import to_categorical
import matplotlib.pyplot as plt
import numpy as np
from os import listdir
from os.path import join
import cv2
import pandas as pd
import os
import random as rn
from scipy import stats
from sklearn.preprocessing import OneHotEncoder
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score
import pickle
from keras import backend as K

# %%
SEED = 321
rn.seed(SEED)
np.random.seed(SEED)
tf.random.set_seed(SEED)

# %%
SUB_REGION_SCALE = 14
NUM_HICO_LAYER = 5
NUM_TN = [10, 8, 6, 4, 2]
NUM_CONNECTION = [0, 5, 4, 3, 2]

#dataset specific parameters
NUM_CLASS = 5

# %% [markdown]
# ## Data Pre-Processing

# %%
with open('../input/hicotine1-layer1-biodiversity/fyp/CIFAR-10.pickle', 'rb') as f:
    X_train_cropped_list, y_train_one_hot, X_val_cropped_list, y_val_one_hot, X_test_cropped_list, y_test_one_hot, coordinate_list, scale_list = pickle.load(f)

# %% [markdown]
# ## HiCo Layer 1

# %%
#build ANN model
ensemble = []
for i in range(NUM_TN[0]):
  model = Sequential()
  model.add(Dense(64, activation='relu', input_dim=SUB_REGION_SCALE*SUB_REGION_SCALE*3))
  model.add(Dense(64, activation='relu'))
  model.add(Dense(NUM_CLASS, activation = 'softmax'))
  model.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])
  ensemble.append((model, i, coordinate_list[i], scale_list[i]))

# %%
for i in range(NUM_TN[0]):
  ensemble[i][0].load_weights('../input/hicotine1-layer1-biodiversity/fyp/CIFAR-10_' + str(i) + '.h5')

# %%
hico_layers = []
hico_layers.append(ensemble)

# %%
del hico_layers[1:]

# %% [markdown]
# ## HiCo Layer 2+

# %%
# Function to get input of layer i-1
def get_previous_layer_input(hico_layers, layer, tn, train_image):
  input_hr = []
  input_ol = []
    
  if layer == 0:
    previous_layer_input = train_image[tn[1]]
    return previous_layer_input

  elif layer > 0:
    for i in range(NUM_CONNECTION[layer]):
      get_input = (K.function(hico_layers[layer-1][tn[1][i]][0].layers[0].input, hico_layers[layer-1][tn[1][i]][0].layers[1].output))
      input_hr.append(get_input(get_previous_layer_input(hico_layers, layer-1, hico_layers[layer-1][tn[1][i]], train_image)))
      
    input_hr = np.array(input_hr)
    input_hr = np.sum(input_hr, axis=0)

    for i in range(NUM_CONNECTION[layer]):
      get_input = (K.function(hico_layers[layer-1][tn[1][i]][0].layers[0].input, hico_layers[layer-1][tn[1][i]][0].layers[2].output))
      input_ol.append(get_input(get_previous_layer_input(hico_layers, layer-1, hico_layers[layer-1][tn[1][i]], train_image)))

    input_ol = np.array(input_ol)
    input_ol = np.sum(input_ol, axis=0)

    input = np.concatenate((input_hr, input_ol), axis=1)
    
    previous_layer_input = input
    return previous_layer_input

# %%
for i in range(1, NUM_HICO_LAYER):
  print('Layer %d' %i)
  ensemble = []
  X_train_input_list = []
  X_test_input_list = []

  for j in range(NUM_TN[i]):
    # Build model of HiCo layer i
    connection = tuple(rn.sample(range(len(hico_layers[i-1])), k=NUM_CONNECTION[i]))
    model = Sequential()
    model.add(Dense(64, activation='relu', input_dim=64+NUM_CLASS))
    model.add(Dense(64, activation='relu'))
    model.add(Dense(NUM_CLASS, activation = 'softmax'))
    model.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])
    ensemble.append((model, connection))
  hico_layers.append(ensemble)
  print('HICO LENGTH')
  print(len(hico_layers))

  for j in range(NUM_TN[i]):
    # Get train hidden representation from HiCo layer i-1
    X_train_input_hr = []
    X_train_input_ol = []
    for k in range(NUM_CONNECTION[i]):
      get_input = (K.function(hico_layers[i-1][hico_layers[i][j][1][k]][0].layers[0].input, hico_layers[i-1][hico_layers[i][j][1][k]][0].layers[1].output))
      X_train_input_hr.append(get_input(get_previous_layer_input(hico_layers, i-1, hico_layers[i-1][hico_layers[i][j][1][k]], X_train_cropped_list)))
    X_train_input_hr = np.array(X_train_input_hr)
    X_train_input_hr = np.sum(X_train_input_hr, axis=0)

    for k in range(NUM_CONNECTION[i]):
      get_input = (K.function(hico_layers[i-1][hico_layers[i][j][1][k]][0].layers[0].input, hico_layers[i-1][hico_layers[i][j][1][k]][0].layers[2].output))
      X_train_input_ol.append(get_input(get_previous_layer_input(hico_layers, i-1, hico_layers[i-1][hico_layers[i][j][1][k]], X_train_cropped_list)))
    X_train_input_ol = np.array(X_train_input_ol)
    X_train_input_ol = np.sum(X_train_input_ol, axis=0)

    X_train_input = np.concatenate((X_train_input_hr, X_train_input_ol), axis=1)
    X_train_input_list.append(X_train_input)

    # Get test hidden representation from HiCo layer i-1
    X_test_input_hr = []
    X_test_input_ol = []
    for k in range(NUM_CONNECTION[i]):
      get_input = (K.function(hico_layers[i-1][hico_layers[i][j][1][k]][0].layers[0].input, hico_layers[i-1][hico_layers[i][j][1][k]][0].layers[1].output))
      X_test_input_hr.append(get_input(get_previous_layer_input(hico_layers, i-1, hico_layers[i-1][hico_layers[i][j][1][k]], X_test_cropped_list)))
    X_test_input_hr = np.array(X_test_input_hr)
    X_test_input_hr = np.sum(X_test_input_hr, axis=0)

    for k in range(NUM_CONNECTION[i]):
      get_input = (K.function(hico_layers[i-1][hico_layers[i][j][1][k]][0].layers[0].input, hico_layers[i-1][hico_layers[i][j][1][k]][0].layers[2].output))
      X_test_input_ol.append(get_input(get_previous_layer_input(hico_layers, i-1, hico_layers[i-1][hico_layers[i][j][1][k]], X_test_cropped_list)))
    X_test_input_ol = np.array(X_test_input_ol)
    X_test_input_ol = np.sum(X_test_input_ol, axis=0)

    X_test_input = np.concatenate((X_test_input_hr, X_test_input_ol), axis=1)
    X_test_input_list.append(X_test_input)

  #train model of HiCo layer i
  for j in range(NUM_TN[i]):
    print('Model %d' %j)
    hico_layers[i][j][0].fit(X_train_input_list[j], y_train_one_hot, validation_data=(X_test_input_list[j], y_test_one_hot), epochs=5, batch_size=128)
# Out:
# Layer 1
# HICO LENGTH
# 2
# Model 0
# Epoch 1/5
# 28/28 [==============================] - 1s 22ms/step - loss: 2.1326 - accuracy: 0.2376 - val_loss: 1.4181 - val_accuracy: 0.3418
# Epoch 2/5
# 28/28 [==============================] - 0s 4ms/step - loss: 1.3583 - accuracy: 0.3864 - val_loss: 1.3145 - val_accuracy: 0.3949
# Epoch 3/5
# 28/28 [==============================] - 0s 4ms/step - loss: 1.2943 - accuracy: 0.4486 - val_loss: 1.3098 - val_accuracy: 0.4480
# Epoch 4/5
# 28/28 [==============================] - 0s 4ms/step - loss: 1.2589 - accuracy: 0.4535 - val_loss: 1.2828 - val_accuracy: 0.4527
# Epoch 5/5
# 28/28 [==============================] - 0s 4ms/step - loss: 1.2115 - accuracy: 0.4647 - val_loss: 1.2867 - val_accuracy: 0.4480
# Model 1
# Epoch 1/5
# 28/28 [==============================] - 1s 9ms/step - loss: 1.5636 - accuracy: 0.3003 - val_loss: 1.3221 - val_accuracy: 0.3949
# Epoch 2/5
# 28/28 [==============================] - 0s 4ms/step - loss: 1.2912 - accuracy: 0.4099 - val_loss: 1.2866 - val_accuracy: 0.4157
# Epoch 3/5
# 28/28 [==============================] - 0s 4ms/step - loss: 1.2854 - accuracy: 0.4290 - val_loss: 1.2825 - val_accuracy: 0.4111
# Epoch 4/5
# 28/28 [==============================] - 0s 4ms/step - loss: 1.2438 - accuracy: 0.4743 - val_loss: 1.2694 - val_accuracy: 0.4388
# Epoch 5/5
# 28/28 [==============================] - 0s 4ms/step - loss: 1.2027 - accuracy: 0.4717 - val_loss: 1.2769 - val_accuracy: 0.4203
# Model 2
# Epoch 1/5
# 28/28 [==============================] - 1s 9ms/step - loss: 1.7023 - accuracy: 0.3301 - val_loss: 1.3414 - val_accuracy: 0.3995
# Epoch 2/5
# 28/28 [==============================] - 0s 4ms/step - loss: 1.2620 - accuracy: 0.4331 - val_loss: 1.3004 - val_accuracy: 0.4342
# Epoch 3/5
# 28/28 [==============================] - 0s 4ms/step - loss: 1.2576 - accuracy: 0.4706 - val_loss: 1.3058 - val_accuracy: 0.4411
# Epoch 4/5
# 28/28 [==============================] - 0s 4ms/step - loss: 1.2536 - accuracy: 0.4544 - val_loss: 1.2842 - val_accuracy: 0.4365
# Epoch 5/5
# 28/28 [==============================] - 0s 4ms/step - loss: 1.1967 - accuracy: 0.4802 - val_loss: 1.3012 - val_accuracy: 0.4180
# Model 3
# Epoch 1/5
# 28/28 [==============================] - 1s 9ms/step - loss: 1.7680 - accuracy: 0.2600 - val_loss: 1.4004 - val_accuracy: 0.3764
# Epoch 2/5
# 28/28 [==============================] - 0s 4ms/step - loss: 1.3146 - accuracy: 0.4290 - val_loss: 1.3104 - val_accuracy: 0.4180
# Epoch 3/5
# 28/28 [==============================] - 0s 4ms/step - loss: 1.2829 - accuracy: 0.4382 - val_loss: 1.3121 - val_accuracy: 0.4226
# Epoch 4/5
# 28/28 [==============================] - 0s 4ms/step - loss: 1.2457 - accuracy: 0.4610 - val_loss: 1.2970 - val_accuracy: 0.4180
# Epoch 5/5
# 28/28 [==============================] - 0s 4ms/step - loss: 1.2241 - accuracy: 0.4620 - val_loss: 1.2962 - val_accuracy: 0.4134
# Model 4
# Epoch 1/5
# 28/28 [==============================] - 1s 9ms/step - loss: 1.6752 - accuracy: 0.2576 - val_loss: 1.3273 - val_accuracy: 0.4042
# Epoch 2/5
# 28/28 [==============================] - 0s 4ms/step - loss: 1.2868 - accuracy: 0.4212 - val_loss: 1.3043 - val_accuracy: 0.3949
# Epoch 3/5
# 28/28 [==============================] - 0s 4ms/step - loss: 1.2688 - accuracy: 0.4415 - val_loss: 1.3033 - val_accuracy: 0.4273
# Epoch 4/5
# 28/28 [==============================] - 0s 4ms/step - loss: 1.2396 - accuracy: 0.4498 - val_loss: 1.2847 - val_accuracy: 0.4434
# Epoch 5/5
# 28/28 [==============================] - 0s 4ms/step - loss: 1.2065 - accuracy: 0.4692 - val_loss: 1.2886 - val_accuracy: 0.4503
# Model 5
# Epoch 1/5
# 28/28 [==============================] - 1s 9ms/step - loss: 2.2097 - accuracy: 0.2772 - val_loss: 1.3727 - val_accuracy: 0.3903
# Epoch 2/5
# 28/28 [==============================] - 0s 4ms/step - loss: 1.
5
# 28/28 [==============================] - 0s 3ms/step - loss: 1.2283 - accuracy: 0.4795 - val_loss: 1.2787 - val_accuracy: 0.4642
# Epoch 4/5
# 28/28 [==============================] - 0s 4ms/step - loss: 1.2138 - accuracy: 0.4812 - val_loss: 1.2659 - val_accuracy: 0.4642
# Epoch 5/5
# 28/28 [==============================] - 0s 4ms/step - loss: 1.1733 - accuracy: 0.4990 - val_loss: 1.2724 - val_accuracy: 0.4573
# Model 3
# Epoch 1/5
# 28/28 [==============================] - 1s 8ms/step - loss: 1.7455 - accuracy: 0.2997 - val_loss: 1.3053 - val_accuracy: 0.4573
# Epoch 2/5
# 28/28 [==============================] - 0s 4ms/step - loss: 1.2380 - accuracy: 0.4682 - val_loss: 1.2772 - val_accuracy: 0.4527
# Epoch 3/5
# 28/28 [==============================] - 0s 4ms/step - loss: 1.2382 - accuracy: 0.4692 - val_loss: 1.2814 - val_accuracy: 0.4734
# Epoch 4/5
# 28/28 [==============================] - 0s 4ms/step - loss: 1.2133 - accuracy: 0.4905 - val_loss: 1.2628 - val_accuracy: 0.4665
# Epoch 5/5
# 28/28 [==============================] - 0s 3ms/step - loss: 1.1796 - accuracy: 0.4879 - val_loss: 1.2685 - val_accuracy: 0.4573
# Layer 4
# HICO LENGTH
# 5
# Model 0
# Epoch 1/5
# 28/28 [==============================] - 1s 9ms/step - loss: 1.6866 - accuracy: 0.2991 - val_loss: 1.3145 - val_accuracy: 0.4226
# Epoch 2/5
# 28/28 [==============================] - 0s 4ms/step - loss: 1.2410 - accuracy: 0.4650 - val_loss: 1.2805 - val_accuracy: 0.4527
# Epoch 3/5
# 28/28 [==============================] - 0s 4ms/step - loss: 1.2250 - accuracy: 0.4777 - val_loss: 1.2708 - val_accuracy: 0.4596
# Epoch 4/5
# 28/28 [==============================] - 0s 4ms/step - loss: 1.2046 - accuracy: 0.4941 - val_loss: 1.2695 - val_accuracy: 0.4527
# Epoch 5/5
# 28/28 [==============================] - 0s 4ms/step - loss: 1.1808 - accuracy: 0.4939 - val_loss: 1.2768 - val_accuracy: 0.4550
# Model 1
# Epoch 1/5
# 28/28 [==============================] - 1s 9ms/step - loss: 1.5948 - accuracy: 0.3281 - val_loss: 1.3205 - val_accuracy: 0.4203
# Epoch 2/5
# 28/28 [==============================] - 0s 4ms/step - loss: 1.2287 - accuracy: 0.4641 - val_loss: 1.2795 - val_accuracy: 0.4411
# Epoch 3/5
# 28/28 [==============================] - 0s 4ms/step - loss: 1.2288 - accuracy: 0.4710 - val_loss: 1.2831 - val_accuracy: 0.4804
# Epoch 4/5
# 28/28 [==============================] - 0s 4ms/step - loss: 1.2079 - accuracy: 0.4937 - val_loss: 1.2749 - val_accuracy: 0.4711
# Epoch 5/5
# 28/28 [==============================] - 0s 4ms/step - loss: 1.1724 - accuracy: 0.4950 - val_loss: 1.2846 - val_accuracy: 0.4457

# %% [markdown]
# # Model Evaluation

# %%
# Predict on test image
y_pred_list = []
for j in range(NUM_TN[0]):
  y_pred = np.argmax(hico_layers[0][j][0].predict(X_test_cropped_list[j]), axis=1)
  y_pred_list.append(y_pred)

for i in range(1, NUM_HICO_LAYER):
  for j in range(NUM_TN[i]):

    # Get test hidden representation from HiCo layer i-1
    X_test_input_hr = []
    X_test_input_ol = []
    for k in range(NUM_CONNECTION[i]):
      get_input = (K.function(hico_layers[i-1][hico_layers[i][j][1][k]][0].layers[0].input, hico_layers[i-1][hico_layers[i][j][1][k]][0].layers[1].output))
      X_test_input_hr.append(get_input(get_previous_layer_input(hico_layers, i-1, hico_layers[i-1][hico_layers[i][j][1][k]], X_test_cropped_list)))
    X_test_input_hr = np.array(X_test_input_hr)
    X_test_input_hr = np.sum(X_test_input_hr, axis=0)

    for k in range(NUM_CONNECTION[i]):
      get_input = (K.function(hico_layers[i-1][hico_layers[i][j][1][k]][0].layers[0].input, hico_layers[i-1][hico_layers[i][j][1][k]][0].layers[2].output))
      X_test_input_ol.append(get_input(get_previous_layer_input(hico_layers, i-1, hico_layers[i-1][hico_layers[i][j][1][k]], X_test_cropped_list)))
    X_test_input_ol = np.array(X_test_input_ol)
    X_test_input_ol = np.sum(X_test_input_ol, axis=0)

    X_test_input = np.concatenate((X_test_input_hr, X_test_input_ol), axis=1)

    y_pred = np.argmax(hico_layers[i][j][0].predict(X_test_input), axis=1)
    y_pred_list.append(y_pred)

# HiCo voting (mode)
y_pred_list = np.array(y_pred_list)
y_pred_list = np.transpose(y_pred_list, (1, 0))
y_pred_list = stats.mode(y_pred_list, axis=1)[0]
y_pred_list = np.squeeze(y_pred_list)

# %%
y_test = np.argmax(y_test_one_hot, axis=1)

# %%
accuracy = accuracy_score(y_test, y_pred_list)
accuracy
# Out:
# 0.4618937644341801
